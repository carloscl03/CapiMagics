# %%
#conversacion con gemini
# https://gemini.google.com/app/2622fa6806eb26a5

import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

# %%
#Variables de entorno dentro del contenedor del docker
print(_printenv)
# Out:
# Reading User Preferences in /foss/designs/.designinit
# SHELL=/bin/bash
# SESSION_MANAGER=local/b9a86f05aad4:@/tmp/.ICE-unix/59,unix/b9a86f05aad4:/tmp/.ICE-unix/59
# OMPI_MCA_btl_vader_single_copy_mechanism=none
# PDK=gf180mcuD
# COLORTERM=truecolor
# XDG_CONFIG_DIRS=/etc/xdg
# XDG_MENU_PREFIX=xfce-
# NSS_WRAPPER_GROUP=/tmp/group
# CONDA_EXE=/headless/conda-env/miniconda3/bin/conda
# _CE_M=
# KLAYOUT_PATH=/headless/.klayout:/foss/pdks/gf180mcuD/libs.tech/klayout
# GLAYOUT_FOLDER=gLayout
# HOSTNAME=b9a86f05aad4
# SSH_AUTH_SOCK=/tmp/ssh-cVw69mGffRqp/agent.86
# XDG_DATA_HOME=/headless/.data-default
# GLAYOUT_PATH=libs
# NO_VNC_HOME=/usr/share/novnc
# NSS_WRAPPER_PASSWD=/tmp/passwd
# DESKTOP_SESSION=xfce
# SSH_AGENT_PID=87
# NO_AT_BRIDGE=1
# KLAYOUT_PYTHONPATH=/foss/tools/klayout_gdsfactory9/lib/python3.12/site-packages
# XML_CATALOG_FILES=file:///headless/conda-env/miniconda3/envs/GLdev/etc/xml/catalog file:///etc/xml/catalog
# EDITOR=gedit
# PWD=/foss/designs
# VNC_RESOLUTION=1680x1050
# GSETTINGS_SCHEMA_DIR=/headless/conda-env/miniconda3/envs/GLdev/share/glib-2.0/schemas
# XDG_SESSION_TYPE=x11
# CONDA_PREFIX=/headless/conda-env/miniconda3/envs/GLdev
# JPY_SESSION_NAME=/foss/designs/integrator-a207a8b6-1c27-4839-9157-df4ce95929ef.ipynb
# GSETTINGS_SCHEMA_DIR_CONDA_BACKUP=
# TZ=Europe/Vienna
# STD_CELL_LIBRARY=gf180mcu_fd_sc_mcu7t5v0
# LD_PRELOAD=/lib/aarch64-linux-gnu/libgcc_s.so.1 /usr/lib/aarch64-linux-gnu/libnss_wrapper.so
# HOME=/headless
# LANG=en_US.UTF-8
# XDG_CURRENT_DESKTOP=XFCE
# VNCDESKTOP=b9a86f05aad4:1 (designer)
# VTE_VERSION=7600
# STARTUPDIR=/dockerstartup
# FORCE_COLOR=1
# CONDA_PROMPT_MODIFIER=(GLdev)
# PYDEVD_USE_FRAME_EVAL=NO
# GNOME_TERMINAL_SCREEN=/org/gnome/Terminal/screen/caad8887_fa23_4789_8e82_d6786455d762
# CLICOLOR=1
# PDKPATH=/foss/pdks/gf180mcuD
# PDK_ROOT=/foss/pdks
# CLICOLOR_FORCE=1
# GLAYOUT_REPOSITORY=git@github.com:ReaLLMASIC/gLayout.git
# FOSS_INIT_DONE=1
# VNC_VIEW_ONLY=false
# VNC_PW=abc123
# SAK=/foss/tools/sak
# JPY_PARENT_PID=356
# _CONDA_EXE=/headless/conda-env/miniconda3/bin/conda
# XDG_SESSION_CLASS=user
# _CONDA_ROOT=/headless/conda-env/miniconda3
# PYTHONPATH=/headless/.local/lib/python3.10/site-packages:
# TERM=xterm-color
# _CE_CONDA=
# PYTHONPYCACHEPREFIX=/tmp/pycache
# USER=designer
# GIT_PAGER=cat
# VNC_COL_DEPTH=24
# LIBRARY_PATH=/foss/tools/ghdl/lib:/foss/tools/ghdl/lib:/foss/tools/ghdl/lib:
# GNOME_TERMINAL_SERVICE=:1.16
# CONDA_SHLVL=1
# DISPLAY=:1.0
# SHLVL=2
# TOOLS=/foss/tools
# PAGER=cat
# MPLBACKEND=module://matplotlib_inline.backend_inline
# DESIGNS=/foss/designs
# JUPYTER_PORT=8888
# CONDA_PYTHON_EXE=/headless/conda-env/miniconda3/bin/python
# LD_LIBRARY_PATH=/foss/tools/klayout:/foss/tools/ngspice/lib:/foss/tools/iverilog/lib:/foss/tools/openems/lib:/foss/tools/kactus2:/foss/tools/gtkwave/lib/aarch64-linux-gnu:/foss/tools/kepler-formal/lib
# XDG_RUNTIME_DIR=/tmp/runtime-default
# KLAYOUT_HOME=/headless/.klayout
# PS1=\[\e\]PDK: $(echo $PDK) \[\033\]\w >\[\033\]
# CONDA_DEFAULT_ENV=GLdev
# LC_ALL=en_US.UTF-8
# XDG_DATA_DIRS=/usr/local/share:/usr/share
# VNC_PORT=5901
# PATH=/foss/designs/user_setup/bin:/foss/designs/scripts:/headless/.local/bin:/headless/conda-env/miniconda3/envs/GLdev/bin:/headless/conda-env/miniconda3/condabin:/headless/conda-env/miniconda3/bin:/foss/designs/user_setup/bin:/foss/designs/scripts:/headless/.local/bin:/foss/designs/user_setup/bin:/foss/designs/scripts:/headless/.local/bin:/foss/tools/bin:/foss/tools/sak:/usr/local/sbin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/foss/tools/kactus2:/foss/tools/klayout:/foss/tools/osic-multitool
# NO_VNC_PORT=80
# EXAMPLES=/foss/examples
# DBUS_SESSION_BUS_ADDRESS=unix:path=/tmp/dbus-ZKfFftKUVs,guid=373891067f343d1f11ebac636a8dcc29
# IIC_OSIC_TOOLS_VERSION=2026.04
# SPICE_USERINIT_DIR=/foss/pdks/gf180mcuD/libs.tech/ngspice
# CPATH=/foss/tools/ghdl/include:/foss/tools/ghdl/include/ghdl:/foss/tools/ghdl/include:/foss/tools/ghdl/include/ghdl:/foss/tools/ghdl/include:/foss/tools/ghdl/include/ghdl:
# DEBIAN_FRONTEND=noninteractive
# OLDPWD=/foss/designs
# _=/usr/bin/printenv

# %%
#funciones para ir desplegando el gds y desplegar los componentes en jupiter

import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file,path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

# %%
# %%

import os
import gdsfactory as gf #duda
from gdsfactory import Component
from glayout import MappedPDK, gf180
from gdsfactory.components import text_freetype, rectangle
from glayout import nmos, pmos
from glayout.primitives.mimcap import mimcap, mimcap_array #Genera un capacitor tipo MIM (Metal-Insulator-Metal)
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route
from glayout.util.comp_utils import align_comp_to_port, evaluate_bbox, prec_center, prec_ref_center
from glayout.util.port_utils import add_ports_perimeter, print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
integrator_config = {
    "pdk": gf180,
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation(),
        "routing_metal": "met2",
        "dummy_devices": True,
        "tie_layers": ("met2", "met1"),
        "sd_rmult": 1,
    },
}

# Base parameters for PMOS and NMOS
nmos_kwargs = {
    "with_tie": True, #checar a true
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2", "met1"),
    "dummy_routes": False,
}

pmos_kwargs = {
    "with_tie": True,#chacar a True
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2", "met1"),
    "dummy_routes": False,
}

# %%
# .subckt integrator_final_mike Vext_pin avdd avss I_50n
# *.PININFO Vext_pin:I avdd:B avss:B I_50n:I
# XM1 vg vg vm avdd pfet_03v3 L=.28u W=1u nf=1 ad='int((nf+1)/2) * W/nf * 0.18u' as='int((nf+2)/2) * W/nf * 0.18u' pd='2*int((nf+1)/2) * (W/nf + 0.18u)'
# + ps='2*int((nf+2)/2) * (W/nf + 0.18u)' nrd='0.18u / W' nrs='0.18u / W' sa=0 sb=0 sd=0
# XM6 vm Vext_pin avdd avss nfet_03v3 L=0.28u W=1u nf=1 ad='int((nf+1)/2) * W/nf * 0.18u' as='int((nf+2)/2) * W/nf * 0.18u' pd='2*int((nf+1)/2) * (W/nf + 0.18u)'
# + ps='2*int((nf+2)/2) * (W/nf + 0.18u)' nrd='0.18u / W' nrs='0.18u / W' sa=0 sb=0 sd=0
# XM2 avss I_50n vg avss nfet_03v3 L=0.28u W=1u nf=1 ad='int((nf+1)/2) * W/nf * 0.18u' as='int((nf+2)/2) * W/nf * 0.18u' pd='2*int((nf+1)/2) * (W/nf + 0.18u)'
# + ps='2*int((nf+2)/2) * (W/nf + 0.18u)' nrd='0.18u / W' nrs='0.18u / W' sa=0 sb=0 sd=0
# XM3 I_50n I_50n avss avss nfet_03v3 L=0.28u W=1u nf=1 ad='int((nf+1)/2) * W/nf * 0.18u' as='int((nf+2)/2) * W/nf * 0.18u' pd='2*int((nf+1)/2) * (W/nf + 0.18u)'
# + ps='2*int((nf+2)/2) * (W/nf + 0.18u)' nrd='0.18u / W' nrs='0.18u / W' sa=0 sb=0 sd=0
# XC3 vm avss cap_mim_2f0fF c_width=17.68e-6 c_length=17.68e-6 m=8
# .ends

# %%
# ----------------------------------------------------------------------
# 2. Instantiate Devices
# ----------------------------------------------------------------------
pdk = integrator_config["pdk"]
integrator = Component(name="integrator")

# PMOS Transistors (XM1, XM6)
xm1 = pmos(pdk, width=1.0, length=0.28, fingers=1,  with_dummy=(False, False), with_substrate_tap=False, **pmos_kwargs)


# NMOS Transistors (XM2, XM3)
xm2 = nmos(pdk, width=1.0, length=0.28, fingers=1, with_dummy=(False, False), with_substrate_tap=False,  **nmos_kwargs)
xm3 = nmos(pdk, width=1.0, length=0.28, fingers=1,  with_dummy=(False, False), with_substrate_tap=False, **nmos_kwargs)
xm6 = nmos(pdk, width=1.0, length=0.28, fingers=1,  with_dummy=(False, False), with_substrate_tap=False, **nmos_kwargs)


# MIM Capacitor Array XC3 (m=8, 2 rows x 4 columns)
xc3 = mimcap_array(
    pdk, 
    size=(17.68, 17.68), 
    rows=2, 
    columns=4
)

#nombrandalos para que aparezcan en el layout

xm1.name ="xm1"
xm6.name ="xm6"
xm2.name ="xm2"
xm3.name ="xm3"
xc3.name ="xc3"

# Add components as references to the main cell
xm1_ref = integrator << xm1
xm6_ref = integrator << xm6
xm2_ref = integrator << xm2
xm3_ref = integrator << xm3
xc3_ref = integrator << xc3



xm1_xy = evaluate_bbox(xm1)
xm2_xy = evaluate_bbox(xm2)
xm3_xy = evaluate_bbox(xm3)
xm6_xy = evaluate_bbox(xm6)
xc3_xy = evaluate_bbox(xc3)


# ----------------------------------------------------------------------
# 3. Component Placement & Floorplanning
# ----------------------------------------------------------------------
# Row 1 (Top): PMOS transistors side-by-side
# xm1_ref.move((15, 24))
sepa=5
xm6_ref.movex(xm6_xy[0]/2)
xm3_ref.movex(xm6_ref.xmax + xm3_xy[0]/2 + pdk.util_max_metal_seperation() + sepa)
xm2_ref.movex(xm3_ref.xmax + xm2_xy[0]/2 + pdk.util_max_metal_seperation() + sepa)
xc3_ref.movex(xm2_ref.xmax + xc3_xy[0]/2 - 13*2)
# Row 2 (Middle): Big MIM Capacitor Array
# xc3_ref.move((0, 0))

xm6_ref.movey(xm6_xy[1]/2)
xm2_ref.movey(xm2_xy[1]/2)
xm3_ref.movey(xm3_xy[1]/2)
xc3_ref.movey(xc3_xy[1]/2 - 12)

xm_max = max(xm6_xy[1], xm2_xy[1], xm3_xy[1])
separacion = 5


xm1_ref.movex(xm3_ref.xmax + 3)
xm1_ref.movey(xm_max + separacion + xm1_xy[1]/2)
# Out:
# 2026-08-25 20:06:20.910 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active
# ComponentReference (parent Component "xm1", ports ['multiplier_0_gate_W', 'gate_W', 'multiplier_0_row0_col0_gate_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_top_met_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'multiplier_0_leftsd_array_row0_col0_top_met_W', 'multiplier_0_leftsd_top_met_W', 'multiplier_0_plusdoped_W', 'multiplier_0_diff_W', 'multiplier_0_source_W', 'source_W', 'multiplier_0_drain_W', 'drain_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row0_col0_bottom_via_N', 'multiplier_0_leftsd_array_row0_col0_bottom_met_N', 'multiplier_0_leftsd_array_row0_col0_top_met_N', 'multiplier_0_leftsd_top_met_N', 'multiplier_0_row0_col0_gate_N', 'multiplier_0_plusdoped_N', 'multiplier_0_diff_N', 'multiplier_0_drain_N', 'multiplier_0_source_N', 'multiplier_0_gate_N', 'source_N', 'drain_N', 'gate_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_top_met_N', 'multiplier_0_drain_E', 'drain_E', 'multiplier_0_source_E', 'source_E', 'multiplier_0_row0_col0_gate_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_E', 'multiplier_0_row0_col0_rightsd_top_met_E', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_E', 'multiplier_0_leftsd_array_row0_col0_bottom_via_E', 'multiplier_0_leftsd_array_row0_col0_bottom_met_E', 'multiplier_0_leftsd_array_row0_col0_top_met_E', 'multiplier_0_leftsd_top_met_E', 'multiplier_0_plusdoped_E', 'multiplier_0_diff_E', 'multiplier_0_gate_E', 'gate_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_S', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_S', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_S', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_S', 'multiplier_0_row0_col0_rightsd_top_met_S', 'multiplier_0_row0_col0_gate_S', 'multiplier_0_plusdoped_S', 'multiplier_0_diff_S', 'multiplier_0_drain_S', 'multiplier_0_source_S', 'multiplier_0_gate_S', 'source_S', 'drain_S', 'gate_S', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_S', 'multiplier_0_leftsd_array_row0_col0_bottom_via_S', 'multiplier_0_leftsd_array_row0_col0_bottom_met_S', 'multiplier_0_leftsd_array_row0_col0_top_met_S', 'multiplier_0_leftsd_top_met_S', 'tie_S_array_row0_col0_bottom_layer_W', 'tie_S_array_row0_col0_bottom_via_W', 'tie_S_array_row0_col0_bottom_met_W', 'tie_S_array_row0_col0_top_met_W', 'tie_S_array_row0_col1_bottom_layer_W', 'tie_S_array_row0_col1_bottom_via_W', 'tie_S_array_row0_col1_bottom_met_W', 'tie_S_array_row0_col1_top_met_W', 'tie_S_bottom_lay_W', 'tie_S_top_met_W', 'tie_bl_bottom_layer_W', 'tie_bl_bottom_via_W', 'tie_bl_bottom_met_W', 'tie_bl_top_met_W', 'tie_br_bottom_layer_W', 'tie_br_bottom_via_W', 'tie_br_bottom_met_W', 'tie_br_top_met_W', 'tie_E_array_row0_col0_bottom_layer_W', 'tie_E_array_row0_col0_bottom_via_W', 'tie_E_array_row0_col0_bottom_met_W', 'tie_E_array_row0_col0_top_met_W', 'tie_W_array_row0_col0_bottom_layer_W', 'tie_W_array_row0_col0_bottom_via_W', 'tie_W_array_row0_col0_bottom_met_W', 'tie_W_array_row0_col0_top_met_W', 'tie_E_array_row1_col0_bottom_layer_W', 'tie_E_array_row1_col0_bottom_via_W', 'tie_E_array_row1_col0_bottom_met_W', 'tie_E_array_row1_col0_top_met_W', 'tie_W_array_row1_col0_bottom_layer_W', 'tie_W_array_row1_col0_bottom_via_W ...

# %%
display_component(integrator, scale = 1, path=".")

# %%
# =========================================================================
# 4. ADD AVDD & AVSS POWER RAILS AND CONNECT SUPPLY NODES
# =========================================================================

# https://gemini.google.com/app/131a537106def8cd
# Calculate full horizontal span of the cell to draw supply rails
bbox = evaluate_bbox(integrator) #calcular el tamaño del componente
top_y = integrator.ymax + 3.0
bottom_y = integrator.ymin - 3.0

# Draw horizontal metal2 power rails
avdd_rail = integrator << gf.components.rectangle(
    size=(bbox[0]+4, 1.0), 
    layer=pdk.get_layer("metal2")
)
avdd_rail.move((-2, top_y))

avss_rail = integrator << gf.components.rectangle(
    size=(bbox[0]+4, 1.0), 
    layer=pdk.get_layer("metal2")
)
avss_rail.move((-2, bottom_y))

#adding a VIA M2M3 to the avdd avss pin, moving to the center of the rail
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
via_avdd = integrator << viam2m3
via_avdd.move((bbox[0]/2, top_y + 0.5))
via_avss = integrator << viam2m3
via_avss.move((bbox[0]/2, bottom_y + 0.5))

# Add global ports for the supply rails
integrator.add_port("avdd", center=(bbox[0]/2, top_y + 0.5), width=1.0, orientation=180, layer=pdk.get_layer("metal3"), port_type="electrical")
integrator.add_port("avss", center=(bbox[0]/2, bottom_y + 0.5), width=1.0, orientation=180, layer=pdk.get_layer("metal3"), port_type="electrical")
# add label to those global ports 
integrator.add_label(text="avdd", position=(bbox[0]/2, top_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1.5)
integrator.add_label(text="avss", position=(bbox[0]/2, bottom_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1.5)
# Out:
# Label(text='avss', origin=(53.98, -4.46), layer=(42, 10))

# %%
# =========================================================================
# 5. ADD MET2 PHYSICAL PINS AND LABELS FOR LVS
# =========================================================================

# Map port names to their source port objects
pins_to_create = {
    "Vext_pin": xm6_ref.ports["gate_E"],
    "i_50": xm3_ref.ports["multiplier_0_drain_E"],
}


for pin_name, port in pins_to_create.items():
    # Extract center position, size, and orientation from port object
    center = port.center
    width = port.width
    height = port.width  # Standard square pin area around the port center


    #adding a via to each pin port to have them into metal 3
    viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
    via_port = integrator << viam2m3
    via_port.move((center[0] - width / 2, center[1]))

    integrator.add_port(pin_name, center=(center[0] - width / 2, center[1]), width=1.0, orientation=180, layer=pdk.get_layer("metal3"),  port_type="electrical") 

    # 2. Add text label on met2_pin layer for net identity
    integrator.add_label(
        text=pin_name, position=(center[0] - width / 2, center[1]), layer=pdk.get_glayer("met3_label"), magnification=1.2
    )

# %%
display_component(integrator, scale = 1, path=".")

# %%
# 4. Connecting vdd and vss rails
# ----------------------------------------------------------------------

integrator << L_route(pdk,xm1_ref.ports["tie_E_top_met_N"], via_avdd.ports["bottom_met_W"])

integrator << L_route(pdk,xm2_ref.ports["tie_E_top_met_S"], via_avss.ports["bottom_met_W"])
integrator << L_route(pdk,xm3_ref.ports["tie_W_top_met_S"], via_avss.ports["bottom_met_W"])
integrator << L_route(pdk,xm6_ref.ports["tie_E_top_met_S"], via_avss.ports["bottom_met_W"])

integrator << c_route(pdk,xm6_ref.ports["multiplier_0_drain_W"], via_avdd.ports["bottom_met_W"])
integrator << straight_route(pdk,xc3_ref.ports["row0_col0_array_row0_col0_bottom_met_S"], via_avss.ports["bottom_met_W"])

integrator << straight_route(pdk, xm2_ref.ports["multiplier_0_source_E"], xm2_ref.ports["tie_E_top_met_N"])

integrator << straight_route(pdk, xm3_ref.ports["multiplier_0_source_E"], xm3_ref.ports["tie_E_top_met_N"])
# Out:
# ComponentReference (parent Component "straight_route_c77412a3", ports ['route_W', 'route_N', 'route_E', 'route_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
# 4. Routing Net Connections
# ----------------------------------------------------------------------


viam2m3 = via_stack(pdk, "met2", "met3", centered=True)
vg_via = integrator << viam2m3
vg_via.move(xm1_ref.ports["multiplier_0_gate_S"].center).movey(-1.5)
integrator << straight_route(pdk, vg_via.ports["top_met_N"],xm1_ref.ports["multiplier_0_gate_S"] )
integrator << c_route(pdk, xm1_ref.ports["multiplier_0_drain_W"], vg_via.ports["bottom_met_W"])
integrator << L_route(pdk, xm2_ref.ports["multiplier_0_drain_W"], vg_via.ports["top_met_S"])

viam2m31 = via_stack(pdk, "met2", "met3", centered=True)
vg_via1 = integrator << viam2m31
vg_via1.move(xm3_ref.ports["multiplier_0_gate_E"].center).movex(2)
integrator << straight_route(pdk, xm3_ref.ports["multiplier_0_gate_E"], vg_via1.ports["top_met_N"])
integrator << L_route(pdk, xm3_ref.ports["multiplier_0_drain_E"], vg_via1.ports["top_met_N"])
integrator << straight_route(pdk, xm2_ref.ports["multiplier_0_gate_W"], vg_via1.ports["top_met_E"])

viam2m32 = via_stack(pdk, "met2", "met3", centered=True)
vg_via2 = integrator << viam2m32
vg_via2.move(xm1_ref.ports["multiplier_0_source_W"].center).movex(-8)
integrator << L_route(pdk, xm6_ref.ports["multiplier_0_source_E"], vg_via2.ports["top_met_N"])
integrator << straight_route(pdk, xm1_ref.ports["multiplier_0_source_W"], vg_via2.ports["top_met_N"])
integrator << L_route(pdk, vg_via2.ports["top_met_N"], xc3_ref.ports["row1_col0_top_met_W"])
# Out:
# ComponentReference (parent Component "L_route_5227ceb6", ports ['array_row0_col0_bottom_layer_W', 'array_row0_col0_bottom_via_W', 'array_row0_col0_bottom_met_W', 'array_row0_col0_top_met_W', 'array_row1_col0_bottom_layer_W', 'array_row1_col0_bottom_via_W', 'array_row1_col0_bottom_met_W', 'array_row1_col0_top_met_W', 'array_row2_col0_bottom_layer_W', 'array_row2_col0_bottom_via_W', 'array_row2_col0_bottom_met_W', 'array_row2_col0_top_met_W', 'array_row3_col0_bottom_layer_W', 'array_row3_col0_bottom_via_W', 'array_row3_col0_bottom_met_W', 'array_row3_col0_top_met_W', 'array_row4_col0_bottom_layer_W', 'array_row4_col0_bottom_via_W', 'array_row4_col0_bottom_met_W', 'array_row4_col0_top_met_W', 'array_row5_col0_bottom_layer_W', 'array_row5_col0_bottom_via_W', 'array_row5_col0_bottom_met_W', 'array_row5_col0_top_met_W', 'array_row6_col0_bottom_layer_W', 'array_row6_col0_bottom_via_W', 'array_row6_col0_bottom_met_W', 'array_row6_col0_top_met_W', 'array_row7_col0_bottom_layer_W', 'array_row7_col0_bottom_via_W', 'array_row7_col0_bottom_met_W', 'array_row7_col0_top_met_W', 'array_row8_col0_bottom_layer_W', 'array_row8_col0_bottom_via_W', 'array_row8_col0_bottom_met_W', 'array_row8_col0_top_met_W', 'array_row9_col0_bottom_layer_W', 'array_row9_col0_bottom_via_W', 'array_row9_col0_bottom_met_W', 'array_row9_col0_top_met_W', 'array_row10_col0_bottom_layer_W', 'array_row10_col0_bottom_via_W', 'array_row10_col0_bottom_met_W', 'array_row10_col0_top_met_W', 'bottom_lay_W', 'top_met_W', 'array_row11_col0_bottom_layer_W', 'array_row11_col0_bottom_via_W', 'array_row11_col0_bottom_met_W', 'array_row11_col0_top_met_W', 'array_row12_col0_bottom_layer_W', 'array_row12_col0_bottom_via_W', 'array_row12_col0_bottom_met_W', 'array_row12_col0_top_met_W', 'array_row13_col0_bottom_layer_W', 'array_row13_col0_bottom_via_W', 'array_row13_col0_bottom_met_W', 'array_row13_col0_top_met_W', 'array_row14_col0_bottom_layer_W', 'array_row14_col0_bottom_via_W', 'array_row14_col0_bottom_met_W', 'array_row14_col0_top_met_W', 'array_row15_col0_bottom_layer_W', 'array_row15_col0_bottom_via_W', 'array_row15_col0_bottom_met_W', 'array_row15_col0_top_met_W', 'array_row16_col0_bottom_layer_W', 'array_row16_col0_bottom_via_W', 'array_row16_col0_bottom_met_W', 'array_row16_col0_top_met_W', 'array_row17_col0_bottom_layer_W', 'array_row17_col0_bottom_via_W', 'array_row17_col0_bottom_met_W', 'array_row17_col0_top_met_W', 'array_row18_col0_bottom_layer_W', 'array_row18_col0_bottom_via_W', 'array_row18_col0_bottom_met_W', 'array_row18_col0_top_met_W', 'array_row19_col0_bottom_layer_W', 'array_row19_col0_bottom_via_W', 'array_row19_col0_bottom_met_W', 'array_row19_col0_top_met_W', 'array_row20_col0_bottom_layer_W', 'array_row20_col0_bottom_via_W', 'array_row20_col0_bottom_met_W', 'array_row20_col0_top_met_W', 'array_row0_col0_bottom_layer_N', 'array_row0_col0_bottom_via_N', 'array_row0_col0_bottom_met_N', 'array_row0_col0_top_met_N', 'array_row1_col0_bottom_layer_N', 'array_row1_col0_bottom_via_N', 'array_row1_col0_bottom_met_N', 'array_row1_col0_top_met_N', 'array_row2_col0_bottom_layer_N', 'array_row2_col0_bottom_via_N', 'array_row2_col0_bottom_met_N', 'array_row2_col0_top_met_N', 'array_row3_col0_bottom_layer_N', 'array_row3_col0_bottom_via_N', 'array_row3_col0_bottom_met_N', 'array_row3_col0_top_met_N', 'array_row4_col0_bottom_layer_N', 'array_row4_col0_bottom_via_N', 'array_row4_col0_bottom_met_N', 'array_row4_col0_top_met_N', 'array_row5_col0_bottom_layer_N', 'array_row5_col0_bottom_via_N', 'array_row5_col0_bottom_met_N', 'array_row5_col0_top_met_N', 'array_row6_col0_bottom_layer_N', 'array_row6_col0_bottom_via_N', 'array_row6_col0_bottom_met_N', 'array_row6_col0_top_met_N', 'array_row7_col0_bottom_layer_N', 'array_row7_col0_bottom_via_N', 'array_row7_col0_bottom_met_N', 'array_row7_col0_top_met_N', 'array_row8_col0_bottom_layer_N', 'array_row8_col0_bottom_via_N', 'array_row8_col0_bottom_met_N', 'array_row8_col0_top_met_N', 'array_row9_col0_bottom_layer_N', 'array_row9_col0_bo ...

# %%
display_component(integrator, scale = 1, path=".")

# %%
display_component(integrator, scale = 1, path=".")

# %%
integrator.name="integrator"
drc_result = gf180.drc_magic(integrator, integrator.name)
# Out:
# 2026-08-25 20:06:35.890 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpgkm7x4rc/integrator.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpgkm7x4rc/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "integrator".
# Reading "via_stack_a2e89513".
# Reading "xm2".
# Reading "compass_238aa27a$1".
# Reading "via_stack_a2e89513$3".
# Reading "L_route_445f0d12".
# Reading "compass_238aa27a".
# Reading "straight_route_c77412a3".
# Reading "L_route_2c7c0f80".
# Reading "L_route_5227ceb6".
# Reading "via_stack_a2e89513$9".
# Reading "c_route_1cf25900".
# Reading "straight_route_f7d24460".
# Reading "xm1".
# Reading "straight_route_0ec11d6a".
# Reading "via_stack_a2e89513$5".
# Reading "L_route_3836e623".
# Reading "straight_route_d3c71f1c".
# Reading "L_route_b602ec8e".
# Reading "rectangle_238aa27a".
# Reading "L_route_4ee192c5".
# Reading "via_stack_a2e89513$1".
# Reading "L_route_8fec0b43".
# Reading "straight_route_9b5e5851".
# Reading "xc3".
# Reading "straight_route_b30f64cd".
# Reading "rectangle_238aa27a$1".
# Reading "L_route_3e45c7a7".
# Reading "straight_route_29f960a2".
# Reading "c_route_ab1ed7e6".
# Reading "xm3".
# Reading "xm6".
# Reading "via_stack_a2e89513$2".
# [INFO]: Loading integrator
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpgkm7x4rc/integrator.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
import os
from pathlib import Path
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name=integrator.name
path_to_dir = "/foss/designs/libs/snn_analog/Integrator/"

pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"

integrator.write_gds(str(gds_path))
    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
exit
"""

# magic_script_content = f"""
# drc off            
# gds flatglob *\\$\\$*
# gds read {gds_path}
# load {design_name}
# select top cell
# extract do local
# extract all
# ext2sim labels on
# ext2sim
# ext2spice lvs
# ext2spice -o {str(pex_path)}
# exit
# """

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# 2026-08-25 20:06:36.282 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/Integrator/integrator.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "integrator".
# Reading "via_stack_a2e89513".
# Reading "xm2".
# Reading "compass_238aa27a$1".
# Reading "via_stack_a2e89513$3".
# Reading "L_route_445f0d12".
# Reading "compass_238aa27a".
# Reading "straight_route_c77412a3".
# Reading "L_route_2c7c0f80".
# Reading "L_route_5227ceb6".
# Reading "via_stack_a2e89513$9".
# Reading "c_route_1cf25900".
# Reading "straight_route_f7d24460".
# Reading "xm1".
# Reading "straight_route_0ec11d6a".
# Reading "via_stack_a2e89513$5".
# Reading "L_route_3836e623".
# Reading "straight_route_d3c71f1c".
# Reading "L_route_b602ec8e".
# Reading "rectangle_238aa27a".
# Reading "L_route_4ee192c5".
# Reading "via_stack_a2e89513$1".
# Reading "L_route_8fec0b43".
# Reading "straight_route_9b5e5851".
# Reading "xc3".
# Reading "straight_route_b30f64cd".
# Reading "rectangle_238aa27a$1".
# Reading "L_route_3e45c7a7".
# Reading "straight_route_29f960a2".
# Reading "c_route_ab1ed7e6".
# Reading "xm3".
# Reading "xm6".
# Reading "via_stack_a2e89513$2".
# Extracting L_route_445f0d12 into L_route_445f0d12.ext:
# Extracting via_stack_a2e89513$1 into via_stack_a2e89513$1.ext:
# Extracting xm6 into xm6.ext:
# Extracting straight_route_c77412a3 into straight_route_c77412a3.ext:
# Extracting straight_route_b30f64cd into straight_route_b30f64cd.ext:
# Extracting L_route_3e45c7a7 into L_route_3e45c7a7.ext:
# Extracting xm3 into xm3.ext:
# Extracting via_stack_a2e89513$2 into via_stack_a2e89513$2.ext:
# Extracting xm2 into xm2.ext:
# Extracting L_route_2c7c0f80 into L_route_2c7c0f80.ext:
# Extracting via_stack_a2e89513$5 into via_stack_a2e89513$5.ext:
# Extracting straight_route_d3c71f1c into straight_route_d3c71f1c.ext:
# Extracting straight_route_f7d24460 into straight_route_f7d24460.ext:
# Extracting straight_route_9b5e5851 into straight_route_9b5e5851.ext:
# Extracting via_stack_a2e89513 into via_stack_a2e89513.ext:
# Extracting L_route_4ee192c5 into L_route_4ee192c5.ext:
# Extracting L_route_b602ec8e into L_route_b602ec8e.ext:
# Extracting L_route_3836e623 into L_route_3836e623.ext:
# Extracting compass_238aa27a$1 into compass_238aa27a$1.ext:
# Extracting rectangle_238aa27a$1 into rectangle_238aa27a$1.ext:
# Extracting c_route_ab1ed7e6 into c_route_ab1ed7e6.ext:
# Extracting straight_route_29f960a2 into straight_route_29f960a2.ext:
# Extracting straight_route_0ec11d6a into straight_route_0ec11d6a.ext:
# Extracting xm1 into xm1.ext:
# Extracting via_stack_a2e89513$9 into via_stack_a2e89513$9.ext:
# Extracting via_stack_a2e89513$3 into via_stack_a2e89513$3.ext:
# Extracting L_route_5227ceb6 into L_route_5227ceb6.ext:
# Extracting compass_238aa27a into compass_238aa27a.ext:
# Extracting rectangle_238aa27a into rectangle_238aa27a.ext:
# Extracting c_route_1cf25900 into c_route_1cf25900.ext:
# Extracting L_route_8fec0b43 into L_route_8fec0b43.ext:
# Extracting xc3 into xc3.ext:
# Extracting integrator into integrator.ext:
# integrator: 6 errors
# exttosim finished.
# Adding  avdd; Tnew = 0.00ns, Told = 0.00ns
# Adding  avss; Tnew = 0.01ns, Told = 0.00ns
# Adding  Vext_pin; Tnew = 0.00ns, Told = 0.00ns
# Adding  i_50; Tnew = 0.01ns, Told = 0.00ns
# Total Nets: 18
# Nets extracted: 4 (0.222222)
# Nets output: 4 (0.222222)
# exttospice finished.

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: straight_route_9b5e5851.ext
# Deleted: L_route_3e45c7a7.ext
# Deleted: L_route_445f0d12.ext
# Deleted: compass_238aa27a.ext
# Deleted: compass_238aa27a$1.ext
# Deleted: L_route_2c7c0f80.ext
# Deleted: via_stack_a2e89513$1.ext
# Deleted: via_stack_a2e89513$2.ext
# Deleted: xc3.ext
# Deleted: via_stack_a2e89513$3.ext
# Deleted: integrator.ext
# Deleted: integrator.res.ext
# Deleted: straight_route_0ec11d6a.ext
# Deleted: via_stack_a2e89513$5.ext
# Deleted: via_stack_a2e89513.ext
# Deleted: L_route_4ee192c5.ext
# Deleted: L_route_b602ec8e.ext
# Deleted: xm2.ext
# Deleted: rectangle_238aa27a$1.ext
# Deleted: via_stack_a2e89513$9.ext
# Deleted: xm3.ext
# Deleted: xm1.ext
# Deleted: L_route_5227ceb6.ext
# Deleted: c_route_1cf25900.ext
# Deleted: c_route_ab1ed7e6.ext
# Deleted: straight_route_d3c71f1c.ext
# Deleted: straight_route_29f960a2.ext
# Deleted: xm6.ext
# Deleted: straight_route_b30f64cd.ext
# Deleted: rectangle_238aa27a.ext
# Deleted: straight_route_f7d24460.ext
# Deleted: L_route_3836e623.ext
# Deleted: L_route_8fec0b43.ext
# Deleted: straight_route_c77412a3.ext
# Error deleting integrator.res.ext: [Errno 2] No such file or directory: 'integrator.res.ext'
# Deleted: integrator.nodes
# Deleted: integrator.sim

# %%
import os
from pathlib import Path

gf180.lvs_netgen(
    layout=integrator,
    design_name = integrator.name,
    pdk_root = Path(os.environ['PDKPATH']),
    lvs_setup_tcl_file = Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    lvs_schematic_ref_file = Path(str(path_to_dir + "integrator.spice")),
    netlist = Path(str(path_to_dir + "integrator_sch.spice")),
    output_file_path =  Path(str(path_to_dir))
)
# Out:
# 2026-08-25 20:06:37.042 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp1_ro2sht/integrator.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "integrator".
# Reading "via_stack_a2e89513".
# Reading "xm2".
# Reading "compass_238aa27a$1".
# Reading "via_stack_a2e89513$3".
# Reading "L_route_445f0d12".
# Reading "compass_238aa27a".
# Reading "straight_route_c77412a3".
# Reading "L_route_2c7c0f80".
# Reading "L_route_5227ceb6".
# Reading "via_stack_a2e89513$9".
# Reading "c_route_1cf25900".
# Reading "straight_route_f7d24460".
# Reading "xm1".
# Reading "straight_route_0ec11d6a".
# Reading "via_stack_a2e89513$5".
# Reading "L_route_3836e623".
# Reading "straight_route_d3c71f1c".
# Reading "L_route_b602ec8e".
# Reading "rectangle_238aa27a".
# Reading "L_route_4ee192c5".
# Reading "via_stack_a2e89513$1".
# Reading "L_route_8fec0b43".
# Reading "straight_route_9b5e5851".
# Reading "xc3".
# Reading "straight_route_b30f64cd".
# Reading "rectangle_238aa27a$1".
# Reading "L_route_3e45c7a7".
# Reading "straight_route_29f960a2".
# Reading "c_route_ab1ed7e6".
# Reading "xm3".
# Reading "xm6".
# Reading "via_stack_a2e89513$2".
# Extracting L_route_445f0d12 into L_route_445f0d12.ext:
# Extracting via_stack_a2e89513$1 into via_stack_a2e89513$1.ext:
# Extracting xm6 into xm6.ext:
# Extracting straight_route_c77412a3 into straight_route_c77412a3.ext:
# Extracting straight_route_b30f64cd into straight_route_b30f64cd.ext:
# Extracting L_route_3e45c7a7 into L_route_3e45c7a7.ext:
# Extracting xm3 into xm3.ext:
# Extracting via_stack_a2e89513$2 into via_stack_a2e89513$2.ext:
# Extracting xm2 into xm2.ext:
# Extracting L_route_2c7c0f80 into L_route_2c7c0f80.ext:
# Extracting via_stack_a2e89513$5 into via_stack_a2e89513$5.ext:
# Extracting straight_route_d3c71f1c into straight_route_d3c71f1c.ext:
# Extracting straight_route_f7d24460 into straight_route_f7d24460.ext:
# Extracting straight_route_9b5e5851 into straight_route_9b5e5851.ext:
# Extracting via_stack_a2e89513 into via_stack_a2e89513.ext:
# Extracting L_route_4ee192c5 into L_route_4ee192c5.ext:
# Extracting L_route_b602ec8e into L_route_b602ec8e.ext:
# Extracting L_route_3836e623 into L_route_3836e623.ext:
# Extracting compass_238aa27a$1 into compass_238aa27a$1.ext:
# Extracting rectangle_238aa27a$1 into rectangle_238aa27a$1.ext:
# Extracting c_route_ab1ed7e6 into c_route_ab1ed7e6.ext:
# Extracting straight_route_29f960a2 into straight_route_29f960a2.ext:
# Extracting straight_route_0ec11d6a into straight_route_0ec11d6a.ext:
# Extracting xm1 into xm1.ext:
# Extracting via_stack_a2e89513$9 into via_stack_a2e89513$9.ext:
# Extracting via_stack_a2e89513$3 into via_stack_a2e89513$3.ext:
# Extracting L_route_5227ceb6 into L_route_5227ceb6.ext:
# Extracting compass_238aa27a into compass_238aa27a.ext:
# Extracting rectangle_238aa27a into rectangle_238aa27a.ext:
# Extracting c_route_1cf25900 into c_route_1cf25900.ext:
# Extracting L_route_8fec0b43 into L_route_8fec0b43.ext:
# Extracting xc3 into xc3.ext:
# Extracting integrator into integrator.ext:
# integrator: 6 errors
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmp1_ro2sht/integrator_lvsmag.spice integrator" "/tmp/tmp1_ro2sht/integrator.spice integrator" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmp1_ro2sht/integrator_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:08:04 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmp1_ro2sht/integrator_lvsmag.spice for /tmp/tmp1_ro2sht/integrator_lvsmag.spice integrator
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit cap_mim_2f0_m4m5_noshield
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmp1_ro2sht/integrator.spice for /tmp/tmp1_ro2sht/integrator.spice integrator
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit cap_mim_2f0_m4m5_noshield
# Creating placeholder cell definition.
# Duplicate cell integrator in file
# Renaming original cell to integrator[[0]]
# Call to undefined subcircuit cap_mim_2f0fF
# Creating placeholder cell definition.
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# No property par1 found for device cap_mim_2f0fF
# No property par1 found for device cap_mim_2f0_m4m5_noshield
# No property par1 found for device cap_mim_2f0_m4m5_noshield
# Device classes cap_mim_2f0_m4m5_noshield and cap_mim_2f0fF are equivalent.
# Comparison output logged to file /tmp/tmp1_ro2sht/integrator_lvs.rpt
# Logging to file "/tmp/tmp1_ro2sht/integrator_lvs.rpt" enabled
# Circuit nfet_03v3 contains no devices.
# Circuit pfet_03v3 contains no devices.
# Circuit cap_mim_2f0_m4m5_noshield contains no devices.
#
# Contents of circuit 1:  Circuit: 'xm3'
# Circuit xm3 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm3'
# Circuit xm3 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm3 xm3
#
# Flattening instances of xm3 in file /tmp/tmp1_ro2sht/integrator_lvsmag.spice
# Flattening instances of xm3 in file /tmp/tmp1_ro2sht/integrator.spice
#
# Contents of circuit 1:  Circuit: 'xm1'
# Circuit xm1 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm1'
# Circuit xm1 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm1 xm1
#
# Flattening instances of xm1 in file /tmp/tmp1_ro2sht/integrator_lvsmag.spice
# Flattening instances of xm1 in file /tmp/tmp1_ro2sht/integrator.spice
#
# Contents of circuit 1:  Circuit: 'xm6'
# Circuit xm6 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm6'
# Circuit xm6 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm6 xm6
#
# Flattening instances of xm6 in file /tmp/tmp1_ro2sht/integrator_lvsmag.spice
# Flattening instances of xm6 in file /tmp/tmp1_ro2sht/integrator.spice
#
# Contents of circuit 1:  Circuit: 'xm2'
# Circuit xm2 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm2'
# Circuit xm2 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm2 xm2
#
# Flattening instances of xm2 in file /tmp/tmp1_ro2sht/integrator_lvsmag.spice
# Flattening instances of xm2 in file /tmp/tmp1_ro2sht/integrator.spice
#
# Contents of circuit 1:  Circuit: 'xc3'
# Circuit xc3 contains 8 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   8
# Circuit contains 2 nets.
# Contents of circuit 2:  Circuit: 'xc3'
# Circuit xc3 contains 11 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   8
#   Class: c                     instances:   3
# Circuit contains 3 nets.
#
# Circuit was modified by parallel/series device merging.
# New circuit summary:
#
# Contents of circuit 1:  Circuit: 'xc3'
# Circuit xc3 contains 1 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   1
# Circuit contains 2 nets.
# Contents of circuit 2:  Circuit: 'xc3'
# Circuit xc3 contains 4 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   1
#   Class: c                     instances:   3
# Circuit contains 3 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 4 devices. *** MISMATCH ***
# Circuit 1 contains 2 nets,    Circuit 2 contains 3 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xc3 xc3
#
# Flattening instances of xc3 in file /tmp/tmp1_ro2sht/integrator_lvsmag.spice
# Flattening instances of xc3 in file /tmp/tmp1_ro2sht/integrator.spice
# Circuit cap_mim_2f0_m4m5_noshield contains no devices.
#
# Contents of circuit 1:  Circuit: 'integrator'
# Circuit integrator contains 5 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   1
#   Class: nfet_03v3             instances:   3
#   Class: pfet_03v3             instances:   1
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'integrator'
# Circuit integrator contains 5 device instances.
#   Class: cap_mim_2f0fF         instances:   1
#   Class: nfet_03v3             instances:   3
#   Class: pfet_03v3             instances:   1
# Circuit contains 6 nets.
#
# Circuit 1 contains 5 devices, Circuit 2 contains 5 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Final result:
# Circuits match uniquely.
# .
# Logging to file "/tmp/tmp1_ro2sht/integrator_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Circuit 1 cell cap_mim_2f0_m4m5_noshield and Circuit 2 cell cap_mim_2f0_m4m5_noshield are black boxes.
# Warning: Equate pins:  cell cap_mim_2f0_m4m5_noshield is a placeholder, treated as a black box.
# Warning: Equate pins:  cell cap_mim_2f0_m4m5_noshield is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: cap_mim_2f0_m4m5_noshield       |Circuit 2: cap_mim_2f0_m4m5_noshield
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes cap_mim_2f0_m4m5_noshield and cap_mim_2f0_m4m5_noshield are equivalent.
#
# Subcircuit summary:
# Circuit 1: xm3                             |Circuit 2: xm3
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm3                             |Circuit 2: xm3
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n181#                            |Net: a_28_n181#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n50_n389#                           |Net: a_n50_n389#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n178_n181#                          |Net: a_n178_n181#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n388_n554#                          |Net: a_n388_n554#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm3                             |Circuit 2: xm3
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm3 xm3
#
# Subcircuit summary:
# Circuit 1: xm1                             |Circuit 2: xm1
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm1                             |Circuit 2: xm1
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n181#                            |Net: a_28_n181#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n178_n181#                          |Net: a_n178_n181#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n50_n389#                           |Net: a_n50_n389#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/top = 4
#                                            |
# Net: w_n444_n610#                          |Net: w_n444_n610#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm1                             |Circuit 2: xm1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm1 xm1
#
# Subcircuit summary:
# Circuit 1: xm6                             |Circuit 2: xm6
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm6                             |Circuit 2: xm6
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n181#                            |Net: a_28_n181#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n50_n389#                           |Net: a_n50_n389#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n178_n181#                          |Net: a_n178_n181#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n388_n554#                          |Net: a_n388_n554#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm6                             |Circuit 2: xm6
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm6 xm6
#
# Subcircuit summary:
# Circuit 1: xm2                             |Circuit 2: xm2
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm2                             |Circuit 2: xm2
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n181#                            |Net: a_28_n181#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n50_n389#                           |Net: a_n50_n389#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n178_n181#                          |Net: a_n178_n181#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n388_n554#                          |Net: a_n388_n554#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm2                             |Circuit 2: xm2
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm2 xm2
#
# Class xc3 (0):  Merged 7 parallel devices.
# Class xc3 (1):  Merged 7 parallel devices.
# Subcircuit summary:
# Circuit 1: xc3                             |Circuit 2: xc3
# -------------------------------------------|-------------------------------------------
# cap_mim_2f0_m4m5_noshield (8->1)           |cap_mim_2f0_m4m5_noshield (8->1)
# (no matching element)                      |c (3)
# Number of devices: 1 **Mismatch**          |Number of devices: 4 **Mismatch**
# Number of nets: 2 **Mismatch**             |Number of nets: 3 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xc3                             |Circuit 2: xc3
#
# ---------------------------------------------------------------------------------------
# Net: m4_n1768_n1768#                       |Net: m4_n1768_n1768#
#   cap_mim_2f0_m4m5_noshield/1 = 1          |  cap_mim_2f0_m4m5_noshield/1 = 1
#                                            |  c/top = 2
#                                            |
# Net: m4_n1968_n1968#                       |Net: m4_n1968_n1968#
#   cap_mim_2f0_m4m5_noshield/2 = 1          |  cap_mim_2f0_m4m5_noshield/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 2
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xc3                             |Circuit 2: xc3
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 3
#                                            |  bottom = 3
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 3
#                                            |  bottom = 2
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 3
#                                            |  bottom = 2
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xc3 xc3
#
# Circuit 1 cell cap_mim_2f0_m4m5_noshield and Circuit 2 cell cap_mim_2f0fF are black boxes.
# Warning: Equate pins:  cell cap_mim_2f0_m4m5_noshield is a placeholder, treated as a black box.
# Warning: Equate pins:  cell cap_mim_2f0fF is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: cap_mim_2f0_m4m5_noshield       |Circuit 2: cap_mim_2f0fF
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes cap_mim_2f0_m4m5_noshield and cap_mim_2f0fF are equivalent.
#
# Subcircuit summary:
# Circuit 1: integrator                      |Circuit 2: integrator
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (3)                              |nfet_03v3 (3)
# pfet_03v3 (1)                              |pfet_03v3 (1)
# cap_mim_2f0_m4m5_noshield (8->1)           |cap_mim_2f0_m4m5_noshield (8->1)
# Number of devices: 5                       |Number of devices: 5
# Number of nets: 6                          |Number of nets: 6
# ---------------------------------------------------------------------------------------
# Netlists match uniquely.
#
# Subcircuit pins:
# Circuit 1: integrator                      |Circuit 2: integrator
# -------------------------------------------|-------------------------------------------
# Vext_pin                                   |Vext_pin
# avdd                                       |avdd
# avss                                       |avss
# i_50                                       |i_50
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes integrator and integrator are equivalent.
#
# Final result: Circuits match uniquely.
# .
# {'magic_subproc_code': 0,
#  'netgen_subproc_code': 0,
#  'result_str': 'LVS run succeeded\nErrors found in LVS report: /tmp/tmp1_ro2sht/integrator_lvs.rpt'}
