# %%
import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file,path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)


# %%
import os
import gdsfactory as gf
from gdsfactory import Component
from glayout import MappedPDK, gf180
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring
from glayout.primitives.mimcap import mimcap_array
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist


# Base parameters for PMOS and NMOS
stdp_config = {
    "pdk": gf180,
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation()+1,
        "routing_metal": "met2",
        "dummy_devices": False,
        "tie_layers": ("met2", "met1"),
        "sd_rmult": 1,
    },
}

nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False,
    "with_substrate_tap":False
}

pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False,
    "with_substrate_tap":False
}

# %%
pdk = gf180
current_mirror = Component(name="current_mirror")
current_mirror.name = "current_mirror"
rules = stdp_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]


#Placement
m1 = nmos(pdk, width=4, length=0.28, with_dummy=(False, False),  tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
m2 = nmos(pdk, width=4, length=4, with_dummy=(False, False),  tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
m3 = pmos(pdk, width=8, length=0.5, with_dummy=(False, False),  tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
m4 = pmos(pdk, width=1.6, length=0.5, with_dummy=(False, False), tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)

m1.name = "M1" 
m2.name = "M2" 
m3.name = "M3" 
m4.name = "M4" 

m1_ref = current_mirror << m1
m2_ref = current_mirror << m2
m3_ref = current_mirror << m3
m4_ref = current_mirror << m4


bottom_row_y = evaluate_bbox(m1)[1]/2 + 4
top_row_y = bottom_row_y + evaluate_bbox(m3)[1]

m1_ref.move((evaluate_bbox(m1)[0]/2,bottom_row_y))
m2_ref.move((m1_ref.xmax + evaluate_bbox(m2_ref)[0]/2 + spacing , bottom_row_y))


m4_ref.move((evaluate_bbox(m1)[0]/2 ,top_row_y ))
m3_ref.move((m4_ref.xmax + evaluate_bbox(m3)[0]/2 + spacing,top_row_y))
# Out:
# 2026-08-22 00:46:41.085 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active
# ComponentReference (parent Component "M3", ports ['multiplier_0_gate_W', 'gate_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'multiplier_0_leftsd_array_row0_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_W', 'multiplier_0_leftsd_array_row1_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row1_col0_bottom_via_W', 'multiplier_0_leftsd_array_row1_col0_bottom_met_W', 'multiplier_0_leftsd_array_row1_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_W', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row2_col0_bottom_via_W', 'multiplier_0_leftsd_array_row2_col0_bottom_met_W', 'multiplier_0_leftsd_array_row2_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_W', 'multiplier_0_leftsd_array_row3_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row3_col0_bottom_via_W', 'multiplier_0_leftsd_array_row3_col0_bottom_met_W', 'multiplier_0_leftsd_array_row3_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_W', 'multiplier_0_leftsd_array_row4_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row4_col0_bottom_via_W', 'multiplier_0_leftsd_array_row4_col0_bottom_met_W', 'multiplier_0_leftsd_array_row4_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_W', 'multiplier_0_leftsd_array_row5_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row5_col0_bottom_via_W', 'multiplier_0_leftsd_array_row5_col0_bottom_met_W', 'multiplier_0_leftsd_array_row5_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_W', 'multiplier_0_leftsd_array_row6_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row6_col0_bottom_via_W', 'multiplier_0_leftsd_array_row6_col0_bottom_met_W', 'multiplier_0_leftsd_array_row6_col0_top_met_W', 'multiplier_0_row0_col0_gate_W', 'multiplier_0_row0_col0_rightsd_array_row7_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row7_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row7_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row7_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_top_met_W', 'multiplier_0_leftsd_array_row7_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row7_col0_bottom_via_W', 'multiplier_0_leftsd_array_row7_col0_bottom_met_W', 'multiplier_0_leftsd_array_row7_col0_top_met_W', 'multiplier_0_leftsd_top_met_W', 'multiplier_0_plusdoped_W', 'multiplier_0_diff_W', 'multiplier_0_row0_col0_rightsd_array_row8_col0_bottom_layer_W', 'multiplier_0_row0_col0_rig ...

# %%
m1.ports
# Out:
# {'multiplier_0_gate_W': {'name': 'multiplier_0_gate_W', 'width': 0.5, 'center': [-0.25, -3.195], 'orientation': 180.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'gate_W': {'name': 'gate_W', 'width': 0.5, 'center': [-0.25, -3.195], 'orientation': 180.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, -1.905], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, -1.905], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, -1.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'width': 0.46, 'center': [0.34, -1.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, -1.905], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, -1.905], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, -1.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row0_col0_top_met_W', 'width': 0.46, 'center': [-0.8, -1.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, -1.405], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, -1.405], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, -1.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_W', 'width': 0.46, 'center': [0.34, -1.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, -1.405], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, -1.405], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, -1.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row1_col0_top_met_W', 'width': 0.46, 'center': [-0.8, -1.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, -0.905], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, -0.905], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, -0.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_W', 'width': 0.46, 'center': [0.34, -0.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, -0.905], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, -0.905], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, -0.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row2_col0_top_met_W', 'width': 0.46, 'center': [-0.8, -0.905], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_gate_W': {'name': 'multiplier_0_row0_col0_gate_W', 'width': 4.48, 'center': [-0.14, -0.405], 'orientation': 180.0, 'layer': [30, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, -0.405], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, -0.405], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, -0.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_W', 'width': 0.46, 'center': [0.34, -0.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_top_met_W', 'width': 4.0, 'center': [0.34, -0.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, -0.405], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, -0.405], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, -0.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row3_col0_top_met_W', 'width': 0.46, 'center': [-0.8, -0.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_top_met_W': {'name': 'multiplier_0_leftsd_top_met_W', 'width': 4.0, 'center': [-0.8, -0.405], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_plusdoped_W': {'name': 'multiplier_0_plusdoped_W', 'width': 4.46, 'center': [-1.12, -0.405], 'orientation': 180.0, 'layer': [32, 0], 'port_type': 'electrical'},
#  'multiplier_0_diff_W': {'name': 'multiplier_0_diff_W', 'width': 4.0, 'center': [-0.89, -0.405], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, 0.095], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, 0.095], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, 0.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_W', 'width': 0.46, 'center': [0.34, 0.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, 0.095], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, 0.095], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, 0.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row4_col0_top_met_W', 'width': 0.46, 'center': [-0.8, 0.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, 0.595], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, 0.595], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, 0.595], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_W', 'width': 0.46, 'center': [0.34, 0.595], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, 0.595], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, 0.595], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, 0.595], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row5_col0_top_met_W', 'width': 0.46, 'center': [-0.8, 0.595], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_W', 'width': 0.36, 'center': [0.39, 1.095], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_W', 'width': 0.22, 'center': [0.46, 1.095], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_W', 'width': 0.46, 'center': [0.34, 1.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_W': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_W', 'width': 0.46, 'center': [0.34, 1.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_layer_W': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_layer_W', 'width': 0.36, 'center': [-0.75, 1.095], 'orientation': 180.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_via_W': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_via_W', 'width': 0.22, 'center': [-0.68, 1.095], 'orientation': 180.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_met_W': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_met_W', 'width': 0.46, 'center': [-0.8, 1.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_top_met_W': {'name': 'multiplier_0_leftsd_array_row6_col0_top_met_W', 'width': 0.46, 'center': [-0.8, 1.095], 'orientation': 180.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_source_W': {'name': 'multiplier_0_source_W', 'width': 0.5, 'center': [-0.82, 2.395], 'orientation': 180.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'source_W': {'name': 'source_W', 'width': 0.5, 'center': [-0.82, 2.395], 'orientation': 180.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_drain_W': {'name': 'multiplier_0_drain_W', 'width': 0.5, 'center': [-0.82, 3.195], 'orientation': 180.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'drain_W': {'name': 'drain_W', 'width': 0.5, 'center': [-0.82, 3.195], 'orientation': 180.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, -1.725], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, -1.795], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, -1.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row0_col0_top_met_N', 'width': 0.46, 'center': [-0.57, -1.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, -1.225], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, -1.295], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, -1.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row1_col0_top_met_N', 'width': 0.46, 'center': [-0.57, -1.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, -0.725], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, -0.795], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, -0.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row2_col0_top_met_N', 'width': 0.46, 'center': [-0.57, -0.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, -0.225], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, -0.295], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, -0.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row3_col0_top_met_N', 'width': 0.46, 'center': [-0.57, -0.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, 0.275], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, 0.205], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, 0.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row4_col0_top_met_N', 'width': 0.46, 'center': [-0.57, 0.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, 0.775], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, 0.705], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, 0.825], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row5_col0_top_met_N', 'width': 0.46, 'center': [-0.57, 0.825], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_layer_N': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_layer_N', 'width': 0.36, 'center': [-0.57, 1.275], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_via_N': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_via_N', 'width': 0.22, 'center': [-0.57, 1.205], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_met_N': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_met_N', 'width': 0.46, 'center': [-0.57, 1.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_top_met_N': {'name': 'multiplier_0_leftsd_array_row6_col0_top_met_N', 'width': 0.46, 'center': [-0.57, 1.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_top_met_N': {'name': 'multiplier_0_leftsd_top_met_N', 'width': 0.46, 'center': [-0.57, 1.595], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_gate_N': {'name': 'multiplier_0_row0_col0_gate_N', 'width': 0.28, 'center': [0.0, 1.835], 'orientation': 90.0, 'layer': [30, 0], 'port_type': 'electrical'},
#  'multiplier_0_plusdoped_N': {'name': 'multiplier_0_plusdoped_N', 'width': 2.24, 'center': [0.0, 1.825], 'orientation': 90.0, 'layer': [32, 0], 'port_type': 'electrical'},
#  'multiplier_0_diff_N': {'name': 'multiplier_0_diff_N', 'width': 1.78, 'center': [0.0, 1.595], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_drain_N': {'name': 'multiplier_0_drain_N', 'width': 1.64, 'center': [0.0, 3.445], 'orientation': 90.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_source_N': {'name': 'multiplier_0_source_N', 'width': 1.64, 'center': [0.0, 2.645], 'orientation': 90.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_gate_N': {'name': 'multiplier_0_gate_N', 'width': 0.5, 'center': [0.0, -2.945], 'orientation': 90.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'source_N': {'name': 'source_N', 'width': 1.64, 'center': [0.0, 2.645], 'orientation': 90.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'drain_N': {'name': 'drain_N', 'width': 1.64, 'center': [0.0, 3.445], 'orientation': 90.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'gate_N': {'name': 'gate_N', 'width': 0.5, 'center': [0.0, -2.945], 'orientation': 90.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, -1.725], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, -1.795], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, -1.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_N', 'width': 0.46, 'center': [0.57, -1.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, -1.225], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, -1.295], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, -1.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_N', 'width': 0.46, 'center': [0.57, -1.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, -0.725], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, -0.795], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, -0.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_N', 'width': 0.46, 'center': [0.57, -0.675], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, -0.225], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, -0.295], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, -0.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_N', 'width': 0.46, 'center': [0.57, -0.175], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, 0.275], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, 0.205], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, 0.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_N', 'width': 0.46, 'center': [0.57, 0.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, 0.775], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, 0.705], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, 0.825], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_N', 'width': 0.46, 'center': [0.57, 0.825], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_N', 'width': 0.36, 'center': [0.57, 1.275], 'orientation': 90.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_N', 'width': 0.22, 'center': [0.57, 1.205], 'orientation': 90.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_N', 'width': 0.46, 'center': [0.57, 1.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_N', 'width': 0.46, 'center': [0.57, 1.325], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_top_met_N': {'name': 'multiplier_0_row0_col0_rightsd_top_met_N', 'width': 0.46, 'center': [0.57, 1.595], 'orientation': 90.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_drain_E': {'name': 'multiplier_0_drain_E', 'width': 0.5, 'center': [0.82, 3.195], 'orientation': 0.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'drain_E': {'name': 'drain_E', 'width': 0.5, 'center': [0.82, 3.195], 'orientation': 0.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_source_E': {'name': 'multiplier_0_source_E', 'width': 0.5, 'center': [0.82, 2.395], 'orientation': 0.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'source_E': {'name': 'source_E', 'width': 0.5, 'center': [0.82, 2.395], 'orientation': 0.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, 1.095], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, 1.095], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, 1.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row6_col0_top_met_E', 'width': 0.46, 'center': [0.8, 1.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, 1.095], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, 1.095], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row6_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, 1.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row6_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row6_col0_top_met_E', 'width': 0.46, 'center': [-0.34, 1.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, 0.595], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, 0.595], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, 0.595], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row5_col0_top_met_E', 'width': 0.46, 'center': [0.8, 0.595], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, 0.595], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, 0.595], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row5_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, 0.595], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row5_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row5_col0_top_met_E', 'width': 0.46, 'center': [-0.34, 0.595], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, 0.095], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, 0.095], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, 0.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row4_col0_top_met_E', 'width': 0.46, 'center': [0.8, 0.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, 0.095], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, 0.095], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row4_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, 0.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row4_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row4_col0_top_met_E', 'width': 0.46, 'center': [-0.34, 0.095], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_gate_E': {'name': 'multiplier_0_row0_col0_gate_E', 'width': 4.48, 'center': [0.14, -0.405], 'orientation': 0.0, 'layer': [30, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, -0.405], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, -0.405], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, -0.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_top_met_E', 'width': 0.46, 'center': [0.8, -0.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_top_met_E', 'width': 4.0, 'center': [0.8, -0.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, -0.405], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, -0.405], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row3_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, -0.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row3_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row3_col0_top_met_E', 'width': 0.46, 'center': [-0.34, -0.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_top_met_E': {'name': 'multiplier_0_leftsd_top_met_E', 'width': 4.0, 'center': [-0.34, -0.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_plusdoped_E': {'name': 'multiplier_0_plusdoped_E', 'width': 4.46, 'center': [1.12, -0.405], 'orientation': 0.0, 'layer': [32, 0], 'port_type': 'electrical'},
#  'multiplier_0_diff_E': {'name': 'multiplier_0_diff_E', 'width': 4.0, 'center': [0.89, -0.405], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, -0.905], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, -0.905], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, -0.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_E', 'width': 0.46, 'center': [0.8, -0.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, -0.905], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, -0.905], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row2_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, -0.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row2_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row2_col0_top_met_E', 'width': 0.46, 'center': [-0.34, -0.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, -1.405], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, -1.405], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, -1.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_E', 'width': 0.46, 'center': [0.8, -1.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, -1.405], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, -1.405], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row1_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, -1.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row1_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row1_col0_top_met_E', 'width': 0.46, 'center': [-0.34, -1.405], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_E', 'width': 0.36, 'center': [0.75, -1.905], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_E', 'width': 0.22, 'center': [0.68, -1.905], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_E', 'width': 0.46, 'center': [0.8, -1.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_E': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_E', 'width': 0.46, 'center': [0.8, -1.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_layer_E': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_layer_E', 'width': 0.36, 'center': [-0.39, -1.905], 'orientation': 0.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_via_E': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_via_E', 'width': 0.22, 'center': [-0.46, -1.905], 'orientation': 0.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_bottom_met_E': {'name': 'multiplier_0_leftsd_array_row0_col0_bottom_met_E', 'width': 0.46, 'center': [-0.34, -1.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_leftsd_array_row0_col0_top_met_E': {'name': 'multiplier_0_leftsd_array_row0_col0_top_met_E', 'width': 0.46, 'center': [-0.34, -1.905], 'orientation': 0.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_gate_E': {'name': 'multiplier_0_gate_E', 'width': 0.5, 'center': [0.25, -3.195], 'orientation': 0.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'gate_E': {'name': 'gate_E', 'width': 0.5, 'center': [0.25, -3.195], 'orientation': 0.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_S', 'width': 0.36, 'center': [0.57, -2.085], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_S', 'width': 0.22, 'center': [0.57, -2.015], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_S', 'width': 0.46, 'center': [0.57, -2.135], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_S', 'width': 0.46, 'center': [0.57, -2.135], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_S', 'width': 0.36, 'center': [0.57, -1.585], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_S', 'width': 0.22, 'center': [0.57, -1.515], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_S', 'width': 0.46, 'center': [0.57, -1.635], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_S', 'width': 0.46, 'center': [0.57, -1.635], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_S', 'width': 0.36, 'center': [0.57, -1.085], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_S', 'width': 0.22, 'center': [0.57, -1.015], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_S', 'width': 0.46, 'center': [0.57, -1.135], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_S', 'width': 0.46, 'center': [0.57, -1.135], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_layer_S', 'width': 0.36, 'center': [0.57, -0.585], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_S': {'name': 'multiplier_0_row0_col0_rightsd_array_row3_col0_bottom_via_S', 'width': 0.22, 'center': [0.57, -0.515], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
# ...
#  'tie_S_array_row0_col1_bottom_via_S': {'name': 'tie_S_array_row0_col1_bottom_via_S', 'width': 0.22, 'center': [0.4, -4.195], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_S_array_row0_col1_bottom_met_S': {'name': 'tie_S_array_row0_col1_bottom_met_S', 'width': 0.5, 'center': [0.4, -4.335], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_S_array_row0_col1_top_met_S': {'name': 'tie_S_array_row0_col1_top_met_S', 'width': 0.5, 'center': [0.4, -4.335], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_N_bottom_lay_S': {'name': 'tie_N_bottom_lay_S', 'width': 1.16, 'center': [0.0, 3.905], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_N_top_met_S': {'name': 'tie_N_top_met_S', 'width': 3.16, 'center': [0.0, 3.835], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_S_bottom_lay_S': {'name': 'tie_S_bottom_lay_S', 'width': 1.16, 'center': [0.0, -4.265], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_S_top_met_S': {'name': 'tie_S_top_met_S', 'width': 3.16, 'center': [0.0, -4.335], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_N_array_row0_col0_bottom_layer_S': {'name': 'tie_N_array_row0_col0_bottom_layer_S', 'width': 0.36, 'center': [-0.4, 3.905], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_N_array_row0_col0_bottom_via_S': {'name': 'tie_N_array_row0_col0_bottom_via_S', 'width': 0.22, 'center': [-0.4, 3.975], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_N_array_row0_col0_bottom_met_S': {'name': 'tie_N_array_row0_col0_bottom_met_S', 'width': 0.5, 'center': [-0.4, 3.835], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_N_array_row0_col0_top_met_S': {'name': 'tie_N_array_row0_col0_top_met_S', 'width': 0.5, 'center': [-0.4, 3.835], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_S_array_row0_col0_bottom_layer_S': {'name': 'tie_S_array_row0_col0_bottom_layer_S', 'width': 0.36, 'center': [-0.4, -4.265], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_S_array_row0_col0_bottom_via_S': {'name': 'tie_S_array_row0_col0_bottom_via_S', 'width': 0.22, 'center': [-0.4, -4.195], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_S_array_row0_col0_bottom_met_S': {'name': 'tie_S_array_row0_col0_bottom_met_S', 'width': 0.5, 'center': [-0.4, -4.335], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_S_array_row0_col0_top_met_S': {'name': 'tie_S_array_row0_col0_top_met_S', 'width': 0.5, 'center': [-0.4, -4.335], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_tl_bottom_layer_S': {'name': 'tie_tl_bottom_layer_S', 'width': 0.5, 'center': [-1.74, 3.835], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_tl_bottom_via_S': {'name': 'tie_tl_bottom_via_S', 'width': 0.26, 'center': [-1.74, 3.955], 'orientation': 270.0, 'layer': [35, 0], 'port_type': 'electrical'},
#  'tie_tl_bottom_met_S': {'name': 'tie_tl_bottom_met_S', 'width': 0.5, 'center': [-1.74, 3.835], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_tl_top_met_S': {'name': 'tie_tl_top_met_S', 'width': 0.5, 'center': [-1.74, 3.835], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_bl_bottom_layer_S': {'name': 'tie_bl_bottom_layer_S', 'width': 0.5, 'center': [-1.74, -4.335], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_bl_bottom_via_S': {'name': 'tie_bl_bottom_via_S', 'width': 0.26, 'center': [-1.74, -4.215], 'orientation': 270.0, 'layer': [35, 0], 'port_type': 'electrical'},
#  'tie_bl_bottom_met_S': {'name': 'tie_bl_bottom_met_S', 'width': 0.5, 'center': [-1.74, -4.335], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_bl_top_met_S': {'name': 'tie_bl_top_met_S', 'width': 0.5, 'center': [-1.74, -4.335], 'orientation': 270.0, 'layer': [36, 0], 'port_type': 'electrical'},
#  'tie_W_array_row0_col0_bottom_layer_S': {'name': 'tie_W_array_row0_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -3.43], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row0_col0_bottom_via_S': {'name': 'tie_W_array_row0_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -3.36], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row0_col0_bottom_met_S': {'name': 'tie_W_array_row0_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -3.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row0_col0_top_met_S': {'name': 'tie_W_array_row0_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -3.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row1_col0_bottom_layer_S': {'name': 'tie_W_array_row1_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -2.93], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row1_col0_bottom_via_S': {'name': 'tie_W_array_row1_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -2.86], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row1_col0_bottom_met_S': {'name': 'tie_W_array_row1_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -2.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row1_col0_top_met_S': {'name': 'tie_W_array_row1_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -2.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row2_col0_bottom_layer_S': {'name': 'tie_W_array_row2_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -2.43], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row2_col0_bottom_via_S': {'name': 'tie_W_array_row2_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -2.36], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row2_col0_bottom_met_S': {'name': 'tie_W_array_row2_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -2.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row2_col0_top_met_S': {'name': 'tie_W_array_row2_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -2.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row3_col0_bottom_layer_S': {'name': 'tie_W_array_row3_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -1.93], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row3_col0_bottom_via_S': {'name': 'tie_W_array_row3_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -1.86], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row3_col0_bottom_met_S': {'name': 'tie_W_array_row3_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -1.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row3_col0_top_met_S': {'name': 'tie_W_array_row3_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -1.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row4_col0_bottom_layer_S': {'name': 'tie_W_array_row4_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -1.43], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row4_col0_bottom_via_S': {'name': 'tie_W_array_row4_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -1.36], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row4_col0_bottom_met_S': {'name': 'tie_W_array_row4_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -1.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row4_col0_top_met_S': {'name': 'tie_W_array_row4_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -1.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row5_col0_bottom_layer_S': {'name': 'tie_W_array_row5_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -0.93], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row5_col0_bottom_via_S': {'name': 'tie_W_array_row5_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -0.86], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row5_col0_bottom_met_S': {'name': 'tie_W_array_row5_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -0.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row5_col0_top_met_S': {'name': 'tie_W_array_row5_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -0.98], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row6_col0_bottom_layer_S': {'name': 'tie_W_array_row6_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, -0.43], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row6_col0_bottom_via_S': {'name': 'tie_W_array_row6_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, -0.36], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row6_col0_bottom_met_S': {'name': 'tie_W_array_row6_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, -0.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row6_col0_top_met_S': {'name': 'tie_W_array_row6_col0_top_met_S', 'width': 0.46, 'center': [-1.76, -0.48], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row7_col0_bottom_layer_S': {'name': 'tie_W_array_row7_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 0.07], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row7_col0_bottom_via_S': {'name': 'tie_W_array_row7_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 0.14], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row7_col0_bottom_met_S': {'name': 'tie_W_array_row7_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 0.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row7_col0_top_met_S': {'name': 'tie_W_array_row7_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 0.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row8_col0_bottom_layer_S': {'name': 'tie_W_array_row8_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 0.57], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row8_col0_bottom_via_S': {'name': 'tie_W_array_row8_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 0.64], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row8_col0_bottom_met_S': {'name': 'tie_W_array_row8_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 0.52], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row8_col0_top_met_S': {'name': 'tie_W_array_row8_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 0.52], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row9_col0_bottom_layer_S': {'name': 'tie_W_array_row9_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 1.07], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row9_col0_bottom_via_S': {'name': 'tie_W_array_row9_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 1.14], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row9_col0_bottom_met_S': {'name': 'tie_W_array_row9_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 1.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row9_col0_top_met_S': {'name': 'tie_W_array_row9_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 1.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row10_col0_bottom_layer_S': {'name': 'tie_W_array_row10_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 1.57], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row10_col0_bottom_via_S': {'name': 'tie_W_array_row10_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 1.64], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row10_col0_bottom_met_S': {'name': 'tie_W_array_row10_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 1.52], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row10_col0_top_met_S': {'name': 'tie_W_array_row10_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 1.52], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row11_col0_bottom_layer_S': {'name': 'tie_W_array_row11_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 2.07], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row11_col0_bottom_via_S': {'name': 'tie_W_array_row11_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 2.14], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row11_col0_bottom_met_S': {'name': 'tie_W_array_row11_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 2.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row11_col0_top_met_S': {'name': 'tie_W_array_row11_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 2.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row12_col0_bottom_layer_S': {'name': 'tie_W_array_row12_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 2.57], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row12_col0_bottom_via_S': {'name': 'tie_W_array_row12_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 2.64], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row12_col0_bottom_met_S': {'name': 'tie_W_array_row12_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 2.52], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row12_col0_top_met_S': {'name': 'tie_W_array_row12_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 2.52], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row13_col0_bottom_layer_S': {'name': 'tie_W_array_row13_col0_bottom_layer_S', 'width': 0.36, 'center': [-1.76, 3.07], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_array_row13_col0_bottom_via_S': {'name': 'tie_W_array_row13_col0_bottom_via_S', 'width': 0.22, 'center': [-1.76, 3.14], 'orientation': 270.0, 'layer': [33, 0], 'port_type': 'electrical'},
#  'tie_W_array_row13_col0_bottom_met_S': {'name': 'tie_W_array_row13_col0_bottom_met_S', 'width': 0.46, 'center': [-1.76, 3.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_array_row13_col0_top_met_S': {'name': 'tie_W_array_row13_col0_top_met_S', 'width': 0.46, 'center': [-1.76, 3.02], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'tie_W_bottom_lay_S': {'name': 'tie_W_bottom_lay_S', 'width': 0.36, 'center': [-1.76, -3.43], 'orientation': 270.0, 'layer': [22, 0], 'port_type': 'electrical'},
#  'tie_W_top_met_S': {'name': 'tie_W_top_met_S', 'width': 0.46, 'center': [-1.76, -3.905], 'orientation': 270.0, 'layer': [34, 0], 'port_type': 'electrical'},
#  'well_W': {'name': 'well_W', 'width': 9.09, 'center': [-2.22, 0.0], 'orientation': 180, 'layer': [204, 0], 'port_type': 'electrical'},
#  'well_N': {'name': 'well_N', 'width': 4.44, 'center': [0.0, 4.545], 'orientation': 90, 'layer': [204, 0], 'port_type': 'electrical'},
#  'well_E': {'name': 'well_E', 'width': 9.09, 'center': [2.22, 0.0], 'orientation': 0, 'layer': [204, 0], 'port_type': 'electrical'},
#  'well_S': {'name': 'well_S', 'width': 4.44, 'center': [0.0, -4.545], 'orientation': 270, 'layer': [204, 0], 'port_type': 'electrical'}}

# %%
# stdp_comp.show()
display_component(current_mirror, scale = 1,path=".")

# %%
# =========================================================================
# 4. ADD AVDD & AVSS POWER RAILS AND CONNECT SUPPLY NODES
# =========================================================================

# https://gemini.google.com/app/131a537106def8cd
# Calculate full horizontal span of the cell to draw supply rails
bbox = evaluate_bbox(current_mirror)
top_y = current_mirror.ymax + 2.0
bottom_y = current_mirror.ymin - 2.0

# Draw horizontal metal2 power rails
avdd_rail = current_mirror << gf.components.rectangle(
    size=(bbox[0]+4, 1.0), 
    layer=pdk.get_layer("metal2")
)
avdd_rail.move((-2, top_y))

avss_rail = current_mirror << gf.components.rectangle(
    size=(bbox[0]+4, 1.0), 
    layer=pdk.get_layer("metal2")
)
avss_rail.move((-2, bottom_y))

viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.

#via en vdd
vdd_via = current_mirror << viam2m3
vdd_via.move((bbox[0]/2, top_y + 0.5))

#via en vss
vss_via = current_mirror << viam2m3
vss_via.move((bbox[0]/2, bottom_y + 0.5))

# Add global ports for the supply rails
current_mirror.add_port("Avdd", center=(bbox[0]/2, top_y + 0.5), width=1.0, orientation=180, layer=pdk.get_layer("metal3"), port_type="electrical")
current_mirror.add_port("Avss", center=(bbox[0]/2, bottom_y + 0.5), width=1.0, orientation=180, layer=pdk.get_layer("metal3"), port_type="electrical")

# add label to those global ports 
current_mirror.add_label(text="Avdd", position=(bbox[0]/2, top_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1.1)
current_mirror.add_label(text="Avss", position=(bbox[0]/2, bottom_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1.1)
# Out:
# Label(text='Avss', origin=(6.8, 2.5), layer=(42, 10))

# %%
# stdp_comp.show()
display_component(current_mirror, scale = 1,path=".")

# %%
#Adding VIAS
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
node_A_via = current_mirror << viam2m3
node_A_via_2 = current_mirror << viam2m3

node_A_via.move(m4_ref.ports["gate_S"].center).movex(2.8).movey(-5)
node_A_via_2.move(m4_ref.ports["gate_S"].center).movex(-2.5).movey(-5)

node_B_via = current_mirror << viam2m3
node_B_via.move(m3_ref.ports["gate_S"].center).movex(2.8).movey(-2)
# Out:
# ComponentReference (parent Component "via_stack_039ab1c9$1", ports ['bottom_layer_W', 'bottom_layer_N', 'bottom_layer_E', 'bottom_layer_S', 'bottom_via_W', 'bottom_via_N', 'bottom_via_E', 'bottom_via_S', 'bottom_met_W', 'bottom_met_N', 'bottom_met_E', 'bottom_met_S', 'top_met_W', 'top_met_N', 'top_met_E', 'top_met_S'], origin (10.68, 14.189999999999998), rotation 0.0, x_reflection False)

# %%
# =========================================================================
# 5. ADD MET2 PHYSICAL PINS AND LABELS FOR LVS
# =========================================================================

# Map port names to their source port objects
pins_to_create = {
    "A": node_A_via.ports["top_met_N"],
    "B": node_B_via.ports["top_met_N"]
}

for pin_name, port in pins_to_create.items():
    # Extract center position, size, and orientation from port object
    center = port.center
    width = port.width
    height = port.width  # Standard square pin area around the port center

    # 1. Add pin rectangle shape on met2_pin
    pin_ref = current_mirror << gf.components.rectangle(
        size = (width,height),
        layer=pdk.get_layer("metal3")
    )
    pin_ref.move((center[0] - width , center[1] - height))
    
    current_mirror.add_port(pin_name, center=(center[0] - width , center[1] - height), width=1.0, orientation=180, layer=pdk.get_layer("metal3"),  port_type="electrical") 

    # 2. Add text label on met2_pin layer for net identity
    current_mirror.add_label(
        text=pin_name, position=(center[0] - width , center[1] - height), layer=pdk.get_glayer("met3_label"), magnification=1.2
    )

# %%
# Connect PMOS bulks to avdd rail
current_mirror << L_route(pdk, m4_ref.ports["tie_W_top_met_N"], vdd_via.ports["bottom_met_W"])
current_mirror << L_route(pdk, m3_ref.ports["tie_W_top_met_N"], vdd_via.ports["bottom_met_W"])

# Connect NMOS BULKS TO AVSS
current_mirror << L_route(pdk, m1_ref.ports["tie_W_top_met_S"], vss_via.ports["bottom_met_W"])
current_mirror << L_route(pdk, m2_ref.ports["tie_W_top_met_S"], vss_via.ports["bottom_met_W"])

#connecting PMOS SOURCES TO AVDD
current_mirror << L_route(pdk,  m4_ref.ports["multiplier_0_source_E"], m4_ref.ports["tie_E_top_met_N"])  # SOURCE m4
current_mirror << L_route(pdk,  m3_ref.ports["multiplier_0_source_E"], m3_ref.ports["tie_E_top_met_N"])  # SOURCE M3

#CONNECTING NMOS SOURCE TO AVSS
current_mirror << L_route(pdk,  m1_ref.ports["multiplier_0_source_E"], m1_ref.ports["tie_E_top_met_N"]) #m1
current_mirror << L_route(pdk,  m2_ref.ports["multiplier_0_source_E"], m2_ref.ports["tie_E_top_met_N"]) #m2
# Out:
# ComponentReference (parent Component "L_route_1ddc387b", ports ['bottom_layer_W', 'bottom_via_W', 'bottom_met_W', 'top_met_W', 'bottom_layer_N', 'bottom_via_N', 'bottom_met_N', 'top_met_N', 'bottom_layer_E', 'bottom_via_E', 'bottom_met_E', 'top_met_E', 'bottom_layer_S', 'bottom_via_S', 'bottom_met_S', 'top_met_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
#NODE A

current_mirror << L_route(pdk, m4_ref.ports["drain_W"], node_A_via_2.ports["top_met_N"])
current_mirror << L_route(pdk, m1_ref.ports["drain_W"], node_A_via_2.ports["top_met_S"])
current_mirror << L_route(pdk, m4_ref.ports["gate_W"], node_A_via_2.ports["top_met_N"])
current_mirror << L_route(pdk, m1_ref.ports["gate_W"], node_A_via_2.ports["top_met_S"])
current_mirror << straight_route(pdk, node_A_via_2.ports["bottom_met_W"], node_A_via.ports["bottom_met_E"])
current_mirror << L_route(pdk, m2_ref.ports["gate_W"], node_A_via.ports["top_met_S"])

#NODE B
current_mirror << c_route(pdk, m3_ref.ports["drain_E"], node_B_via.ports["bottom_met_E"])
current_mirror << c_route(pdk, m3_ref.ports["gate_E"], node_B_via.ports["bottom_met_E"])
current_mirror << c_route(pdk, m2_ref.ports["drain_W"], node_B_via.ports["bottom_met_W"])
# Out:
# ComponentReference (parent Component "c_route_7ae59be0", ports ['con_N', 'con_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
current_mirror.show()
display_component(current_mirror, scale = 3,path=".")
# Out:
# 2026-08-22 00:46:46.326 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/current_mirror.gds"}

# %%
current_mirror.pprint_ports()
# Out:
# ┏━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name ┃ width ┃ center         ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ Avdd │ 1.0   │ [6.8, 30.68]   │ 180         │ [42, 0] │ electrical │
# │ Avss │ 1.0   │ [6.8, 2.5]     │ 180         │ [42, 0] │ electrical │
# │ A    │ 1.0   │ [4.52, 14.14]  │ 180         │ [42, 0] │ electrical │
# │ B    │ 1.0   │ [10.18, 13.94] │ 180         │ [42, 0] │ electrical │
# └──────┴───────┴────────────────┴─────────────┴─────────┴────────────┘

# %%
evaluate_bbox(current_mirror)
# Out:
# (17.6, 29.18)

# %%
current_mirror_est_area = evaluate_bbox(current_mirror)[0] * evaluate_bbox(current_mirror)[1]
current_mirror_est_area
# Out:
# 513.568

# %%
m1_ref.info['netlist'].generate_netlist()
# Out:
# '\n\n.subckt NMOS D G S B l=0.28 w=4 m=1 dm=1 \nXMAIN   D G S B nfet_03v3 l={l} w={w} m={m}\n.ends NMOS'

# %%
# netlist = Netlist(circuit_name="current_mirror", nodes=['avss', 'avdd', 'B', 'A'])
# netlist.connect_netlist(m1_ref.info['netlist'], [('D', 'A'),   ('G', 'A'),   ('S', 'avss'), ('B', 'avss')])
# netlist.connect_netlist(m2_ref.info['netlist'], [('D', 'B'),   ('G', 'A'),   ('S', 'avss'), ('B', 'avss')])
# netlist.connect_netlist(m3_ref.info['netlist'], [('D', 'B'),   ('G', 'B'),   ('S', 'avdd'), ('B', 'avdd')])
# netlist.connect_netlist(m4_ref.info['netlist'], [('D', 'A'),   ('G', 'A'),   ('S', 'avdd'), ('B', 'avdd')])

# current_mirror.info["netlist"] = netlist
# print(current_mirror.info['netlist'].generate_netlist())

# %%
import os
from pathlib import Path
import tempfile

path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/current_mirror/"
# path_to_dir = "/foss/designs/libs/snn_analog/current_mirror/"
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name=current_mirror.name

pex_path = path_to_dir + f"{current_mirror.name}.spice"
gds_path = path_to_dir + f"{current_mirror.name}.gds"
current_mirror.write_gds(str(gds_path))


magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
exit
"""

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# 2026-08-22 00:46:46.746 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/CapiMagics/designs/libs/snn_analog/current_mirror/current_mirror.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "current_mirror".
# Reading "L_route_5c650b72".
# Reading "rectangle_2d1cdd23$1".
# Reading "c_route_9698ebce".
# Reading "rectangle_efcb33f4".
# Reading "M1".
# Reading "straight_route_87544b93".
# Reading "L_route_32991990".
# Reading "via_stack_039ab1c9$1".
# Reading "c_route_7ae59be0".
# Reading "L_route_1ddc387b".
# Reading "L_route_8faa4cf1".
# Reading "via_stack_039ab1c9".
# Reading "L_route_d42bcf03".
# Reading "L_route_607d0a8e".
# Reading "M4".
# Reading "L_route_be6b2926".
# Reading "rectangle_2d1cdd23".
# Reading "L_route_e7c7b2cc".
# Reading "L_route_b5c73ab1".
# Reading "L_route_27dc8161".
# Reading "compass_efcb33f4".
# Reading "compass_2d1cdd23$2".
# Reading "c_route_10941356".
# Reading "M3".
# Reading "rectangle_efcb33f4$1".
# Reading "L_route_27eaa236".
# Reading "L_route_fff7a4f3".
# Reading "compass_2d1cdd23$3".
# Reading "compass_efcb33f4$1".
# Reading "M2".
# Reading "L_route_b6b5f7da".
# Extracting L_route_5c650b72 into L_route_5c650b72.ext:
# Extracting via_stack_039ab1c9$1 into via_stack_039ab1c9$1.ext:
# Extracting L_route_d42bcf03 into L_route_d42bcf03.ext:
# Extracting L_route_27eaa236 into L_route_27eaa236.ext:
# Extracting L_route_b6b5f7da into L_route_b6b5f7da.ext:
# Extracting c_route_7ae59be0 into c_route_7ae59be0.ext:
# Extracting L_route_8faa4cf1 into L_route_8faa4cf1.ext:
# Extracting via_stack_039ab1c9 into via_stack_039ab1c9.ext:
# Extracting L_route_e7c7b2cc into L_route_e7c7b2cc.ext:
# Extracting L_route_27dc8161 into L_route_27dc8161.ext:
# Extracting compass_2d1cdd23$2 into compass_2d1cdd23$2.ext:
# Extracting rectangle_2d1cdd23 into rectangle_2d1cdd23.ext:
# Extracting M3 into M3.ext:
# Extracting M1 into M1.ext:
# Extracting straight_route_87544b93 into straight_route_87544b93.ext:
# Extracting L_route_be6b2926 into L_route_be6b2926.ext:
# Extracting M2 into M2.ext:
# Extracting compass_2d1cdd23$3 into compass_2d1cdd23$3.ext:
# Extracting rectangle_2d1cdd23$1 into rectangle_2d1cdd23$1.ext:
# Extracting c_route_10941356 into c_route_10941356.ext:
# Extracting L_route_1ddc387b into L_route_1ddc387b.ext:
# Extracting c_route_9698ebce into c_route_9698ebce.ext:
# Extracting compass_efcb33f4$1 into compass_efcb33f4$1.ext:
# Extracting rectangle_efcb33f4$1 into rectangle_efcb33f4$1.ext:
# Extracting L_route_32991990 into L_route_32991990.ext:
# Extracting L_route_607d0a8e into L_route_607d0a8e.ext:
# Extracting M4 into M4.ext:
# Extracting L_route_b5c73ab1 into L_route_b5c73ab1.ext:
# Extracting L_route_fff7a4f3 into L_route_fff7a4f3.ext:
# Extracting compass_efcb33f4 into compass_efcb33f4.ext:
# Extracting rectangle_efcb33f4 into rectangle_efcb33f4.ext:
# Extracting current_mirror into current_mirror.ext:
# exttosim finished.
# Adding  Avdd; Tnew = 0.01ns, Told = 0.00ns
# Adding  Avss; Tnew = 0.04ns, Told = 0.00ns
# Adding  A; Tnew = 0.01ns, Told = 0.00ns
# Adding  B; Tnew = 0.02ns, Told = 0.00ns
# Total Nets: 14
# Nets extracted: 4 (0.285714)
# Nets output: 4 (0.285714)
# exttospice finished.

# %%
drc_result = gf180.drc_magic(current_mirror, current_mirror.name)
# Out:
# 2026-08-22 00:46:47.024 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp62po5imk/current_mirror.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmp62po5imk/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "current_mirror".
# Reading "L_route_5c650b72".
# Reading "rectangle_2d1cdd23$1".
# Reading "c_route_9698ebce".
# Reading "rectangle_efcb33f4".
# Reading "M1".
# Reading "straight_route_87544b93".
# Reading "L_route_32991990".
# Reading "via_stack_039ab1c9$1".
# Reading "c_route_7ae59be0".
# Reading "L_route_1ddc387b".
# Reading "L_route_8faa4cf1".
# Reading "via_stack_039ab1c9".
# Reading "L_route_d42bcf03".
# Reading "L_route_607d0a8e".
# Reading "M4".
# Reading "L_route_be6b2926".
# Reading "rectangle_2d1cdd23".
# Reading "L_route_e7c7b2cc".
# Reading "L_route_b5c73ab1".
# Reading "L_route_27dc8161".
# Reading "compass_efcb33f4".
# Reading "compass_2d1cdd23$2".
# Reading "c_route_10941356".
# Reading "M3".
# Reading "rectangle_efcb33f4$1".
# Reading "L_route_27eaa236".
# Reading "L_route_fff7a4f3".
# Reading "compass_2d1cdd23$3".
# Reading "compass_efcb33f4$1".
# Reading "M2".
# Reading "L_route_b6b5f7da".
# [INFO]: Loading current_mirror
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmp62po5imk/current_mirror.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: c_route_b76fbf9c.ext
# Deleted: c_route_72b22e32.ext
# Deleted: M3.ext
# Deleted: rectangle_2d1cdd23$1.ext
# Deleted: xm7.ext
# Deleted: L_route_35c6b3df.ext
# Deleted: compass_2d3cd8bd$158.ext
# Deleted: M2.ext
# Deleted: L_route_b6b5f7da.ext
# Deleted: L_route_126e89cd.ext
# Deleted: c_route_3cdfbc18.ext
# Deleted: L_route_f4df1e18.ext
# Deleted: compass_2d1cdd23$3.ext
# Deleted: compass_2d1cdd23$2.ext
# Deleted: L_route_fff7a4f3.ext
# Deleted: rectangle_2d3cd8bd$4.ext
# Deleted: rectangle_2d3cd8bd$1.ext
# Deleted: L_route_5c650b72.ext
# Deleted: xm10.ext
# Deleted: L_route_4190e7d0.ext
# Deleted: xm9.ext
# Deleted: rectangle_2d1cdd23.ext
# Deleted: c_route_c296568a.ext
# Deleted: straight_route_2981da30.ext
# Deleted: L_route_1ddc387b.ext
# Deleted: L_route_c596c3c6.ext
# Deleted: via_stack_039ab1c9.ext
# Deleted: compass_fb02b408.ext
# Deleted: via_stack_039ab1c9$1.ext
# Deleted: M4.ext
# Deleted: L_route_7e2865de.ext
# Deleted: rectangle_2d3cd8bd$2.ext
# Deleted: L_route_e7c7b2cc.ext
# Deleted: L_route_c3c26bb8.ext
# Deleted: xm2.ext
# Deleted: L_route_e647fd58.ext
# Deleted: L_route_27eaa236.ext
# Deleted: xm3.ext
# Deleted: L_route_607d0a8e.ext
# Deleted: L_route_4b26df46.ext
# Deleted: c_route_32317408.ext
# Deleted: straight_route_69493452.ext
# Deleted: L_route_be6b2926.ext
# Deleted: compass_2d3cd8bd$155.ext
# Deleted: c_route_9698ebce.ext
# Deleted: L_route_acd180cd.ext
# Deleted: xm6.ext
# Deleted: compass_2d3cd8bd$154.ext
# Deleted: L_route_6e3cca24.ext
# Deleted: straight_route_9a3f94a1.ext
# Deleted: L_route_1de51676.ext
# Deleted: L_route_27dc8161.ext
# Deleted: rectangle_efcb33f4$1.ext
# Deleted: L_route_ff1f98df.ext
# Deleted: compass_2d1cdd23$1.ext
# Deleted: compass_fb02b408$1.ext
# Deleted: c_route_d120be29.ext
# Deleted: rectangle_efcb33f4.ext
# Deleted: c_route_45c4f389.ext
# Deleted: compass_efcb33f4$1.ext
# Deleted: L_route_fceab155.ext
# Deleted: L_route_32991990.ext
# Deleted: L_route_e83029f9.ext
# Deleted: compass_efcb33f4.ext
# Deleted: rectangle_fb02b408.ext
# Deleted: L_route_8faa4cf1.ext
# Deleted: straight_route_f5b9d741.ext
# Deleted: rectangle_2d3cd8bd.ext
# Deleted: L_route_c62ce436.ext
# Deleted: xm4.ext
# Deleted: L_route_bbe813fc.ext
# Deleted: M1.ext
# Deleted: current_mirror.res.ext
# Deleted: c_route_b70cfe11.ext
# Deleted: straight_route_e11b8bb6.ext
# Deleted: L_route_d42bcf03.ext
# Deleted: straight_route_b30f5547.ext
# Deleted: rectangle_fb02b408$1.ext
# Deleted: L_route_0b7dd08b.ext
# Deleted: L_route_52dc3e23.ext
# Deleted: compass_2d3cd8bd$157.ext
# Deleted: c_route_10941356.ext
# Deleted: c_route_7ae59be0.ext
# Deleted: xm5.ext
# Deleted: straight_route_f6aed911.ext
# Deleted: rectangle_2d3cd8bd$3.ext
# Deleted: xm8.ext
# Deleted: L_route_b5c73ab1.ext
# Deleted: L_route_b7898066.ext
# Deleted: current_mirror.ext
# Deleted: straight_route_87544b93.ext
# Deleted: compass_2d3cd8bd$156.ext
# Deleted: L_route_a49f181d.ext
# Deleted: xm11.ext
# Deleted: xm1.ext
# Error deleting current_mirror.res.ext: [Errno 2] No such file or directory: 'current_mirror.res.ext'
# Deleted: current_mirror.nodes
# Deleted: current_mirror.sim

# %%
help(gf180.lvs_netgen)
# Out:
# Help on method lvs_netgen in module glayout.pdk.mappedpdk:
#
# lvs_netgen(layout: gdsfactory.component.Component | str | pathlib.Path, design_name: str, pdk_root: Union[str, pathlib.Path, NoneType] = None, lvs_setup_tcl_file: Union[str, pathlib.Path, NoneType] = None, lvs_schematic_ref_file: Union[str, pathlib.Path, NoneType] = None, magic_drc_file: Union[str, pathlib.Path, NoneType] = None, netlist: Union[str, pathlib.Path, NoneType] = None, output_file_path: Union[str, pathlib.Path, NoneType] = None, copy_intermediate_files: Optional[bool] = False, show_scripts: Optional[bool] = False) -> dict method of glayout.pdk.mappedpdk.MappedPDK instance
#     Runs LVS using netgen on the either the component or the gds file path provided. Requires the design name and the pdk_root to be specified, handles importing the required magicrc and other setup files, if not specified. Accepts overriden lvs_setup_tcl_file, lvs_schematic_ref_file, and magic_drc_file.
#
#     Args:
#         - layout (Component | PathType):
#             - Either the Component or the gds file path to run LVS on
#         - design_name (str):
#             - The designated name of the design
#         - pdk_root (Optional[PathType], optional):
#             - The directory where the pdk files are located.
#             - e.g. - "/usr/bin/miniconda3/share/pdk/". Defaults to None.
#         - lvs_setup_tcl_file (Optional[PathType], optional):
#             - The .tcl file with setup commands for LVS.
#             - Defaults to None.
#         - lvs_schematic_ref_file (Optional[PathType], optional):
#             - The .spice file with subckt references for LVS.
#             - Defaults to None.
#         - magic_drc_file (Optional[PathType], optional):
#             - The .magicrc file for your PDK of choice.
#             - Defaults to None.
#         - netlist (Optional[PathType], optional):
#             - The .cdl or .spice file for the netlist.
#             - Defaults to None.
#         - output_file_path (Optional[PathType], optional):
#             - The path to the report file
#             - Will write the report to regression/lvs/{design_name}/{output_file_path}
#             - Defaults to None.
#         - copy_intermediate_files (Optional[bool], optional):
#             - If True, copies intermediate files to the currenty working directory (lvsmag, pex spice, prepex spice).
#             - Defaults to False.
#
#     Raises:
#         - NotImplementedError:
#             - If the LVS cannot be run!
#         - ValueError:
#             - If the netlist file is not provided!
#         - RuntimeError:
#             - If the netgen command is not found in the system!
#             - If the magic command is not found in the system!
#         - RuntimeError:
#             - If the magic DRC file is not found in the system!
#         - ValueError:
#             - If the path to the netlist file is not a file!
#
#     Returns:
#         dict: a dictionary containing the result string and the subprocess code

# %%
gf180.lvs_netgen(
    layout=current_mirror,
    design_name = str(current_mirror.name),
    pdk_root = Path(os.environ['PDKPATH']),
    lvs_setup_tcl_file = Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    lvs_schematic_ref_file = Path(str(path_to_dir + "current_mirror.spice")),
    netlist = Path(str(path_to_dir + "current_mirror_sch.spice")),
    output_file_path =  Path(str(path_to_dir))
)
# Out:
# 2026-08-22 00:46:47.460 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpvjti29j1/current_mirror.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "current_mirror".
# Reading "L_route_5c650b72".
# Reading "rectangle_2d1cdd23$1".
# Reading "c_route_9698ebce".
# Reading "rectangle_efcb33f4".
# Reading "M1".
# Reading "straight_route_87544b93".
# Reading "L_route_32991990".
# Reading "via_stack_039ab1c9$1".
# Reading "c_route_7ae59be0".
# Reading "L_route_1ddc387b".
# Reading "L_route_8faa4cf1".
# Reading "via_stack_039ab1c9".
# Reading "L_route_d42bcf03".
# Reading "L_route_607d0a8e".
# Reading "M4".
# Reading "L_route_be6b2926".
# Reading "rectangle_2d1cdd23".
# Reading "L_route_e7c7b2cc".
# Reading "L_route_b5c73ab1".
# Reading "L_route_27dc8161".
# Reading "compass_efcb33f4".
# Reading "compass_2d1cdd23$2".
# Reading "c_route_10941356".
# Reading "M3".
# Reading "rectangle_efcb33f4$1".
# Reading "L_route_27eaa236".
# Reading "L_route_fff7a4f3".
# Reading "compass_2d1cdd23$3".
# Reading "compass_efcb33f4$1".
# Reading "M2".
# Reading "L_route_b6b5f7da".
# Extracting L_route_5c650b72 into L_route_5c650b72.ext:
# Extracting via_stack_039ab1c9$1 into via_stack_039ab1c9$1.ext:
# Extracting L_route_d42bcf03 into L_route_d42bcf03.ext:
# Extracting L_route_27eaa236 into L_route_27eaa236.ext:
# Extracting L_route_b6b5f7da into L_route_b6b5f7da.ext:
# Extracting c_route_7ae59be0 into c_route_7ae59be0.ext:
# Extracting L_route_8faa4cf1 into L_route_8faa4cf1.ext:
# Extracting via_stack_039ab1c9 into via_stack_039ab1c9.ext:
# Extracting L_route_e7c7b2cc into L_route_e7c7b2cc.ext:
# Extracting L_route_27dc8161 into L_route_27dc8161.ext:
# Extracting compass_2d1cdd23$2 into compass_2d1cdd23$2.ext:
# Extracting rectangle_2d1cdd23 into rectangle_2d1cdd23.ext:
# Extracting M3 into M3.ext:
# Extracting M1 into M1.ext:
# Extracting straight_route_87544b93 into straight_route_87544b93.ext:
# Extracting L_route_be6b2926 into L_route_be6b2926.ext:
# Extracting M2 into M2.ext:
# Extracting compass_2d1cdd23$3 into compass_2d1cdd23$3.ext:
# Extracting rectangle_2d1cdd23$1 into rectangle_2d1cdd23$1.ext:
# Extracting c_route_10941356 into c_route_10941356.ext:
# Extracting L_route_1ddc387b into L_route_1ddc387b.ext:
# Extracting c_route_9698ebce into c_route_9698ebce.ext:
# Extracting compass_efcb33f4$1 into compass_efcb33f4$1.ext:
# Extracting rectangle_efcb33f4$1 into rectangle_efcb33f4$1.ext:
# Extracting L_route_32991990 into L_route_32991990.ext:
# Extracting L_route_607d0a8e into L_route_607d0a8e.ext:
# Extracting M4 into M4.ext:
# Extracting L_route_b5c73ab1 into L_route_b5c73ab1.ext:
# Extracting L_route_fff7a4f3 into L_route_fff7a4f3.ext:
# Extracting compass_efcb33f4 into compass_efcb33f4.ext:
# Extracting rectangle_efcb33f4 into rectangle_efcb33f4.ext:
# Extracting current_mirror into current_mirror.ext:
# exttospice finished.
# Extracting L_route_5c650b72 into L_route_5c650b72.ext:
# Extracting via_stack_039ab1c9$1 into via_stack_039ab1c9$1.ext:
# Extracting L_route_d42bcf03 into L_route_d42bcf03.ext:
# Extracting L_route_27eaa236 into L_route_27eaa236.ext:
# Extracting L_route_b6b5f7da into L_route_b6b5f7da.ext:
# Extracting c_route_7ae59be0 into c_route_7ae59be0.ext:
# Extracting L_route_8faa4cf1 into L_route_8faa4cf1.ext:
# Extracting via_stack_039ab1c9 into via_stack_039ab1c9.ext:
# Extracting L_route_e7c7b2cc into L_route_e7c7b2cc.ext:
# Extracting L_route_27dc8161 into L_route_27dc8161.ext:
# Extracting compass_2d1cdd23$2 into compass_2d1cdd23$2.ext:
# Extracting rectangle_2d1cdd23 into rectangle_2d1cdd23.ext:
# Extracting M3 into M3.ext:
# Extracting M1 into M1.ext:
# Extracting straight_route_87544b93 into straight_route_87544b93.ext:
# Extracting L_route_be6b2926 into L_route_be6b2926.ext:
# Extracting M2 into M2.ext:
# Extracting compass_2d1cdd23$3 into compass_2d1cdd23$3.ext:
# Extracting rectangle_2d1cdd23$1 into rectangle_2d1cdd23$1.ext:
# Extracting c_route_10941356 into c_route_10941356.ext:
# Extracting L_route_1ddc387b into L_route_1ddc387b.ext:
# Extracting c_route_9698ebce into c_route_9698ebce.ext:
# Extracting compass_efcb33f4$1 into compass_efcb33f4$1.ext:
# Extracting rectangle_efcb33f4$1 into rectangle_efcb33f4$1.ext:
# Extracting L_route_32991990 into L_route_32991990.ext:
# Extracting L_route_607d0a8e into L_route_607d0a8e.ext:
# Extracting M4 into M4.ext:
# Extracting L_route_b5c73ab1 into L_route_b5c73ab1.ext:
# Extracting L_route_fff7a4f3 into L_route_fff7a4f3.ext:
# Extracting compass_efcb33f4 into compass_efcb33f4.ext:
# Extracting rectangle_efcb33f4 into rectangle_efcb33f4.ext:
# Extracting current_mirror into current_mirror.ext:
# exttosim finished.
# Extracting L_route_5c650b72 into L_route_5c650b72.ext:
# Extracting via_stack_039ab1c9$1 into via_stack_039ab1c9$1.ext:
# Extracting L_route_d42bcf03 into L_route_d42bcf03.ext:
# Extracting L_route_27eaa236 into L_route_27eaa236.ext:
# Extracting L_route_b6b5f7da into L_route_b6b5f7da.ext:
# Extracting c_route_7ae59be0 into c_route_7ae59be0.ext:
# Extracting L_route_8faa4cf1 into L_route_8faa4cf1.ext:
# Extracting via_stack_039ab1c9 into via_stack_039ab1c9.ext:
# Extracting L_route_e7c7b2cc into L_route_e7c7b2cc.ext:
# Extracting L_route_27dc8161 into L_route_27dc8161.ext:
# Extracting compass_2d1cdd23$2 into compass_2d1cdd23$2.ext:
# Extracting rectangle_2d1cdd23 into rectangle_2d1cdd23.ext:
# Extracting M3 into M3.ext:
# Extracting M1 into M1.ext:
# Extracting straight_route_87544b93 into straight_route_87544b93.ext:
# Extracting L_route_be6b2926 into L_route_be6b2926.ext:
# Extracting M2 into M2.ext:
# Extracting compass_2d1cdd23$3 into compass_2d1cdd23$3.ext:
# Extracting rectangle_2d1cdd23$1 into rectangle_2d1cdd23$1.ext:
# Extracting c_route_10941356 into c_route_10941356.ext:
# Extracting L_route_1ddc387b into L_route_1ddc387b.ext:
# Extracting c_route_9698ebce into c_route_9698ebce.ext:
# Extracting compass_efcb33f4$1 into compass_efcb33f4$1.ext:
# Extracting rectangle_efcb33f4$1 into rectangle_efcb33f4$1.ext:
# Extracting L_route_32991990 into L_route_32991990.ext:
# Extracting L_route_607d0a8e into L_route_607d0a8e.ext:
# Extracting M4 into M4.ext:
# Extracting L_route_b5c73ab1 into L_route_b5c73ab1.ext:
# Extracting L_route_fff7a4f3 into L_route_fff7a4f3.ext:
# Extracting compass_efcb33f4 into compass_efcb33f4.ext:
# Extracting rectangle_efcb33f4 into rectangle_efcb33f4.ext:
# Extracting current_mirror into current_mirror.ext:
# exttospice finished.
#
# Running netgen command: netgen -batch lvs "/tmp/tmpvjti29j1/current_mirror_lvsmag.spice current_mirror" "/tmp/tmpvjti29j1/current_mirror.spice current_mirror" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpvjti29j1/current_mirror_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:02:45 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpvjti29j1/current_mirror_lvsmag.spice for /tmp/tmpvjti29j1/current_mirror_lvsmag.spice current_mirror
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpvjti29j1/current_mirror.spice for /tmp/tmpvjti29j1/current_mirror.spice current_mirror
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Duplicate cell current_mirror in file
# Renaming original cell to current_mirror[[0]]
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Comparison output logged to file /tmp/tmpvjti29j1/current_mirror_lvs.rpt
# Logging to file "/tmp/tmpvjti29j1/current_mirror_lvs.rpt" enabled
# Circuit pfet_03v3 contains no devices.
# Circuit nfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'M3'
# Circuit M3 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M3'
# Circuit M3 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits M3 M3
#
# Flattening instances of M3 in file /tmp/tmpvjti29j1/current_mirror_lvsmag.spice
# Flattening instances of M3 in file /tmp/tmpvjti29j1/current_mirror.spice
#
# Contents of circuit 1:  Circuit: 'M1'
# Circuit M1 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M1'
# Circuit M1 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits M1 M1
#
# Flattening instances of M1 in file /tmp/tmpvjti29j1/current_mirror_lvsmag.spice
# Flattening instances of M1 in file /tmp/tmpvjti29j1/current_mirror.spice
#
# Contents of circuit 1:  Circuit: 'M4'
# Circuit M4 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M4'
# Circuit M4 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits M4 M4
#
# Flattening instances of M4 in file /tmp/tmpvjti29j1/current_mirror_lvsmag.spice
# Flattening instances of M4 in file /tmp/tmpvjti29j1/current_mirror.spice
#
# Contents of circuit 1:  Circuit: 'M2'
# Circuit M2 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M2'
# Circuit M2 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits M2 M2
#
# Flattening instances of M2 in file /tmp/tmpvjti29j1/current_mirror_lvsmag.spice
# Flattening instances of M2 in file /tmp/tmpvjti29j1/current_mirror.spice
#
# Contents of circuit 1:  Circuit: 'current_mirror'
# Circuit current_mirror contains 4 device instances.
#   Class: nfet_03v3             instances:   2
#   Class: pfet_03v3             instances:   2
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'current_mirror'
# Circuit current_mirror contains 4 device instances.
#   Class: nfet_03v3             instances:   2
#   Class: pfet_03v3             instances:   2
# Circuit contains 4 nets.
#
# Circuit 1 contains 4 devices, Circuit 2 contains 4 devices.
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#
# Final result:
# Circuits match uniquely.
# .
# Logging to file "/tmp/tmpvjti29j1/current_mirror_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Subcircuit summary:
# Circuit 1: M3                              |Circuit 2: M3
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M3                              |Circuit 2: M3
#
# ---------------------------------------------------------------------------------------
# Net: a_50_n881#                            |Net: a_50_n881#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n170_n881#                          |Net: a_n170_n881#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n50_n1089#                          |Net: a_n50_n1089#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: w_n436_n1309#                         |Net: w_n436_n1309#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M3                              |Circuit 2: M3
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits M3 M3
#
# Subcircuit summary:
# Circuit 1: M1                              |Circuit 2: M1
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M1                              |Circuit 2: M1
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n481#                            |Net: a_28_n481#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n50_n689#                           |Net: a_n50_n689#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n178_n481#                          |Net: a_n178_n481#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n388_n853#                          |Net: a_n388_n853#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M1                              |Circuit 2: M1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits M1 M1
#
# Subcircuit summary:
# Circuit 1: M4                              |Circuit 2: M4
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M4                              |Circuit 2: M4
#
# ---------------------------------------------------------------------------------------
# Net: a_50_n241#                            |Net: a_50_n241#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n170_n241#                          |Net: a_n170_n241#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n50_n449#                           |Net: a_n50_n449#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: w_n436_n669#                          |Net: w_n436_n669#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M4                              |Circuit 2: M4
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits M4 M4
#
# Subcircuit summary:
# Circuit 1: M2                              |Circuit 2: M2
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M2                              |Circuit 2: M2
#
# ---------------------------------------------------------------------------------------
# Net: a_400_n481#                           |Net: a_400_n481#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n400_n689#                          |Net: a_n400_n689#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n520_n481#                          |Net: a_n520_n481#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n730_n853#                          |Net: a_n730_n853#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M2                              |Circuit 2: M2
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits M2 M2
#
# Subcircuit summary:
# Circuit 1: current_mirror                  |Circuit 2: current_mirror
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (2)                              |pfet_03v3 (2)
# nfet_03v3 (2)                              |nfet_03v3 (2)
# Number of devices: 4                       |Number of devices: 4
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# Netlists match uniquely.
#
# Subcircuit pins:
# Circuit 1: current_mirror                  |Circuit 2: current_mirror
# -------------------------------------------|-------------------------------------------
# A                                          |A
# B                                          |B
# Avss                                       |Avss
# Avdd                                       |Avdd
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes current_mirror and current_mirror are equivalent.
#
# Final result: Circuits match uniquely.
# .
# {'magic_subproc_code': 0,
#  'netgen_subproc_code': 0,
#  'result_str': 'LVS run succeeded\nErrors found in LVS report: /tmp/tmpvjti29j1/current_mirror_lvs.rpt'}
