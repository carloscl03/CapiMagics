# %%
# Librerias y configuraciones iniciales

import os
import subprocess

# Intenta cargar variables de entorno desde ~/.bashrc usando bash
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    # Recorre cada línea de salida y agrega las variables al entorno de Python
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    # Si ocurre algún error (timeout, archivo inexistente, etc.), lo ignora
    pass

# Configura la variable PDKPATH si existen PDK_ROOT y PDK en el entorno
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))


# --- Librerías para manejo de layouts y visualización ---
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirige salidas a un widget oculto (útil en notebooks)
hide = widgets.Output()


def display_gds(gds_file, path, scale=3):
    """
    Lee un archivo GDS, lo convierte a SVG, escala la imagen y la muestra inline.
    """
    # Obtiene la celda top-level del GDS
    top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
    top_level_cell.write_svg(os.path.join(path, 'out.svg'))
    
    # Escala la imagen para mejorar la visualización
    fig = sg.fromfile(os.path.join(path, 'out.svg'))
    fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
    fig.save(os.path.join(path, 'out.svg'))

    # Muestra el SVG en el notebook
    IPython.display.display(IPython.display.SVG(os.path.join(path, 'out.svg')))
    os.remove(os.path.join(path, 'out.gds'))  # Limpieza del archivo temporal


def display_component(component, path, scale=3):
    """
    Guarda un componente en GDS y lo muestra usando display_gds.
    """
    with hide:
        component.write_gds(os.path.join(path, 'out.gds'))
    display_gds(os.path.join(path, 'out.gds'), path, scale)


# --- Importación de librerías específicas para layout y PDK ---
import os
import gdsfactory as gf
from gdsfactory import Component
from glayout import MappedPDK, gf180
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring
from glayout.primitives.mimcap import mimcap_array
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter, print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist


# --- Configuración base para dispositivos NMOS y PMOS ---
neurona_config = {
    "pdk": gf180,  # Define el PDK a usar
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation() + 1,  # Espaciado mínimo entre metales
        "routing_metal": "met2",  # Capa metálica principal para ruteo
        "dummy_devices": False,   # No usar dispositivos dummy
        "tie_layers": ("met2", "met1"),  # Capas para conexiones de substrato
        "sd_rmult": 1,  # Multiplicador de source/drain
    },
}

# Parámetros para NMOS
nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2", "met1"),
    "dummy_routes": False
}

# Parámetros para PMOS
pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2", "met1"),
    "dummy_routes": False
}


# --- Creación del componente principal ---
pdk = gf180
neurona_comp = Component(name="neurona_lvs")  # Componente base para la neurona
neurona_comp.name = "neurona_lvs"

# Extrae reglas de layout desde la configuración
rules = neurona_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]

# %%
# Create transistor primitives based on .spice parameters
# M1, M3, M7: PMOS W=0.22u, L=0.28u, nf=1
m_p = pmos(
    pdk,
    width=0.5,                   # Ancho del canal (ajustado respecto al valor SPICE)
    length=0.28*2.27,            # Longitud efectiva (escalada por factor 2.27)
    with_dummy=(False, False),   # No se colocan transistores dummy
    with_substrate_tap=False,    # Sin conexión explícita al substrato
    tie_layers=tie_layers,       # Capas metálicas usadas para conexiones de substrato
    sd_rmult=sd_rmult,           # Multiplicador de ancho en source/drain
    **pmos_kwargs                # Parámetros adicionales definidos previamente
)

# M2, M4, M8: NMOS W=0.22u, L=0.28u, nf=1
m_n = nmos(
    pdk,
    width=0.5,
    length=0.28*2.27,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

# M5: Reset NMOS W=1.25u, L=50u, nf=1 (Long channel device)
m5_reset = nmos(
    pdk,
    width=1.25,                  # Transistor más ancho para reset
    length=50.0,                 # Canal largo (dispositivo de alta resistencia)
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

# XC2: MIM Capacitor (3 parallel caps with 5u x 5u geometry)
cap_mim = mimcap_array(
    pdk,
    size=(15.0, 5.0),             # Cada capacitor mide 5x5 micras
    columns=1,                   # Tres capacitores en paralelo (columna)
    rows=1                       # Una fila
)

# ==============================================================================
# PLACEMENT & INSTANTIATION
# ==============================================================================

# Row 1: PMOS Transistors (M1, M3, M7)
m1_ref = neurona_comp << m_p    # Instancia M1 en el componente neurona
m3_ref = neurona_comp << m_p    # Instancia M3
m7_ref = neurona_comp << m_p    # Instancia M7

# Row 2: Standard NMOS Transistors (M2, M4, M8) placed directly below PMOS
m2_ref = neurona_comp << m_n    # Instancia M2
m4_ref = neurona_comp << m_n    # Instancia M4
m8_ref = neurona_comp << m_n    # Instancia M8

# Placement: Reset NMOS (M5) - Long channel, placed below M2/M4
m5_ref = neurona_comp << m5_reset

# Placement: MIM Capacitor Array (XC2) - Placed adjacent to the inverter core
cap_ref = neurona_comp << cap_mim

# Renombrar instancias para identificación clara en LVS/Netlist
m1_ref.name = "m1"
m3_ref.name = "m3"
m7_ref.name = "m7"
m2_ref.name = "m2"
m4_ref.name = "m4"
m8_ref.name = "m8"
m5_ref.name = "m5"
cap_ref.name = "cap"

# Ensure grid snap compliance (alinear a la grilla de diseño)
# neurona_comp = component_snap_to_grid(neurona_comp)

# Display rendered placement component (visualización en notebook)
# display_component(stdp_comp, "./")
# Out:
# 2026-08-20 22:03:15.693 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
# Funcion para visualizar el layout y realizar DRC
def view_and_check_lvs():
    """
    Función para visualizar el layout de la neurona LVS.
    Muestra el componente y realiza un DRC.
    """
    neurona_comp.show()
    display_component(neurona_comp, scale=2, path=".")
    drc_result = gf180.drc_magic(neurona_comp, neurona_comp.name)

#    # Revisar si hay errores
#    if drc_result.get("errors"):   # si la lista no está vacía
#        print(f"⚠ DRC encontró {len(drc_result['errors'])} violaciones")
#    else:
#        print("✔ DRC limpio: No errors found")
        
    return

# %%
# Calcular coordenadas base para filas
bottom_row = evaluate_bbox(m2_ref)[1]/2
# → Altura de la fila inferior (NMOS), usando la mitad de la dimensión Y de M2

middle_row = bottom_row + evaluate_bbox(m5_ref)[1]
# → Fila intermedia: se coloca justo encima de la fila inferior,
#   sumando la altura del transistor de reset (M5)

top_row = middle_row + evaluate_bbox(m1_ref)[1] + 2
# → Fila superior: encima de la fila intermedia,
#   sumando la altura de un PMOS (M1) y un margen extra de 2 unidades

#-------------------------------------------------------------------------------

spacing_x = 1  # µm, ajusta según el reporte DRC

# --- Colocación de PMOS en la fila superior ---
m1_ref.move((0 + evaluate_bbox(m1_ref)[0]/2, top_row))
# → M1 se coloca en el origen X, centrado en su ancho, y en la fila superior

m3_ref.move((m1_ref.xmax + evaluate_bbox(m3_ref)[0]/2 + spacing_x, top_row))
# → M3 se coloca a la derecha de M1, usando xmax de M1 como referencia

m7_ref.move((m3_ref.xmax + evaluate_bbox(m7_ref)[0]/2 + spacing_x, top_row))
# → M7 se coloca a la derecha de M3

# --- Colocación de NMOS en la fila inferior ---
m2_ref.move((0 + evaluate_bbox(m2_ref)[0]/2, bottom_row))
# → M2 en el origen X, centrado, en la fila inferior

m4_ref.move((m2_ref.xmax + evaluate_bbox(m4_ref)[0]/2 + spacing_x, bottom_row))
# → M4 a la derecha de M2

m8_ref.move((m4_ref.xmax + evaluate_bbox(m8_ref)[0]/2 + spacing_x, bottom_row))
# → M8 a la derecha de M4

# --- Colocación del capacitor MIM ---
cap_ref.move((m8_ref.xmax + evaluate_bbox(cap_ref)[0]/2 + spacing_x, bottom_row))
# → El capacitor se coloca a la derecha de M8, en la misma fila inferior

# --- Colocación del NMOS de reset (M5) ---
m5_ref.move((0 + evaluate_bbox(m5_ref)[0]/2, middle_row+0.75))
# → M5 se coloca centrado en X=0, pero en la fila intermedia
# Out:
# ComponentReference (parent Component "Unnamed_6ef8fc62", ports ['multiplier_0_gate_W', 'gate_W', 'multiplier_0_row0_col0_gate_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_top_met_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'multiplier_0_leftsd_array_row0_col0_top_met_W', 'multiplier_0_leftsd_top_met_W', 'multiplier_0_plusdoped_W', 'multiplier_0_diff_W', 'multiplier_0_source_W', 'source_W', 'multiplier_0_drain_W', 'drain_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row0_col0_bottom_via_N', 'multiplier_0_leftsd_array_row0_col0_bottom_met_N', 'multiplier_0_leftsd_array_row0_col0_top_met_N', 'multiplier_0_leftsd_top_met_N', 'multiplier_0_row0_col0_gate_N', 'multiplier_0_plusdoped_N', 'multiplier_0_diff_N', 'multiplier_0_drain_N', 'multiplier_0_source_N', 'source_N', 'drain_N', 'multiplier_0_gate_N', 'gate_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_top_met_N', 'multiplier_0_drain_E', 'drain_E', 'multiplier_0_source_E', 'source_E', 'multiplier_0_row0_col0_gate_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_E', 'multiplier_0_row0_col0_rightsd_top_met_E', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_E', 'multiplier_0_leftsd_array_row0_col0_bottom_via_E', 'multiplier_0_leftsd_array_row0_col0_bottom_met_E', 'multiplier_0_leftsd_array_row0_col0_top_met_E', 'multiplier_0_leftsd_top_met_E', 'multiplier_0_plusdoped_E', 'multiplier_0_diff_E', 'multiplier_0_gate_E', 'gate_E', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_S', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_S', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_S', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_S', 'multiplier_0_row0_col0_rightsd_top_met_S', 'multiplier_0_row0_col0_gate_S', 'multiplier_0_plusdoped_S', 'multiplier_0_diff_S', 'multiplier_0_drain_S', 'multiplier_0_source_S', 'source_S', 'drain_S', 'multiplier_0_gate_S', 'gate_S', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_S', 'multiplier_0_leftsd_array_row0_col0_bottom_via_S', 'multiplier_0_leftsd_array_row0_col0_bottom_met_S', 'multiplier_0_leftsd_array_row0_col0_top_met_S', 'multiplier_0_leftsd_top_met_S', 'tie_S_array_row0_col0_bottom_layer_W', 'tie_S_array_row0_col0_bottom_via_W', 'tie_S_array_row0_col0_bottom_met_W', 'tie_S_array_row0_col0_top_met_W', 'tie_S_array_row0_col1_bottom_layer_W', 'tie_S_array_row0_col1_bottom_via_W', 'tie_S_array_row0_col1_bottom_met_W', 'tie_S_array_row0_col1_top_met_W', 'tie_S_array_row0_col2_bottom_layer_W', 'tie_S_array_row0_col2_bottom_via_W', 'tie_S_array_row0_col2_bottom_met_W', 'tie_S_array_row0_col2_top_met_W', 'tie_S_array_row0_col3_bottom_layer_W', 'tie_S_array_row0_col3_bottom_via_W', 'tie_S_array_row0_col3_bottom_met_W', 'tie_S_array_row0_col3_top_met_W', 'tie_S_array_row0_col4_bottom_layer_W', 'tie_S_array_row0_col4_bottom_via_W', 'tie_S_array_row0_col4_bottom_met_W', 'tie_S_array_row0_col4_top_met_W', 'tie_S_array_row0_col5_bottom_layer_W', 'tie_S_array_row0_col5_bottom_via_W', 'tie_S_array_row0_col5_bottom_met_W', 'tie_S_array_row0_col5_top_met_W', 'tie_S_array_row0_col6_bottom_layer_W', 'tie_S_array_row0_col6_bottom_via_W', 'tie_S_array_row0_col6_bottom_met_W', 'tie_S_array_row0_ ...

# %%
# --- Nodo de salida: spike ---
# Rectángulo metálico en Metal2, colocado en drain de M7
spike_ref = neurona_comp << gf.components.rectangle(
    size=(1.0, 1.0),
    layer=pdk.get_layer("metal2")
)
spike_ref.move(m7_ref.ports["drain_S"].center)

# Puerto lógico "spike"
neurona_comp.add_port(
    name="spike",
    center=m7_ref.ports["drain_S"].center,
    width=1.0,
    orientation=270,   # hacia el Sur
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)

# Etiqueta "spike"
neurona_comp.add_label(
    text="spike",
    position=m7_ref.ports["drain_S"].center,
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)

# --- Nodo de salida: spike_neg ---
# Rectángulo metálico en Metal2, colocado en drain de M3
spike_neg_ref = neurona_comp << gf.components.rectangle(
    size=(1.0, 1.0),
    layer=pdk.get_layer("metal2")
)
spike_neg_ref.move(m3_ref.ports["drain_S"].center)

# Puerto lógico "spike_neg"
neurona_comp.add_port(
    name="spike_neg",
    center=m3_ref.ports["drain_S"].center,
    width=1.0,
    orientation=270,   # hacia el Sur
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)

# Etiqueta "spike_neg"
neurona_comp.add_label(
    text="spike_neg",
    position=m3_ref.ports["drain_S"].center,
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)

# --- Nodo de entrada: Iin ---
# Rectángulo metálico en Metal2, colocado en drain de M5
iin_ref = neurona_comp << gf.components.rectangle(
    size=(1.0, 1.0),
    layer=pdk.get_layer("metal2")
)
iin_ref.move(m5_ref.ports["drain_S"].center)

# Puerto lógico "Iin"
neurona_comp.add_port(
    name="Iin",
    center=m5_ref.ports["drain_S"].center,
    width=1.0,
    orientation=270,   # hacia el Sur
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)

# Etiqueta "Iin"
neurona_comp.add_label(
    text="Iin",
    position=m5_ref.ports["drain_S"].center,
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)
# Out:
# Label(text='Iin', origin=(26.93, 11.474999999999998), layer=(36, 10))

# %%
# ADD AVDD & AVSS POWER RAILS AND CONNECT SUPPLY NODES
# =========================================================================

# Calculate full horizontal span of the cell to draw supply rails
bbox = evaluate_bbox(neurona_comp)
# → Obtiene el bounding box del componente neurona_comp (ancho total y alto)

top_y = neurona_comp.ymax + 3.0
# → Coordenada Y para la línea superior (AVDD), con margen extra de 3 µm

bottom_y = neurona_comp.ymin - 3.0
# → Coordenada Y para la línea inferior (AVSS), con margen extra de 3 µm


# Draw horizontal metal2 power rails
avdd_rail = neurona_comp << gf.components.rectangle(
    size=(bbox[0]+4, 1.0),              # Largo = ancho del layout + 4 µm, grosor = 1 µm
    layer=pdk.get_layer("metal2")       # Se dibuja en la capa metal2
)
avdd_rail.move((-2, top_y))             # Se coloca en la parte superior (rail AVDD)

avss_rail = neurona_comp << gf.components.rectangle(
    size=(bbox[0]+4, 1.0),
    layer=pdk.get_layer("metal2")
)
avss_rail.move((-2, bottom_y))          # Se coloca en la parte inferior (rail AVSS)


# Add global ports for the supply rails
neurona_comp.add_port(
    "vdd",                              # Nombre del puerto global de alimentación
    center=(bbox[0]/2, top_y + 0.5),    # Centro del puerto sobre el rail superior
    width=1.0,
    orientation=180,                    # Orientación hacia la izquierda
    layer=pdk.get_layer("metal2"),
    port_type="electrical"              # Tipo de puerto: eléctrico
)

neurona_comp.add_port(
    "vss",                              # Nombre del puerto global de tierra
    center=(bbox[0]/2, bottom_y + 0.5), # Centro del puerto sobre el rail inferior
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)


# add label to those global ports 
neurona_comp.add_label(
    text="vdd",                         # Etiqueta para el rail superior
    position=(bbox[0]/2, top_y + 0.5),
    layer=pdk.get_glayer("met2_label"), # Capa de etiquetas para metal2
    magnification=1.5
)

neurona_comp.add_label(
    text="vss",                         # Etiqueta para el rail inferior
    position=(bbox[0]/2, bottom_y + 0.5),
    layer=pdk.get_glayer("met2_label"),
    magnification=1.5
)
# Out:
# Label(text='vss', origin=(26.93, -3.2), layer=(36, 10))

# %%
#conectando todos los sustratos
#Transistores P
neurona_comp  << L_route(pdk, m1_ref.ports["tie_N_top_met_N"], neurona_comp.ports["vdd"])
neurona_comp  << L_route(pdk, m3_ref.ports["tie_N_top_met_N"], neurona_comp.ports["vdd"])
neurona_comp  << L_route(pdk, m7_ref.ports["tie_N_top_met_N"], neurona_comp.ports["vdd"])

#Transistores N
neurona_comp  << L_route(pdk, m2_ref.ports["tie_S_top_met_S"], neurona_comp.ports["vss"])
neurona_comp  << L_route(pdk, m4_ref.ports["tie_S_top_met_S"], neurona_comp.ports["vss"])
neurona_comp  << L_route(pdk, m8_ref.ports["tie_S_top_met_S"], neurona_comp.ports["vss"])
# --- Conexión del sustrato de M5 a VSS ---
neurona_comp << c_route(pdk,m5_ref.ports["tie_S_top_met_W"], neurona_comp.ports["vss"]  )
# Out:
# ComponentReference (parent Component "c_route_3a609428", ports ['con_N', 'con_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
# conectar source con bulk
#Transistores N
neurona_comp << straight_route(pdk, m2_ref.ports["source_W"], m2_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m4_ref.ports["source_W"], m4_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m8_ref.ports["source_W"], m8_ref.ports["tie_W_top_met_E"])
# --- Conexión del bulk de M5 ---
neurona_comp << straight_route(pdk, m5_ref.ports["source_W"], m5_ref.ports["tie_W_top_met_E"])
#Transistores P
neurona_comp << straight_route(pdk, m1_ref.ports["source_W"], m1_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m3_ref.ports["source_W"], m3_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m7_ref.ports["source_W"], m7_ref.ports["tie_W_top_met_E"])
# Out:
# ComponentReference (parent Component "straight_route_384f6383", ports ['route_W', 'route_N', 'route_E', 'route_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
#inversor 1 -------------------------------------------------------------------------------------------
#subir de metal 2 a metal 3 en las terminales de gate de M1
via_gate_m1 = via_stack(pdk, "met2", "met3", centered=True)
node_m1_gate = neurona_comp << via_gate_m1
node_m1_gate.move(m1_ref.ports["gate_N"].center)
# Gate M1 → nodo M1 (Metal2)
neurona_comp << straight_route(pdk, m1_ref.ports["gate_S"], node_m1_gate.ports["bottom_met_W"]) 

#subir de metal 2 a metal 3 en las terminales de gate de M2
via_gate_m2 = via_stack(pdk, "met2", "met3", centered=True)
node_m2_gate = neurona_comp << via_gate_m2
node_m2_gate.move(m2_ref.ports["gate_N"].center)
# Gate M2 → nodo M2 (Metal2)
neurona_comp << straight_route(pdk, m2_ref.ports["gate_S"], node_m2_gate.ports["bottom_met_N"])   

# Nodo M1 ↔ Nodo M2 (Metal3)
neurona_comp << straight_route(pdk, node_m1_gate.ports["top_met_S"], node_m2_gate.ports["top_met_N"])
neurona_comp << c_route(pdk, m1_ref.ports["drain_E"], m2_ref.ports["drain_E"])

#inversor 2 -------------------------------------------------------------------------------------------
#subir de metal 2 a metal 3 en las terminales de gate de M1
via_gate_m3 = via_stack(pdk, "met2", "met3", centered=True)
node_m3_gate = neurona_comp << via_gate_m3
node_m3_gate.move(m3_ref.ports["gate_N"].center)
# Gate M3 → nodo M3 (Metal2)
neurona_comp << straight_route(pdk, m3_ref.ports["gate_S"], node_m3_gate.ports["bottom_met_W"]) 

#subir de metal 2 a metal 3 en las terminales de gate de M2
via_gate_m4 = via_stack(pdk, "met2", "met3", centered=True)
node_m4_gate = neurona_comp << via_gate_m4
node_m4_gate.move(m4_ref.ports["gate_N"].center)
# Gate M4 → nodo M4 (Metal2)
neurona_comp << straight_route(pdk, m4_ref.ports["gate_S"], node_m4_gate.ports["bottom_met_N"])   

# Nodo M3 ↔ Nodo M4 (Metal3) 
neurona_comp << straight_route(pdk, node_m3_gate.ports["top_met_S"], node_m4_gate.ports["top_met_N"])
neurona_comp << c_route(pdk, m3_ref.ports["drain_E"], m4_ref.ports["drain_E"])

#inversor 3 -------------------------------------------------------------------------------------------
#subir de metal 2 a metal 3 en las terminales de gate de M1
via_gate_m7 = via_stack(pdk, "met2", "met3", centered=True)
node_m7_gate = neurona_comp << via_gate_m7
node_m7_gate.move(m7_ref.ports["gate_N"].center) 
# Gate M7 → nodo M7 (Metal2)
neurona_comp << straight_route(pdk, m7_ref.ports["gate_S"], node_m7_gate.ports["bottom_met_W"]) 

#subir de metal 2 a metal 3 en las terminales de gate de M2
via_gate_m8 = via_stack(pdk, "met2", "met3", centered=True)
node_m8_gate = neurona_comp << via_gate_m8
node_m8_gate.move(m8_ref.ports["gate_N"].center)
# Gate M8 → nodo M8 (Metal2)
neurona_comp << straight_route(pdk, m8_ref.ports["gate_S"], node_m8_gate.ports["bottom_met_N"])   

# Nodo M7 ↔ Nodo M8 (Metal3)
neurona_comp << straight_route(pdk, node_m7_gate.ports["top_met_S"], node_m8_gate.ports["top_met_N"])
neurona_comp << c_route(pdk, m7_ref.ports["drain_E"], m8_ref.ports["drain_E"])
# Out:
# ComponentReference (parent Component "c_route_55819acf", ports ['con_N', 'con_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
#otras conexiones -------------------------------------------------------------------------------------
# Crear via stack para subir de M2 a M3
via_drain_m2 = via_stack(pdk, "met2", "met3", centered=True)
node_m2_drain = neurona_comp << via_drain_m2

# Obtener coordenadas del puerto drain_E
drain_pos = m2_ref.ports["drain_E"].center

# Calcular borde derecho de la celda de M2
bbox = evaluate_bbox(m2_ref)   # [width, height]
x_edge = m2_ref.xmax+0.2           # borde derecho en X

# Mover el nodo al borde derecho, centrado en Y del drain
node_m2_drain.move((x_edge, drain_pos[1]))

# Conectar drain → nodo en Metal2
neurona_comp << straight_route(pdk, m2_ref.ports["drain_E"], node_m2_drain.ports["bottom_met_W"])

# Gate M4 (lado W) → Nodo M2 (Metal2, lado S)
neurona_comp << L_route(pdk, m4_ref.ports["gate_W"], node_m2_drain.ports["bottom_met_S"] )

# Conexión directa entre gate de M4 y gate de M8
neurona_comp << straight_route(pdk, m4_ref.ports["gate_E"], m8_ref.ports["gate_W"])

# --- Conexión del capacitor MIM (electrodo inferior) a VSS ---
neurona_comp << straight_route(pdk,cap_ref.ports["row0_col0_bottom_met_S"],neurona_comp.ports["vss"])
neurona_comp << straight_route(pdk,cap_ref.ports["row0_col0_top_met_N"],m5_ref.ports["drain_S"])

# Conexión directa drain M2 → gate M5
neurona_comp << straight_route(pdk, m4_ref.ports["drain_N"], m5_ref.ports["gate_S"])
# Out:
# ComponentReference (parent Component "straight_route_a5cfaa65", ports ['route_W', 'route_N', 'route_E', 'route_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
view_and_check_lvs()
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/gdsfactory/show.py:40: UserWarning: Unnamed cells, 4 in 'neurona_lvs'
#   gdspath = component.write_gds(
# 2026-08-20 22:03:21.340 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/glayout/pdk/mappedpdk.py:540: UserWarning: Unnamed cells, 4 in 'neurona_lvs'
#   layout.write_gds(gds_path)
# 2026-08-20 22:03:21.382 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpc0p4483d/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpc0p4483d/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_3a609428".
# Reading "compass_25e347fc".
# Reading "via_stack_22f48a44$2".
# Reading "via_stack_22f48a44$5".
# Reading "straight_route_895b28ab".
# Reading "straight_route_7ac2cc77".
# Reading "straight_route_04dec2d0".
# Reading "L_route_b6128b76".
# Reading "rectangle_25e347fc$1".
# Reading "c_route_8cb7e4c3".
# Reading "straight_route_0f9dfd58".
# Reading "straight_route_07066a6b".
# Reading "rectangle_e9c8146d".
# Reading "compass_e9c8146d".
# Reading "straight_route_a981a125".
# Reading "straight_route_b18af222".
# Reading "straight_route_101eeef7".
# Reading "straight_route_cc7cb8b2".
# Reading "straight_route_ffc0ab6d".
# Reading "compass_e9c8146d$1".
# Reading "via_stack_22f48a44$3".
# Reading "via_stack_22f48a44$6".
# Reading "straight_route_384f6383".
# Reading "straight_route_a5cfaa65".
# Reading "L_route_1e9ebd24".
# Reading "Unnamed_6ef8fc62".
# Reading "straight_route_c604054c".
# Reading "Unnamed_32beef5d".
# Reading "rectangle_e9c8146d$1".
# Reading "L_route_60a16dcd".
# Reading "straight_route_abc0ae76".
# Reading "rectangle_25e347fc$2".
# Reading "Unnamed_e175abcc".
# Reading "L_route_1681f66e".
# Reading "compass_25e347fc$1".
# Reading "via_stack_22f48a44$1".
# Reading "straight_route_84234d1f".
# Reading "via_stack_22f48a44$4".
# Reading "straight_route_9ab0b607".
# Reading "Unnamed_89a8896a".
# Reading "L_route_f054dfe7".
# Reading "straight_route_6922e07b".
# Reading "straight_route_73b0a842".
# Reading "straight_route_f8a28cec".
# Reading "compass_25e347fc$2".
# Reading "via_stack_22f48a44$7".
# Reading "straight_route_875ef33b".
# Reading "c_route_d42a64a8".
# Reading "c_route_55819acf".
# Reading "L_route_041e30b8".
# Reading "rectangle_25e347fc".
# Reading "L_route_72c61b40".
# Reading "straight_route_8a82472b".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpc0p4483d/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
neurona_comp.pprint_ports()
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name      ┃ width ┃ center          ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ spike     │ 1.0   │ [13.25, 17.945] │ 270         │ [36, 0] │ electrical │
# │ spike_neg │ 1.0   │ [7.75, 17.945]  │ 270         │ [36, 0] │ electrical │
# │ Iin       │ 1.0   │ [26.93, 11.475] │ 270         │ [36, 0] │ electrical │
# │ vdd       │ 1.0   │ [26.93, 23.05]  │ 180         │ [36, 0] │ electrical │
# │ vss       │ 1.0   │ [26.93, -3.2]   │ 180         │ [36, 0] │ electrical │
# └───────────┴───────┴─────────────────┴─────────────┴─────────┴────────────┘

# %%
import os
from pathlib import Path
import tempfile
import subprocess

# Configuración de Magic
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"

# Nombre del diseño
design_name = neurona_comp.name

# Ruta donde guardas tus archivos
path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/lif/"

# Archivos de salida
pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"

# Exportar GDS
neurona_comp.write_gds(str(gds_path))

#Script de Magic para extracción
magic_script_content = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {pex_path}
exit
"""


# Guardar script temporal
with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name

# Ejecutar Magic en modo batch
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'"
magic_subproc = subprocess.run(
    magic_cmd,
    shell=True,
    check=True,
    capture_output=True
)

# Capturar salida
magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# /tmp/ipykernel_17004/3773988896.py:20: UserWarning: Unnamed cells, 4 in 'neurona_lvs'
#   neurona_comp.write_gds(str(gds_path))
# 2026-08-20 22:03:21.838 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/CapiMagics/designs/libs/snn_analog/lif/neurona_lvs.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_3a609428".
# Reading "compass_25e347fc".
# Reading "via_stack_22f48a44$2".
# Reading "via_stack_22f48a44$5".
# Reading "straight_route_895b28ab".
# Reading "straight_route_7ac2cc77".
# Reading "straight_route_04dec2d0".
# Reading "L_route_b6128b76".
# Reading "rectangle_25e347fc$1".
# Reading "c_route_8cb7e4c3".
# Reading "straight_route_0f9dfd58".
# Reading "straight_route_07066a6b".
# Reading "rectangle_e9c8146d".
# Reading "compass_e9c8146d".
# Reading "straight_route_a981a125".
# Reading "straight_route_b18af222".
# Reading "straight_route_101eeef7".
# Reading "straight_route_cc7cb8b2".
# Reading "straight_route_ffc0ab6d".
# Reading "compass_e9c8146d$1".
# Reading "via_stack_22f48a44$3".
# Reading "via_stack_22f48a44$6".
# Reading "straight_route_384f6383".
# Reading "straight_route_a5cfaa65".
# Reading "L_route_1e9ebd24".
# Reading "Unnamed_6ef8fc62".
# Reading "straight_route_c604054c".
# Reading "Unnamed_32beef5d".
# Reading "rectangle_e9c8146d$1".
# Reading "L_route_60a16dcd".
# Reading "straight_route_abc0ae76".
# Reading "rectangle_25e347fc$2".
# Reading "Unnamed_e175abcc".
# Reading "L_route_1681f66e".
# Reading "compass_25e347fc$1".
# Reading "via_stack_22f48a44$1".
# Reading "straight_route_84234d1f".
# Reading "via_stack_22f48a44$4".
# Reading "straight_route_9ab0b607".
# Reading "Unnamed_89a8896a".
# Reading "L_route_f054dfe7".
# Reading "straight_route_6922e07b".
# Reading "straight_route_73b0a842".
# Reading "straight_route_f8a28cec".
# Reading "compass_25e347fc$2".
# Reading "via_stack_22f48a44$7".
# Reading "straight_route_875ef33b".
# Reading "c_route_d42a64a8".
# Reading "c_route_55819acf".
# Reading "L_route_041e30b8".
# Reading "rectangle_25e347fc".
# Reading "L_route_72c61b40".
# Reading "straight_route_8a82472b".
# Extracting L_route_041e30b8 into L_route_041e30b8.ext:
# Extracting via_stack_22f48a44$4 into via_stack_22f48a44$4.ext:
# Extracting Unnamed_32beef5d into Unnamed_32beef5d.ext:
# Extracting straight_route_cc7cb8b2 into straight_route_cc7cb8b2.ext:
# Extracting straight_route_101eeef7 into straight_route_101eeef7.ext:
# Extracting straight_route_895b28ab into straight_route_895b28ab.ext:
# Extracting via_stack_22f48a44$2 into via_stack_22f48a44$2.ext:
# Extracting via_stack_22f48a44$6 into via_stack_22f48a44$6.ext:
# Extracting straight_route_a981a125 into straight_route_a981a125.ext:
# Extracting L_route_1681f66e into L_route_1681f66e.ext:
# Extracting L_route_1e9ebd24 into L_route_1e9ebd24.ext:
# Extracting straight_route_ffc0ab6d into straight_route_ffc0ab6d.ext:
# Extracting L_route_b6128b76 into L_route_b6128b76.ext:
# Extracting straight_route_0f9dfd58 into straight_route_0f9dfd58.ext:
# Extracting straight_route_a5cfaa65 into straight_route_a5cfaa65.ext:
# Extracting straight_route_9ab0b607 into straight_route_9ab0b607.ext:
# Extracting straight_route_6922e07b into straight_route_6922e07b.ext:
# Extracting straight_route_73b0a842 into straight_route_73b0a842.ext:
# Extracting via_stack_22f48a44$7 into via_stack_22f48a44$7.ext:
# Extracting straight_route_8a82472b into straight_route_8a82472b.ext:
# Extracting c_route_3a609428 into c_route_3a609428.ext:
# Extracting straight_route_7ac2cc77 into straight_route_7ac2cc77.ext:
# Extracting straight_route_abc0ae76 into straight_route_abc0ae76.ext:
# Extracting Unnamed_e175abcc into Unnamed_e175abcc.ext:
# Extracting straight_route_875ef33b into straight_route_875ef33b.ext:
# Extracting compass_e9c8146d$1 into compass_e9c8146d$1.ext:
# Extracting rectangle_e9c8146d$1 into rectangle_e9c8146d$1.ext:
# Extracting Unnamed_6ef8fc62 into Unnamed_6ef8fc62.ext:
# Extracting straight_route_07066a6b into straight_route_07066a6b.ext:
# Extracting straight_route_b18af222 into straight_route_b18af222.ext:
# Extracting via_stack_22f48a44$1 into via_stack_22f48a44$1.ext:
# Extracting Unnamed_89a8896a into Unnamed_89a8896a.ext:
# Extracting via_stack_22f48a44$3 into via_stack_22f48a44$3.ext:
# Extracting straight_route_c604054c into straight_route_c604054c.ext:
# Extracting via_stack_22f48a44$5 into via_stack_22f48a44$5.ext:
# Extracting straight_route_04dec2d0 into straight_route_04dec2d0.ext:
# Extracting compass_25e347fc$2 into compass_25e347fc$2.ext:
# Extracting rectangle_25e347fc$2 into rectangle_25e347fc$2.ext:
# Extracting L_route_72c61b40 into L_route_72c61b40.ext:
# Extracting compass_25e347fc into compass_25e347fc.ext:
# Extracting rectangle_25e347fc into rectangle_25e347fc.ext:
# Extracting straight_route_f8a28cec into straight_route_f8a28cec.ext:
# Extracting L_route_f054dfe7 into L_route_f054dfe7.ext:
# Extracting straight_route_84234d1f into straight_route_84234d1f.ext:
# Extracting compass_25e347fc$1 into compass_25e347fc$1.ext:
# Extracting rectangle_25e347fc$1 into rectangle_25e347fc$1.ext:
# Extracting L_route_60a16dcd into L_route_60a16dcd.ext:
# Extracting straight_route_384f6383 into straight_route_384f6383.ext:
# Extracting compass_e9c8146d into compass_e9c8146d.ext:
# Extracting rectangle_e9c8146d into rectangle_e9c8146d.ext:
# Extracting c_route_8cb7e4c3 into c_route_8cb7e4c3.ext:
# Extracting c_route_d42a64a8 into c_route_d42a64a8.ext:
# Extracting c_route_55819acf into c_route_55819acf.ext:
# Extracting neurona_lvs into neurona_lvs.ext:
# exttosim finished.
# Adding  spike
# Adding  spike_neg
# Adding  Iin
# Adding  vdd
# Adding  vss; Tnew = 0.00ns, Told = 0.00ns
# Total Nets: 19
# Nets extracted: 5 (0.263158)
# Nets output: 5 (0.263158)
# exttospice finished.

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: via_stack_22f48a44$2.ext
# Deleted: straight_route_a981a125.ext
# Deleted: via_stack_22f48a44$6.ext
# Deleted: L_route_b6128b76.ext
# Deleted: c_route_d42a64a8.ext
# Deleted: compass_e9c8146d$1.ext
# Deleted: Unnamed_e175abcc.ext
# Deleted: c_route_3a609428.ext
# Deleted: rectangle_e9c8146d$1.ext
# Deleted: compass_25e347fc$2.ext
# Deleted: straight_route_9ab0b607.ext
# Deleted: straight_route_c604054c.ext
# Deleted: straight_route_f8a28cec.ext
# Deleted: compass_25e347fc.ext
# Deleted: rectangle_25e347fc$2.ext
# Deleted: straight_route_8a82472b.ext
# Deleted: straight_route_101eeef7.ext
# Deleted: L_route_041e30b8.ext
# Deleted: rectangle_25e347fc.ext
# Deleted: L_route_1681f66e.ext
# Deleted: straight_route_b18af222.ext
# Deleted: Unnamed_89a8896a.ext
# Deleted: Unnamed_6ef8fc62.ext
# Deleted: Unnamed_32beef5d.ext
# Deleted: straight_route_cc7cb8b2.ext
# Deleted: straight_route_875ef33b.ext
# Deleted: L_route_f054dfe7.ext
# Deleted: c_route_55819acf.ext
# Deleted: straight_route_04dec2d0.ext
# Deleted: via_stack_22f48a44$7.ext
# Deleted: straight_route_6922e07b.ext
# Deleted: via_stack_22f48a44$5.ext
# Deleted: straight_route_73b0a842.ext
# Deleted: c_route_8cb7e4c3.ext
# Deleted: straight_route_0f9dfd58.ext
# Deleted: straight_route_84234d1f.ext
# Deleted: neurona_lvs.res.ext
# Deleted: straight_route_07066a6b.ext
# Deleted: L_route_1e9ebd24.ext
# Deleted: via_stack_22f48a44$1.ext
# Deleted: straight_route_7ac2cc77.ext
# Deleted: straight_route_a5cfaa65.ext
# Deleted: straight_route_895b28ab.ext
# Deleted: via_stack_22f48a44$3.ext
# Deleted: L_route_72c61b40.ext
# Deleted: L_route_60a16dcd.ext
# Deleted: straight_route_ffc0ab6d.ext
# Deleted: rectangle_e9c8146d.ext
# Deleted: neurona_lvs.ext
# Deleted: compass_e9c8146d.ext
# Deleted: compass_25e347fc$1.ext
# Deleted: via_stack_22f48a44$4.ext
# Deleted: straight_route_384f6383.ext
# Deleted: rectangle_25e347fc$1.ext
# Deleted: straight_route_abc0ae76.ext
# Error deleting neurona_lvs.res.ext: [Errno 2] No such file or directory: 'neurona_lvs.res.ext'
# Deleted: neurona_lvs.nodes
# Deleted: neurona_lvs.sim

# %%
import os
from pathlib import Path

# Ruta donde guardas tus archivos de la neurona
path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/lif/"

# Ejecutar LVS con Netgen usando el PDK gf180
gf180.lvs_netgen(
    layout=neurona_comp,   # tu layout exportado
    design_name=neurona_comp.name,   # nombre del diseño
    pdk_root=Path(os.environ['PDKPATH']),   # raíz del PDK
    lvs_setup_tcl_file=Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    
    # Netlist de referencia (esquemático ideal)
    lvs_schematic_ref_file=Path(path_to_dir + "neurona_lvs.spice"),
    
    # Netlist extraído del layout (PEX/LVS)
    netlist=Path(path_to_dir + "neurona_sch.spice"),
    
    # Carpeta donde se guarda el reporte .lvs.rpt
    output_file_path=Path(path_to_dir)
)
# Out:
# /headless/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/glayout/pdk/mappedpdk.py:762: UserWarning: Unnamed cells, 4 in 'neurona_lvs'
#   layout.write_gds(str(gds_path))
# 2026-08-20 22:03:22.559 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpg45fn6m1/neurona_lvs.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_3a609428".
# Reading "compass_25e347fc".
# Reading "via_stack_22f48a44$2".
# Reading "via_stack_22f48a44$5".
# Reading "straight_route_895b28ab".
# Reading "straight_route_7ac2cc77".
# Reading "straight_route_04dec2d0".
# Reading "L_route_b6128b76".
# Reading "rectangle_25e347fc$1".
# Reading "c_route_8cb7e4c3".
# Reading "straight_route_0f9dfd58".
# Reading "straight_route_07066a6b".
# Reading "rectangle_e9c8146d".
# Reading "compass_e9c8146d".
# Reading "straight_route_a981a125".
# Reading "straight_route_b18af222".
# Reading "straight_route_101eeef7".
# Reading "straight_route_cc7cb8b2".
# Reading "straight_route_ffc0ab6d".
# Reading "compass_e9c8146d$1".
# Reading "via_stack_22f48a44$3".
# Reading "via_stack_22f48a44$6".
# Reading "straight_route_384f6383".
# Reading "straight_route_a5cfaa65".
# Reading "L_route_1e9ebd24".
# Reading "Unnamed_6ef8fc62".
# Reading "straight_route_c604054c".
# Reading "Unnamed_32beef5d".
# Reading "rectangle_e9c8146d$1".
# Reading "L_route_60a16dcd".
# Reading "straight_route_abc0ae76".
# Reading "rectangle_25e347fc$2".
# Reading "Unnamed_e175abcc".
# Reading "L_route_1681f66e".
# Reading "compass_25e347fc$1".
# Reading "via_stack_22f48a44$1".
# Reading "straight_route_84234d1f".
# Reading "via_stack_22f48a44$4".
# Reading "straight_route_9ab0b607".
# Reading "Unnamed_89a8896a".
# Reading "L_route_f054dfe7".
# Reading "straight_route_6922e07b".
# Reading "straight_route_73b0a842".
# Reading "straight_route_f8a28cec".
# Reading "compass_25e347fc$2".
# Reading "via_stack_22f48a44$7".
# Reading "straight_route_875ef33b".
# Reading "c_route_d42a64a8".
# Reading "c_route_55819acf".
# Reading "L_route_041e30b8".
# Reading "rectangle_25e347fc".
# Reading "L_route_72c61b40".
# Reading "straight_route_8a82472b".
# Extracting L_route_041e30b8 into L_route_041e30b8.ext:
# Extracting via_stack_22f48a44$4 into via_stack_22f48a44$4.ext:
# Extracting Unnamed_32beef5d into Unnamed_32beef5d.ext:
# Extracting straight_route_cc7cb8b2 into straight_route_cc7cb8b2.ext:
# Extracting straight_route_101eeef7 into straight_route_101eeef7.ext:
# Extracting straight_route_895b28ab into straight_route_895b28ab.ext:
# Extracting via_stack_22f48a44$2 into via_stack_22f48a44$2.ext:
# Extracting via_stack_22f48a44$6 into via_stack_22f48a44$6.ext:
# Extracting straight_route_a981a125 into straight_route_a981a125.ext:
# Extracting L_route_1681f66e into L_route_1681f66e.ext:
# Extracting L_route_1e9ebd24 into L_route_1e9ebd24.ext:
# Extracting straight_route_ffc0ab6d into straight_route_ffc0ab6d.ext:
# Extracting L_route_b6128b76 into L_route_b6128b76.ext:
# Extracting straight_route_0f9dfd58 into straight_route_0f9dfd58.ext:
# Extracting straight_route_a5cfaa65 into straight_route_a5cfaa65.ext:
# Extracting straight_route_9ab0b607 into straight_route_9ab0b607.ext:
# Extracting straight_route_6922e07b into straight_route_6922e07b.ext:
# Extracting straight_route_73b0a842 into straight_route_73b0a842.ext:
# Extracting via_stack_22f48a44$7 into via_stack_22f48a44$7.ext:
# Extracting straight_route_8a82472b into straight_route_8a82472b.ext:
# Extracting c_route_3a609428 into c_route_3a609428.ext:
# Extracting straight_route_7ac2cc77 into straight_route_7ac2cc77.ext:
# Extracting straight_route_abc0ae76 into straight_route_abc0ae76.ext:
# Extracting Unnamed_e175abcc into Unnamed_e175abcc.ext:
# Extracting straight_route_875ef33b into straight_route_875ef33b.ext:
# Extracting compass_e9c8146d$1 into compass_e9c8146d$1.ext:
# Extracting rectangle_e9c8146d$1 into rectangle_e9c8146d$1.ext:
# Extracting Unnamed_6ef8fc62 into Unnamed_6ef8fc62.ext:
# Extracting straight_route_07066a6b into straight_route_07066a6b.ext:
# Extracting straight_route_b18af222 into straight_route_b18af222.ext:
# Extracting via_stack_22f48a44$1 into via_stack_22f48a44$1.ext:
# Extracting Unnamed_89a8896a into Unnamed_89a8896a.ext:
# Extracting via_stack_22f48a44$3 into via_stack_22f48a44$3.ext:
# Extracting straight_route_c604054c into straight_route_c604054c.ext:
# Extracting via_stack_22f48a44$5 into via_stack_22f48a44$5.ext:
# Extracting straight_route_04dec2d0 into straight_route_04dec2d0.ext:
# Extracting compass_25e347fc$2 into compass_25e347fc$2.ext:
# Extracting rectangle_25e347fc$2 into rectangle_25e347fc$2.ext:
# Extracting L_route_72c61b40 into L_route_72c61b40.ext:
# Extracting compass_25e347fc into compass_25e347fc.ext:
# Extracting rectangle_25e347fc into rectangle_25e347fc.ext:
# Extracting straight_route_f8a28cec into straight_route_f8a28cec.ext:
# Extracting L_route_f054dfe7 into L_route_f054dfe7.ext:
# Extracting straight_route_84234d1f into straight_route_84234d1f.ext:
# Extracting compass_25e347fc$1 into compass_25e347fc$1.ext:
# Extracting rectangle_25e347fc$1 into rectangle_25e347fc$1.ext:
# Extracting L_route_60a16dcd into L_route_60a16dcd.ext:
# Extracting straight_route_384f6383 into straight_route_384f6383.ext:
# Extracting compass_e9c8146d into compass_e9c8146d.ext:
# Extracting rectangle_e9c8146d into rectangle_e9c8146d.ext:
# Extracting c_route_8cb7e4c3 into c_route_8cb7e4c3.ext:
# Extracting c_route_d42a64a8 into c_route_d42a64a8.ext:
# Extracting c_route_55819acf into c_route_55819acf.ext:
# Extracting neurona_lvs into neurona_lvs.ext:
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmpg45fn6m1/neurona_lvs_lvsmag.spice neurona_lvs" "/tmp/tmpg45fn6m1/neurona_lvs.spice neurona_lvs" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpg45fn6m1/neurona_lvs_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:02:45 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpg45fn6m1/neurona_lvs_lvsmag.spice for /tmp/tmpg45fn6m1/neurona_lvs_lvsmag.spice neurona_lvs
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpg45fn6m1/neurona_lvs.spice for /tmp/tmpg45fn6m1/neurona_lvs.spice neurona_lvs
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Duplicate cell neurona_lvs in file
# Renaming original cell to neurona_lvs[[0]]
# Call to undefined subcircuit cap_mim_2f0fF
# Creating placeholder cell definition.
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# No property par1 found for device cap_mim_2f0fF
# Comparison output logged to file /tmp/tmpg45fn6m1/neurona_lvs_lvs.rpt
# Logging to file "/tmp/tmpg45fn6m1/neurona_lvs_lvs.rpt" enabled
# Circuit nfet_03v3 contains no devices.
# Circuit pfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'Unnamed_6ef8fc62'
# Circuit Unnamed_6ef8fc62 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'Unnamed_6ef8fc62'
# Circuit Unnamed_6ef8fc62 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits Unnamed_6ef8fc62 Unnamed_6ef8fc62
#
# Flattening instances of Unnamed_6ef8fc62 in file /tmp/tmpg45fn6m1/neurona_lvs_lvsmag.spice
# Flattening instances of Unnamed_6ef8fc62 in file /tmp/tmpg45fn6m1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'Unnamed_89a8896a'
# Circuit Unnamed_89a8896a contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'Unnamed_89a8896a'
# Circuit Unnamed_89a8896a contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits Unnamed_89a8896a Unnamed_89a8896a
#
# Flattening instances of Unnamed_89a8896a in file /tmp/tmpg45fn6m1/neurona_lvs_lvsmag.spice
# Flattening instances of Unnamed_89a8896a in file /tmp/tmpg45fn6m1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'Unnamed_32beef5d'
# Circuit Unnamed_32beef5d contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'Unnamed_32beef5d'
# Circuit Unnamed_32beef5d contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits Unnamed_32beef5d Unnamed_32beef5d
#
# Flattening instances of Unnamed_32beef5d in file /tmp/tmpg45fn6m1/neurona_lvs_lvsmag.spice
# Flattening instances of Unnamed_32beef5d in file /tmp/tmpg45fn6m1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'neurona_lvs'
# Circuit neurona_lvs contains 7 device instances.
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   3
# Circuit contains 3 nets.
# Contents of circuit 2:  Circuit: 'neurona_lvs'
# Circuit neurona_lvs contains 8 device instances.
#   Class: cap_mim_2f0fF         instances:   1
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   3
# Circuit contains 7 nets.
#
# Circuit was modified by parallel/series device merging.
# New circuit summary:
#
# Contents of circuit 1:  Circuit: 'neurona_lvs'
# Circuit neurona_lvs contains 5 device instances.
#   Class: nfet_03v3             instances:   3
#   Class: pfet_03v3             instances:   2
# Circuit contains 3 nets.
# Contents of circuit 2:  Circuit: 'neurona_lvs'
# Circuit neurona_lvs contains 8 device instances.
#   Class: cap_mim_2f0fF         instances:   1
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   3
# Circuit contains 7 nets.
#
# Circuit 1 contains 5 devices, Circuit 2 contains 8 devices. *** MISMATCH ***
# Circuit 1 contains 3 nets,    Circuit 2 contains 7 nets. *** MISMATCH ***
#
#
# Final result:
# Top level cell failed pin matching.
#
# Logging to file "/tmp/tmpg45fn6m1/neurona_lvs_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Equate elements:  no current cell.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Equate elements:  no current cell.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Subcircuit summary:
# Circuit 1: Unnamed_6ef8fc62                |Circuit 2: Unnamed_6ef8fc62
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: Unnamed_6ef8fc62                |Circuit 2: Unnamed_6ef8fc62
#
# ---------------------------------------------------------------------------------------
# Net: a_5000_n205#                          |Net: a_5000_n205#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n5000_n414#                         |Net: a_n5000_n414#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n5120_n205#                         |Net: a_n5120_n205#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n5330_n579#                         |Net: a_n5330_n579#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: Unnamed_6ef8fc62                |Circuit 2: Unnamed_6ef8fc62
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits Unnamed_6ef8fc62 Unnamed_6ef8fc62
#
# Subcircuit summary:
# Circuit 1: Unnamed_89a8896a                |Circuit 2: Unnamed_89a8896a
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: Unnamed_89a8896a                |Circuit 2: Unnamed_89a8896a
#
# ---------------------------------------------------------------------------------------
# Net: a_64_n131#                            |Net: a_64_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: a_n184_n131#                          |Net: a_n184_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n64_n339#                           |Net: a_n64_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: w_n450_n560#                          |Net: w_n450_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 4
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: Unnamed_89a8896a                |Circuit 2: Unnamed_89a8896a
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits Unnamed_89a8896a Unnamed_89a8896a
#
# Subcircuit summary:
# Circuit 1: Unnamed_32beef5d                |Circuit 2: Unnamed_32beef5d
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: Unnamed_32beef5d                |Circuit 2: Unnamed_32beef5d
#
# ---------------------------------------------------------------------------------------
# Net: a_64_n131#                            |Net: a_64_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n64_n339#                           |Net: a_n64_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n184_n131#                          |Net: a_n184_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n394_n504#                          |Net: a_n394_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: Unnamed_32beef5d                |Circuit 2: Unnamed_32beef5d
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits Unnamed_32beef5d Unnamed_32beef5d
#
# Class neurona_lvs (0):  Merged 2 parallel devices.
# Subcircuit summary:
# Circuit 1: neurona_lvs                     |Circuit 2: neurona_lvs
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (4->3)                           |nfet_03v3 (4) **Mismatch**
# pfet_03v3 (3->2)                           |pfet_03v3 (3) **Mismatch**
# (no matching element)                      |cap_mim_2f0fF (3->1)
# Number of devices: 5 **Mismatch**          |Number of devices: 8 **Mismatch**
# Number of nets: 3 **Mismatch**             |Number of nets: 7 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: neurona_lvs                     |Circuit 2: neurona_lvs
#
# ---------------------------------------------------------------------------------------
# Net: vss                                   |Net: Vss
#   nfet_03v3/(1|3) = 5                      |  nfet_03v3/(1|3) = 3
#   nfet_03v3/4 = 3                          |  nfet_03v3/4 = 3
#   nfet_03v3/2 = 1                          |  cap_mim_2f0fF/2 = 1
#   pfet_03v3/(1|3) = 3                      |
#   pfet_03v3/4 = 2                          |
#                                            |
# Net: Unnamed_89a8896a_2/a_n64_n339#        |Net: GND
#   pfet_03v3/2 = 1                          |  nfet_03v3/(1|3) = 1
#   nfet_03v3/2 = 1                          |  nfet_03v3/4 = 1
#                                            |
# (no matching net)                          |Net: spike_neg
#                                            |  pfet_03v3/(1|3) = 1
#                                            |  nfet_03v3/(1|3) = 1
#                                            |  pfet_03v3/2 = 2
#                                            |  nfet_03v3/2 = 2
#                                            |
# (no matching net)                          |Net: Vdd
#                                            |  pfet_03v3/(1|3) = 3
#                                            |  pfet_03v3/4 = 3
#                                            |
# (no matching net)                          |Net: spike
#                                            |  pfet_03v3/(1|3) = 1
#                                            |  nfet_03v3/(1|3) = 1
#                                            |
# (no matching net)                          |Net: spike/reset
#                                            |  pfet_03v3/(1|3) = 1
#                                            |  nfet_03v3/(1|3) = 1
#                                            |  nfet_03v3/2 = 1
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# Net: Unnamed_89a8896a_2/a_64_n131#         |Net: Iin
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#   pfet_03v3/(1|3) = 1                      |  cap_mim_2f0fF/1 = 1
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: neurona_lvs                     |Circuit 2: neurona_lvs
#
# ---------------------------------------------------------------------------------------
# Instance: Unnamed_6ef8fc62_0/nfet_03v3:0   |Instance: nfet_03v3:4
#   (1,3) = (14,14)                          |  (1,3) = (7,3)
#   2 = 14                                   |  2 = 6
#   4 = 14                                   |  4 = 7
#                                            |
# Instance: Unnamed_89a8896a_2/pfet_03v3:0   |Instance: nfet_03v3:8
#   (1,3) = (14,4)                           |  (1,3) = (2,2)
#   2 = 2                                    |  2 = 6
#   4 = 14                                   |  4 = 2
#                                            |
# (no matching instance)                     |Instance: pfet_03v3:3
#                                            |  (1,3) = (6,3)
#                                            |  2 = 6
#                                            |  4 = 6
#                                            |
#                                            |
# (no matching instance)                     |Instance: pfet_03v3:7
#                                            |  (1,3) = (6,2)
#                                            |  2 = 6
#                                            |  4 = 6
#                                            |
#                                            |
# (no matching instance)                     |Instance: cap_mim_2f0fF:C2
#                                            |  1 = 4
#                                            |  2 = 7
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#
# Subcircuit pins:
# Circuit 1: neurona_lvs                     |Circuit 2: neurona_lvs
# -------------------------------------------|-------------------------------------------
# vss                                        |spike **Mismatch**
# (no pin, node is Unnamed_89a8896a_2/a_n64_ |Vdd
# (no pin, node is Unnamed_89a8896a_2/a_n64_ |Vss
# (no pin, node is Unnamed_89a8896a_2/a_64_n |Iin
# (no pin, node is Unnamed_89a8896a_2/a_n64_ |spike_neg
# ---------------------------------------------------------------------------------------
# Cell pin lists for neurona_lvs and neurona_lvs altered to match.
# Device classes neurona_lvs and neurona_lvs are equivalent.
#
# Final result: Top level cell failed pin matching.
# {'magic_subproc_code': 0,
#  'netgen_subproc_code': 0,
#  'result_str': 'LVS run succeeded\nErrors found in LVS report: /tmp/tmpg45fn6m1/neurona_lvs_lvs.rpt'}

# %%
from pathlib import Path
import os
import subprocess

pdk_name = os.environ.get("PDK", "gf180mcuD")
pdk_root = Path(os.environ.get("PDK_ROOT", ""))
pdk_path_env = Path(os.environ.get("PDKPATH", ""))

# Resolve the correct magicrc path even if PDKPATH is stale or duplicated.
candidate_pdkpaths = [
    pdk_path_env,
    pdk_root / pdk_name,
    pdk_root,
]
magicrc_file = None
for candidate in candidate_pdkpaths:
    if not str(candidate):
        continue
    rc = candidate / "libs.tech" / "magic" / f"{pdk_name}.magicrc"
    if rc.exists():
        magicrc_file = rc
        break

if magicrc_file is None:
    raise FileNotFoundError(
        "No se encontro el magicrc. Revisar PDK_ROOT/PDK/PDKPATH. "
        f"Busque en: {[str(c) for c in candidate_pdkpaths if str(c)]}"
    )

# --- Cambio clave: usar path_to_dir en vez de Path.cwd()/"exports" ---
path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/lif/"
output_dir = Path(path_to_dir)
output_dir.mkdir(parents=True, exist_ok=True)

design_name = neurona_comp.name
gds_path = output_dir / f"{design_name}.gds"
lef_path = output_dir / f"{design_name}.lef"

neurona_comp.write_gds(str(gds_path))

magic_script = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}
load {design_name}
lef write {lef_path}
quit -noprompt
"""

result = subprocess.run(
    ["magic", "-rcfile", str(magicrc_file), "-noconsole", "-dnull"],
    input=magic_script,
    text=True,
    capture_output=True,
    check=True,
)

print(f"CWD kernel: {Path.cwd()}")
print(f"LEF generado: {lef_path}")
print(f"LEF existe: {lef_path.exists()}")
if lef_path.exists():
    print("\nCabecera LEF:")
    with open(lef_path, "r", encoding="utf-8", errors="ignore") as f:
        for _ in range(15):
            line = f.readline()
            if not line:
                break
            print(line.rstrip())
else:
    print("\n--- STDOUT COMPLETO DE MAGIC (para depurar) ---")
    print(result.stdout)
    print("\n--- STDERR COMPLETO DE MAGIC ---")
    print(result.stderr)
# Out:
# /tmp/ipykernel_17004/2720220758.py:39: UserWarning: Unnamed cells, 4 in 'neurona_lvs'
#   neurona_comp.write_gds(str(gds_path))
# 2026-08-20 22:03:23.209 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/CapiMagics/designs/libs/snn_analog/lif/neurona_lvs.gds'
# CWD kernel: /foss/designs
# LEF generado: /foss/designs/CapiMagics/designs/libs/snn_analog/lif/neurona_lvs.lef
# LEF existe: True
#
# Cabecera LEF:
# VERSION 5.7 ;
#   NOWIREEXTENSIONATPIN ON ;
#   DIVIDERCHAR "/" ;
#   BUSBITCHARS "[]" ;
# MACRO neurona_lvs
#   CLASS BLOCK ;
#   FOREIGN neurona_lvs ;
#   ORIGIN 2.000 3.700 ;
#   SIZE 57.860 BY 27.250 ;
#   PIN spike
#     ANTENNAGATEAREA 62.500000 ;
#     ANTENNADIFFAREA 82.209595 ;
#     PORT
#       LAYER Nwell ;
#         RECT 0.000 13.950 4.500 19.550 ;
