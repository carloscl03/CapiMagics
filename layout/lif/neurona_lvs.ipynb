# %%
# Librerias y configuraciones iniciales

import os
import subprocess

# Intenta cargar variables de entorno desde ~/.bashrc usando bash
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    # Recorre cada línea de salida y agrega las variables al entorno de Python
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    # Si ocurre algún error (timeout, archivo inexistente, etc.), lo ignora
    pass

# Configura la variable PDKPATH si existen PDK_ROOT y PDK en el entorno
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))


# --- Librerías para manejo de layouts y visualización ---
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirige salidas a un widget oculto (útil en notebooks)
hide = widgets.Output()


def display_gds(gds_file, path, scale=3):
    """
    Lee un archivo GDS, lo convierte a SVG, escala la imagen y la muestra inline.
    """
    # Obtiene la celda top-level del GDS
    top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
    top_level_cell.write_svg(os.path.join(path, 'out.svg'))
    
    # Escala la imagen para mejorar la visualización
    fig = sg.fromfile(os.path.join(path, 'out.svg'))
    fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
    fig.save(os.path.join(path, 'out.svg'))

    # Muestra el SVG en el notebook
    IPython.display.display(IPython.display.SVG(os.path.join(path, 'out.svg')))
    os.remove(os.path.join(path, 'out.gds'))  # Limpieza del archivo temporal


def display_component(component, path, scale=3):
    """
    Guarda un componente en GDS y lo muestra usando display_gds.
    """
    with hide:
        component.write_gds(os.path.join(path, 'out.gds'))
    display_gds(os.path.join(path, 'out.gds'), path, scale)


# --- Importación de librerías específicas para layout y PDK ---
import os
import gdsfactory as gf
from gdsfactory import Component
from glayout import MappedPDK, gf180
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring
from glayout.primitives.mimcap import mimcap_array, mimcap
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter, print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist


# --- Configuración base para dispositivos NMOS y PMOS ---
neurona_config = {
    "pdk": gf180,  # Define el PDK a usar
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation() + 2,  # Espaciado mínimo entre metales
        "routing_metal": "met2",  # Capa metálica principal para ruteo
        "dummy_devices": False,   # No usar dispositivos dummy
        "tie_layers": ("met2", "met1"),  # Capas para conexiones de substrato
        "sd_rmult": 1,  # Multiplicador de source/drain
    },
}

# Parámetros para NMOS
nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2", "met1"),
    "dummy_routes": False
}

# Parámetros para PMOS
pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2", "met1"),
    "dummy_routes": False
}


# --- Creación del componente principal ---
pdk = gf180
neurona_comp = Component(name="neurona_lvs")  # Componente base para la neurona
neurona_comp.name = "neurona_lvs"

# Extrae reglas de layout desde la configuración
rules = neurona_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Create transistor primitives based on .spice parameters
# M1, M3, M7: PMOS W=0.22u, L=0.28u, nf=1
m1 = pmos(
    pdk,
    width=0.5,                   # Ancho del canal (ajustado respecto al valor SPICE)
    length=0.28,            # Longitud efectiva (escalada por factor 2.27)
    with_dummy=(False, False),   # No se colocan transistores dummy
    with_substrate_tap=False,    # Sin conexión explícita al substrato
    tie_layers=tie_layers,       # Capas metálicas usadas para conexiones de substrato
    sd_rmult=sd_rmult,           # Multiplicador de ancho en source/drain
    **pmos_kwargs                # Parámetros adicionales definidos previamente
)

m3 = pmos(
    pdk,
    width=0.5,                   # Ancho del canal (ajustado respecto al valor SPICE)
    length=0.28,            # Longitud efectiva (escalada por factor 2.27)
    with_dummy=(False, False),   # No se colocan transistores dummy
    with_substrate_tap=False,    # Sin conexión explícita al substrato
    tie_layers=tie_layers,       # Capas metálicas usadas para conexiones de substrato
    sd_rmult=sd_rmult,           # Multiplicador de ancho en source/drain
    **pmos_kwargs                # Parámetros adicionales definidos previamente
)

m7 = pmos(
    pdk,
    width=0.5,                   # Ancho del canal (ajustado respecto al valor SPICE)
    length=0.28,            # Longitud efectiva (escalada por factor 2.27)
    with_dummy=(False, False),   # No se colocan transistores dummy
    with_substrate_tap=False,    # Sin conexión explícita al substrato
    tie_layers=tie_layers,       # Capas metálicas usadas para conexiones de substrato
    sd_rmult=sd_rmult,           # Multiplicador de ancho en source/drain
    **pmos_kwargs                # Parámetros adicionales definidos previamente
)


# M2, M4, M8: NMOS W=0.22u, L=0.28u, nf=1
m2 = nmos(
    pdk,
    width=0.5,
    length=0.28,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

m4 = nmos(
    pdk,
    width=0.5,
    length=0.28,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

m8 = nmos(
    pdk,
    width=0.5,
    length=0.28,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

# M5: Reset NMOS W=1.25u, L=50u, nf=1 (Long channel device)
m5_reset = nmos(
    pdk,
    width=2.3,                  # Transistor más ancho para reset
    length=50.0,                 # Canal largo (dispositivo de alta resistencia)
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

# # XC2: MIM Capacitor (3 parallel caps with 5u x 5u geometry)
# cap_mim = mimcap_array(
#     pdk,
#     size=(15.0, 5.0),             # Cada capacitor mide 5x5 micras
#     columns=1,                   # Tres capacitores en paralelo (columna)
#     rows=1                       # Una fila
# )

cap_mim = mimcap(
    pdk,
    size=(28.0, 5.0),             #  size=(15.0, 5.0),
    option="B",
    with_extension=False
)

# Renombrar instancias para identificación clara en LVS/Netlist
m1.name = "m1"
m3.name = "m3"
m7.name = "m7"
m2.name = "m2"
m4.name = "m4"
m8.name = "m8"
m5_reset.name = "m5"
cap_mim.name = "cap"

# ==============================================================================
# PLACEMENT & INSTANTIATION
# ==============================================================================

# Row 1: PMOS Transistors (M1, M3, M7)
m1_ref = neurona_comp << m1    # Instancia M1 en el componente neurona
m3_ref = neurona_comp << m3    # Instancia M3
m7_ref = neurona_comp << m7    # Instancia M7

# Row 2: Standard NMOS Transistors (M2, M4, M8) placed directly below PMOS
m2_ref = neurona_comp << m2   # Instancia M2
m4_ref = neurona_comp << m4    # Instancia M4
m8_ref = neurona_comp << m8    # Instancia M8

# Placement: Reset NMOS (M5) - Long channel, placed below M2/M4
m5_ref = neurona_comp << m5_reset

# Placement: MIM Capacitor Array (XC2) - Placed adjacent to the inverter core
cap_ref = neurona_comp << cap_mim



# Ensure grid snap compliance (alinear a la grilla de diseño)
# neurona_comp = component_snap_to_grid(neurona_comp)

# Display rendered placement component (visualización en notebook)
# display_component(stdp_comp, "./")
# Out:
# 2026-09-02 20:03:42.889 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
help(mimcap)
# Out:
# Help on function mimcap in module glayout.primitives.mimcap:
#
# mimcap(pdk: glayout.pdk.mappedpdk.MappedPDK, size: tuple[float, float] = (5.0, 5.0), option: str = 'B', with_extension: bool = True, extension_direction: str = 'S', extension_width: float = 0.0, extension_length: float = 0.0) -> gdsfactory.component.Component
#     create a MIM capacitor according to GF180MCU Option A or Option B
#
#     MIM Option A structure (Metal3-Metal2 stack):
#     - FuseTop layer defines the top plate of MIM capacitor
#     - Metal3 forms the actual top plate
#     - CAP_MK defines the dielectric layer
#     - Metal2 forms the bottom plate
#     - For 3 metal layer processes
#
#     MIM Option B structure (Metal5-Metal4 stack):
#     - FuseTop layer defines the top plate area
#     - Metal5 (top metal) forms the actual top plate
#     - CAP_MK defines the dielectric
#     - Metal4 (bottom metal) forms the bottom plate
#     - MIM_L_MK marks the capacitor's length dimension
#     - For 4+ metal layer processes
#
#     args:
#     pdk=pdk to use
#     size=tuple(float,float) size of cap
#     option=str either "A" for Metal3-Metal2 or "B" for Metal5-Metal4 (default: "B")
#     with_extension=bool enable extension or not
#     extension_direction=str specify which direction to use for the extension
#     extension_width=float width of bottom plate extensions for via connections (default: 0.0um)
#     extension_length=float length of bottom plate extensions outside capacitor (default: 0.0um)
#
#     ports:
#     top_met_...all edges, this is the top metal plate
#     met5_...all edges, this is the bottom metal plate connection through metal5 vias

# %%
# Funcion para visualizar el layout y realizar DRC
def view_and_check_lvs():
    """
    Función para visualizar el layout de la neurona LVS.
    Muestra el componente y realiza un DRC.
    """
    neurona_comp.show()
    display_component(neurona_comp, scale=1, path=".")
    drc_result = gf180.drc_magic(neurona_comp, neurona_comp.name)

#    # Revisar si hay errores
#    if drc_result.get("errors"):   # si la lista no está vacía
#        print(f"⚠ DRC encontró {len(drc_result['errors'])} violaciones")
#    else:
#        print("✔ DRC limpio: No errors found")
        
    return

# %%
# Calcular coordenadas base para filas
bottom_row = evaluate_bbox(m2_ref)[1]/2
# → Altura de la fila inferior (NMOS), usando la mitad de la dimensión Y de M2

middle_row = bottom_row + evaluate_bbox(m5_ref)[1]
# → Fila intermedia: se coloca justo encima de la fila inferior,
#   sumando la altura del transistor de reset (M5)

top_row = middle_row + evaluate_bbox(m1_ref)[1] + 2
# → Fila superior: encima de la fila intermedia,
#   sumando la altura de un PMOS (M1) y un margen extra de 2 unidades

#-------------------------------------------------------------------------------

spacing_x = 1.5  # µm, ajusta según el reporte DRC

# --- Colocación de PMOS en la fila superior ---
m1_ref.move((0 + evaluate_bbox(m1_ref)[0]/2, top_row))
# → M1 se coloca en el origen X, centrado en su ancho, y en la fila superior

m3_ref.move((m1_ref.xmax + evaluate_bbox(m3_ref)[0]/2 + spacing_x, top_row))
# → M3 se coloca a la derecha de M1, usando xmax de M1 como referencia

m7_ref.move((m3_ref.xmax + evaluate_bbox(m7_ref)[0]/2 + spacing_x, top_row))
# → M7 se coloca a la derecha de M3

# --- Colocación de NMOS en la fila inferior ---
m2_ref.move((0 + evaluate_bbox(m2_ref)[0]/2, bottom_row))
# → M2 en el origen X, centrado, en la fila inferior

m4_ref.move((m2_ref.xmax + evaluate_bbox(m4_ref)[0]/2 + spacing_x, bottom_row))
# → M4 a la derecha de M2

m8_ref.move((m4_ref.xmax + evaluate_bbox(m8_ref)[0]/2 + spacing_x, bottom_row))
# → M8 a la derecha de M4

# --- Colocación del capacitor MIM ---
cap_ref.move((m8_ref.xmax + evaluate_bbox(cap_ref)[0]/2 + spacing_x + 2, bottom_row))
# → El capacitor se coloca a la derecha de M8, en la misma fila inferior

# --- Colocación del NMOS de reset (M5) ---
m5_ref.move((0 + evaluate_bbox(m5_ref)[0]/2, middle_row+0.75))
# → M5 se coloca centrado en X=0, pero en la fila intermedia
# Out:
# ComponentReference (parent Component "m5", ports ['multiplier_0_gate_W', 'gate_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'multiplier_0_leftsd_array_row0_col0_top_met_W', 'multiplier_0_row0_col0_gate_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_top_met_W', 'multiplier_0_leftsd_array_row1_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row1_col0_bottom_via_W', 'multiplier_0_leftsd_array_row1_col0_bottom_met_W', 'multiplier_0_leftsd_array_row1_col0_top_met_W', 'multiplier_0_leftsd_top_met_W', 'multiplier_0_plusdoped_W', 'multiplier_0_diff_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_W', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row2_col0_bottom_via_W', 'multiplier_0_leftsd_array_row2_col0_bottom_met_W', 'multiplier_0_leftsd_array_row2_col0_top_met_W', 'multiplier_0_source_W', 'source_W', 'multiplier_0_drain_W', 'drain_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row0_col0_bottom_via_N', 'multiplier_0_leftsd_array_row0_col0_bottom_met_N', 'multiplier_0_leftsd_array_row0_col0_top_met_N', 'multiplier_0_leftsd_array_row1_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row1_col0_bottom_via_N', 'multiplier_0_leftsd_array_row1_col0_bottom_met_N', 'multiplier_0_leftsd_array_row1_col0_top_met_N', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row2_col0_bottom_via_N', 'multiplier_0_leftsd_array_row2_col0_bottom_met_N', 'multiplier_0_leftsd_array_row2_col0_top_met_N', 'multiplier_0_leftsd_top_met_N', 'multiplier_0_row0_col0_gate_N', 'multiplier_0_plusdoped_N', 'multiplier_0_diff_N', 'multiplier_0_drain_N', 'multiplier_0_source_N', 'source_N', 'drain_N', 'multiplier_0_gate_N', 'gate_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_top_met_N', 'multiplier_0_drain_E', 'drain_E', 'multiplier_0_source_E', 'source_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_E', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_E', 'multiplier_0_leftsd_array_row2_col0_bottom_via_E', 'multiplier_0_leftsd_array_row2_col0_bottom_met_E', 'multiplier_0_leftsd_array_row2_col0_top_met_E', 'multiplier_0_row0_col0_gate_E', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_E', 'multiplier_0_row0_col0_rightsd_array_row1 ...

# %%
# ADD AVDD & AVSS POWER RAILS AND CONNECT SUPPLY NODES
# =========================================================================

# Calculate full horizontal span of the cell to draw supply rails
bbox = evaluate_bbox(neurona_comp)
# → Obtiene el bounding box del componente neurona_comp (ancho total y alto)

top_y = neurona_comp.ymax + 3.0
# → Coordenada Y para la línea superior (AVDD), con margen extra de 3 µm

bottom_y = neurona_comp.ymin - 3.0
# → Coordenada Y para la línea inferior (AVSS), con margen extra de 3 µm


# Draw horizontal metal2 power rails
avdd_rail = neurona_comp << gf.components.rectangle(
    size=(bbox[0]+4, 1.0),              # Largo = ancho del layout + 4 µm, grosor = 1 µm
    layer=pdk.get_layer("metal5")       # Se dibuja en la capa metal2
)
avdd_rail.move((-2, top_y))             # Se coloca en la parte superior (rail AVDD)

avss_rail = neurona_comp << gf.components.rectangle(
    size=(bbox[0]+4, 1.0),
    layer=pdk.get_layer("metal5")
)
avss_rail.move((-2, bottom_y))          # Se coloca en la parte inferior (rail AVSS)


### METAL5 TOP
#bbox_vdd = evaluate_bbox(avdd_rail)
#
#avdd_M5 = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+10, 6.13), 
#    layer=pdk.get_layer("metal5")
#)
#avdd_M5.move((-7, top_y + bbox_vdd[1] + 2))
#
##m5_label
#avdd_label = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+10, 6.13), 
#    layer=pdk.get_layer("metal5_label")
#)
#avdd_label.move((-7, top_y + bbox_vdd[1] + 2))
#
#bbox_vss_M5 = evaluate_bbox(avdd_M5)
#
## Draw horizontal metal5 power rails
#avss_M5 = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+20, 6.13), 
#    layer=pdk.get_layer("metal5")
#)
#avss_M5.move((-12, top_y + bbox_vdd[1] + bbox_vss_M5[1] + 4))
#
##m5 lABEL
#avss_label = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+20, 6.13), 
#    layer=pdk.get_layer("metal5_label")
#)
#avss_label.move((-12, top_y + bbox_vdd[1] + bbox_vss_M5[1] + 4))
#
#
### METAL5 BOTTOM
#bbox_vss = evaluate_bbox(avss_rail)
#
#avdd_M5_bot = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+10, 6.13), 
#    layer=pdk.get_layer("metal5")
#)
#bbox_vssbot = evaluate_bbox(avdd_M5_bot)
#avdd_M5_bot.move((-7, bottom_y - bbox_vssbot[1] - 2))
#
##met5_label
#avdd_label_bot = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+10, 6.13), 
#    layer=pdk.get_layer("metal5_label")
#)
#avdd_label_bot.move((-7, bottom_y - bbox_vssbot[1] - 2))
#
#
#avss_M5_bot = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+20, 6.13), 
#    layer=pdk.get_layer("metal5")
#)
#avss_M5_bot.move((-12, bottom_y - 2 * bbox_vssbot[1] - 4))
#
##metal5_label VSS
#avss_label_bot = neurona_comp << gf.components.rectangle(
#    size=(bbox_vdd[0]+20, 6.13), 
#    layer=pdk.get_layer("metal5_label")
#)
#avss_label_bot.move((-12, bottom_y - 2 * bbox_vssbot[1] - 4))
#
##verticales
#
##met4_label Vss left
#avss1_label_m4 = neurona_comp << gf.components.rectangle(
#    size=(5,56.81), #56.81
#    layer=pdk.get_layer("metal4_label")
#)
#avss1_label_m4.move((-13,-18.71)) #38
#
##met4_label VDD left
#avdd1_label_m4 = neurona_comp << gf.components.rectangle(
#    size=(5,38.55), #56.81
#    layer=pdk.get_layer("metal4_label")
#)
#avdd1_label_m4.move((-6,-9.58)) #38
#
##met4_label VDD right
#avdd2_label_m4 = neurona_comp << gf.components.rectangle(
#    size=(5,38.55), #56.81
#    layer=pdk.get_layer("metal4_label")
#)
#avdd2_label_m4.move((54.5,-9.58)) #38
#
##met4_label Vss right
#avss2_label_m4 = neurona_comp << gf.components.rectangle(
#    size=(5,56.81), #56.81
#    layer=pdk.get_layer("metal4_label")
#)
#avss2_label_m4.move((61.5,-18.71)) #38


#adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avdd_M5 = neurona_comp << viam2m5
# via_avdd_M5.move((-3.5, top_y + bbox_vss_M5[1] - 0.5))
# via_avdd_M5B = neurona_comp << viam2m5
# via_avdd_M5B.move((-3.5, bottom_y - bbox_vss_M5[1] + 0.5))

# neurona_comp  << straight_route(pdk, via_avdd_M5.ports["bottom_met_S"], via_avdd_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")
# #neurona_comp  << straight_route(pdk, via_avdd_M5.ports["bottom_met_S"], via_avdd_M5B.ports["bottom_met_N"],glayer1="met4_label",glayer2="met4_label",width="5")


# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avss_M5 = neurona_comp << viam2m5
# via_avss_M5.move((-10.5, top_y + 2* bbox_vss_M5[1] + 2.5))
# via_avss_M5B = neurona_comp << viam2m5
# via_avss_M5B.move((-10.5, bottom_y - 2*bbox_vss_M5[1] - 2.5))

# neurona_comp  << straight_route(pdk, via_avss_M5.ports["bottom_met_S"], via_avss_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avddL_M5 = neurona_comp << viam2m5
# via_avddL_M5.move((57, top_y + bbox_vss_M5[1] - 0.5))
# via_avddL_M5B = neurona_comp << viam2m5
# via_avddL_M5B.move((57, bottom_y - bbox_vss_M5[1] + 0.5))

# neurona_comp  << straight_route(pdk, via_avddL_M5.ports["bottom_met_S"], via_avddL_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avssL_M5 = neurona_comp << viam2m5
# via_avssL_M5.move((64, top_y + 2* bbox_vss_M5[1] + 2.5))
# via_avssL_M5B = neurona_comp << viam2m5
# via_avssL_M5B.move((64, bottom_y - 2*bbox_vss_M5[1] - 2.5))

# neurona_comp  << straight_route(pdk, via_avssL_M5.ports["bottom_met_S"], via_avssL_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")




#adding a VIA M2M3 to the avdd avss pin, moving to the center of the rail
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.

via_avdd = neurona_comp << viam2m5
via_avdd.move((bbox[0]/2, top_y + 0.5))
via_avss = neurona_comp << viam2m5
via_avss.move((bbox[0]/2, bottom_y + 0.5))

# #connecting ports to ring
# neurona_comp  << L_route(pdk, via_avdd.ports["bottom_met_N"], via_avddL_M5.ports["bottom_met_W"])
# neurona_comp  << L_route(pdk, via_avss.ports["bottom_met_S"], via_avssL_M5B.ports["bottom_met_W"])
# Out:
# ComponentReference (parent Component "via_stack_b843013f", ports ['bottom_layer_W', 'bottom_layer_N', 'bottom_layer_E', 'bottom_layer_S', 'bottom_via_W', 'bottom_via_N', 'bottom_via_E', 'bottom_via_S', 'bottom_met_W', 'bottom_met_N', 'bottom_met_E', 'bottom_met_S', 'top_met_W', 'top_met_N', 'top_met_E', 'top_met_S'], origin (26.93, -2.8), rotation 0.0, x_reflection False)

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:50.046 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "open", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:50.245 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp0gsagtxf/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmp0gsagtxf/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "m8".
# Reading "m4".
# Reading "via_stack_b843013f".
# Reading "rectangle_9b95c421".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "compass_9b95c421$1".
# Reading "m3".
# Reading "m5".
# Reading "cap".
# Reading "m7".
# Reading "m2".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmp0gsagtxf/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
#conectando todos los sustratos
#Transistores P
neurona_comp  << L_route(pdk, m1_ref.ports["tie_N_top_met_N"], via_avdd.ports["bottom_met_W"])
neurona_comp  << L_route(pdk, m3_ref.ports["tie_N_top_met_N"], via_avdd.ports["bottom_met_W"])
neurona_comp  << L_route(pdk, m7_ref.ports["tie_N_top_met_N"], via_avdd.ports["bottom_met_W"])

#Transistores N
neurona_comp  << L_route(pdk, m2_ref.ports["tie_S_top_met_S"], via_avss.ports["bottom_met_W"])
neurona_comp  << L_route(pdk, m4_ref.ports["tie_S_top_met_S"], via_avss.ports["bottom_met_W"])
neurona_comp  << L_route(pdk, m8_ref.ports["tie_S_top_met_S"], via_avss.ports["bottom_met_W"])
# --- Conexión del sustrato de M5 a VSS ---
neurona_comp << c_route(pdk,m5_ref.ports["tie_S_top_met_W"], via_avss.ports["bottom_met_W"] )
# Out:
# ComponentReference (parent Component "c_route_22950f53", ports ['con_N', 'con_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
# conectar source con bulk
#Transistores N
neurona_comp << straight_route(pdk, m2_ref.ports["source_W"], m2_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m4_ref.ports["source_W"], m4_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m8_ref.ports["source_W"], m8_ref.ports["tie_W_top_met_E"])
# --- Conexión del bulk de M5 ---
neurona_comp << straight_route(pdk, m5_ref.ports["source_W"], m5_ref.ports["tie_W_top_met_E"])
#Transistores P
neurona_comp << straight_route(pdk, m1_ref.ports["source_W"], m1_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m3_ref.ports["source_W"], m3_ref.ports["tie_W_top_met_E"])
neurona_comp << straight_route(pdk, m7_ref.ports["source_W"], m7_ref.ports["tie_W_top_met_E"])
# Out:
# ComponentReference (parent Component "straight_route_f0d99bf9", ports ['route_W', 'route_N', 'route_E', 'route_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:51.759 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:52.129 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmps0wo7ekv/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmps0wo7ekv/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "c_route_22950f53".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "L_route_87c4f6ee".
# Reading "cap".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "via_stack_b843013f".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_5e09102b".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "compass_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "m5".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmps0wo7ekv/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
#inversor 1 -------------------------------------------------------------------------------------------
#subir de metal 2 a metal 3 en las terminales de gate de M1
via_gate_m1 = via_stack(pdk, "met2", "met3", centered=True)
node_m1_gate = neurona_comp << via_gate_m1
node_m1_gate.move(m1_ref.ports["gate_N"].center)
# Gate M1 → nodo M1 (Metal2)
neurona_comp << straight_route(pdk, m1_ref.ports["gate_S"], node_m1_gate.ports["bottom_met_W"]) 

#subir de metal 2 a metal 3 en las terminales de gate de M2
via_gate_m2 = via_stack(pdk, "met2", "met3", centered=True)
node_m2_gate = neurona_comp << via_gate_m2
node_m2_gate.move(m2_ref.ports["gate_N"].center)
# Gate M2 → nodo M2 (Metal2)
neurona_comp << straight_route(pdk, m2_ref.ports["gate_S"], node_m2_gate.ports["bottom_met_N"])   

node_cap = neurona_comp << via_gate_m2
node_cap.move(m1_ref.ports["gate_S"].center).movey(-2.8) #connecting top plate cap with gate M1 gate m2

# Nodo M1 ↔ Nodo M2 (Metal3)
neurona_comp << straight_route(pdk, node_m1_gate.ports["top_met_S"], node_m2_gate.ports["top_met_N"])
neurona_comp << c_route(pdk, m1_ref.ports["drain_E"], m2_ref.ports["drain_E"])

#inversor 2 -------------------------------------------------------------------------------------------
#subir de metal 2 a metal 3 en las terminales de gate de M1
via_gate_m3 = via_stack(pdk, "met2", "met3", centered=True)
node_m3_gate = neurona_comp << via_gate_m3
node_m3_gate.move(m3_ref.ports["gate_N"].center)
# Gate M3 → nodo M3 (Metal2)
neurona_comp << straight_route(pdk, m3_ref.ports["gate_S"], node_m3_gate.ports["bottom_met_W"]) 

#subir de metal 2 a metal 3 en las terminales de gate de M2
via_gate_m4 = via_stack(pdk, "met2", "met3", centered=True)
node_m4_gate = neurona_comp << via_gate_m4
node_m4_gate.move(m4_ref.ports["gate_N"].center)
# Gate M4 → nodo M4 (Metal2)
neurona_comp << straight_route(pdk, m4_ref.ports["gate_S"], node_m4_gate.ports["bottom_met_N"])   
# Nodo M3 ↔ Nodo M4 (Metal3) 
neurona_comp << straight_route(pdk, node_m3_gate.ports["top_met_S"], node_m4_gate.ports["top_met_N"])
neurona_comp << c_route(pdk, m3_ref.ports["drain_E"], m4_ref.ports["drain_E"])
via_spk_neg = neurona_comp << via_gate_m4               #creating a via
via_spk_neg.move(m5_ref.ports["gate_W"]).movex(7.5)     #to connect gate m5 to m3drain, m4 drain

#inversor 3 -------------------------------------------------------------------------------------------
#subir de metal 2 a metal 3 en las terminales de gate de M1
via_gate_m7 = via_stack(pdk, "met2", "met3", centered=True)
node_m7_gate = neurona_comp << via_gate_m7
node_m7_gate.move(m7_ref.ports["gate_N"].center) 
# Gate M7 → nodo M7 (Metal2)
neurona_comp << straight_route(pdk, m7_ref.ports["gate_S"], node_m7_gate.ports["bottom_met_W"]) 

#subir de metal 2 a metal 3 en las terminales de gate de M2
via_gate_m8 = via_stack(pdk, "met2", "met3", centered=True)
node_m8_gate = neurona_comp << via_gate_m8
node_m8_gate.move(m8_ref.ports["gate_N"].center)
# Gate M8 → nodo M8 (Metal2)
neurona_comp << straight_route(pdk, m8_ref.ports["gate_S"], node_m8_gate.ports["bottom_met_N"])   

# Nodo M7 ↔ Nodo M8 (Metal3)
neurona_comp << straight_route(pdk, node_m7_gate.ports["top_met_S"], node_m8_gate.ports["top_met_N"])
neurona_comp << c_route(pdk, m7_ref.ports["drain_E"], m8_ref.ports["drain_E"])

Iin_via = via_stack(pdk, "met2", "met4", centered=True)
Iin_via_ref=neurona_comp << Iin_via
Iin_via_ref.move(m5_ref.ports["drain_W"].center).movex(-2.5)

neurona_comp << straight_route(pdk, Iin_via_ref.ports["bottom_met_E"], m5_ref.ports["drain_W"])


spike_via = via_stack(pdk, "met2", "met4", centered=True)
spike_via_ref=neurona_comp << spike_via
spike_via_ref.move(m7_ref.ports["drain_E"].center).movex(39)

neurona_comp << straight_route(pdk, spike_via_ref.ports["bottom_met_E"], m7_ref.ports["drain_E"])

spike_neg_via = via_stack(pdk, "met3", "met4", centered=True)
spike_neg_via_ref=neurona_comp << spike_neg_via
spike_neg_via_ref.move(m7_ref.ports["drain_E"].center).movex(40).movey(3)

neurona_comp << c_route(pdk, spike_neg_via_ref.ports["top_met_W"], m1_ref.ports["drain_W"],e1glayer="met3", e2glayer="met2",cglayer="met2", extension=2)
# Out:
# ComponentReference (parent Component "c_route_84615c86", ports ['con_N', 'con_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:53.913 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:54.250 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpj0vwb3ow/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpj0vwb3ow/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_7a5b3fd8".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpj0vwb3ow/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
help(c_route)
# Out:
# Help on function c_route in module glayout.routing.c_route:
#
# c_route(pdk: glayout.pdk.mappedpdk.MappedPDK, edge1: gdsfactory.port.Port, edge2: gdsfactory.port.Port, extension: Optional[float] = 0.5, width1: Optional[float] = None, width2: Optional[float] = None, cwidth: Optional[float] = None, e1glayer: Optional[str] = None, e2glayer: Optional[str] = None, cglayer: Optional[str] = None, viaoffset: Union[bool, tuple[Optional[bool], Optional[bool]], NoneType] = (True, True), fullbottom: Optional[bool] = False, extra_vias: Optional[bool] = False, debug=False) -> gdsfactory.component.Component
#     creates a C shaped route between two Ports.
#
#     edge1--|
#            |
#     edge2--|
#
#     REQUIRES: ports be parralel vertical or horizontal edges
#     ****NOTE: does no drc error checking (creates a dumb route)
#     args:
#     pdk = pdk to use
#     edge1 = first port
#     edge2 = second port
#     width1 = optional will default to edge1 width if None
#     width2 = optional will default to edge2 width if None
#     e1glayer = glayer for the parts connecting to the edge1. Default to layer of edge1
#     e2glayer = glayer for the parts connecting to the edge2. Default to layer of edge2
#     cglayer = glayer for the connection part (part that goes through a via) defaults to e1glayer met+1
#     viaoffset = offsets the via so that it is flush with the cglayer (may be needed for drc) i.e. -| vs _|
#     - True offsets via towards the other via
#     - False offsets via away from the other via
#     - None means center (no offset)
#     ****NOTE: viaoffset pushes both vias towards each other slightly
#     extra_vias = adds extra vias at intermediate nodes if metal width permits

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:55.052 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:55.283 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpve214gm_/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpve214gm_/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_7a5b3fd8".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpve214gm_/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
#otras conexiones -------------------------------------------------------------------------------------
# Crear via stack para subir de M2 a M3
via_drain_m2 = via_stack(pdk, "met2", "met3", centered=True)
node_m2_drain = neurona_comp << via_drain_m2

# Obtener coordenadas del puerto drain_E
drain_pos = m2_ref.ports["drain_E"].center

# Calcular borde derecho de la celda de M2
bbox = evaluate_bbox(m2_ref)   # [width, height]
x_edge = m2_ref.xmax+0.2           # borde derecho en X

# Mover el nodo al borde derecho, centrado en Y del drain
node_m2_drain.move((x_edge, drain_pos[1]))

# Conectar drain → nodo en Metal2
neurona_comp << straight_route(pdk, m2_ref.ports["drain_E"], node_m2_drain.ports["bottom_met_W"])

# Gate M4 (lado W) → Nodo M2 (Metal2, lado S)
neurona_comp << L_route(pdk, m4_ref.ports["gate_W"], node_m2_drain.ports["bottom_met_S"] )

# Conexión directa entre gate de M4 y gate de M8
neurona_comp << straight_route(pdk, m4_ref.ports["gate_E"], m8_ref.ports["gate_W"])

# --- Conexión del capacitor MIM (electrodo inferior) a VSS ---

neurona_comp << straight_route(pdk,cap_ref.ports["top_met_N"],m5_ref.ports["drain_S"])
#neurona_comp << straight_route(pdk,cap_ref.ports["array_row0_col0_bottom_met_S"],via_avss.ports["bottom_met_W"])

# Conexión del puerto inferior del capacitor hacia AVSS
neurona_comp << c_route(
    pdk,
    cap_ref.ports["array_row0_col0_bottom_met_W"],   # puerto inferior del capacitor (lado Este)
    via_avss.ports["bottom_met_W"],                  # puerto del anillo AVSS (lado Este)
    e1glayer="met4",                                 # primer tramo en Metal5
    e2glayer="met2",                                 # destino en Metal2 (AVSS)
    cglayer="met5",                                  # capa de conexión intermedia
    extension=2                                      # extensión opcional para ajustar
)


## Bounding box del capacitor
#(xmin, ymin), (xmax, ymax) = cap_ref.bbox
#cap_width = xmax - xmin
#cap_center_x = (xmin + xmax) / 2
#
## Altura del nodo en Metal5
#tab_height = 2.0
#
## Offset vertical (positivo = separado, negativo = superpuesto)
#offset_y = -0.5   # ejemplo: 0.5 µm separado; -0.5 µm superpuesto
#
## Crear nodo en Metal5 (mismo ancho que el capacitor)
#node_m5 = gf.components.rectangle(
#    size=(cap_width, tab_height),
#    layer=pdk.get_layer("metal5"),
#    name="node_m5"
#)
#
## Insertar y colocar centrado en X, con offset respecto al borde inferior del capacitor
#node_m5_ref = neurona_comp << node_m5
#node_m5_ref.center = (cap_center_x, ymin - tab_height/2 - offset_y)
#
## Bounding box del nodo en Metal5
#(xmin_m5, ymin_m5), (xmax_m5, ymax_m5) = node_m5_ref.bbox
#
## Crear un puerto artificial en el borde sur del nodo Metal5
#port_node_m5_south = gf.Port(
#    name="node_m5_south",
#    center=((xmin_m5 + xmax_m5) / 2, ymin_m5),  # borde sur
#    width=cap_width,
#    orientation=270,                            # hacia abajo
#    layer=pdk.get_layer("metal5")
#)
#
## Conexión del nodo en Metal5 hacia via_avss
#neurona_comp << straight_route(
#    pdk,
#    port_node_m5_south,
#    via_avss.ports["bottom_met_W"]
#)
# Out:
# ComponentReference (parent Component "c_route_da7bb6fc", ports ['con_N', 'con_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:56.287 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:56.673 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmptlt5hm4b/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmptlt5hm4b/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "L_route_929a1543".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_25921472".
# Reading "straight_route_7a5b3fd8".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "via_stack_0933432e".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "straight_route_ef21a436".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "straight_route_8c66551b".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "c_route_da7bb6fc".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmptlt5hm4b/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
display_component(neurona_comp, scale = 1,path=".")

# %%
# ----------- adding a full rectangle in metal (0/0) ---------------------
full_rect_00 = neurona_comp << gf.components.rectangle(
    size=evaluate_bbox(neurona_comp), 
    layer=(0, 0)
)
#moviendo a las coordenadas 0,0 del layout
full_rect_00.move((neurona_comp.xmin, neurona_comp.ymin))
# Out:
# ComponentReference (parent Component "rectangle_c22e7f21", ports ['e1', 'e2', 'e3', 'e4'], origin (-2.0, -3.3), rotation 0.0, x_reflection False)

# %%
#----------- Adding snippet code to move all the placed components to the proper position, 
#----------- in order to set origin into 0,0
# Place this snippet after all your material polygones are placed, and before your ports are placed
bbox = neurona_comp.bbox[0]
for ref in neurona_comp.references:
    ref.movex(-1*bbox[0]).movey(-1*bbox[1])

# %%
evaluate_bbox(neurona_comp)
# Out:
# (57.86, 27.89)

# %%
evaluate_bbox(neurona_comp)[0] * evaluate_bbox(neurona_comp)[1]
# Out:
# 1613.7154

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:57.729 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:58.090 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp_t3d4ype/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmp_t3d4ype/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "L_route_929a1543".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_25921472".
# Reading "straight_route_7a5b3fd8".
# Reading "compass_c22e7f21".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "rectangle_c22e7f21".
# Reading "via_stack_0933432e".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "straight_route_ef21a436".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "straight_route_8c66551b".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "c_route_da7bb6fc".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmp_t3d4ype/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
# =========================================================================
# 5. ADD MET2 PHYSICAL PINS AND LABELS FOR LVS
# =========================================================================


# Add global ports for the supply rails
# modifico a m5
neurona_comp.add_port(
    "vdd",                              # Nombre del puerto global de alimentación
    # center=(bbox[0]/2, top_y + 0.5),    # Centro del puerto sobre el rail superior
    center = via_avdd.center,
    width=1.0,
    orientation=180,                    # Orientación hacia la izquierda
    layer=pdk.get_layer("metal5"),
    port_type="electrical"              # Tipo de puerto: eléctrico
)

neurona_comp.add_port(
    "vss",                              # Nombre del puerto global de tierra
    # center=(bbox[0]/2, bottom_y + 0.5), # Centro del puerto sobre el rail inferior
    center = via_avss.center,
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal5"),
    port_type="electrical"
)


# # add label to those global ports 
# neurona_comp.add_label(
#     text="vdd",                         # Etiqueta para el rail superior
#     position=(bbox[0]/2, top_y + 0.5),
#     layer=pdk.get_glayer("met3_label"), # Capa de etiquetas para metal2
#     magnification=1.5
# )

# neurona_comp.add_label(
#     text="vss",                         # Etiqueta para el rail inferior
#     position=(bbox[0]/2, bottom_y + 0.5),
#     layer=pdk.get_glayer("met3_label"),
#     magnification=1.5
# )

neurona_comp.add_label(
    text="vss",                         # Etiqueta para el rail inferior
    # position=(64, top_y + 2* bbox_vss_M5[1] + 2.5),
    position = via_avss.center,
    layer=pdk.get_glayer("met5_label"),
    magnification=1.5
)

# add label to those global ports 
neurona_comp.add_label(
    text="vdd",                         # Etiqueta para el rail superior
    # position=(-3.5, top_y + bbox_vss_M5[1] - 0.5),
    position = via_avdd.center,
    layer=pdk.get_glayer("met5_label"), # Capa de etiquetas para metal2
    magnification=1.5
)


# "Iin"
neurona_comp.add_port("Iin", center=(Iin_via_ref.ports["top_met_W"].center), width=1.0, orientation=180, layer=pdk.get_layer("metal4"),  port_type="electrical")
neurona_comp.add_label(
        text="Iin", position=(Iin_via_ref.ports["top_met_W"].center), layer=pdk.get_glayer("met4_label"), magnification=1.2
    )


# "Spike_neg"
neurona_comp.add_port("spike_neg", center=(spike_neg_via_ref.ports["top_met_W"].center), width=1.0, orientation=180, layer=pdk.get_layer("metal4"),  port_type="electrical")
neurona_comp.add_label(
        text="spike_neg", position=(spike_neg_via_ref.ports["top_met_W"].center), layer=pdk.get_glayer("met4_label"), magnification=1.2
    )

# "Spike"
neurona_comp.add_port("spike", center=(spike_via_ref.ports["top_met_E"].center), width=1.0, orientation=180, layer=pdk.get_layer("metal4"),  port_type="electrical")
neurona_comp.add_label(
        text="spike", position=(spike_via_ref.ports["top_met_E"].center), layer=pdk.get_glayer("met4_label"), magnification=1.2
    )

# Crear una lámina de metal4 de 1 µm x 1 µm
spike_metal = gf.components.rectangle(
    size=(2.0, 2.0),                       # dimensiones en µm
    layer=pdk.get_layer("metal4"),
    name="spike_metal"
)

# Insertar la lámina en el diseño, centrada en el puerto spike existente
spike_metal_ref = neurona_comp << spike_metal
spike_metal_ref.center = spike_via_ref.ports["top_met_E"]

# %%
display_component(neurona_comp, scale = 1,path=".")

# %%
view_and_check_lvs()
# Out:
# 2026-09-02 20:03:59.048 | INFO     | gdsfactory.klive:show:55 - Message from klive: {"version": "0.4.1", "klayout_version": "0.30.8", "type": "reload", "file": "/tmp/gdsfactory/neurona_lvs.gds"}
# 2026-09-02 20:03:59.642 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpxmisgn__/neurona_lvs.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpxmisgn__/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "L_route_929a1543".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "compass_669c8fc8".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_25921472".
# Reading "straight_route_7a5b3fd8".
# Reading "compass_c22e7f21".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "rectangle_c22e7f21".
# Reading "via_stack_0933432e".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "straight_route_ef21a436".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "straight_route_8c66551b".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "c_route_da7bb6fc".
# Reading "spike_metal".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# [INFO]: Loading neurona_lvs
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpxmisgn__/neurona_lvs.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
neurona_comp.pprint_ports()
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name      ┃ width ┃ center          ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ vdd       │ 1.0   │ [28.93, 27.39]  │ 180         │ [81, 0] │ electrical │
# │ vss       │ 1.0   │ [28.93, 0.5]    │ 180         │ [81, 0] │ electrical │
# │ Iin       │ 1.0   │ [0.65, 16.585]  │ 180         │ [46, 0] │ electrical │
# │ spike_neg │ 1.0   │ [56.67, 25.535] │ 180         │ [46, 0] │ electrical │
# │ spike     │ 1.0   │ [56.17, 22.535] │ 180         │ [46, 0] │ electrical │
# └───────────┴───────┴─────────────────┴─────────────┴─────────┴────────────┘

# %%
evaluate_bbox(neurona_comp)
# Out:
# (57.86, 27.89)

# %%
neurona_comp.unlock()

# %%
import os
from pathlib import Path
import tempfile
import subprocess

# Configuración de Magic
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"

# Nombre del diseño
design_name = neurona_comp.name

# Ruta donde guardas tus archivos
path_to_dir = "/foss/designs/libs/snn_analog/lif/"

# Archivos de salida
pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"
lef_path = path_to_dir + f"{design_name}.lef"

# Exportar GDS
neurona_comp.write_gds(str(gds_path))

#Script de Magic para extracción
magic_script_content = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
port avdd use power
port avss use ground
ext2spice -o {pex_path}
exit
"""



# Guardar script temporal
with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name

# Ejecutar Magic en modo batch
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'"
magic_subproc = subprocess.run(
    magic_cmd,
    shell=True,
    check=True,
    capture_output=True
)

# Capturar salida
magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# 2026-09-02 20:04:00.356 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/lif/neurona_lvs.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "L_route_929a1543".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "compass_669c8fc8".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_25921472".
# Reading "straight_route_7a5b3fd8".
# Reading "compass_c22e7f21".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "rectangle_c22e7f21".
# Reading "via_stack_0933432e".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "straight_route_ef21a436".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "straight_route_8c66551b".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "c_route_da7bb6fc".
# Reading "spike_metal".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# Extracting m2 into m2.ext:
# Extracting via_stack_21868f90$1 into via_stack_21868f90$1.ext:
# Extracting straight_route_120da5af into straight_route_120da5af.ext:
# Extracting straight_route_d675ca8e into straight_route_d675ca8e.ext:
# Extracting m4 into m4.ext:
# Extracting L_route_929a1543 into L_route_929a1543.ext:
# Extracting straight_route_7a5b3fd8 into straight_route_7a5b3fd8.ext:
# Extracting straight_route_ef21a436 into straight_route_ef21a436.ext:
# Extracting via_stack_21868f90$3 into via_stack_21868f90$3.ext:
# Extracting straight_route_a46fca22 into straight_route_a46fca22.ext:
# Extracting m8 into m8.ext:
# Extracting straight_route_2ed983a1 into straight_route_2ed983a1.ext:
# Extracting via_stack_21868f90$5 into via_stack_21868f90$5.ext:
# Extracting c_route_da7bb6fc into c_route_da7bb6fc.ext:
# Extracting straight_route_653e943a into straight_route_653e943a.ext:
# Extracting via_stack_b843013f into via_stack_b843013f.ext:
# Extracting L_route_87c4f6ee into L_route_87c4f6ee.ext:
# Extracting L_route_00354b45 into L_route_00354b45.ext:
# Extracting L_route_6f66c2b4 into L_route_6f66c2b4.ext:
# Extracting cap into cap.ext:
# Extracting compass_9b95c421$1 into compass_9b95c421$1.ext:
# Extracting rectangle_9b95c421$1 into rectangle_9b95c421$1.ext:
# Extracting via_stack_0933432e into via_stack_0933432e.ext:
# Extracting straight_route_25921472 into straight_route_25921472.ext:
# Extracting straight_route_8c66551b into straight_route_8c66551b.ext:
# Extracting m5 into m5.ext:
# Extracting c_route_22950f53 into c_route_22950f53.ext:
# Extracting via_stack_0f6cf869 into via_stack_0f6cf869.ext:
# Extracting straight_route_fbaec8c0 into straight_route_fbaec8c0.ext:
# Extracting straight_route_70d98054 into straight_route_70d98054.ext:
# Extracting straight_route_a8163400 into straight_route_a8163400.ext:
# Extracting m1 into m1.ext:
# Extracting straight_route_4bc47704 into straight_route_4bc47704.ext:
# Extracting m3 into m3.ext:
# Extracting m7 into m7.ext:
# Extracting straight_route_a068c351 into straight_route_a068c351.ext:
# Extracting via_stack_21868f90$2 into via_stack_21868f90$2.ext:
# Extracting straight_route_49cca32b into straight_route_49cca32b.ext:
# Extracting straight_route_5e09102b into straight_route_5e09102b.ext:
# Extracting via_stack_21868f90$4 into via_stack_21868f90$4.ext:
# Extracting via_stack_21868f90 into via_stack_21868f90.ext:
# Extracting straight_route_f0d99bf9 into straight_route_f0d99bf9.ext:
# Extracting L_route_8c5b9559 into L_route_8c5b9559.ext:
# Extracting L_route_c986ba91 into L_route_c986ba91.ext:
# Extracting L_route_5425554c into L_route_5425554c.ext:
# Extracting via_stack_0f6cf869$1 into via_stack_0f6cf869$1.ext:
# Extracting compass_669c8fc8 into compass_669c8fc8.ext:
# Extracting spike_metal into spike_metal.ext:
# Extracting c_route_84615c86 into c_route_84615c86.ext:
# Extracting straight_route_eb083e09 into straight_route_eb083e09.ext:
# Extracting compass_9b95c421 into compass_9b95c421.ext:
# Extracting rectangle_9b95c421 into rectangle_9b95c421.ext:
# Extracting via_stack_d064ec7a into via_stack_d064ec7a.ext:
# Extracting c_route_cbf36677 into c_route_cbf36677.ext:
# Extracting c_route_b822627d into c_route_b822627d.ext:
# Extracting straight_route_1ab41405 into straight_route_1ab41405.ext:
# Extracting straight_route_d00f6094 into straight_route_d00f6094.ext:
# Extracting c_route_aabd7881 into c_route_aabd7881.ext:
# Extracting straight_route_2ae42c1d into straight_route_2ae42c1d.ext:
# Extracting neurona_lvs into neurona_lvs.ext:
# neurona_lvs: 18 errors
# exttosim finished.
# Adding  vss; Tnew = 0.76ns, Told = 0.00ns
# Adding  vdd; Tnew = 0.02ns, Told = 0.00ns
# Adding  Iin; Tnew = 0.05ns, Told = 0.00ns
# Adding  spike_neg; Tnew = 0.00ns, Told = 0.00ns
# Adding  spike
# Total Nets: 31
# Nets extracted: 5 (0.161290)
# Nets output: 5 (0.161290)
# exttospice finished.

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: cap.ext
# Deleted: compass_669c8fc8.ext
# Deleted: compass_9b95c421$1.ext
# Deleted: compass_9b95c421.ext
# Deleted: c_route_22950f53.ext
# Deleted: c_route_84615c86.ext
# Deleted: c_route_aabd7881.ext
# Deleted: c_route_b822627d.ext
# Deleted: c_route_cbf36677.ext
# Deleted: c_route_da7bb6fc.ext
# Deleted: L_route_00354b45.ext
# Deleted: L_route_5425554c.ext
# Deleted: L_route_6f66c2b4.ext
# Deleted: L_route_87c4f6ee.ext
# Deleted: L_route_8c5b9559.ext
# Deleted: L_route_929a1543.ext
# Deleted: L_route_c986ba91.ext
# Deleted: m1.ext
# Deleted: m2.ext
# Deleted: m3.ext
# Deleted: m4.ext
# Deleted: m5.ext
# Deleted: m7.ext
# Deleted: m8.ext
# Deleted: neurona_lvs.ext
# Deleted: neurona_lvs.res.ext
# Deleted: rectangle_9b95c421$1.ext
# Deleted: rectangle_9b95c421.ext
# Deleted: spike_metal.ext
# Deleted: straight_route_120da5af.ext
# Deleted: straight_route_1ab41405.ext
# Deleted: straight_route_25921472.ext
# Deleted: straight_route_2ae42c1d.ext
# Deleted: straight_route_2ed983a1.ext
# Deleted: straight_route_49cca32b.ext
# Deleted: straight_route_4bc47704.ext
# Deleted: straight_route_5e09102b.ext
# Deleted: straight_route_653e943a.ext
# Deleted: straight_route_70d98054.ext
# Deleted: straight_route_7a5b3fd8.ext
# Deleted: straight_route_8c66551b.ext
# Deleted: straight_route_a068c351.ext
# Deleted: straight_route_a46fca22.ext
# Deleted: straight_route_a8163400.ext
# Deleted: straight_route_d00f6094.ext
# Deleted: straight_route_d675ca8e.ext
# Deleted: straight_route_eb083e09.ext
# Deleted: straight_route_ef21a436.ext
# Deleted: straight_route_f0d99bf9.ext
# Deleted: straight_route_fbaec8c0.ext
# Deleted: via_stack_0933432e.ext
# Deleted: via_stack_0f6cf869$1.ext
# Deleted: via_stack_0f6cf869.ext
# Deleted: via_stack_21868f90$1.ext
# Deleted: via_stack_21868f90$2.ext
# Deleted: via_stack_21868f90$3.ext
# Deleted: via_stack_21868f90$4.ext
# Deleted: via_stack_21868f90$5.ext
# Deleted: via_stack_21868f90.ext
# Deleted: via_stack_b843013f.ext
# Deleted: via_stack_d064ec7a.ext
# Error deleting neurona_lvs.res.ext: [Errno 2] No such file or directory: 'neurona_lvs.res.ext'
# Deleted: neurona_lvs.nodes
# Deleted: neurona_lvs.sim

# %%
import os
from pathlib import Path

# Ruta donde guardas tus archivos de la neurona
path_to_dir = "/foss/designs/libs/snn_analog/lif/"

# Ejecutar LVS con Netgen usando el PDK gf180
gf180.lvs_netgen(
    layout=neurona_comp,   # tu layout exportado
    design_name=neurona_comp.name,   # nombre del diseño
    pdk_root=Path(os.environ['PDKPATH']),   # raíz del PDK
    lvs_setup_tcl_file=Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    
    # Netlist de referencia (esquemático ideal)
    lvs_schematic_ref_file=Path(path_to_dir + "neurona_lvs.spice"),
    
    # Netlist extraído del layout (PEX/LVS)
    netlist=Path(path_to_dir + "neurona_sch.spice"),
    
    # Carpeta donde se guarda el reporte .lvs.rpt
    output_file_path=Path(path_to_dir)
)
# Out:
# 2026-09-02 20:04:01.552 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpoc19pha1/neurona_lvs.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "neurona_lvs".
# Reading "c_route_84615c86".
# Reading "m4".
# Reading "L_route_6f66c2b4".
# Reading "L_route_929a1543".
# Reading "via_stack_0f6cf869$1".
# Reading "c_route_22950f53".
# Reading "straight_route_a068c351".
# Reading "via_stack_0f6cf869".
# Reading "c_route_cbf36677".
# Reading "L_route_87c4f6ee".
# Reading "via_stack_21868f90$2".
# Reading "compass_669c8fc8".
# Reading "m7".
# Reading "m2".
# Reading "straight_route_49cca32b".
# Reading "m8".
# Reading "straight_route_eb083e09".
# Reading "straight_route_25921472".
# Reading "straight_route_7a5b3fd8".
# Reading "compass_c22e7f21".
# Reading "straight_route_2ed983a1".
# Reading "rectangle_9b95c421".
# Reading "straight_route_fbaec8c0".
# Reading "straight_route_5e09102b".
# Reading "rectangle_c22e7f21".
# Reading "via_stack_0933432e".
# Reading "compass_9b95c421$1".
# Reading "via_stack_21868f90$4".
# Reading "c_route_b822627d".
# Reading "straight_route_4bc47704".
# Reading "m5".
# Reading "straight_route_70d98054".
# Reading "via_stack_d064ec7a".
# Reading "straight_route_1ab41405".
# Reading "straight_route_d00f6094".
# Reading "via_stack_21868f90$1".
# Reading "straight_route_a8163400".
# Reading "straight_route_120da5af".
# Reading "m3".
# Reading "L_route_00354b45".
# Reading "straight_route_ef21a436".
# Reading "cap".
# Reading "c_route_aabd7881".
# Reading "via_stack_21868f90".
# Reading "straight_route_8c66551b".
# Reading "via_stack_b843013f".
# Reading "via_stack_21868f90$3".
# Reading "straight_route_d675ca8e".
# Reading "straight_route_f0d99bf9".
# Reading "straight_route_653e943a".
# Reading "m1".
# Reading "rectangle_9b95c421$1".
# Reading "L_route_8c5b9559".
# Reading "L_route_c986ba91".
# Reading "straight_route_a46fca22".
# Reading "L_route_5425554c".
# Reading "straight_route_2ae42c1d".
# Reading "c_route_da7bb6fc".
# Reading "spike_metal".
# Reading "via_stack_21868f90$5".
# Reading "compass_9b95c421".
# Extracting m2 into m2.ext:
# Extracting via_stack_21868f90$1 into via_stack_21868f90$1.ext:
# Extracting straight_route_120da5af into straight_route_120da5af.ext:
# Extracting straight_route_d675ca8e into straight_route_d675ca8e.ext:
# Extracting m4 into m4.ext:
# Extracting L_route_929a1543 into L_route_929a1543.ext:
# Extracting straight_route_7a5b3fd8 into straight_route_7a5b3fd8.ext:
# Extracting straight_route_ef21a436 into straight_route_ef21a436.ext:
# Extracting via_stack_21868f90$3 into via_stack_21868f90$3.ext:
# Extracting straight_route_a46fca22 into straight_route_a46fca22.ext:
# Extracting m8 into m8.ext:
# Extracting straight_route_2ed983a1 into straight_route_2ed983a1.ext:
# Extracting via_stack_21868f90$5 into via_stack_21868f90$5.ext:
# Extracting c_route_da7bb6fc into c_route_da7bb6fc.ext:
# Extracting straight_route_653e943a into straight_route_653e943a.ext:
# Extracting via_stack_b843013f into via_stack_b843013f.ext:
# Extracting L_route_87c4f6ee into L_route_87c4f6ee.ext:
# Extracting L_route_00354b45 into L_route_00354b45.ext:
# Extracting L_route_6f66c2b4 into L_route_6f66c2b4.ext:
# Extracting cap into cap.ext:
# Extracting compass_9b95c421$1 into compass_9b95c421$1.ext:
# Extracting rectangle_9b95c421$1 into rectangle_9b95c421$1.ext:
# Extracting via_stack_0933432e into via_stack_0933432e.ext:
# Extracting straight_route_25921472 into straight_route_25921472.ext:
# Extracting straight_route_8c66551b into straight_route_8c66551b.ext:
# Extracting m5 into m5.ext:
# Extracting c_route_22950f53 into c_route_22950f53.ext:
# Extracting via_stack_0f6cf869 into via_stack_0f6cf869.ext:
# Extracting straight_route_fbaec8c0 into straight_route_fbaec8c0.ext:
# Extracting straight_route_70d98054 into straight_route_70d98054.ext:
# Extracting straight_route_a8163400 into straight_route_a8163400.ext:
# Extracting m1 into m1.ext:
# Extracting straight_route_4bc47704 into straight_route_4bc47704.ext:
# Extracting m3 into m3.ext:
# Extracting m7 into m7.ext:
# Extracting straight_route_a068c351 into straight_route_a068c351.ext:
# Extracting via_stack_21868f90$2 into via_stack_21868f90$2.ext:
# Extracting straight_route_49cca32b into straight_route_49cca32b.ext:
# Extracting straight_route_5e09102b into straight_route_5e09102b.ext:
# Extracting via_stack_21868f90$4 into via_stack_21868f90$4.ext:
# Extracting via_stack_21868f90 into via_stack_21868f90.ext:
# Extracting straight_route_f0d99bf9 into straight_route_f0d99bf9.ext:
# Extracting L_route_8c5b9559 into L_route_8c5b9559.ext:
# Extracting L_route_c986ba91 into L_route_c986ba91.ext:
# Extracting L_route_5425554c into L_route_5425554c.ext:
# Extracting via_stack_0f6cf869$1 into via_stack_0f6cf869$1.ext:
# Extracting compass_669c8fc8 into compass_669c8fc8.ext:
# Extracting spike_metal into spike_metal.ext:
# Extracting c_route_84615c86 into c_route_84615c86.ext:
# Extracting straight_route_eb083e09 into straight_route_eb083e09.ext:
# Extracting compass_9b95c421 into compass_9b95c421.ext:
# Extracting rectangle_9b95c421 into rectangle_9b95c421.ext:
# Extracting via_stack_d064ec7a into via_stack_d064ec7a.ext:
# Extracting c_route_cbf36677 into c_route_cbf36677.ext:
# Extracting c_route_b822627d into c_route_b822627d.ext:
# Extracting straight_route_1ab41405 into straight_route_1ab41405.ext:
# Extracting straight_route_d00f6094 into straight_route_d00f6094.ext:
# Extracting c_route_aabd7881 into c_route_aabd7881.ext:
# Extracting straight_route_2ae42c1d into straight_route_2ae42c1d.ext:
# Extracting neurona_lvs into neurona_lvs.ext:
# neurona_lvs: 18 errors
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice neurona_lvs" "/tmp/tmpoc19pha1/neurona_lvs.spice neurona_lvs" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpoc19pha1/neurona_lvs_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:02:45 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice for /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice neurona_lvs
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit cap_mim_2f0_m4m5_noshield
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpoc19pha1/neurona_lvs.spice for /tmp/tmpoc19pha1/neurona_lvs.spice neurona_lvs
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit cap_mim_2f0_m4m5_noshield
# Creating placeholder cell definition.
# Duplicate cell neurona_lvs in file
# Renaming original cell to neurona_lvs[[0]]
# Call to undefined subcircuit cap_mim_2f0fF
# Creating placeholder cell definition.
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# No property par1 found for device cap_mim_2f0fF
# No property par1 found for device cap_mim_2f0_m4m5_noshield
# No property par1 found for device cap_mim_2f0_m4m5_noshield
# Device classes cap_mim_2f0_m4m5_noshield and cap_mim_2f0fF are equivalent.
# Comparison output logged to file /tmp/tmpoc19pha1/neurona_lvs_lvs.rpt
# Logging to file "/tmp/tmpoc19pha1/neurona_lvs_lvs.rpt" enabled
# Circuit pfet_03v3 contains no devices.
# Circuit nfet_03v3 contains no devices.
# Circuit cap_mim_2f0_m4m5_noshield contains no devices.
#
# Contents of circuit 1:  Circuit: 'm1'
# Circuit m1 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm1'
# Circuit m1 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits m1 m1
#
# Flattening instances of m1 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m1 in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'm8'
# Circuit m8 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm8'
# Circuit m8 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits m8 m8
#
# Flattening instances of m8 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m8 in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'cap'
# Circuit cap contains 1 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   1
# Circuit contains 2 nets.
# Contents of circuit 2:  Circuit: 'cap'
# Circuit cap contains 4 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   1
#   Class: c                     instances:   3
# Circuit contains 3 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 4 devices. *** MISMATCH ***
# Circuit 1 contains 2 nets,    Circuit 2 contains 3 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits cap cap
#
# Flattening instances of cap in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of cap in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'm4'
# Circuit m4 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm4'
# Circuit m4 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits m4 m4
#
# Flattening instances of m4 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m4 in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'm2'
# Circuit m2 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm2'
# Circuit m2 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits m2 m2
#
# Flattening instances of m2 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m2 in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'm7'
# Circuit m7 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm7'
# Circuit m7 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits m7 m7
#
# Flattening instances of m7 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m7 in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'm5'
# Circuit m5 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm5'
# Circuit m5 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits m5 m5
#
# Flattening instances of m5 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m5 in file /tmp/tmpoc19pha1/neurona_lvs.spice
#
# Contents of circuit 1:  Circuit: 'm3'
# Circuit m3 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'm3'
# Circuit m3 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits m3 m3
#
# Flattening instances of m3 in file /tmp/tmpoc19pha1/neurona_lvs_lvsmag.spice
# Flattening instances of m3 in file /tmp/tmpoc19pha1/neurona_lvs.spice
# Circuit cap_mim_2f0_m4m5_noshield contains no devices.
#
# Contents of circuit 1:  Circuit: 'neurona_lvs'
# Circuit neurona_lvs contains 8 device instances.
#   Class: cap_mim_2f0_m4m5_noshield instances:   1
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   3
# Circuit contains 6 nets.
# Contents of circuit 2:  Circuit: 'neurona_lvs'
# Circuit neurona_lvs contains 8 device instances.
#   Class: cap_mim_2f0fF         instances:   1
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   3
# Circuit contains 6 nets.
#
# Circuit 1 contains 8 devices, Circuit 2 contains 8 devices.
# Circuit 1 contains 6 nets,    Circuit 2 contains 6 nets.
#
#
# Final result:
# Circuits match uniquely.
# .
# Logging to file "/tmp/tmpoc19pha1/neurona_lvs_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Circuit 1 cell cap_mim_2f0_m4m5_noshield and Circuit 2 cell cap_mim_2f0_m4m5_noshield are black boxes.
# Warning: Equate pins:  cell cap_mim_2f0_m4m5_noshield is a placeholder, treated as a black box.
# Warning: Equate pins:  cell cap_mim_2f0_m4m5_noshield is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: cap_mim_2f0_m4m5_noshield       |Circuit 2: cap_mim_2f0_m4m5_noshield
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes cap_mim_2f0_m4m5_noshield and cap_mim_2f0_m4m5_noshield are equivalent.
#
# Subcircuit summary:
# Circuit 1: m1                              |Circuit 2: m1
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: m1                              |Circuit 2: m1
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n444_n560#                          |Net: w_n444_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m1                              |Circuit 2: m1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits m1 m1
#
# Subcircuit summary:
# Circuit 1: m8                              |Circuit 2: m8
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: m8                              |Circuit 2: m8
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n388_n504#                          |Net: a_n388_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m8                              |Circuit 2: m8
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits m8 m8
#
# Subcircuit summary:
# Circuit 1: cap                             |Circuit 2: cap
# -------------------------------------------|-------------------------------------------
# cap_mim_2f0_m4m5_noshield (1)              |cap_mim_2f0_m4m5_noshield (1)
# (no matching element)                      |c (3)
# Number of devices: 1 **Mismatch**          |Number of devices: 4 **Mismatch**
# Number of nets: 2 **Mismatch**             |Number of nets: 3 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: cap                             |Circuit 2: cap
#
# ---------------------------------------------------------------------------------------
# Net: m4_n2800_n500#                        |Net: m4_n2800_n500#
#   cap_mim_2f0_m4m5_noshield/1 = 1          |  cap_mim_2f0_m4m5_noshield/1 = 1
#                                            |  c/top = 2
#                                            |
# Net: m4_n2920_n620#                        |Net: m4_n2920_n620#
#   cap_mim_2f0_m4m5_noshield/2 = 1          |  cap_mim_2f0_m4m5_noshield/2 = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 2
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: cap                             |Circuit 2: cap
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 3
#                                            |  bottom = 3
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 3
#                                            |  bottom = 2
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 3
#                                            |  bottom = 2
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits cap cap
#
# Subcircuit summary:
# Circuit 1: m4                              |Circuit 2: m4
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: m4                              |Circuit 2: m4
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n388_n504#                          |Net: a_n388_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m4                              |Circuit 2: m4
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits m4 m4
#
# Subcircuit summary:
# Circuit 1: m2                              |Circuit 2: m2
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: m2                              |Circuit 2: m2
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n388_n504#                          |Net: a_n388_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m2                              |Circuit 2: m2
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits m2 m2
#
# Subcircuit summary:
# Circuit 1: m7                              |Circuit 2: m7
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: m7                              |Circuit 2: m7
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n444_n560#                          |Net: w_n444_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m7                              |Circuit 2: m7
#
# ---------------------------------------------------------------------------------------
# ...
#                                            |
# Net: a_n5120_n311#                         |Net: a_n5120_n311#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n5330_n683#                         |Net: a_n5330_n683#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m5                              |Circuit 2: m5
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits m5 m5
#
# Subcircuit summary:
# Circuit 1: m3                              |Circuit 2: m3
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: m3                              |Circuit 2: m3
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n444_n560#                          |Net: w_n444_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: m3                              |Circuit 2: m3
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits m3 m3
#
# Circuit 1 cell cap_mim_2f0_m4m5_noshield and Circuit 2 cell cap_mim_2f0fF are black boxes.
# Warning: Equate pins:  cell cap_mim_2f0_m4m5_noshield is a placeholder, treated as a black box.
# Warning: Equate pins:  cell cap_mim_2f0fF is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: cap_mim_2f0_m4m5_noshield       |Circuit 2: cap_mim_2f0fF
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes cap_mim_2f0_m4m5_noshield and cap_mim_2f0fF are equivalent.
#
# Subcircuit summary:
# Circuit 1: neurona_lvs                     |Circuit 2: neurona_lvs
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (3)                              |pfet_03v3 (3)
# nfet_03v3 (4)                              |nfet_03v3 (4)
# cap_mim_2f0_m4m5_noshield (1)              |cap_mim_2f0_m4m5_noshield (1)
# Number of devices: 8                       |Number of devices: 8
# Number of nets: 6                          |Number of nets: 6
# ---------------------------------------------------------------------------------------
# Netlists match uniquely.
#
# Subcircuit pins:
# Circuit 1: neurona_lvs                     |Circuit 2: neurona_lvs
# -------------------------------------------|-------------------------------------------
# spike                                      |spike
# vss                                        |vss
# Iin                                        |Iin
# spike_neg                                  |spike_neg
# vdd                                        |vdd
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes neurona_lvs and neurona_lvs are equivalent.
#
# Final result: Circuits match uniquely.
# .
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[31], line 8
#       5 path_to_dir = "/foss/designs/libs/snn_analog/lif/"
#       7 # Ejecutar LVS con Netgen usando el PDK gf180
# ----> 8 gf180.lvs_netgen(
#       9     layout=neurona_comp,   # tu layout exportado
#      10     design_name=neurona_comp.name,   # nombre del diseño
#      11     pdk_root=Path(os.environ['PDKPATH']),   # raíz del PDK
#      12     lvs_setup_tcl_file=Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
#      13
#      14     # Netlist de referencia (esquemático ideal)
#      15     lvs_schematic_ref_file=Path(path_to_dir + "neurona_lvs.spice"),
#      16
#      17     # Netlist extraído del layout (PEX/LVS)
#      18     netlist=Path(path_to_dir + "neurona_sch.spice"),
#      19
#      20     # Carpeta donde se guarda el reporte .lvs.rpt
#      21     output_file_path=Path(path_to_dir)
#      22 )
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:56, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      54 @wraps(_func)
#      55 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 56     return vd.call(*args, **kwargs)
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:151, in ValidatedFunction.call(self, *args, **kwargs)
#     149 def call(self, *args: Any, **kwargs: Any) -> Any:
#     150     m = self.init_model_instance(*args, **kwargs)
# --> 151     return self.execute(m)
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:227, in ValidatedFunction.execute(self, m)
#     225     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     226 else:
# --> 227     return self.raw_function(**d, **var_kwargs)
#
# File /foss/designs/libs/gLayout/src/glayout/pdk/mappedpdk.py:938, in MappedPDK.lvs_netgen(self, layout, design_name, pdk_root, lvs_setup_tcl_file, lvs_schematic_ref_file, magic_drc_file, netlist, output_file_path, copy_intermediate_files, show_scripts)
#     933 # Overwrite the report file if it exists. When the run
#     934 # failed before the report was written, leave the
#     935 # original exception (raised in the try block) intact
#     936 # rather than masking it with a FileNotFoundError here.
#     937 if Path(report_path).is_file():
# --> 938     shutil.copy(report_path, new_output_file_path)
#     939 # if not new_output_file_path.exists():
#     940 #     shutil.copy(report_path, path_to_dir / output_file_path)
#     941 # else:
#     942 #     raise ValueError("Output file already exists!")
#     944 if copy_intermediate_files:
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/shutil.py:418, in copy(src, dst, follow_symlinks)
#     416     dst = os.path.join(dst, os.path.basename(src))
#     417 copyfile(src, dst, follow_symlinks=follow_symlinks)
# --> 418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/shutil.py:307, in copymode(src, dst, follow_symlinks)
#     304     stat_func, chmod_func = _stat, os.chmod
#     306 st = stat_func(src)
# --> 307 chmod_func(dst, stat.S_IMODE(st.st_mode))
#
# PermissionError: [Errno 1] Operation not permitted: '/foss/designs/libs/snn_analog/lif/lvs/neurona_lvs/neurona_lvs_lvs.rpt'

# %%
from pathlib import Path
import os
import subprocess

pdk_name = os.environ.get("PDK", "gf180mcuD")
pdk_root = Path(os.environ.get("PDK_ROOT", ""))
pdk_path_env = Path(os.environ.get("PDKPATH", ""))

# Resolve the correct magicrc path even if PDKPATH is stale or duplicated.
candidate_pdkpaths = [
    pdk_path_env,
    pdk_root / pdk_name,
    pdk_root,
]
magicrc_file = None
for candidate in candidate_pdkpaths:
    if not str(candidate):
        continue
    rc = candidate / "libs.tech" / "magic" / f"{pdk_name}.magicrc"
    if rc.exists():
        magicrc_file = rc
        break

if magicrc_file is None:
    raise FileNotFoundError(
        "No se encontro el magicrc. Revisar PDK_ROOT/PDK/PDKPATH. "
        f"Busque en: {[str(c) for c in candidate_pdkpaths if str(c)]}"
    )

# --- Cambio clave: usar path_to_dir en vez de Path.cwd()/"exports" ---
path_to_dir = "/foss/designs/libs/snn_analog/lif/"
output_dir = Path(path_to_dir)
output_dir.mkdir(parents=True, exist_ok=True)

design_name = neurona_comp.name
gds_path = output_dir / f"{design_name}.gds"
lef_path = output_dir / f"{design_name}.lef"

neurona_comp.write_gds(str(gds_path))

magic_script = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}
load {design_name}
lef write {lef_path}
quit -noprompt
"""

result = subprocess.run(
    ["magic", "-rcfile", str(magicrc_file), "-noconsole", "-dnull"],
    input=magic_script,
    text=True,
    capture_output=True,
    check=True,
)

print(f"CWD kernel: {Path.cwd()}")
print(f"LEF generado: {lef_path}")
print(f"LEF existe: {lef_path.exists()}")
if lef_path.exists():
    print("\nCabecera LEF:")
    with open(lef_path, "r", encoding="utf-8", errors="ignore") as f:
        for _ in range(15):
            line = f.readline()
            if not line:
                break
            print(line.rstrip())
else:
    print("\n--- STDOUT COMPLETO DE MAGIC (para depurar) ---")
    print(result.stdout)
    print("\n--- STDERR COMPLETO DE MAGIC ---")
    print(result.stderr)
# Out:
# 2026-09-02 20:06:22.237 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/lif/neurona_lvs.gds'
# CWD kernel: /foss/designs
# LEF generado: /foss/designs/libs/snn_analog/lif/neurona_lvs.lef
# LEF existe: True
#
# Cabecera LEF:
# VERSION 5.7 ;
#   NOWIREEXTENSIONATPIN ON ;
#   DIVIDERCHAR "/" ;
#   BUSBITCHARS "[]" ;
# MACRO neurona_lvs
#   CLASS BLOCK ;
#   FOREIGN neurona_lvs ;
#   ORIGIN 0.000 0.000 ;
#   SIZE 57.860 BY 27.890 ;
#   PIN vss
#     ANTENNADIFFAREA 62.992199 ;
#     PORT
#       LAYER Pwell ;
#         RECT 2.000 10.545 55.860 17.935 ;
#         RECT 2.000 3.300 6.440 8.900 ;
