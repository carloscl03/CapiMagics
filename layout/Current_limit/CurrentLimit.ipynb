# %%
import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

# %%
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file, path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

# %%
from glayout import MappedPDK,gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from glayout import pmos, nmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

# %%
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

# %%
#########################################
# 6.     Instanciación de PDKs
#########################################
pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False
}

# %%
##########################################
# 7.    Instanciación de top_module
##########################################
current_limit_config = {
    "pdk": gf180,
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation() + 1,
        "routing_metal": "met2",
        "dummy_devices": False,
        "tie_layers": ("met2", "met1"),
        "sd_rmult": 1,
    },
}

pdk = gf180
top_comp = Component(name="Current_limit")
top_comp.name = "Current_limit"

rules = current_limit_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]

top_level = Component(name="current_limit")

# %%
# =========================================================================
# 8. INSTANCIACIÓN DE DISPOSITIVOS
# =========================================================================
M0 = pmos(
    pdk,
    width=0.5,
    length=5.0,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **pmos_kwargs
)
M1 = pmos(
    pdk,
    width=0.5,
    length=5.0,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **pmos_kwargs
)

M2 = nmos(
    pdk,
    width=0.5,
    length=5.0,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **nmos_kwargs
)

M0.name = "M0"
M1.name = "M1"
M2.name = "M1"
# Out:
# 2026-08-28 21:30:41.291 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
# =========================================================================
# 9. COLOCACIÓN Y FLOORPLANNING 
# =========================================================================
from glayout.util.comp_utils import (
    align_comp_to_port,
    evaluate_bbox,
    prec_center,
    prec_ref_center,
)
M0_ref = top_comp << M0
M1_ref = top_comp << M1
M2_ref = top_comp << M2

M0_bbox = evaluate_bbox(M0)
M1_bbox = evaluate_bbox(M1)
M2_bbox = evaluate_bbox(M2)

M0_ref.move((0, 0))
M1_ref.move((0, -(M0_bbox[1] / 2 + M1_bbox[1] / 2 + spacing)))

M2_ref.rotate(90)
M2_ref.move((M1_ref.xmax + M2_bbox[0]/2 +  1.5*spacing, -(M0_bbox[1] / 2 + M1_bbox[1] / 2 + 0.25*spacing)))

display_component(top_comp, "./", scale=3)

# %%
###################################################
# 10. Create a via stack from met2 to met3
###################################################
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.

i_SUM_via = top_comp << viam2m3
ifwd_via = top_comp << viam2m3

# %%
###################################################
# 11. Moving via stack from met2 to met3
###################################################

i_SUM_via.move(M0_ref.ports["multiplier_0_source_E"].center).movex(M1_bbox[1] / 3 + spacing)
ifwd_via.move(M1_ref.ports["multiplier_0_drain_E"].center).movex(M1_bbox[1] / 3 + spacing)

display_component(top_comp, "./", scale=3)

# %%
import gdsfactory as gf
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

# %%
###################################################
# 12.b Internal Conections
###################################################
top_comp << straight_route( pdk, M0_ref.ports["tie_W_top_met_S"], M1_ref.ports["tie_W_top_met_N"])
top_comp << c_route(pdk, M1_ref.ports["source_W"], M0_ref.ports["gate_W"], extension=1.8)
top_comp << c_route(pdk, M0_ref.ports["gate_E"], M0_ref.ports["drain_E"], extension=1.5)
top_comp << L_route(pdk, M1_ref.ports["gate_E"], ifwd_via.ports["bottom_met_S"])
top_comp << straight_route(pdk, M2_ref.ports["source_S"], M2_ref.ports["gate_N"])
top_comp << straight_route(pdk, M2_ref.ports["gate_S"], M2_ref.ports["drain_N"])
top_comp << straight_route(pdk, M2_ref.ports["drain_N"], M2_ref.ports["tie_W_top_met_N"])

display_component(top_comp, "./", scale=3)

# %%
# top_comp.add_ports(M0_ref.get_ports_list(), prefix="M0_")
# top_comp.add_ports(M1_ref.get_ports_list(), prefix="M1_")

# top_comp.add_ports(i_SUM_via.get_ports_list(), prefix="i_SUM_")
# top_comp.add_ports(ifwd_via.get_ports_list(), prefix="ifwd_")
# top_comp.add_ports(M2_ref.get_ports_list(), prefix="M2_")
display_component(top_comp, "./", scale=3)

# %%
# =========================================================================
# 4. ADD AVDD POWER RAIL AND CONNECT SUPPLY NODES
# =========================================================================

# Calcular extensión horizontal para trazar el riel de alimentación
bbox = evaluate_bbox(top_comp)
top_y = top_comp.ymax + 3.0

# Trazar riel horizontal de metal2 para AVDD
avdd_rail = top_comp << gf.components.rectangle(
    size=(bbox[0] + 1, 1.0), 
    layer=pdk.get_layer("metal2")
)
avdd_rail.move(((M1_bbox[1] / 2) - 9, top_y))

via_avdd = top_comp << viam2m3
via_avdd.move((bbox[0] / 2 - 4.5, top_y + 0.5))

## METAL5 VSS TOP
bbox_vdd = evaluate_bbox(avdd_rail)

avdd_M5 = top_comp << gf.components.rectangle(
    size=(bbox_vdd[0]+18.14, 6.13), 
    layer=pdk.get_layer("metal5")
)
avdd_M5.move((-15, 6.8 + (6.13/2)))

#m5_label
avdd_label = top_comp << gf.components.rectangle(
    size=(bbox_vdd[0]+18.14, 6.13), 
    layer=pdk.get_layer("metal5_label")
)
avdd_label.move((-15, 6.8 + (6.13/2)))

avdd_M5_bot = top_comp << gf.components.rectangle(
    size=(bbox_vdd[0]+18.14, 6.13), 
    layer=pdk.get_layer("metal5")
)
avdd_M5_bot.move((-15, -14.8 - (6.13/2)))

#m5_label
avdd_label_bot = top_comp << gf.components.rectangle(
    size=(bbox_vdd[0]+18.14, 6.13), 
    layer=pdk.get_layer("metal5_label")
)
avdd_label_bot.move((-15, -14.8 - (6.13/2)))

display_component(top_comp, "./", scale=3)

# %%
#met4_label VDD left
avdd1_label_m4 = top_comp << gf.components.rectangle(
    size=(5,27.5), #56.81
    layer=pdk.get_layer("metal4_label")
)
avdd1_label_m4.move((-15,-17.86+3.605)) #38

#met4_label VDD right
avdd2_label_m4 = top_comp << gf.components.rectangle(
    size=(5,27.5), #56.81
    layer=pdk.get_layer("metal4_label")
)
avdd2_label_m4.move((17.43 + 0.65,-17.86+3.605)) #38

display_component(top_comp, "./", scale=3)

# %%
viam4m5 = via_stack(pdk, "met4", "met5", centered=True)

via_avdd_M5 = top_comp << viam4m5
via_avdd_M5.move((-12.5,16-2.5))

via_avdd_M5B = top_comp << viam4m5
via_avdd_M5B.move((-12.5,-16+1.5))

via_avdd_M5C = top_comp << viam4m5
via_avdd_M5C.move((18.29+2.29,16-2.5))

via_avdd_M5D = top_comp << viam4m5
via_avdd_M5D.move((18.29+2.29,-16+1.5))

top_comp  << straight_route(pdk, via_avdd_M5.ports["bottom_met_S"], via_avdd_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")
top_comp  << straight_route(pdk, via_avdd_M5.ports["bottom_met_S"], via_avdd_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")
top_comp  << straight_route(pdk, via_avdd_M5C.ports["bottom_met_S"], via_avdd_M5D.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")
top_comp  << straight_route(pdk, via_avdd_M5C.ports["bottom_met_S"], via_avdd_M5D.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

viam2m5 = via_stack(pdk, "met2", "met5", centered=True)
avdd_M5_PIN = top_comp << viam2m5
avdd_M5_PIN.move((0,16-(6.13/2)))

top_comp << L_route(pdk,avdd_M5_PIN.ports["bottom_met_S"], via_avdd.ports["bottom_met_W"])
top_comp << L_route(pdk, M0_ref.ports["tie_W_top_met_N"], via_avdd.ports["bottom_met_W"])


display_component(top_comp, "./", scale=2)

# %%
bbox1 = evaluate_bbox(top_comp)


avss_M5 = top_comp << gf.components.rectangle(
    size=(bbox1[0]+15, 5), 
    layer=pdk.get_layer("metal5")
)
avss_M5.move((-(bbox1[0]/2)-3.5, bbox1[1]/2 + spacing))

avss_M5B = top_comp << gf.components.rectangle(
    size=(bbox1[0]+15, 5), 
    layer=pdk.get_layer("metal5")
)
avss_M5B.move((-(bbox1[0]/2)-3.5, -bbox1[1]/2 - spacing - 6.87))



avss_M5L = top_comp << gf.components.rectangle(
    size=(bbox1[0]+15, 5), 
    layer=pdk.get_layer("metal5_label")
)
avss_M5L.move((-(bbox1[0]/2)-3.5, bbox1[1]/2 + spacing))

avss_M5BL = top_comp << gf.components.rectangle(
    size=(bbox1[0]+15, 5), 
    layer=pdk.get_layer("metal5_label")
)
avss_M5BL.move((-(bbox1[0]/2)-3.5, -bbox1[1]/2 - spacing - 6.87))

bbox_d = evaluate_bbox(avss_M5BL)

via_avss_M5 = top_comp << viam4m5
via_avss_M5.move((-20.04,bbox1[1]/2 + spacing + 2.5))

via_avss_M5B = top_comp << viam4m5
via_avss_M5B.move((28.04,bbox1[1]/2 + spacing + 2.5))

via_avss_M5C = top_comp << viam4m5
via_avss_M5C.move((-20.04,-bbox1[1]/2 - spacing - 4.37))

via_avss_M5D = top_comp << viam4m5
via_avss_M5D.move((28.04,-bbox1[1]/2 - spacing - 4.37))

top_comp  << straight_route(pdk, via_avss_M5.ports["bottom_met_S"], via_avss_M5C.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")
top_comp  << straight_route(pdk, via_avss_M5B.ports["bottom_met_S"], via_avss_M5D.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

avss_M4L = top_comp << gf.components.rectangle(
    size=(5, 42.83), 
    layer=pdk.get_layer("metal4_label")
)
avss_M4L.move((25.54, -22.35))

avss_M4BL = top_comp << gf.components.rectangle(
    size=(5, 42.83), 
    layer=pdk.get_layer("metal4_label")
)
avss_M4BL.move((-22.54, -22.35))


avss_M5_PIN = top_comp << viam2m5
avss_M5_PIN.move((4,-22.6))

top_comp << L_route(pdk,avss_M5_PIN.ports["bottom_met_W"], M2_ref.ports["drain_E"])


display_component(top_comp, "./", scale=1)

# %%
#----------- Adding snippet code to move all the placed components to the proper position, 
#----------- in order to set origin into 0,0
# Place this snippet after all your material polygones are placed, and before your ports are placed
bbox_all = top_comp.bbox[0]
for ref in top_comp.references:
    ref.movex(-1*bbox_all[0]).movey(-1*bbox_all[1])
display_component(top_comp, "./", scale=1)

# %%
# =========================================================================
# 5. ADD PORTS AND PHYSICAL PIN LABELS (done BEFORE routing)
# =========================================================================

psize = (0.5, 0.5)

# i_SUM
box_isum = evaluate_bbox(i_SUM_via)
center_S_i_SUM = i_SUM_via.ports["bottom_met_S"].center

i_SUM_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal2"))
i_SUM_port.move(i_SUM_via.ports["bottom_met_S"].center)
top_comp.add_port(
    "i_SUM",
    center= (center_S_i_SUM[0], center_S_i_SUM[1] + box_isum[1]/2), # Move the port up by half the height of the bounding box plus an offset
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)
top_comp.add_label(
    text="i_SUM",
    position=(center_S_i_SUM[0], center_S_i_SUM[1] + box_isum[1]/2),
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)

# ifwd
box_ifwd = evaluate_bbox(ifwd_via)
center_S_ifwd = ifwd_via.ports["bottom_met_S"].center

ifwd_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal2"))
ifwd_port.move(ifwd_via.ports["bottom_met_S"].center)

top_comp.add_port(
    "ifwd",
    center=(center_S_ifwd[0], center_S_ifwd[1] + box_ifwd[1]/2),
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)
top_comp.add_label(
    text="ifwd",
    position=(center_S_ifwd[0], center_S_ifwd[1] + box_ifwd[1]/2),
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)

###################################################
# 12.a Pin Conections
###################################################
top_comp << straight_route(pdk, M0_ref.ports["multiplier_0_source_E"], top_comp.ports["i_SUM"])
top_comp << straight_route(pdk, M1_ref.ports["multiplier_0_drain_E"], top_comp.ports["ifwd"])


# avdd (bulk tie, via avdd1)

avdd_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal5"))
avdd_port.move(avdd_M5_PIN.ports["top_met_S"].center)



top_comp.add_port(
    "avdd",
    center=avdd_M5_PIN.ports["top_met_S"].center,
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal5"),
    port_type="electrical"
)
top_comp.add_label(
    text="avdd",
    position=avdd_M5_PIN.ports["top_met_S"].center,
    layer=pdk.get_glayer("met5_label"),
    magnification=1
)
################################################################################################

avss_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal5"))
avss_port.move(avss_M5_PIN.ports["top_met_S"].center)

top_comp.add_port(
    "avss",
    center=avss_M5_PIN.ports["top_met_S"].center,
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal5"),
    port_type="electrical"
)
top_comp.add_label(
    text="avss",
    position=avss_M5_PIN.ports["top_met_S"].center,
    layer=pdk.get_glayer("met5_label"),
    magnification=1
)

display_component(top_comp, "./", scale=1)

# %%
bbox1 = evaluate_bbox(top_comp)
boundary = top_comp << gf.components.rectangle(
    size=(bbox1[0], bbox1[1]), 
    layer=(0,0)
)
boundary.move((top_comp.xmin, top_comp.ymin))
display_component(top_comp, "./", scale=1)

# %%
evaluate_bbox(top_comp)
# Out:
# (53.08, 48.33)

# %%
evaluate_bbox(top_comp)[0]*evaluate_bbox(top_comp)[1]
# Out:
# 2565.3563999999997

# %%
top_comp.name="Current_limit"
drc_result = gf180.drc_magic(top_comp, top_comp.name)
print("Making sure your environment varriables are still correctly set")
print(" I am using PDK in: ",os.environ['PDK_ROOT'],"\n PDK name: ",os.environ['PDK'],"\n The PDK files are at: ",os.environ['PDKPATH'])
# Out:
# 2026-08-28 21:30:45.761 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpzfccluaj/Current_limit.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpzfccluaj/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Current_limit".
# Reading "compass_10797ac3$1".
# Reading "via_stack_a2e89513".
# Reading "c_route_5e97492c".
# Reading "straight_route_0bcfe59c$1".
# Reading "rectangle_6760ec2c".
# Reading "L_route_5ae191ae".
# Reading "straight_route_34cb479d".
# Reading "straight_route_0bcfe59c".
# Reading "rectangle_aefcfd81$1".
# Reading "straight_route_c9e90393".
# Reading "straight_route_946b62ad".
# Reading "rectangle_fe5ba1b6".
# Reading "M0".
# Reading "rectangle_fe2bdf2b".
# Reading "compass_55e1285c".
# Reading "compass_6760ec2c".
# Reading "compass_8f91b1b8$3".
# Reading "straight_route_72643bc0".
# Reading "L_route_edb15d97".
# Reading "compass_2d3cd8bd$51".
# Reading "c_route_4b6a6f06".
# Reading "L_route_8efb6f3a".
# Reading "rectangle_8f91b1b8".
# Reading "via_stack_7fdd5994".
# Reading "rectangle_6760ec2c$1".
# Reading "compass_10797ac3".
# Reading "rectangle_2d3cd8bd".
# Reading "rectangle_971cdbe0".
# Reading "rectangle_10797ac3".
# Reading "rectangle_6d509b94$1".
# Reading "compass_2d3cd8bd$52".
# Reading "rectangle_aefcfd81".
# Reading "compass_971cdbe0".
# Reading "via_stack_b1a70b50".
# Reading "rectangle_6d509b94".
# Reading "M1$1".
# Reading "rectangle_fe5ba1b6$1".
# Reading "compass_8f91b1b8$2".
# Reading "M1".
# Reading "compass_aefcfd81".
# Reading "compass_6d509b94".
# Reading "straight_route_b913b1bf".
# Reading "compass_aefcfd81$1".
# Reading "compass_55e1285c$1".
# Reading "compass_6760ec2c$1".
# Reading "straight_route_2650232b$1".
# Reading "straight_route_2650232b".
# Reading "straight_route_ce83010f".
# Reading "straight_route_e95133d1".
# Reading "straight_route_ecd45504".
# Reading "rectangle_10797ac3$1".
# Reading "compass_6d509b94$1".
# Reading "compass_fe2bdf2b".
# Reading "rectangle_8f91b1b8$1".
# Reading "compass_fe5ba1b6$1".
# Reading "compass_fe5ba1b6".
# Reading "rectangle_2d3cd8bd$1".
# Reading "L_route_8075e724".
# Reading "rectangle_55e1285c".
# Reading "rectangle_55e1285c$1".
# [INFO]: Loading Current_limit
#
# Loading DRC CIF style.
# [INFO]: DONE with /tmp/tmpzfccluaj/Current_limit.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
#
# Current_limit count:
#
# ----------------------------------------
#
# Via1 spacing < 0.26um (V1.2a)
#
# ----------------------------------------
#
#  30.880um 19.460um 30.895um 19.565um
#
#  30.895um 19.460um 31.070um 19.565um
#
#  30.880um 19.445um 31.070um 19.460um
#
#  31.070um 19.460um 31.125um 19.565um
#
#  31.125um 19.460um 31.140um 19.565um
#
#  31.070um 19.445um 31.140um 19.460um
#
#  30.810um 19.045um 31.070um 19.165um
#
#  30.880um 19.460um 30.895um 19.565um
#
#  30.895um 19.460um 31.070um 19.565um
#
#  30.880um 19.445um 31.070um 19.460um
#
#  31.070um 19.460um 31.125um 19.565um
#
#  31.125um 19.460um 31.140um 19.565um
#
#  31.070um 19.445um 31.140um 19.460um
#
#  30.810um 19.045um 31.070um 19.165um
#
# ----------------------------------------
#
#
#
# Making sure your environment varriables are still correctly set
#  I am using PDK in:  /foss/pdks
#  PDK name:  gf180mcuD
#  The PDK files are at:  /foss/pdks/gf180mcuD

# %%
top_comp.unlock()

# %%
import os
from pathlib import Path
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name = top_comp.name
path_to_dir = "/foss/designs/libs/snn_analog/Current_limit/"

pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"

top_comp.write_gds(str(gds_path))
    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
exit
"""



with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)

import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# 2026-08-28 21:30:46.112 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/Current_limit/Current_limit.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Current_limit".
# Reading "compass_10797ac3$1".
# Reading "via_stack_a2e89513".
# Reading "c_route_5e97492c".
# Reading "straight_route_0bcfe59c$1".
# Reading "rectangle_6760ec2c".
# Reading "L_route_5ae191ae".
# Reading "straight_route_34cb479d".
# Reading "straight_route_0bcfe59c".
# Reading "rectangle_aefcfd81$1".
# Reading "straight_route_c9e90393".
# Reading "straight_route_946b62ad".
# Reading "rectangle_fe5ba1b6".
# Reading "M0".
# Reading "rectangle_fe2bdf2b".
# Reading "compass_55e1285c".
# Reading "compass_6760ec2c".
# Reading "compass_8f91b1b8$3".
# Reading "straight_route_72643bc0".
# Reading "L_route_edb15d97".
# Reading "compass_2d3cd8bd$51".
# Reading "c_route_4b6a6f06".
# Reading "L_route_8efb6f3a".
# Reading "rectangle_8f91b1b8".
# Reading "via_stack_7fdd5994".
# Reading "rectangle_6760ec2c$1".
# Reading "compass_10797ac3".
# Reading "rectangle_2d3cd8bd".
# Reading "rectangle_971cdbe0".
# Reading "rectangle_10797ac3".
# Reading "rectangle_6d509b94$1".
# Reading "compass_2d3cd8bd$52".
# Reading "rectangle_aefcfd81".
# Reading "compass_971cdbe0".
# Reading "via_stack_b1a70b50".
# Reading "rectangle_6d509b94".
# Reading "M1$1".
# Reading "rectangle_fe5ba1b6$1".
# Reading "compass_8f91b1b8$2".
# Reading "M1".
# Reading "compass_aefcfd81".
# Reading "compass_6d509b94".
# Reading "straight_route_b913b1bf".
# Reading "compass_aefcfd81$1".
# Reading "compass_55e1285c$1".
# Reading "compass_6760ec2c$1".
# Reading "straight_route_2650232b$1".
# Reading "straight_route_2650232b".
# Reading "straight_route_ce83010f".
# Reading "straight_route_e95133d1".
# Reading "straight_route_ecd45504".
# Reading "rectangle_10797ac3$1".
# Reading "compass_6d509b94$1".
# Reading "compass_fe2bdf2b".
# Reading "rectangle_8f91b1b8$1".
# Reading "compass_fe5ba1b6$1".
# Reading "compass_fe5ba1b6".
# Reading "rectangle_2d3cd8bd$1".
# Reading "L_route_8075e724".
# Reading "rectangle_55e1285c".
# Reading "rectangle_55e1285c$1".
# Extracting compass_aefcfd81$1 into compass_aefcfd81$1.ext:
# Extracting rectangle_aefcfd81$1 into rectangle_aefcfd81$1.ext:
# Extracting straight_route_b913b1bf into straight_route_b913b1bf.ext:
# Extracting via_stack_b1a70b50 into via_stack_b1a70b50.ext:
# Extracting compass_10797ac3 into compass_10797ac3.ext:
# Extracting rectangle_10797ac3 into rectangle_10797ac3.ext:
# Extracting straight_route_0bcfe59c into straight_route_0bcfe59c.ext:
# Extracting straight_route_0bcfe59c$1 into straight_route_0bcfe59c$1.ext:
# Extracting c_route_5e97492c into c_route_5e97492c.ext:
# Extracting straight_route_c9e90393 into straight_route_c9e90393.ext:
# Extracting L_route_edb15d97 into L_route_edb15d97.ext:
# Extracting via_stack_7fdd5994 into via_stack_7fdd5994.ext:
# Extracting M1 into M1.ext:
# Extracting L_route_8075e724 into L_route_8075e724.ext:
# Extracting L_route_5ae191ae into L_route_5ae191ae.ext:
# Extracting straight_route_34cb479d into straight_route_34cb479d.ext:
# Extracting M0 into M0.ext:
# Extracting c_route_4b6a6f06 into c_route_4b6a6f06.ext:
# Extracting L_route_8efb6f3a into L_route_8efb6f3a.ext:
# Extracting compass_8f91b1b8$2 into compass_8f91b1b8$2.ext:
# Extracting rectangle_8f91b1b8 into rectangle_8f91b1b8.ext:
# Extracting straight_route_e95133d1 into straight_route_e95133d1.ext:
# Extracting compass_fe2bdf2b into compass_fe2bdf2b.ext:
# Extracting rectangle_fe2bdf2b into rectangle_fe2bdf2b.ext:
# Extracting compass_8f91b1b8$3 into compass_8f91b1b8$3.ext:
# Extracting rectangle_8f91b1b8$1 into rectangle_8f91b1b8$1.ext:
# Extracting straight_route_946b62ad into straight_route_946b62ad.ext:
# Extracting straight_route_72643bc0 into straight_route_72643bc0.ext:
# Extracting M1$1 into M1$1.ext:
# Extracting via_stack_a2e89513 into via_stack_a2e89513.ext:
# Extracting compass_2d3cd8bd$51 into compass_2d3cd8bd$51.ext:
# Extracting rectangle_2d3cd8bd into rectangle_2d3cd8bd.ext:
# Extracting compass_2d3cd8bd$52 into compass_2d3cd8bd$52.ext:
# Extracting rectangle_2d3cd8bd$1 into rectangle_2d3cd8bd$1.ext:
# Extracting straight_route_ecd45504 into straight_route_ecd45504.ext:
# Extracting compass_10797ac3$1 into compass_10797ac3$1.ext:
# Extracting rectangle_10797ac3$1 into rectangle_10797ac3$1.ext:
# Extracting straight_route_2650232b into straight_route_2650232b.ext:
# Extracting straight_route_2650232b$1 into straight_route_2650232b$1.ext:
# Extracting straight_route_ce83010f into straight_route_ce83010f.ext:
# Extracting compass_aefcfd81 into compass_aefcfd81.ext:
# Extracting rectangle_aefcfd81 into rectangle_aefcfd81.ext:
# Extracting compass_6760ec2c into compass_6760ec2c.ext:
# Extracting rectangle_6760ec2c into rectangle_6760ec2c.ext:
# Extracting compass_6d509b94 into compass_6d509b94.ext:
# Extracting rectangle_6d509b94 into rectangle_6d509b94.ext:
# Extracting compass_6760ec2c$1 into compass_6760ec2c$1.ext:
# Extracting rectangle_6760ec2c$1 into rectangle_6760ec2c$1.ext:
# Extracting compass_6d509b94$1 into compass_6d509b94$1.ext:
# Extracting rectangle_6d509b94$1 into rectangle_6d509b94$1.ext:
# Extracting compass_fe5ba1b6$1 into compass_fe5ba1b6$1.ext:
# Extracting rectangle_fe5ba1b6$1 into rectangle_fe5ba1b6$1.ext:
# Extracting compass_fe5ba1b6 into compass_fe5ba1b6.ext:
# Extracting rectangle_fe5ba1b6 into rectangle_fe5ba1b6.ext:
# Extracting compass_55e1285c into compass_55e1285c.ext:
# Extracting rectangle_55e1285c into rectangle_55e1285c.ext:
# Extracting compass_55e1285c$1 into compass_55e1285c$1.ext:
# Extracting rectangle_55e1285c$1 into rectangle_55e1285c$1.ext:
# Extracting Current_limit into Current_limit.ext:
# exttosim finished.
# Adding  i_SUM
# Adding  ifwd; Tnew = 0.00ns, Told = 0.00ns
# Adding  avdd; Tnew = 0.00ns, Told = 0.00ns
# Adding  avss; Tnew = 1.99ns, Told = 0.00ns
# Total Nets: 32
# Nets extracted: 4 (0.125000)
# Nets output: 4 (0.125000)
# exttospice finished.
#
# Deleted: rectangle_fe2bdf2b.ext
# Deleted: straight_route_34cb479d.ext
# Deleted: rectangle_fe5ba1b6.ext
# Deleted: compass_10797ac3.ext
# Deleted: compass_2d3cd8bd$51.ext
# Deleted: compass_aefcfd81.ext
# Deleted: rectangle_10797ac3$1.ext
# Deleted: compass_fe2bdf2b.ext
# Deleted: compass_fe5ba1b6.ext
# Deleted: L_route_edb15d97.ext
# Deleted: compass_6760ec2c.ext
# Deleted: c_route_5e97492c.ext
# Deleted: L_route_5ae191ae.ext
# Deleted: compass_fe5ba1b6$1.ext
# Deleted: via_stack_b1a70b50.ext
# Deleted: rectangle_2d3cd8bd$1.ext
# Deleted: straight_route_c9e90393.ext
# Deleted: compass_6d509b94.ext
# Deleted: rectangle_8f91b1b8.ext
# Deleted: compass_55e1285c$1.ext
# Deleted: via_stack_7fdd5994.ext
# Deleted: straight_route_e95133d1.ext
# Deleted: via_stack_a2e89513.ext
# Deleted: M1.ext
# Deleted: rectangle_55e1285c$1.ext
# Deleted: compass_10797ac3$1.ext
# Deleted: compass_6760ec2c$1.ext
# Deleted: M0.ext
# Deleted: rectangle_55e1285c.ext
# Deleted: rectangle_8f91b1b8$1.ext
# Deleted: rectangle_6d509b94.ext
# Deleted: compass_2d3cd8bd$52.ext
# Deleted: rectangle_aefcfd81.ext
# Deleted: Current_limit.res.ext
# Deleted: rectangle_6760ec2c$1.ext
# Deleted: compass_8f91b1b8$2.ext
# Deleted: Current_limit.ext
# Deleted: straight_route_ecd45504.ext
# Deleted: straight_route_0bcfe59c.ext
# Deleted: rectangle_aefcfd81$1.ext
# Deleted: straight_route_946b62ad.ext
# Deleted: rectangle_fe5ba1b6$1.ext
# Deleted: rectangle_10797ac3.ext
# Deleted: straight_route_72643bc0.ext
# Deleted: rectangle_2d3cd8bd.ext
# Deleted: compass_8f91b1b8$3.ext
# Deleted: M1$1.ext
# Deleted: straight_route_b913b1bf.ext
# Deleted: straight_route_2650232b.ext
# Deleted: straight_route_0bcfe59c$1.ext
# Deleted: compass_55e1285c.ext
# Deleted: compass_6d509b94$1.ext
# Deleted: straight_route_2650232b$1.ext
# Deleted: straight_route_ce83010f.ext
# Deleted: rectangle_6760ec2c.ext
# Deleted: L_route_8efb6f3a.ext
# Deleted: compass_aefcfd81$1.ext
# Deleted: c_route_4b6a6f06.ext
# Deleted: rectangle_6d509b94$1.ext
# Deleted: L_route_8075e724.ext
# Error deleting Current_limit.res.ext: [Errno 2] No such file or directory: 'Current_limit.res.ext'
# Deleted: Current_limit.nodes
# Deleted: Current_limit.sim

# %%
gf180.lvs_netgen(
    layout=top_comp,
    design_name = top_comp.name,
    pdk_root = Path(os.environ['PDKPATH']),
    lvs_setup_tcl_file = Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    lvs_schematic_ref_file = Path(str(path_to_dir + "Current_limit.spice")),
    netlist = Path(str(path_to_dir + "Current_limitSCH.spice")),
    output_file_path =  Path(str(path_to_dir))
)
# Out:
# 2026-08-28 21:30:46.443 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpdhddp60v/Current_limit.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Current_limit".
# Reading "compass_10797ac3$1".
# Reading "via_stack_a2e89513".
# Reading "c_route_5e97492c".
# Reading "straight_route_0bcfe59c$1".
# Reading "rectangle_6760ec2c".
# Reading "L_route_5ae191ae".
# Reading "straight_route_34cb479d".
# Reading "straight_route_0bcfe59c".
# Reading "rectangle_aefcfd81$1".
# Reading "straight_route_c9e90393".
# Reading "straight_route_946b62ad".
# Reading "rectangle_fe5ba1b6".
# Reading "M0".
# Reading "rectangle_fe2bdf2b".
# Reading "compass_55e1285c".
# Reading "compass_6760ec2c".
# Reading "compass_8f91b1b8$3".
# Reading "straight_route_72643bc0".
# Reading "L_route_edb15d97".
# Reading "compass_2d3cd8bd$51".
# Reading "c_route_4b6a6f06".
# Reading "L_route_8efb6f3a".
# Reading "rectangle_8f91b1b8".
# Reading "via_stack_7fdd5994".
# Reading "rectangle_6760ec2c$1".
# Reading "compass_10797ac3".
# Reading "rectangle_2d3cd8bd".
# Reading "rectangle_971cdbe0".
# Reading "rectangle_10797ac3".
# Reading "rectangle_6d509b94$1".
# Reading "compass_2d3cd8bd$52".
# Reading "rectangle_aefcfd81".
# Reading "compass_971cdbe0".
# Reading "via_stack_b1a70b50".
# Reading "rectangle_6d509b94".
# Reading "M1$1".
# Reading "rectangle_fe5ba1b6$1".
# Reading "compass_8f91b1b8$2".
# Reading "M1".
# Reading "compass_aefcfd81".
# Reading "compass_6d509b94".
# Reading "straight_route_b913b1bf".
# Reading "compass_aefcfd81$1".
# Reading "compass_55e1285c$1".
# Reading "compass_6760ec2c$1".
# Reading "straight_route_2650232b$1".
# Reading "straight_route_2650232b".
# Reading "straight_route_ce83010f".
# Reading "straight_route_e95133d1".
# Reading "straight_route_ecd45504".
# Reading "rectangle_10797ac3$1".
# Reading "compass_6d509b94$1".
# Reading "compass_fe2bdf2b".
# Reading "rectangle_8f91b1b8$1".
# Reading "compass_fe5ba1b6$1".
# Reading "compass_fe5ba1b6".
# Reading "rectangle_2d3cd8bd$1".
# Reading "L_route_8075e724".
# Reading "rectangle_55e1285c".
# Reading "rectangle_55e1285c$1".
# Extracting compass_aefcfd81$1 into compass_aefcfd81$1.ext:
# Extracting rectangle_aefcfd81$1 into rectangle_aefcfd81$1.ext:
# Extracting straight_route_b913b1bf into straight_route_b913b1bf.ext:
# Extracting via_stack_b1a70b50 into via_stack_b1a70b50.ext:
# Extracting compass_10797ac3 into compass_10797ac3.ext:
# Extracting rectangle_10797ac3 into rectangle_10797ac3.ext:
# Extracting straight_route_0bcfe59c into straight_route_0bcfe59c.ext:
# Extracting straight_route_0bcfe59c$1 into straight_route_0bcfe59c$1.ext:
# Extracting c_route_5e97492c into c_route_5e97492c.ext:
# Extracting straight_route_c9e90393 into straight_route_c9e90393.ext:
# Extracting L_route_edb15d97 into L_route_edb15d97.ext:
# Extracting via_stack_7fdd5994 into via_stack_7fdd5994.ext:
# Extracting M1 into M1.ext:
# Extracting L_route_8075e724 into L_route_8075e724.ext:
# Extracting L_route_5ae191ae into L_route_5ae191ae.ext:
# Extracting straight_route_34cb479d into straight_route_34cb479d.ext:
# Extracting M0 into M0.ext:
# Extracting c_route_4b6a6f06 into c_route_4b6a6f06.ext:
# Extracting L_route_8efb6f3a into L_route_8efb6f3a.ext:
# Extracting compass_8f91b1b8$2 into compass_8f91b1b8$2.ext:
# Extracting rectangle_8f91b1b8 into rectangle_8f91b1b8.ext:
# Extracting straight_route_e95133d1 into straight_route_e95133d1.ext:
# Extracting compass_fe2bdf2b into compass_fe2bdf2b.ext:
# Extracting rectangle_fe2bdf2b into rectangle_fe2bdf2b.ext:
# Extracting compass_8f91b1b8$3 into compass_8f91b1b8$3.ext:
# Extracting rectangle_8f91b1b8$1 into rectangle_8f91b1b8$1.ext:
# Extracting straight_route_946b62ad into straight_route_946b62ad.ext:
# Extracting straight_route_72643bc0 into straight_route_72643bc0.ext:
# Extracting M1$1 into M1$1.ext:
# Extracting via_stack_a2e89513 into via_stack_a2e89513.ext:
# Extracting compass_2d3cd8bd$51 into compass_2d3cd8bd$51.ext:
# Extracting rectangle_2d3cd8bd into rectangle_2d3cd8bd.ext:
# Extracting compass_2d3cd8bd$52 into compass_2d3cd8bd$52.ext:
# Extracting rectangle_2d3cd8bd$1 into rectangle_2d3cd8bd$1.ext:
# Extracting straight_route_ecd45504 into straight_route_ecd45504.ext:
# Extracting compass_10797ac3$1 into compass_10797ac3$1.ext:
# Extracting rectangle_10797ac3$1 into rectangle_10797ac3$1.ext:
# Extracting straight_route_2650232b into straight_route_2650232b.ext:
# Extracting straight_route_2650232b$1 into straight_route_2650232b$1.ext:
# Extracting straight_route_ce83010f into straight_route_ce83010f.ext:
# Extracting compass_aefcfd81 into compass_aefcfd81.ext:
# Extracting rectangle_aefcfd81 into rectangle_aefcfd81.ext:
# Extracting compass_6760ec2c into compass_6760ec2c.ext:
# Extracting rectangle_6760ec2c into rectangle_6760ec2c.ext:
# Extracting compass_6d509b94 into compass_6d509b94.ext:
# Extracting rectangle_6d509b94 into rectangle_6d509b94.ext:
# Extracting compass_6760ec2c$1 into compass_6760ec2c$1.ext:
# Extracting rectangle_6760ec2c$1 into rectangle_6760ec2c$1.ext:
# Extracting compass_6d509b94$1 into compass_6d509b94$1.ext:
# Extracting rectangle_6d509b94$1 into rectangle_6d509b94$1.ext:
# Extracting compass_fe5ba1b6$1 into compass_fe5ba1b6$1.ext:
# Extracting rectangle_fe5ba1b6$1 into rectangle_fe5ba1b6$1.ext:
# Extracting compass_fe5ba1b6 into compass_fe5ba1b6.ext:
# Extracting rectangle_fe5ba1b6 into rectangle_fe5ba1b6.ext:
# Extracting compass_55e1285c into compass_55e1285c.ext:
# Extracting rectangle_55e1285c into rectangle_55e1285c.ext:
# Extracting compass_55e1285c$1 into compass_55e1285c$1.ext:
# Extracting rectangle_55e1285c$1 into rectangle_55e1285c$1.ext:
# Extracting Current_limit into Current_limit.ext:
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmpdhddp60v/Current_limit_lvsmag.spice Current_limit" "/tmp/tmpdhddp60v/Current_limit.spice Current_limit" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpdhddp60v/Current_limit_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:02:45 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpdhddp60v/Current_limit_lvsmag.spice for /tmp/tmpdhddp60v/Current_limit_lvsmag.spice Current_limit
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpdhddp60v/Current_limit.spice for /tmp/tmpdhddp60v/Current_limit.spice Current_limit
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Duplicate cell Current_limit in file
# Renaming original cell to Current_limit[[0]]
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Comparison output logged to file /tmp/tmpdhddp60v/Current_limit_lvs.rpt
# Logging to file "/tmp/tmpdhddp60v/Current_limit_lvs.rpt" enabled
# Circuit pfet_03v3 contains no devices.
# Circuit nfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'M1'
# Circuit M1 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M1'
# Circuit M1 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits M1 M1
#
# Flattening instances of M1 in file /tmp/tmpdhddp60v/Current_limit_lvsmag.spice
# Flattening instances of M1 in file /tmp/tmpdhddp60v/Current_limit.spice
#
# Contents of circuit 1:  Circuit: 'M1$1'
# Circuit M1$1 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M1$1'
# Circuit M1$1 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits {M1$1} {M1$1}
#
# Flattening instances of M1$1 in file /tmp/tmpdhddp60v/Current_limit_lvsmag.spice
# Flattening instances of M1$1 in file /tmp/tmpdhddp60v/Current_limit.spice
#
# Contents of circuit 1:  Circuit: 'M0'
# Circuit M0 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'M0'
# Circuit M0 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits M0 M0
#
# Flattening instances of M0 in file /tmp/tmpdhddp60v/Current_limit_lvsmag.spice
# Flattening instances of M0 in file /tmp/tmpdhddp60v/Current_limit.spice
#
# Contents of circuit 1:  Circuit: 'Current_limit'
# Circuit Current_limit contains 3 device instances.
#   Class: nfet_03v3             instances:   1
#   Class: pfet_03v3             instances:   2
# Circuit contains 5 nets.
# Contents of circuit 2:  Circuit: 'Current_limit'
# Circuit Current_limit contains 3 device instances.
#   Class: nfet_03v3             instances:   1
#   Class: pfet_03v3             instances:   2
# Circuit contains 5 nets.
#
# Circuit 1 contains 3 devices, Circuit 2 contains 3 devices.
# Circuit 1 contains 5 nets,    Circuit 2 contains 5 nets.
#
#
# Final result:
# Circuits match uniquely.
# .
# Logging to file "/tmp/tmpdhddp60v/Current_limit_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Subcircuit summary:
# Circuit 1: M1                              |Circuit 2: M1
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M1                              |Circuit 2: M1
#
# ---------------------------------------------------------------------------------------
# Net: a_500_n131#                           |Net: a_500_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n620_n131#                          |Net: a_n620_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: a_n500_n339#                          |Net: a_n500_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: w_n886_n560#                          |Net: w_n886_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 4
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M1                              |Circuit 2: M1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits M1 M1
#
# Subcircuit summary:
# Circuit 1: M1$1                            |Circuit 2: M1$1
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M1$1                            |Circuit 2: M1$1
#
# ---------------------------------------------------------------------------------------
# Net: a_500_n131#                           |Net: a_500_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 1
#                                            |  c/top = 2
#                                            |
# Net: a_n500_n339#                          |Net: a_n500_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n620_n131#                          |Net: a_n620_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n830_n504#                          |Net: a_n830_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M1$1                            |Circuit 2: M1$1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits {M1$1} {M1$1}
#
# Subcircuit summary:
# Circuit 1: M0                              |Circuit 2: M0
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: M0                              |Circuit 2: M0
#
# ---------------------------------------------------------------------------------------
# Net: a_500_n131#                           |Net: a_500_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# Net: a_n620_n131#                          |Net: a_n620_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: a_n500_n339#                          |Net: a_n500_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: w_n886_n560#                          |Net: w_n886_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 4
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: M0                              |Circuit 2: M0
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits M0 M0
#
# Subcircuit summary:
# Circuit 1: Current_limit                   |Circuit 2: Current_limit
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (2)                              |pfet_03v3 (2)
# nfet_03v3 (1)                              |nfet_03v3 (1)
# Number of devices: 3                       |Number of devices: 3
# Number of nets: 5                          |Number of nets: 5
# ---------------------------------------------------------------------------------------
# Netlists match uniquely.
#
# Subcircuit pins:
# Circuit 1: Current_limit                   |Circuit 2: Current_limit
# -------------------------------------------|-------------------------------------------
# i_SUM                                      |i_SUM
# avss                                       |avss
# avdd                                       |avdd
# ifwd                                       |ifwd
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes Current_limit and Current_limit are equivalent.
#
# Final result: Circuits match uniquely.
# .
# {'magic_subproc_code': 0,
#  'netgen_subproc_code': 0,
#  'result_str': 'LVS run succeeded\nErrors found in LVS report: /tmp/tmpdhddp60v/Current_limit_lvs.rpt'}

# %%
from pathlib import Path
import os
import subprocess

pdk_name = os.environ.get("PDK", "gf180mcuD")
pdk_root = Path(os.environ.get("PDK_ROOT", ""))
pdk_path_env = Path(os.environ.get("PDKPATH", ""))

# Resolve the correct magicrc path even if PDKPATH is stale or duplicated.
candidate_pdkpaths = [
    pdk_path_env,
    pdk_root / pdk_name,
    pdk_root,
]
magicrc_file = None
for candidate in candidate_pdkpaths:
    if not str(candidate):
        continue
    rc = candidate / "libs.tech" / "magic" / f"{pdk_name}.magicrc"
    if rc.exists():
        magicrc_file = rc
        break

if magicrc_file is None:
    raise FileNotFoundError(
        "No se encontro el magicrc. Revisar PDK_ROOT/PDK/PDKPATH. "
        f"Busque en: {[str(c) for c in candidate_pdkpaths if str(c)]}"
    )

# --- Cambio clave: usar path_to_dir en vez de Path.cwd()/"exports" ---
path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/"
output_dir = Path(path_to_dir)
output_dir.mkdir(parents=True, exist_ok=True)

design_name = top_comp.name
gds_path = output_dir / f"{design_name}.gds"
lef_path = output_dir / f"{design_name}.lef"

top_comp.write_gds(str(gds_path))

magic_script = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}
load {design_name}
lef write {lef_path}
quit -noprompt
"""

result = subprocess.run(
    ["magic", "-rcfile", str(magicrc_file), "-noconsole", "-dnull"],
    input=magic_script,
    text=True,
    capture_output=True,
    check=True,
)

print(f"CWD kernel: {Path.cwd()}")
print(f"LEF generado: {lef_path}")
print(f"LEF existe: {lef_path.exists()}")
if lef_path.exists():
    print("\nCabecera LEF:")
    with open(lef_path, "r", encoding="utf-8", errors="ignore") as f:
        for _ in range(15):
            line = f.readline()
            if not line:
                break
            print(line.rstrip())
else:
    print("\n--- STDOUT COMPLETO DE MAGIC (para depurar) ---")
    print(result.stdout)
    print("\n--- STDERR COMPLETO DE MAGIC ---")
    print(result.stderr)
# Out:
# 2026-08-28 21:30:46.815 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/Current_limit.gds'
# CWD kernel: /foss/designs
# LEF generado: /foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/Current_limit.lef
# LEF existe: True
#
# Cabecera LEF:
# VERSION 5.7 ;
#   NOWIREEXTENSIONATPIN ON ;
#   DIVIDERCHAR "/" ;
#   BUSBITCHARS "[]" ;
# MACRO Current_limit
#   CLASS BLOCK ;
#   FOREIGN Current_limit ;
#   ORIGIN 0.000 0.000 ;
#   SIZE 53.080 BY 48.330 ;
#   PIN i_SUM
#     ANTENNADIFFAREA 0.300000 ;
#     PORT
#       LAYER Metal1 ;
#         RECT 19.510 25.495 20.010 25.995 ;
#         RECT 19.530 24.945 19.990 25.495 ;
