# %%
import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

# %%
import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file, path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

# %%
from glayout import MappedPDK,gf180
#from gdsfactory.cell import cell
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

# %%
from glayout import pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring

# %%
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route

# %%
#########################################
# 6.     Instanciación de PDKs
#########################################
pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": True
}

# %%
##########################################
# 7.    Instanciación de top_module
##########################################
current_limit_config = {
    "pdk": gf180,
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation() + 1,
        "routing_metal": "met2",
        "dummy_devices": False,
        "tie_layers": ("met2", "met1"),
        "sd_rmult": 1,
    },
}

pdk = gf180
top_comp = Component(name="Current_limit")
top_comp.name = "Current_limit"

rules = current_limit_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]

top_level = Component(name="current_limit")

# %%
# =========================================================================
# 8. INSTANCIACIÓN DE DISPOSITIVOS
# =========================================================================
M0 = pmos(
    pdk,
    width=0.5,
    length=5.0,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **pmos_kwargs
)
M1 = pmos(
    pdk,
    width=0.5,
    length=5.0,
    with_dummy=(False, False),
    with_substrate_tap=False,
    tie_layers=tie_layers,
    sd_rmult=sd_rmult,
    **pmos_kwargs
)

M0.name = "M0"
M1.name = "M1"
# Out:
# 2026-08-20 21:55:13.851 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
# =========================================================================
# 9. COLOCACIÓN Y FLOORPLANNING 
# =========================================================================
from glayout.util.comp_utils import (
    align_comp_to_port,
    evaluate_bbox,
    prec_center,
    prec_ref_center,
)
M0_ref = top_comp << M0
M1_ref = top_comp << M1

M0_bbox = evaluate_bbox(M0)
M1_bbox = evaluate_bbox(M1)

M0_ref.move((0, 0))
M1_ref.move((0, -(M0_bbox[1] / 2 + M1_bbox[1] / 2 + spacing)))

display_component(top_comp, "./", scale=3)

# %%
###################################################
# 10. Create a via stack from met2 to met3
###################################################
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.

i_SUM_via = top_comp << viam2m3
avdd_via1 = top_comp << viam2m3
avdd_via2 = top_comp << viam2m3
ifwd_via = top_comp << viam2m3

# %%
###################################################
# 11. Moving via stack from met2 to met3
###################################################

i_SUM_via.move(M0_ref.ports["multiplier_0_source_E"].center).movex(M1_bbox[1] / 3 + spacing)
ifwd_via.move(M1_ref.ports["multiplier_0_drain_E"].center).movex(M1_bbox[1] / 3 + spacing)

avdd_via1.move(M0_ref.ports["tie_W_top_met_N"].center).movey(M1_bbox[1] / 3 + spacing)
avdd_via2.move(avdd_via1.ports["bottom_met_E"].center).movex(spacing)

display_component(top_comp, "./", scale=3)

# %%
import gdsfactory as gf
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle

# =========================================================================
# 5. ADD PORTS AND PHYSICAL PIN LABELS (done BEFORE routing)
# =========================================================================

psize = (0.5, 0.5)

# avdd (bulk tie, via avdd1)
avdd_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal2"))
avdd_port.move(avdd_via1.ports["bottom_met_S"].center)
top_comp.add_port(
    "avdd",
    center=avdd_via1.ports["bottom_met_S"].center,
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)
top_comp.add_label(
    text="avdd",
    position=avdd_via1.ports["bottom_met_S"].center,
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)

# i_SUM
i_SUM_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal2"))
i_SUM_port.move(i_SUM_via.ports["bottom_met_S"].center)
top_comp.add_port(
    "i_SUM",
    center=i_SUM_via.ports["bottom_met_S"].center,
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)
top_comp.add_label(
    text="i_SUM",
    position=i_SUM_via.ports["bottom_met_S"].center,
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)

# ifwd
ifwd_port = top_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal2"))
ifwd_port.move(ifwd_via.ports["bottom_met_S"].center)
top_comp.add_port(
    "ifwd",
    center=ifwd_via.ports["bottom_met_S"].center,
    width=1.0,
    orientation=180,
    layer=pdk.get_layer("metal2"),
    port_type="electrical"
)
top_comp.add_label(
    text="ifwd",
    position=ifwd_via.ports["bottom_met_S"].center,
    layer=pdk.get_glayer("met2_label"),
    magnification=1
)
# Out:
# Label(text='ifwd', origin=(6.196666666666666, -5.704999999999999), layer=(36, 10))

# %%
###################################################
# 12.a Pin Conections
###################################################
top_comp << straight_route(pdk, M0_ref.ports["multiplier_0_source_E"], top_comp.ports["i_SUM"])
top_comp << straight_route(pdk, M1_ref.ports["multiplier_0_drain_E"], top_comp.ports["ifwd"])
top_comp << straight_route( pdk, M0_ref.ports["tie_W_top_met_N"], avdd_via1.ports["bottom_met_S"])
top_comp << straight_route( pdk, avdd_via1.ports["bottom_met_E"], avdd_via2.ports["bottom_met_W"])

###################################################
# 12.b Internal Conections
###################################################
top_comp << straight_route( pdk, M0_ref.ports["tie_W_top_met_S"], M1_ref.ports["tie_W_top_met_N"])
top_comp << c_route(pdk, M1_ref.ports["source_W"], M0_ref.ports["gate_W"], extension=1.8)
top_comp << c_route(pdk, M0_ref.ports["gate_E"], M0_ref.ports["drain_E"], extension=1.5)
top_comp << L_route(pdk, M1_ref.ports["gate_E"], ifwd_via.ports["bottom_met_S"])
display_component(top_comp, "./", scale=3)

# %%
top_comp.add_ports(M0_ref.get_ports_list(), prefix="M0_")
top_comp.add_ports(M1_ref.get_ports_list(), prefix="M1_")

top_comp.add_ports(i_SUM_via.get_ports_list(), prefix="i_SUM_")
top_comp.add_ports(ifwd_via.get_ports_list(), prefix="ifwd_")

top_comp.add_ports(avdd_via1.get_ports_list(), prefix="avdd1_")
top_comp.add_ports(avdd_via2.get_ports_list(), prefix="avdd2_")

display_component(top_comp, "./", scale=3)

# %%
top_comp.pprint_ports()
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name                                             ┃ width ┃ center          ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ avdd                                             │ 1.0   │ [-3.97, 5.075]  │ 180         │ [36, 0] │ electrical │
# │ i_SUM                                            │ 1.0   │ [6.195, 0.395]  │ 180         │ [36, 0] │ electrical │
# │ ifwd                                             │ 1.0   │ [6.195, -5.705] │ 180         │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_bottom_layer_W          │ 0.36  │ [-2.98, -2.34]  │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_bottom_via_W            │ 0.22  │ [-2.91, -2.34]  │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_bottom_met_W            │ 0.5   │ [-3.05, -2.34]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_top_met_W               │ 0.5   │ [-3.05, -2.34]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_bottom_layer_W          │ 0.36  │ [-2.18, -2.34]  │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_bottom_via_W            │ 0.22  │ [-2.11, -2.34]  │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_bottom_met_W            │ 0.5   │ [-2.25, -2.34]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_top_met_W               │ 0.5   │ [-2.25, -2.34]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_bottom_layer_W          │ 0.36  │ [-1.38, -2.34]  │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_bottom_via_W            │ 0.22  │ [-1.31, -2.34]  │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_bottom_met_W            │ 0.5   │ [-1.45, -2.34]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_top_met_W               │ 0.5   │ [-1.45, -2.34]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_bottom_layer_W          │ 0.36  │ [-0.58, -2.34]  │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_bottom_via_W            │ 0.22  │ [-0.51, -2.34]  │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_bottom_met_W            │ 0.5   │ [-0.65, -2.34]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_top_met_W               │ 0.5   │ [-0.65, -2.34]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_bottom_layer_W          │ 0.36  │ [0.22, -2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_bottom_via_W            │ 0.22  │ [0.29, -2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_bottom_met_W            │ 0.5   │ [0.15, -2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_top_met_W               │ 0.5   │ [0.15, -2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_bottom_layer_W          │ 0.36  │ [1.02, -2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_bottom_via_W            │ 0.22  │ [1.09, -2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_bottom_met_W            │ 0.5   │ [0.95, -2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_top_met_W               │ 0.5   │ [0.95, -2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_bottom_layer_W          │ 0.36  │ [1.82, -2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_bottom_via_W            │ 0.22  │ [1.89, -2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_bottom_met_W            │ 0.5   │ [1.75, -2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_top_met_W               │ 0.5   │ [1.75, -2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_bottom_layer_W          │ 0.36  │ [2.62, -2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_bottom_via_W            │ 0.22  │ [2.69, -2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_bottom_met_W            │ 0.5   │ [2.55, -2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_top_met_W               │ 0.5   │ [2.55, -2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_S_bottom_lay_W                            │ 0.36  │ [-2.98, -2.34]  │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_S_top_met_W                               │ 0.5   │ [-3.79, -2.34]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_bl_bottom_layer_W                         │ 0.5   │ [-4.2, -2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_bl_bottom_via_W                           │ 0.26  │ [-4.08, -2.34]  │ 180.0       │ [35, 0] │ electrical │
# │ M0_tie_bl_bottom_met_W                           │ 0.5   │ [-4.2, -2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_bl_top_met_W                              │ 0.5   │ [-4.2, -2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_br_bottom_layer_W                         │ 0.5   │ [3.7, -2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_br_bottom_via_W                           │ 0.26  │ [3.82, -2.34]   │ 180.0       │ [35, 0] │ electrical │
# │ M0_tie_br_bottom_met_W                           │ 0.5   │ [3.7, -2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_br_top_met_W                              │ 0.5   │ [3.7, -2.34]    │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_bottom_layer_W          │ 0.36  │ [3.79, -1.5]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_bottom_via_W            │ 0.22  │ [3.86, -1.5]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_bottom_met_W            │ 0.46  │ [3.74, -1.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_top_met_W               │ 0.46  │ [3.74, -1.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_bottom_layer_W          │ 0.36  │ [-4.15, -1.5]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_bottom_via_W            │ 0.22  │ [-4.08, -1.5]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_bottom_met_W            │ 0.46  │ [-4.2, -1.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_top_met_W               │ 0.46  │ [-4.2, -1.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_gate_W                           │ 0.5   │ [-2.5, -1.445]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_gate_W                                        │ 0.5   │ [-2.5, -1.445]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_bottom_layer_W          │ 0.36  │ [3.79, -1.0]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_bottom_via_W            │ 0.22  │ [3.86, -1.0]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_bottom_met_W            │ 0.46  │ [3.74, -1.0]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_top_met_W               │ 0.46  │ [3.74, -1.0]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_bottom_layer_W          │ 0.36  │ [-4.15, -1.0]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_bottom_via_W            │ 0.22  │ [-4.08, -1.0]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_bottom_met_W            │ 0.46  │ [-4.2, -1.0]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_top_met_W               │ 0.46  │ [-4.2, -1.0]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_bottom_layer_W          │ 0.36  │ [3.79, -0.5]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_bottom_via_W            │ 0.22  │ [3.86, -0.5]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_bottom_met_W            │ 0.46  │ [3.74, -0.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_top_met_W               │ 0.46  │ [3.74, -0.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_bottom_layer_W          │ 0.36  │ [-4.15, -0.5]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_bottom_via_W            │ 0.22  │ [-4.08, -0.5]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_bottom_met_W            │ 0.46  │ [-4.2, -0.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_top_met_W               │ 0.46  │ [-4.2, -0.5]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_gate_W                 │ 0.98  │ [-2.5, -0.405]  │ 180.0       │ [30, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.36  │ [2.6, -0.405]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.22  │ [2.67, -0.405]  │ 180.0       │ [33, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.46  │ [2.55, -0.405]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.46  │ [2.55, -0.405]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_top_met_W      │ 0.5   │ [2.55, -0.405]  │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_bottom_l… │ 0.36  │ [-2.96, -0.405] │ 180.0       │ [22, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_bottom_v… │ 0.22  │ [-2.89, -0.405] │ 180.0       │ [33, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_bottom_m… │ 0.46  │ [-3.01, -0.405] │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_top_met_W │ 0.46  │ [-3.01, -0.405] │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_leftsd_top_met_W                 │ 0.5   │ [-3.01, -0.405] │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_plusdoped_W                      │ 0.96  │ [-3.33, -0.405] │ 180.0       │ [31, 0] │ electrical │
# │ M0_multiplier_0_diff_W                           │ 0.5   │ [-3.1, -0.405]  │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_layer_W          │ 0.36  │ [3.79, 0.0]     │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_via_W            │ 0.22  │ [3.86, 0.0]     │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_met_W            │ 0.46  │ [3.74, 0.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_top_met_W               │ 0.46  │ [3.74, 0.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_bottom_lay_W                            │ 3.36  │ [3.79, 0.0]     │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_top_met_W                               │ 4.32  │ [3.74, 0.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_layer_W          │ 0.36  │ [-4.15, 0.0]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_via_W            │ 0.22  │ [-4.08, 0.0]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_met_W            │ 0.46  │ [-4.2, 0.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_top_met_W               │ 0.46  │ [-4.2, 0.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_bottom_lay_W                            │ 3.36  │ [-4.15, 0.0]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_top_met_W                               │ 4.32  │ [-4.2, 0.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_well_W                                        │ 5.6   │ [-4.43, 0.0]    │ 180.0       │ [21, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_layer_W          │ 0.36  │ [3.79, 0.5]     │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_via_W            │ 0.22  │ [3.86, 0.5]     │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_met_W            │ 0.46  │ [3.74, 0.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_top_met_W               │ 0.46  │ [3.74, 0.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_layer_W          │ 0.36  │ [-4.15, 0.5]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_via_W            │ 0.22  │ [-4.08, 0.5]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_met_W            │ 0.46  │ [-4.2, 0.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_top_met_W               │ 0.46  │ [-4.2, 0.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_source_W                         │ 0.5   │ [-3.03, 0.645]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_source_W                                      │ 0.5   │ [-3.03, 0.645]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_layer_W          │ 0.36  │ [3.79, 1.0]     │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_via_W            │ 0.22  │ [3.86, 1.0]     │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_met_W            │ 0.46  │ [3.74, 1.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_top_met_W               │ 0.46  │ [3.74, 1.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_layer_W          │ 0.36  │ [-4.15, 1.0]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_via_W            │ 0.22  │ [-4.08, 1.0]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_met_W            │ 0.46  │ [-4.2, 1.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_top_met_W               │ 0.46  │ [-4.2, 1.0]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_multiplier_0_drain_W                          │ 0.5   │ [-3.03, 1.445]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_drain_W                                       │ 0.5   │ [-3.03, 1.445]  │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_layer_W          │ 0.36  │ [3.79, 1.5]     │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_via_W            │ 0.22  │ [3.86, 1.5]     │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_met_W            │ 0.46  │ [3.74, 1.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_top_met_W               │ 0.46  │ [3.74, 1.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_layer_W          │ 0.36  │ [-4.15, 1.5]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_via_W            │ 0.22  │ [-4.08, 1.5]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_met_W            │ 0.46  │ [-4.2, 1.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_top_met_W               │ 0.46  │ [-4.2, 1.5]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_layer_W          │ 0.36  │ [-2.98, 2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_via_W            │ 0.22  │ [-2.91, 2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_met_W            │ 0.5   │ [-3.05, 2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_top_met_W               │ 0.5   │ [-3.05, 2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_layer_W          │ 0.36  │ [-2.18, 2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_via_W            │ 0.22  │ [-2.11, 2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_met_W            │ 0.5   │ [-2.25, 2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_top_met_W               │ 0.5   │ [-2.25, 2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_layer_W          │ 0.36  │ [-1.38, 2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_via_W            │ 0.22  │ [-1.31, 2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_met_W            │ 0.5   │ [-1.45, 2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_top_met_W               │ 0.5   │ [-1.45, 2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_layer_W          │ 0.36  │ [-0.58, 2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_via_W            │ 0.22  │ [-0.51, 2.34]   │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_met_W            │ 0.5   │ [-0.65, 2.34]   │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_top_met_W               │ 0.5   │ [-0.65, 2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_layer_W          │ 0.36  │ [0.22, 2.34]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_via_W            │ 0.22  │ [0.29, 2.34]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_met_W            │ 0.5   │ [0.15, 2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_top_met_W               │ 0.5   │ [0.15, 2.34]    │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_layer_W          │ 0.36  │ [1.02, 2.34]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_via_W            │ 0.22  │ [1.09, 2.34]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_met_W            │ 0.5   │ [0.95, 2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_top_met_W               │ 0.5   │ [0.95, 2.34]    │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_layer_W          │ 0.36  │ [1.82, 2.34]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_via_W            │ 0.22  │ [1.89, 2.34]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_met_W            │ 0.5   │ [1.75, 2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_top_met_W               │ 0.5   │ [1.75, 2.34]    │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_layer_W          │ 0.36  │ [2.62, 2.34]    │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_via_W            │ 0.22  │ [2.69, 2.34]    │ 180.0       │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_met_W            │ 0.5   │ [2.55, 2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_top_met_W               │ 0.5   │ [2.55, 2.34]    │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_N_bottom_lay_W                            │ 0.36  │ [-2.98, 2.34]   │ 180.0       │ [22, 0] │ electrical │
# │ M0_tie_N_top_met_W                               │ 0.5   │ [-3.79, 2.34]   │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_tl_bottom_layer_W                         │ 0.5   │ [-4.2, 2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_tl_bottom_via_W                           │ 0.26  │ [-4.08, 2.34]   │ 180.0       │ [35, 0] │ electrical │
# │ M0_tie_tl_bottom_met_W                           │ 0.5   │ [-4.2, 2.34]    │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_tl_top_met_W                              │ 0.5   │ [-4.2, 2.34]    │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_tr_bottom_layer_W                         │ 0.5   │ [3.7, 2.34]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_tr_bottom_via_W                           │ 0.26  │ [3.82, 2.34]    │ 180.0       │ [35, 0] │ electrical │
# │ M0_tie_tr_bottom_met_W                           │ 0.5   │ [3.7, 2.34]     │ 180.0       │ [34, 0] │ electrical │
# │ M0_tie_tr_top_met_W                              │ 0.5   │ [3.7, 2.34]     │ 180.0       │ [36, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_bottom_layer_N          │ 0.36  │ [-3.97, -1.32]  │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_bottom_via_N            │ 0.22  │ [-3.97, -1.39]  │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_bottom_met_N            │ 0.46  │ [-3.97, -1.27]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row0_col0_top_met_N               │ 0.46  │ [-3.97, -1.27]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_bottom_layer_N          │ 0.36  │ [-3.97, -0.82]  │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_bottom_via_N            │ 0.22  │ [-3.97, -0.89]  │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_bottom_met_N            │ 0.46  │ [-3.97, -0.77]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row1_col0_top_met_N               │ 0.46  │ [-3.97, -0.77]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_bottom_layer_N          │ 0.36  │ [-3.97, -0.32]  │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_bottom_via_N            │ 0.22  │ [-3.97, -0.39]  │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_bottom_met_N            │ 0.46  │ [-3.97, -0.27]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row2_col0_top_met_N               │ 0.46  │ [-3.97, -0.27]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_layer_N          │ 0.36  │ [-3.97, 0.18]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_via_N            │ 0.22  │ [-3.97, 0.11]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_met_N            │ 0.46  │ [-3.97, 0.23]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_top_met_N               │ 0.46  │ [-3.97, 0.23]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_layer_N          │ 0.36  │ [-3.97, 0.68]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_via_N            │ 0.22  │ [-3.97, 0.61]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_met_N            │ 0.46  │ [-3.97, 0.73]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_top_met_N               │ 0.46  │ [-3.97, 0.73]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_layer_N          │ 0.36  │ [-3.97, 1.18]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_via_N            │ 0.22  │ [-3.97, 1.11]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_met_N            │ 0.46  │ [-3.97, 1.23]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_top_met_N               │ 0.46  │ [-3.97, 1.23]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_layer_N          │ 0.36  │ [-3.97, 1.68]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_via_N            │ 0.22  │ [-3.97, 1.61]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_met_N            │ 0.46  │ [-3.97, 1.73]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_top_met_N               │ 0.46  │ [-3.97, 1.73]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_W_bottom_lay_N                            │ 0.36  │ [-3.97, 1.68]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_W_top_met_N                               │ 0.46  │ [-3.97, 2.16]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_tl_bottom_layer_N                         │ 0.5   │ [-3.95, 2.59]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_tl_bottom_via_N                           │ 0.26  │ [-3.95, 2.47]   │ 90.0        │ [35, 0] │ electrical │
# │ M0_tie_tl_bottom_met_N                           │ 0.5   │ [-3.95, 2.59]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_tl_top_met_N                              │ 0.5   │ [-3.95, 2.59]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_bl_bottom_layer_N                         │ 0.5   │ [-3.95, -2.09]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_bl_bottom_via_N                           │ 0.26  │ [-3.95, -2.21]  │ 90.0        │ [35, 0] │ electrical │
# │ M0_tie_bl_bottom_met_N                           │ 0.5   │ [-3.95, -2.09]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_bl_top_met_N                              │ 0.5   │ [-3.95, -2.09]  │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_layer_N          │ 0.36  │ [-2.8, 2.52]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_via_N            │ 0.22  │ [-2.8, 2.45]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_met_N            │ 0.5   │ [-2.8, 2.59]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_top_met_N               │ 0.5   │ [-2.8, 2.59]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_bottom_layer_N          │ 0.36  │ [-2.8, -2.16]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_bottom_via_N            │ 0.22  │ [-2.8, -2.23]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_bottom_met_N            │ 0.5   │ [-2.8, -2.09]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col0_top_met_N               │ 0.5   │ [-2.8, -2.09]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_bottom_l… │ 0.36  │ [-2.78, -0.225] │ 90.0        │ [22, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_bottom_v… │ 0.22  │ [-2.78, -0.295] │ 90.0        │ [33, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_bottom_m… │ 0.46  │ [-2.78, -0.175] │ 90.0        │ [34, 0] │ electrical │
# │ M0_multiplier_0_leftsd_array_row0_col0_top_met_N │ 0.46  │ [-2.78, -0.175] │ 90.0        │ [34, 0] │ electrical │
# │ M0_multiplier_0_leftsd_top_met_N                 │ 0.46  │ [-2.78, -0.155] │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_layer_N          │ 0.36  │ [-2.0, 2.52]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_via_N            │ 0.22  │ [-2.0, 2.45]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_met_N            │ 0.5   │ [-2.0, 2.59]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_top_met_N               │ 0.5   │ [-2.0, 2.59]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_bottom_layer_N          │ 0.36  │ [-2.0, -2.16]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_bottom_via_N            │ 0.22  │ [-2.0, -2.23]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_bottom_met_N            │ 0.5   │ [-2.0, -2.09]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col1_top_met_N               │ 0.5   │ [-2.0, -2.09]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_layer_N          │ 0.36  │ [-1.2, 2.52]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_via_N            │ 0.22  │ [-1.2, 2.45]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_met_N            │ 0.5   │ [-1.2, 2.59]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_top_met_N               │ 0.5   │ [-1.2, 2.59]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_bottom_layer_N          │ 0.36  │ [-1.2, -2.16]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_bottom_via_N            │ 0.22  │ [-1.2, -2.23]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_bottom_met_N            │ 0.5   │ [-1.2, -2.09]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col2_top_met_N               │ 0.5   │ [-1.2, -2.09]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_layer_N          │ 0.36  │ [-0.4, 2.52]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_via_N            │ 0.22  │ [-0.4, 2.45]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_met_N            │ 0.5   │ [-0.4, 2.59]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_top_met_N               │ 0.5   │ [-0.4, 2.59]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_bottom_layer_N          │ 0.36  │ [-0.4, -2.16]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_bottom_via_N            │ 0.22  │ [-0.4, -2.23]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_bottom_met_N            │ 0.5   │ [-0.4, -2.09]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col3_top_met_N               │ 0.5   │ [-0.4, -2.09]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_gate_N                 │ 5.0   │ [0.0, 0.085]    │ 90.0        │ [30, 0] │ electrical │
# │ M0_multiplier_0_plusdoped_N                      │ 6.66  │ [0.0, 0.075]    │ 90.0        │ [31, 0] │ electrical │
# │ M0_multiplier_0_diff_N                           │ 6.2   │ [0.0, -0.155]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_multiplier_0_drain_N                          │ 6.06  │ [0.0, 1.695]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_multiplier_0_source_N                         │ 6.06  │ [0.0, 0.895]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_source_N                                      │ 6.06  │ [0.0, 0.895]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_drain_N                                       │ 6.06  │ [0.0, 1.695]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_N_bottom_lay_N                            │ 5.96  │ [0.0, 2.52]     │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_top_met_N                               │ 7.58  │ [0.0, 2.59]     │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_bottom_lay_N                            │ 5.96  │ [0.0, -2.16]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_top_met_N                               │ 7.58  │ [0.0, -2.09]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_well_N                                        │ 8.86  │ [0.0, 2.8]      │ 90.0        │ [21, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_layer_N          │ 0.36  │ [0.4, 2.52]     │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_via_N            │ 0.22  │ [0.4, 2.45]     │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_met_N            │ 0.5   │ [0.4, 2.59]     │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_top_met_N               │ 0.5   │ [0.4, 2.59]     │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_bottom_layer_N          │ 0.36  │ [0.4, -2.16]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_bottom_via_N            │ 0.22  │ [0.4, -2.23]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_bottom_met_N            │ 0.5   │ [0.4, -2.09]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col4_top_met_N               │ 0.5   │ [0.4, -2.09]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_layer_N          │ 0.36  │ [1.2, 2.52]     │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_via_N            │ 0.22  │ [1.2, 2.45]     │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_met_N            │ 0.5   │ [1.2, 2.59]     │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_top_met_N               │ 0.5   │ [1.2, 2.59]     │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_bottom_layer_N          │ 0.36  │ [1.2, -2.16]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_bottom_via_N            │ 0.22  │ [1.2, -2.23]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_bottom_met_N            │ 0.5   │ [1.2, -2.09]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col5_top_met_N               │ 0.5   │ [1.2, -2.09]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_multiplier_0_gate_N                           │ 0.5   │ [1.6, -1.195]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_gate_N                                        │ 0.5   │ [1.6, -1.195]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_layer_N          │ 0.36  │ [2.0, 2.52]     │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_via_N            │ 0.22  │ [2.0, 2.45]     │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_met_N            │ 0.5   │ [2.0, 2.59]     │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_top_met_N               │ 0.5   │ [2.0, 2.59]     │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_bottom_layer_N          │ 0.36  │ [2.0, -2.16]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_bottom_via_N            │ 0.22  │ [2.0, -2.23]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_bottom_met_N            │ 0.5   │ [2.0, -2.09]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col6_top_met_N               │ 0.5   │ [2.0, -2.09]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.36  │ [2.78, -0.225]  │ 90.0        │ [22, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.22  │ [2.78, -0.295]  │ 90.0        │ [33, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.46  │ [2.78, -0.175]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_array_row0_co… │ 0.46  │ [2.78, -0.175]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_multiplier_0_row0_col0_rightsd_top_met_N      │ 0.46  │ [2.78, -0.155]  │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_layer_N          │ 0.36  │ [2.8, 2.52]     │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_via_N            │ 0.22  │ [2.8, 2.45]     │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_met_N            │ 0.5   │ [2.8, 2.59]     │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_top_met_N               │ 0.5   │ [2.8, 2.59]     │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_bottom_layer_N          │ 0.36  │ [2.8, -2.16]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_bottom_via_N            │ 0.22  │ [2.8, -2.23]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_bottom_met_N            │ 0.5   │ [2.8, -2.09]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_S_array_row0_col7_top_met_N               │ 0.5   │ [2.8, -2.09]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_tr_bottom_layer_N                         │ 0.5   │ [3.95, 2.59]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_tr_bottom_via_N                           │ 0.26  │ [3.95, 2.47]    │ 90.0        │ [35, 0] │ electrical │
# │ M0_tie_tr_bottom_met_N                           │ 0.5   │ [3.95, 2.59]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_tr_top_met_N                              │ 0.5   │ [3.95, 2.59]    │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_br_bottom_layer_N                         │ 0.5   │ [3.95, -2.09]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_br_bottom_via_N                           │ 0.26  │ [3.95, -2.21]   │ 90.0        │ [35, 0] │ electrical │
# │ M0_tie_br_bottom_met_N                           │ 0.5   │ [3.95, -2.09]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_br_top_met_N                              │ 0.5   │ [3.95, -2.09]   │ 90.0        │ [36, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_bottom_layer_N          │ 0.36  │ [3.97, -1.32]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_bottom_via_N            │ 0.22  │ [3.97, -1.39]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_bottom_met_N            │ 0.46  │ [3.97, -1.27]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row0_col0_top_met_N               │ 0.46  │ [3.97, -1.27]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_bottom_layer_N          │ 0.36  │ [3.97, -0.82]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_bottom_via_N            │ 0.22  │ [3.97, -0.89]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_bottom_met_N            │ 0.46  │ [3.97, -0.77]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row1_col0_top_met_N               │ 0.46  │ [3.97, -0.77]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_bottom_layer_N          │ 0.36  │ [3.97, -0.32]   │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_bottom_via_N            │ 0.22  │ [3.97, -0.39]   │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_bottom_met_N            │ 0.46  │ [3.97, -0.27]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row2_col0_top_met_N               │ 0.46  │ [3.97, -0.27]   │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_layer_N          │ 0.36  │ [3.97, 0.18]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_via_N            │ 0.22  │ [3.97, 0.11]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_met_N            │ 0.46  │ [3.97, 0.23]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_top_met_N               │ 0.46  │ [3.97, 0.23]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_layer_N          │ 0.36  │ [3.97, 0.68]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_via_N            │ 0.22  │ [3.97, 0.61]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_met_N            │ 0.46  │ [3.97, 0.73]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_top_met_N               │ 0.46  │ [3.97, 0.73]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_layer_N          │ 0.36  │ [3.97, 1.18]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_via_N            │ 0.22  │ [3.97, 1.11]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_met_N            │ 0.46  │ [3.97, 1.23]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_top_met_N               │ 0.46  │ [3.97, 1.23]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_layer_N          │ 0.36  │ [3.97, 1.68]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_via_N            │ 0.22  │ [3.97, 1.61]    │ 90.0        │ [33, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_met_N            │ 0.46  │ [3.97, 1.73]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_top_met_N               │ 0.46  │ [3.97, 1.73]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_E_bottom_lay_N                            │ 0.36  │ [3.97, 1.68]    │ 90.0        │ [22, 0] │ electrical │
# │ M0_tie_E_top_met_N                               │ 0.46  │ [3.97, 2.16]    │ 90.0        │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_layer_E          │ 0.36  │ [-2.62, 2.34]   │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_via_E            │ 0.22  │ [-2.69, 2.34]   │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_bottom_met_E            │ 0.5   │ [-2.55, 2.34]   │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col0_top_met_E               │ 0.5   │ [-2.55, 2.34]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_layer_E          │ 0.36  │ [-1.82, 2.34]   │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_via_E            │ 0.22  │ [-1.89, 2.34]   │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_bottom_met_E            │ 0.5   │ [-1.75, 2.34]   │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col1_top_met_E               │ 0.5   │ [-1.75, 2.34]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_layer_E          │ 0.36  │ [-1.02, 2.34]   │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_via_E            │ 0.22  │ [-1.09, 2.34]   │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_bottom_met_E            │ 0.5   │ [-0.95, 2.34]   │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col2_top_met_E               │ 0.5   │ [-0.95, 2.34]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_layer_E          │ 0.36  │ [-0.22, 2.34]   │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_via_E            │ 0.22  │ [-0.29, 2.34]   │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_bottom_met_E            │ 0.5   │ [-0.15, 2.34]   │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col3_top_met_E               │ 0.5   │ [-0.15, 2.34]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_layer_E          │ 0.36  │ [0.58, 2.34]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_via_E            │ 0.22  │ [0.51, 2.34]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_bottom_met_E            │ 0.5   │ [0.65, 2.34]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col4_top_met_E               │ 0.5   │ [0.65, 2.34]    │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_layer_E          │ 0.36  │ [1.38, 2.34]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_via_E            │ 0.22  │ [1.31, 2.34]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_bottom_met_E            │ 0.5   │ [1.45, 2.34]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col5_top_met_E               │ 0.5   │ [1.45, 2.34]    │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_layer_E          │ 0.36  │ [2.18, 2.34]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_via_E            │ 0.22  │ [2.11, 2.34]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_bottom_met_E            │ 0.5   │ [2.25, 2.34]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col6_top_met_E               │ 0.5   │ [2.25, 2.34]    │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_layer_E          │ 0.36  │ [2.98, 2.34]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_via_E            │ 0.22  │ [2.91, 2.34]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_bottom_met_E            │ 0.5   │ [3.05, 2.34]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_N_array_row0_col7_top_met_E               │ 0.5   │ [3.05, 2.34]    │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_N_bottom_lay_E                            │ 0.36  │ [2.98, 2.34]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_N_top_met_E                               │ 0.5   │ [3.79, 2.34]    │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_tl_bottom_layer_E                         │ 0.5   │ [-3.7, 2.34]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_tl_bottom_via_E                           │ 0.26  │ [-3.82, 2.34]   │ 0.0         │ [35, 0] │ electrical │
# │ M0_tie_tl_bottom_met_E                           │ 0.5   │ [-3.7, 2.34]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_tl_top_met_E                              │ 0.5   │ [-3.7, 2.34]    │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_tr_bottom_layer_E                         │ 0.5   │ [4.2, 2.34]     │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_tr_bottom_via_E                           │ 0.26  │ [4.08, 2.34]    │ 0.0         │ [35, 0] │ electrical │
# │ M0_tie_tr_bottom_met_E                           │ 0.5   │ [4.2, 2.34]     │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_tr_top_met_E                              │ 0.5   │ [4.2, 2.34]     │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_layer_E          │ 0.36  │ [4.15, 1.5]     │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_via_E            │ 0.22  │ [4.08, 1.5]     │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_bottom_met_E            │ 0.46  │ [4.2, 1.5]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_E_array_row6_col0_top_met_E               │ 0.46  │ [4.2, 1.5]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_layer_E          │ 0.36  │ [-3.79, 1.5]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_via_E            │ 0.22  │ [-3.86, 1.5]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_bottom_met_E            │ 0.46  │ [-3.74, 1.5]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row6_col0_top_met_E               │ 0.46  │ [-3.74, 1.5]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_multiplier_0_drain_E                          │ 0.5   │ [3.03, 1.445]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_drain_E                                       │ 0.5   │ [3.03, 1.445]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_layer_E          │ 0.36  │ [4.15, 1.0]     │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_via_E            │ 0.22  │ [4.08, 1.0]     │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_bottom_met_E            │ 0.46  │ [4.2, 1.0]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_E_array_row5_col0_top_met_E               │ 0.46  │ [4.2, 1.0]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_layer_E          │ 0.36  │ [-3.79, 1.0]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_via_E            │ 0.22  │ [-3.86, 1.0]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_bottom_met_E            │ 0.46  │ [-3.74, 1.0]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row5_col0_top_met_E               │ 0.46  │ [-3.74, 1.0]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_multiplier_0_source_E                         │ 0.5   │ [3.03, 0.645]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_source_E                                      │ 0.5   │ [3.03, 0.645]   │ 0.0         │ [36, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_layer_E          │ 0.36  │ [4.15, 0.5]     │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_via_E            │ 0.22  │ [4.08, 0.5]     │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_bottom_met_E            │ 0.46  │ [4.2, 0.5]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_E_array_row4_col0_top_met_E               │ 0.46  │ [4.2, 0.5]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_layer_E          │ 0.36  │ [-3.79, 0.5]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_via_E            │ 0.22  │ [-3.86, 0.5]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_bottom_met_E            │ 0.46  │ [-3.74, 0.5]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row4_col0_top_met_E               │ 0.46  │ [-3.74, 0.5]    │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_layer_E          │ 0.36  │ [4.15, 0.0]     │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_via_E            │ 0.22  │ [4.08, 0.0]     │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_bottom_met_E            │ 0.46  │ [4.2, 0.0]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_E_array_row3_col0_top_met_E               │ 0.46  │ [4.2, 0.0]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_E_bottom_lay_E                            │ 3.36  │ [4.15, 0.0]     │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_E_top_met_E                               │ 4.32  │ [4.2, 0.0]      │ 0.0         │ [34, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_layer_E          │ 0.36  │ [-3.79, 0.0]    │ 0.0         │ [22, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_via_E            │ 0.22  │ [-3.86, 0.0]    │ 0.0         │ [33, 0] │ electrical │
# │ M0_tie_W_array_row3_col0_bottom_met_E            │ 0.46  │ [-3.74, 0.0]    │ 0.0         │ [34, 0] │ electrical │
# ...
# │ M1_tie_S_array_row0_col3_bottom_via_S            │ 0.22  │ [-0.4, -9.35]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_S_array_row0_col3_bottom_met_S            │ 0.5   │ [-0.4, -9.49]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_S_array_row0_col3_top_met_S               │ 0.5   │ [-0.4, -9.49]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_N_array_row0_col2_bottom_layer_S          │ 0.36  │ [-1.2, -4.74]   │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_N_array_row0_col2_bottom_via_S            │ 0.22  │ [-1.2, -4.67]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_N_array_row0_col2_bottom_met_S            │ 0.5   │ [-1.2, -4.81]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_N_array_row0_col2_top_met_S               │ 0.5   │ [-1.2, -4.81]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_S_array_row0_col2_bottom_layer_S          │ 0.36  │ [-1.2, -9.42]   │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_S_array_row0_col2_bottom_via_S            │ 0.22  │ [-1.2, -9.35]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_S_array_row0_col2_bottom_met_S            │ 0.5   │ [-1.2, -9.49]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_S_array_row0_col2_top_met_S               │ 0.5   │ [-1.2, -9.49]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_multiplier_0_gate_S                           │ 0.5   │ [-1.6, -8.595]  │ 270.0       │ [36, 0] │ electrical │
# │ M1_gate_S                                        │ 0.5   │ [-1.6, -8.595]  │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_N_array_row0_col1_bottom_layer_S          │ 0.36  │ [-2.0, -4.74]   │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_N_array_row0_col1_bottom_via_S            │ 0.22  │ [-2.0, -4.67]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_N_array_row0_col1_bottom_met_S            │ 0.5   │ [-2.0, -4.81]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_N_array_row0_col1_top_met_S               │ 0.5   │ [-2.0, -4.81]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_S_array_row0_col1_bottom_layer_S          │ 0.36  │ [-2.0, -9.42]   │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_S_array_row0_col1_bottom_via_S            │ 0.22  │ [-2.0, -9.35]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_S_array_row0_col1_bottom_met_S            │ 0.5   │ [-2.0, -9.49]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_S_array_row0_col1_top_met_S               │ 0.5   │ [-2.0, -9.49]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_multiplier_0_leftsd_array_row0_col0_bottom_l… │ 0.36  │ [-2.78, -7.485] │ 270.0       │ [22, 0] │ electrical │
# │ M1_multiplier_0_leftsd_array_row0_col0_bottom_v… │ 0.22  │ [-2.78, -7.415] │ 270.0       │ [33, 0] │ electrical │
# │ M1_multiplier_0_leftsd_array_row0_col0_bottom_m… │ 0.46  │ [-2.78, -7.535] │ 270.0       │ [34, 0] │ electrical │
# │ M1_multiplier_0_leftsd_array_row0_col0_top_met_S │ 0.46  │ [-2.78, -7.535] │ 270.0       │ [34, 0] │ electrical │
# │ M1_multiplier_0_leftsd_top_met_S                 │ 0.46  │ [-2.78, -7.555] │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_N_array_row0_col0_bottom_layer_S          │ 0.36  │ [-2.8, -4.74]   │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_N_array_row0_col0_bottom_via_S            │ 0.22  │ [-2.8, -4.67]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_N_array_row0_col0_bottom_met_S            │ 0.5   │ [-2.8, -4.81]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_N_array_row0_col0_top_met_S               │ 0.5   │ [-2.8, -4.81]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_S_array_row0_col0_bottom_layer_S          │ 0.36  │ [-2.8, -9.42]   │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_S_array_row0_col0_bottom_via_S            │ 0.22  │ [-2.8, -9.35]   │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_S_array_row0_col0_bottom_met_S            │ 0.5   │ [-2.8, -9.49]   │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_S_array_row0_col0_top_met_S               │ 0.5   │ [-2.8, -9.49]   │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_tl_bottom_layer_S                         │ 0.5   │ [-3.95, -4.81]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_tl_bottom_via_S                           │ 0.26  │ [-3.95, -4.69]  │ 270.0       │ [35, 0] │ electrical │
# │ M1_tie_tl_bottom_met_S                           │ 0.5   │ [-3.95, -4.81]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_tl_top_met_S                              │ 0.5   │ [-3.95, -4.81]  │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_bl_bottom_layer_S                         │ 0.5   │ [-3.95, -9.49]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_bl_bottom_via_S                           │ 0.26  │ [-3.95, -9.37]  │ 270.0       │ [35, 0] │ electrical │
# │ M1_tie_bl_bottom_met_S                           │ 0.5   │ [-3.95, -9.49]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_bl_top_met_S                              │ 0.5   │ [-3.95, -9.49]  │ 270.0       │ [36, 0] │ electrical │
# │ M1_tie_W_array_row0_col0_bottom_layer_S          │ 0.36  │ [-3.97, -8.58]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row0_col0_bottom_via_S            │ 0.22  │ [-3.97, -8.51]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row0_col0_bottom_met_S            │ 0.46  │ [-3.97, -8.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row0_col0_top_met_S               │ 0.46  │ [-3.97, -8.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row1_col0_bottom_layer_S          │ 0.36  │ [-3.97, -8.08]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row1_col0_bottom_via_S            │ 0.22  │ [-3.97, -8.01]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row1_col0_bottom_met_S            │ 0.46  │ [-3.97, -8.13]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row1_col0_top_met_S               │ 0.46  │ [-3.97, -8.13]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row2_col0_bottom_layer_S          │ 0.36  │ [-3.97, -7.58]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row2_col0_bottom_via_S            │ 0.22  │ [-3.97, -7.51]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row2_col0_bottom_met_S            │ 0.46  │ [-3.97, -7.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row2_col0_top_met_S               │ 0.46  │ [-3.97, -7.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row3_col0_bottom_layer_S          │ 0.36  │ [-3.97, -7.08]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row3_col0_bottom_via_S            │ 0.22  │ [-3.97, -7.01]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row3_col0_bottom_met_S            │ 0.46  │ [-3.97, -7.13]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row3_col0_top_met_S               │ 0.46  │ [-3.97, -7.13]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row4_col0_bottom_layer_S          │ 0.36  │ [-3.97, -6.58]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row4_col0_bottom_via_S            │ 0.22  │ [-3.97, -6.51]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row4_col0_bottom_met_S            │ 0.46  │ [-3.97, -6.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row4_col0_top_met_S               │ 0.46  │ [-3.97, -6.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row5_col0_bottom_layer_S          │ 0.36  │ [-3.97, -6.08]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row5_col0_bottom_via_S            │ 0.22  │ [-3.97, -6.01]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row5_col0_bottom_met_S            │ 0.46  │ [-3.97, -6.13]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row5_col0_top_met_S               │ 0.46  │ [-3.97, -6.13]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row6_col0_bottom_layer_S          │ 0.36  │ [-3.97, -5.58]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_array_row6_col0_bottom_via_S            │ 0.22  │ [-3.97, -5.51]  │ 270.0       │ [33, 0] │ electrical │
# │ M1_tie_W_array_row6_col0_bottom_met_S            │ 0.46  │ [-3.97, -5.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_array_row6_col0_top_met_S               │ 0.46  │ [-3.97, -5.63]  │ 270.0       │ [34, 0] │ electrical │
# │ M1_tie_W_bottom_lay_S                            │ 0.36  │ [-3.97, -8.58]  │ 270.0       │ [22, 0] │ electrical │
# │ M1_tie_W_top_met_S                               │ 0.46  │ [-3.97, -9.06]  │ 270.0       │ [34, 0] │ electrical │
# │ i_SUM_bottom_layer_W                             │ 0.5   │ [5.945, 0.645]  │ 180.0       │ [36, 0] │ electrical │
# │ i_SUM_bottom_via_W                               │ 0.26  │ [6.065, 0.645]  │ 180.0       │ [38, 0] │ electrical │
# │ i_SUM_bottom_met_W                               │ 0.5   │ [5.945, 0.645]  │ 180.0       │ [36, 0] │ electrical │
# │ i_SUM_top_met_W                                  │ 0.5   │ [5.945, 0.645]  │ 180.0       │ [42, 0] │ electrical │
# │ i_SUM_bottom_layer_N                             │ 0.5   │ [6.195, 0.895]  │ 90.0        │ [36, 0] │ electrical │
# │ i_SUM_bottom_via_N                               │ 0.26  │ [6.195, 0.775]  │ 90.0        │ [38, 0] │ electrical │
# │ i_SUM_bottom_met_N                               │ 0.5   │ [6.195, 0.895]  │ 90.0        │ [36, 0] │ electrical │
# │ i_SUM_top_met_N                                  │ 0.5   │ [6.195, 0.895]  │ 90.0        │ [42, 0] │ electrical │
# │ i_SUM_bottom_layer_E                             │ 0.5   │ [6.445, 0.645]  │ 0.0         │ [36, 0] │ electrical │
# │ i_SUM_bottom_via_E                               │ 0.26  │ [6.325, 0.645]  │ 0.0         │ [38, 0] │ electrical │
# │ i_SUM_bottom_met_E                               │ 0.5   │ [6.445, 0.645]  │ 0.0         │ [36, 0] │ electrical │
# │ i_SUM_top_met_E                                  │ 0.5   │ [6.445, 0.645]  │ 0.0         │ [42, 0] │ electrical │
# │ i_SUM_bottom_layer_S                             │ 0.5   │ [6.195, 0.395]  │ 270.0       │ [36, 0] │ electrical │
# │ i_SUM_bottom_via_S                               │ 0.26  │ [6.195, 0.515]  │ 270.0       │ [38, 0] │ electrical │
# │ i_SUM_bottom_met_S                               │ 0.5   │ [6.195, 0.395]  │ 270.0       │ [36, 0] │ electrical │
# │ i_SUM_top_met_S                                  │ 0.5   │ [6.195, 0.395]  │ 270.0       │ [42, 0] │ electrical │
# │ ifwd_bottom_layer_W                              │ 0.5   │ [5.945, -5.455] │ 180.0       │ [36, 0] │ electrical │
# │ ifwd_bottom_via_W                                │ 0.26  │ [6.065, -5.455] │ 180.0       │ [38, 0] │ electrical │
# │ ifwd_bottom_met_W                                │ 0.5   │ [5.945, -5.455] │ 180.0       │ [36, 0] │ electrical │
# │ ifwd_top_met_W                                   │ 0.5   │ [5.945, -5.455] │ 180.0       │ [42, 0] │ electrical │
# │ ifwd_bottom_layer_N                              │ 0.5   │ [6.195, -5.205] │ 90.0        │ [36, 0] │ electrical │
# │ ifwd_bottom_via_N                                │ 0.26  │ [6.195, -5.325] │ 90.0        │ [38, 0] │ electrical │
# │ ifwd_bottom_met_N                                │ 0.5   │ [6.195, -5.205] │ 90.0        │ [36, 0] │ electrical │
# │ ifwd_top_met_N                                   │ 0.5   │ [6.195, -5.205] │ 90.0        │ [42, 0] │ electrical │
# │ ifwd_bottom_layer_E                              │ 0.5   │ [6.445, -5.455] │ 0.0         │ [36, 0] │ electrical │
# │ ifwd_bottom_via_E                                │ 0.26  │ [6.325, -5.455] │ 0.0         │ [38, 0] │ electrical │
# │ ifwd_bottom_met_E                                │ 0.5   │ [6.445, -5.455] │ 0.0         │ [36, 0] │ electrical │
# │ ifwd_top_met_E                                   │ 0.5   │ [6.445, -5.455] │ 0.0         │ [42, 0] │ electrical │
# │ ifwd_bottom_layer_S                              │ 0.5   │ [6.195, -5.705] │ 270.0       │ [36, 0] │ electrical │
# │ ifwd_bottom_via_S                                │ 0.26  │ [6.195, -5.585] │ 270.0       │ [38, 0] │ electrical │
# │ ifwd_bottom_met_S                                │ 0.5   │ [6.195, -5.705] │ 270.0       │ [36, 0] │ electrical │
# │ ifwd_top_met_S                                   │ 0.5   │ [6.195, -5.705] │ 270.0       │ [42, 0] │ electrical │
# │ avdd1_bottom_layer_W                             │ 0.5   │ [-4.22, 5.325]  │ 180.0       │ [36, 0] │ electrical │
# │ avdd1_bottom_via_W                               │ 0.26  │ [-4.1, 5.325]   │ 180.0       │ [38, 0] │ electrical │
# │ avdd1_bottom_met_W                               │ 0.5   │ [-4.22, 5.325]  │ 180.0       │ [36, 0] │ electrical │
# │ avdd1_top_met_W                                  │ 0.5   │ [-4.22, 5.325]  │ 180.0       │ [42, 0] │ electrical │
# │ avdd1_bottom_layer_N                             │ 0.5   │ [-3.97, 5.575]  │ 90.0        │ [36, 0] │ electrical │
# │ avdd1_bottom_via_N                               │ 0.26  │ [-3.97, 5.455]  │ 90.0        │ [38, 0] │ electrical │
# │ avdd1_bottom_met_N                               │ 0.5   │ [-3.97, 5.575]  │ 90.0        │ [36, 0] │ electrical │
# │ avdd1_top_met_N                                  │ 0.5   │ [-3.97, 5.575]  │ 90.0        │ [42, 0] │ electrical │
# │ avdd1_bottom_layer_E                             │ 0.5   │ [-3.72, 5.325]  │ 0.0         │ [36, 0] │ electrical │
# │ avdd1_bottom_via_E                               │ 0.26  │ [-3.84, 5.325]  │ 0.0         │ [38, 0] │ electrical │
# │ avdd1_bottom_met_E                               │ 0.5   │ [-3.72, 5.325]  │ 0.0         │ [36, 0] │ electrical │
# │ avdd1_top_met_E                                  │ 0.5   │ [-3.72, 5.325]  │ 0.0         │ [42, 0] │ electrical │
# │ avdd1_bottom_layer_S                             │ 0.5   │ [-3.97, 5.075]  │ 270.0       │ [36, 0] │ electrical │
# │ avdd1_bottom_via_S                               │ 0.26  │ [-3.97, 5.195]  │ 270.0       │ [38, 0] │ electrical │
# │ avdd1_bottom_met_S                               │ 0.5   │ [-3.97, 5.075]  │ 270.0       │ [36, 0] │ electrical │
# │ avdd1_top_met_S                                  │ 0.5   │ [-3.97, 5.075]  │ 270.0       │ [42, 0] │ electrical │
# │ avdd2_bottom_layer_W                             │ 0.5   │ [-2.67, 5.325]  │ 180.0       │ [36, 0] │ electrical │
# │ avdd2_bottom_via_W                               │ 0.26  │ [-2.55, 5.325]  │ 180.0       │ [38, 0] │ electrical │
# │ avdd2_bottom_met_W                               │ 0.5   │ [-2.67, 5.325]  │ 180.0       │ [36, 0] │ electrical │
# │ avdd2_top_met_W                                  │ 0.5   │ [-2.67, 5.325]  │ 180.0       │ [42, 0] │ electrical │
# │ avdd2_bottom_layer_N                             │ 0.5   │ [-2.42, 5.575]  │ 90.0        │ [36, 0] │ electrical │
# │ avdd2_bottom_via_N                               │ 0.26  │ [-2.42, 5.455]  │ 90.0        │ [38, 0] │ electrical │
# │ avdd2_bottom_met_N                               │ 0.5   │ [-2.42, 5.575]  │ 90.0        │ [36, 0] │ electrical │
# │ avdd2_top_met_N                                  │ 0.5   │ [-2.42, 5.575]  │ 90.0        │ [42, 0] │ electrical │
# │ avdd2_bottom_layer_E                             │ 0.5   │ [-2.17, 5.325]  │ 0.0         │ [36, 0] │ electrical │
# │ avdd2_bottom_via_E                               │ 0.26  │ [-2.29, 5.325]  │ 0.0         │ [38, 0] │ electrical │
# │ avdd2_bottom_met_E                               │ 0.5   │ [-2.17, 5.325]  │ 0.0         │ [36, 0] │ electrical │
# │ avdd2_top_met_E                                  │ 0.5   │ [-2.17, 5.325]  │ 0.0         │ [42, 0] │ electrical │
# │ avdd2_bottom_layer_S                             │ 0.5   │ [-2.42, 5.075]  │ 270.0       │ [36, 0] │ electrical │
# │ avdd2_bottom_via_S                               │ 0.26  │ [-2.42, 5.195]  │ 270.0       │ [38, 0] │ electrical │
# │ avdd2_bottom_met_S                               │ 0.5   │ [-2.42, 5.075]  │ 270.0       │ [36, 0] │ electrical │
# │ avdd2_top_met_S                                  │ 0.5   │ [-2.42, 5.075]  │ 270.0       │ [42, 0] │ electrical │
# └──────────────────────────────────────────────────┴───────┴─────────────────┴─────────────┴─────────┴────────────┘

# %%
top_comp.name="Current_limit"
drc_result = gf180.drc_magic(top_comp, top_comp.name)
print("Making sure your environment varriables are still correctly set")
print(" I am using PDK in: ",os.environ['PDK_ROOT'],"\n PDK name: ",os.environ['PDK'],"\n The PDK files are at: ",os.environ['PDKPATH'])
# Out:
# 2026-08-20 21:55:17.497 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpp4pdtyj_/Current_limit.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpp4pdtyj_/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Current_limit".
# Reading "L_route_8a9085e1".
# Reading "rectangle_2d3cd8bd$2".
# Reading "M1".
# Reading "straight_route_27de76d1".
# Reading "straight_route_3aeded5d".
# Reading "c_route_7b813cc3".
# Reading "M0".
# Reading "straight_route_fae26f94".
# Reading "c_route_37dfc8e9".
# Reading "compass_2d3cd8bd$30".
# Reading "straight_route_b31679a7".
# Reading "compass_2d3cd8bd$29".
# Reading "straight_route_ecf1fe62".
# Reading "via_stack_22f48a44".
# Reading "rectangle_2d3cd8bd".
# Reading "compass_2d3cd8bd$31".
# Reading "rectangle_2d3cd8bd$1".
# [INFO]: Loading Current_limit
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpp4pdtyj_/Current_limit.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
#
# Making sure your environment varriables are still correctly set
#  I am using PDK in:  /foss/pdks
#  PDK name:  gf180mcuD
#  The PDK files are at:  /foss/pdks/gf180mcuD

# %%
import os
from pathlib import Path
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name = top_comp.name
path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/"

pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"

top_comp.write_gds(str(gds_path))
    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
exit
"""

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)

import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# 2026-08-20 21:55:17.847 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/Current_limit.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Current_limit".
# Reading "L_route_8a9085e1".
# Reading "rectangle_2d3cd8bd$2".
# Reading "M1".
# Reading "straight_route_27de76d1".
# Reading "straight_route_3aeded5d".
# Reading "c_route_7b813cc3".
# Reading "M0".
# Reading "straight_route_fae26f94".
# Reading "c_route_37dfc8e9".
# Reading "compass_2d3cd8bd$30".
# Reading "straight_route_b31679a7".
# Reading "compass_2d3cd8bd$29".
# Reading "straight_route_ecf1fe62".
# Reading "via_stack_22f48a44".
# Reading "rectangle_2d3cd8bd".
# Reading "compass_2d3cd8bd$31".
# Reading "rectangle_2d3cd8bd$1".
# Extracting L_route_8a9085e1 into L_route_8a9085e1.ext:
# Extracting M1 into M1.ext:
# Extracting c_route_7b813cc3 into c_route_7b813cc3.ext:
# Extracting straight_route_b31679a7 into straight_route_b31679a7.ext:
# Extracting straight_route_ecf1fe62 into straight_route_ecf1fe62.ext:
# Extracting via_stack_22f48a44 into via_stack_22f48a44.ext:
# Extracting compass_2d3cd8bd$31 into compass_2d3cd8bd$31.ext:
# Extracting rectangle_2d3cd8bd$2 into rectangle_2d3cd8bd$2.ext:
# Extracting straight_route_3aeded5d into straight_route_3aeded5d.ext:
# Extracting M0 into M0.ext:
# Extracting c_route_37dfc8e9 into c_route_37dfc8e9.ext:
# Extracting compass_2d3cd8bd$30 into compass_2d3cd8bd$30.ext:
# Extracting rectangle_2d3cd8bd$1 into rectangle_2d3cd8bd$1.ext:
# Extracting straight_route_27de76d1 into straight_route_27de76d1.ext:
# Extracting straight_route_fae26f94 into straight_route_fae26f94.ext:
# Extracting compass_2d3cd8bd$29 into compass_2d3cd8bd$29.ext:
# Extracting rectangle_2d3cd8bd into rectangle_2d3cd8bd.ext:
# Extracting Current_limit into Current_limit.ext:
# exttosim finished.
# Adding  avdd; Tnew = 0.01ns, Told = 0.00ns
# Adding  i_SUM
# Adding  ifwd; Tnew = 0.00ns, Told = 0.00ns
# Total Nets: 5
# Nets extracted: 3 (0.600000)
# Nets output: 3 (0.600000)
# exttospice finished.
#
# Deleted: straight_route_27de76d1.ext
# Deleted: straight_route_b31679a7.ext
# Deleted: compass_2d3cd8bd$30.ext
# Deleted: rectangle_2d3cd8bd$1.ext
# Deleted: straight_route_3aeded5d.ext
# Deleted: M1.ext
# Deleted: M0.ext
# Deleted: c_route_7b813cc3.ext
# Deleted: Current_limit.res.ext
# Deleted: compass_2d3cd8bd$31.ext
# Deleted: c_route_37dfc8e9.ext
# Deleted: Current_limit.ext
# Deleted: straight_route_fae26f94.ext
# Deleted: rectangle_2d3cd8bd.ext
# Deleted: straight_route_ecf1fe62.ext
# Deleted: rectangle_2d3cd8bd$2.ext
# Deleted: compass_2d3cd8bd$29.ext
# Deleted: L_route_8a9085e1.ext
# Deleted: via_stack_22f48a44.ext
# Error deleting Current_limit.res.ext: [Errno 2] No such file or directory: 'Current_limit.res.ext'
# Deleted: Current_limit.nodes
# Deleted: Current_limit.sim

# %%
gf180.lvs_netgen(
    layout=top_comp,
    design_name = top_comp.name,
    pdk_root = Path(os.environ['PDKPATH']),
    lvs_setup_tcl_file = Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    netlist = Path(str(path_to_dir + "Current_limitSCH.spice")),
    output_file_path =  Path(str(path_to_dir))
)
# Out:
# 2026-08-20 21:55:18.101 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmp5hjf3nxm/Current_limit.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=4096]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "Current_limit".
# Reading "L_route_8a9085e1".
# Reading "rectangle_2d3cd8bd$2".
# Reading "M1".
# Reading "straight_route_27de76d1".
# Reading "straight_route_3aeded5d".
# Reading "c_route_7b813cc3".
# Reading "M0".
# Reading "straight_route_fae26f94".
# Reading "c_route_37dfc8e9".
# Reading "compass_2d3cd8bd$30".
# Reading "straight_route_b31679a7".
# Reading "compass_2d3cd8bd$29".
# Reading "straight_route_ecf1fe62".
# Reading "via_stack_22f48a44".
# Reading "rectangle_2d3cd8bd".
# Reading "compass_2d3cd8bd$31".
# Reading "rectangle_2d3cd8bd$1".
# Extracting L_route_8a9085e1 into L_route_8a9085e1.ext:
# Extracting M1 into M1.ext:
# Extracting c_route_7b813cc3 into c_route_7b813cc3.ext:
# Extracting straight_route_b31679a7 into straight_route_b31679a7.ext:
# Extracting straight_route_ecf1fe62 into straight_route_ecf1fe62.ext:
# Extracting via_stack_22f48a44 into via_stack_22f48a44.ext:
# Extracting compass_2d3cd8bd$31 into compass_2d3cd8bd$31.ext:
# Extracting rectangle_2d3cd8bd$2 into rectangle_2d3cd8bd$2.ext:
# Extracting straight_route_3aeded5d into straight_route_3aeded5d.ext:
# Extracting M0 into M0.ext:
# Extracting c_route_37dfc8e9 into c_route_37dfc8e9.ext:
# Extracting compass_2d3cd8bd$30 into compass_2d3cd8bd$30.ext:
# Extracting rectangle_2d3cd8bd$1 into rectangle_2d3cd8bd$1.ext:
# Extracting straight_route_27de76d1 into straight_route_27de76d1.ext:
# Extracting straight_route_fae26f94 into straight_route_fae26f94.ext:
# Extracting compass_2d3cd8bd$29 into compass_2d3cd8bd$29.ext:
# Extracting rectangle_2d3cd8bd into rectangle_2d3cd8bd.ext:
# Extracting Current_limit into Current_limit.ext:
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmp5hjf3nxm/Current_limit_lvsmag.spice Current_limit" "/tmp/tmp5hjf3nxm/Current_limit.spice Current_limit" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmp5hjf3nxm/Current_limit_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:02:45 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmp5hjf3nxm/Current_limit_lvsmag.spice for /tmp/tmp5hjf3nxm/Current_limit_lvsmag.spice Current_limit
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmp5hjf3nxm/Current_limit.spice for /tmp/tmp5hjf3nxm/Current_limit.spice Current_limit
# Call to undefined subcircuit pmos_3p3
# Creating placeholder cell definition.
# Call to undefined subcircuit nmos_3p3
# Creating placeholder cell definition.
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property area found for device c
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property as found for device pfet_03v3
# No property ad found for device pfet_03v3
# No property ps found for device pfet_03v3
# No property pd found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Comparison output logged to file /tmp/tmp5hjf3nxm/Current_limit_lvs.rpt
# Logging to file "/tmp/tmp5hjf3nxm/Current_limit_lvs.rpt" enabled
# Circuit pfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'Current_limit'
# Circuit Current_limit contains 2 device instances.
#   Class: pfet_03v3             instances:   2
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'Current_limit'
# Circuit Current_limit contains 2 device instances.
#   Class: pfet_03v3             instances:   2
# Circuit contains 4 nets.
#
# Circuit 1 contains 2 devices, Circuit 2 contains 2 devices.
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#
# Final result:
# Circuits match uniquely.
# .
# Logging to file "/tmp/tmp5hjf3nxm/Current_limit_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
# Flattening unmatched subcell M1 in circuit Current_limit (0)(1 instance)
# Flattening unmatched subcell M0 in circuit Current_limit (0)(1 instance)
#
# Subcircuit summary:
# Circuit 1: Current_limit                   |Circuit 2: Current_limit
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (2)                              |pfet_03v3 (2)
# Number of devices: 2                       |Number of devices: 2
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# Netlists match uniquely.
#
# Subcircuit pins:
# Circuit 1: Current_limit                   |Circuit 2: Current_limit
# -------------------------------------------|-------------------------------------------
# i_SUM                                      |i_SUM
# avdd                                       |avdd
# ifwd                                       |ifwd
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes Current_limit and Current_limit are equivalent.
#
# Final result: Circuits match uniquely.
# .
# {'magic_subproc_code': 0,
#  'netgen_subproc_code': 0,
#  'result_str': 'LVS run succeeded\nErrors found in LVS report: /tmp/tmp5hjf3nxm/Current_limit_lvs.rpt'}

# %%
from pathlib import Path
import os
import subprocess

pdk_name = os.environ.get("PDK", "gf180mcuD")
pdk_root = Path(os.environ.get("PDK_ROOT", ""))
pdk_path_env = Path(os.environ.get("PDKPATH", ""))

# Resolve the correct magicrc path even if PDKPATH is stale or duplicated.
candidate_pdkpaths = [
    pdk_path_env,
    pdk_root / pdk_name,
    pdk_root,
]
magicrc_file = None
for candidate in candidate_pdkpaths:
    if not str(candidate):
        continue
    rc = candidate / "libs.tech" / "magic" / f"{pdk_name}.magicrc"
    if rc.exists():
        magicrc_file = rc
        break

if magicrc_file is None:
    raise FileNotFoundError(
        "No se encontro el magicrc. Revisar PDK_ROOT/PDK/PDKPATH. "
        f"Busque en: {[str(c) for c in candidate_pdkpaths if str(c)]}"
    )

# --- Cambio clave: usar path_to_dir en vez de Path.cwd()/"exports" ---
path_to_dir = "/foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/"
output_dir = Path(path_to_dir)
output_dir.mkdir(parents=True, exist_ok=True)

design_name = top_comp.name
gds_path = output_dir / f"{design_name}.gds"
lef_path = output_dir / f"{design_name}.lef"

top_comp.write_gds(str(gds_path))

magic_script = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}
load {design_name}
lef write {lef_path}
quit -noprompt
"""

result = subprocess.run(
    ["magic", "-rcfile", str(magicrc_file), "-noconsole", "-dnull"],
    input=magic_script,
    text=True,
    capture_output=True,
    check=True,
)

print(f"CWD kernel: {Path.cwd()}")
print(f"LEF generado: {lef_path}")
print(f"LEF existe: {lef_path.exists()}")
if lef_path.exists():
    print("\nCabecera LEF:")
    with open(lef_path, "r", encoding="utf-8", errors="ignore") as f:
        for _ in range(15):
            line = f.readline()
            if not line:
                break
            print(line.rstrip())
else:
    print("\n--- STDOUT COMPLETO DE MAGIC (para depurar) ---")
    print(result.stdout)
    print("\n--- STDERR COMPLETO DE MAGIC ---")
    print(result.stderr)
# Out:
# 2026-08-20 21:55:18.385 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/Current_limit.gds'
# CWD kernel: /foss/designs
# LEF generado: /foss/designs/CapiMagics/designs/libs/snn_analog/Current_limit/Current_limit.lef
# LEF existe: True
#
# Cabecera LEF:
# VERSION 5.7 ;
#   NOWIREEXTENSIONATPIN ON ;
#   DIVIDERCHAR "/" ;
#   BUSBITCHARS "[]" ;
# MACRO Current_limit
#   CLASS BLOCK ;
#   FOREIGN Current_limit ;
#   ORIGIN 5.330 9.700 ;
#   SIZE 12.025 BY 15.275 ;
#   PIN avdd
#     ANTENNADIFFAREA 18.172800 ;
#     PORT
#       LAYER Nwell ;
#         RECT -4.430 -2.800 4.430 2.800 ;
#         RECT -4.430 -9.700 4.430 -4.100 ;
