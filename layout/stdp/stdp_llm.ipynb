# %%
import os
import subprocess
try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file,path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)


# %%
import os
import gdsfactory as gf
from gdsfactory import Component
from glayout import MappedPDK, gf180
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring
from glayout.primitives.mimcap import mimcap_array
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist


# Base parameters for PMOS and NMOS
stdp_config = {
    "pdk": gf180,
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation()+1,
        "routing_metal": "met2",
        "dummy_devices": False,
        "tie_layers": ("met2", "met1"),
        "sd_rmult": 1,
    },
}

nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False
}

pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False
}
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
pdk = gf180
stdp_comp = Component(name="stdp")
stdp_comp.name = "stdp"
rules = stdp_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]

# =========================================================================
# 1. INSTANTIATE ALL DEVICES MATCHING SPICE NETLIST
# =========================================================================

# --- PMOS TRANSISTORS ---
# XM1: W=0.22u, L=0.28u -> w=0.5 L=0.63 
xm1 = pmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
# XM2: W=0.22u, L=0.28u
xm2 = pmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
# XM7: W=0.22u, L=0.28u
xm7 = pmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
# XM8: W=0.22u, L=0.28u
xm8 = pmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
# XM17: W=0.3u, L=4.6u
xm17 = pmos(pdk, width=0.5, length=4.6, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
# XM16: W=10.2u, L=2.8u
xm16 = pmos(pdk, width=10.2, length=2.8, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
#adding XM5 W=0.5 L=15U
xm5 = pmos(pdk, width=0.5, length=15, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)


# --- NMOS TRANSISTORS ---
# XM3: W=0.22u, L=0.28u
xm3 = nmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
# XM4: W=0.22u, L=0.28u
xm4 = nmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
# XM9: W=0.22u, L=0.28u
xm9 = nmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
# XM12: W=0.22u, L=0.28u
xm12 = nmos(pdk, width=0.5, length=0.63, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
# XMCM_1: W=0.61u, L=2.8u
xmcm_1 = nmos(pdk, width=0.61, length=2.8, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)

# --- LONG-CHANNEL BIAS CHAIN (XMCM_5 to XMCM_9): W=0.5u, L=10u ---
xmcm_chain = [
    nmos(pdk, width=0.5, length=10.0, with_dummy=(False, False), with_substrate_tap=False, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
    for _ in range(5)
]


# --- MIM CAPACITORS ---
# Cpot: 5x5um, m=2 (2 rows, 1 col)
cpot = mimcap_array(pdk, size=(5, 5), rows=2, columns=1)
# Cdep: 5x5um, m=2 (2 rows, 1 col)
cdep = mimcap_array(pdk, size=(5, 5), rows=2, columns=1)
# Cw: 5x5um, m=10 (2 rows, 5 cols)
cw = mimcap_array(pdk, size=(5, 5), rows=5, columns=2)


xm1.name = "xm1" 
xm2.name = "xm2" 
xm7.name = "xm7" 
xm8.name = "xm8" 
xm17.name = "xm17" 
xm16.name = "xm16" 
xm5.name = "xm5"
xm3.name = "xm3"
xm4.name = "xm4"
xm9.name = "xm9"
xm12.name = "xm12"
xmcm_1.name = "xmcm_1"
xmcm_chain[0].name = "xmcm_chain_0"
xmcm_chain[1].name = "xmcm_chain_1"
xmcm_chain[2].name = "xmcm_chain_2"
xmcm_chain[3].name = "xmcm_chain_3"
xmcm_chain[4].name = "xmcm_chain_4"
cpot.name = "cpot" 
cdep.name = "cdep" 
cw.name = "cw" 


# =========================================================================
# 2. PLACEMENT & FLOORPLANNING
# =========================================================================

# Add components to subcircuit
#top row
xm1_ref = stdp_comp << xm1
xm2_ref = stdp_comp << xm2
xm7_ref = stdp_comp << xm7
xm8_ref = stdp_comp << xm8
xm17_ref = stdp_comp << xm17
xm16_ref = stdp_comp << xm16
xm5_ref = stdp_comp << xm5

# second row
xm3_ref = stdp_comp << xm3
xm4_ref = stdp_comp << xm4
xm9_ref = stdp_comp << xm9
xm12_ref = stdp_comp << xm12
xmcm_1_ref = stdp_comp << xmcm_1
chain_refs = [stdp_comp << dev for dev in xmcm_chain]

cpot_ref = stdp_comp << cpot
cdep_ref = stdp_comp << cdep
cw_ref = stdp_comp << cw



#placement of three rows
bottom_row_y = evaluate_bbox(chain_refs[1])[1]/2 + 4
middle_row_y = bottom_row_y + evaluate_bbox(chain_refs[0])[1]
top_row_y = middle_row_y + evaluate_bbox(xmcm_1)[1] + evaluate_bbox(xm16)[1]/2
# --- TOP ROW: PMOS Array ---
xm1_xy = evaluate_bbox(xm1)
xm2_xy = evaluate_bbox(xm2)
xm7_xy = evaluate_bbox(xm7)
xm8_xy = evaluate_bbox(xm8)
xm17_xy = evaluate_bbox(xm17)
xm16_xy = evaluate_bbox(xm16)
cpot_xy = evaluate_bbox(cpot)
xm1_ref.move((0 + xm1_xy[0]/2, top_row_y ))
xm2_ref.move((xm1_ref.xmax + xm2_xy[0]/2 + spacing, top_row_y))
xm7_ref.move((xm2_ref.xmax + xm7_xy[0]/2 + spacing, top_row_y))
xm8_ref.move((xm7_ref.xmax + xm8_xy[0]/2 + spacing, top_row_y))
xm17_ref.move((xm8_ref.xmax + xm17_xy[0]/2 + spacing, top_row_y))
xm16_ref.move((xm17_ref.xmax + xm16_xy[0]/2 + spacing, top_row_y))
#placing xm5 the current source for next neuron
xm5_ref.move((evaluate_bbox(xm5_ref)[0]/2,top_row_y + xm1_xy[1] + spacing))


# --- MIDDLE ROW: Standard NMOS Array ---
xm3_xy = evaluate_bbox(xm3)
xm4_xy = evaluate_bbox(xm4)
xm9_xy = evaluate_bbox(xm9)
xm12_xy = evaluate_bbox(xm12)
xmcm_1_xy = evaluate_bbox(xmcm_1)
cdep_xy = evaluate_bbox(cdep)

xm3_ref.move((0 + xm3_xy[0]/2, middle_row_y+ spacing))
xm4_ref.move((xm3_ref.xmax + xm4_xy[0]/2 + spacing, middle_row_y+ spacing))
xm9_ref.move((xm4_ref.xmax + xm9_xy[0]/2 + spacing, middle_row_y+ spacing))
xm12_ref.move((xm9_ref.xmax + xm12_xy[0]/2 + spacing, middle_row_y+ spacing))
xmcm_1_ref.move((xm12_ref.xmax + xmcm_1_xy[0]/2 + spacing, middle_row_y + spacing))
chain_refs[0].move((xmcm_1_ref.xmax + evaluate_bbox(chain_refs[0])[0]/2 + spacing, middle_row_y + spacing))

# --- BOTTOM ROW: Long-Channel Bias Chain (Series connected) ---
chain_refs[1].move((evaluate_bbox(chain_refs[1])[0]/2, bottom_row_y))
chain_refs[2].move((chain_refs[1].xmax + evaluate_bbox(chain_refs[2])[0]/2 + spacing, bottom_row_y))
chain_refs[3].move((chain_refs[2].xmax + evaluate_bbox(chain_refs[3])[0]/2 + spacing, bottom_row_y))
chain_refs[4].move((chain_refs[3].xmax + evaluate_bbox(chain_refs[4])[0]/2 + spacing, bottom_row_y))


# --- MOVING CAPACITORS: 
cw_xy = evaluate_bbox(cw)
cpot_ref.move((xm16_ref.xmax + cpot_xy[0]/2 + 1.5, top_row_y-4))
cdep_ref.move((cpot_ref.xmax + cdep_xy[0]/2 + 1.5, top_row_y-4))
cw_ref.move((cdep_ref.xmax + cdep_xy[0]/2 + 4, bottom_row_y))
# Out:
# 2026-08-21 21:33:39.957 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active
# ComponentReference (parent Component "cw", ports ['row0_col0_array_row0_col0_bottom_layer_W', 'row0_col0_array_row0_col0_bottom_via_W', 'row0_col0_array_row0_col0_bottom_met_W', 'row0_col0_array_row0_col0_top_met_W', 'row0_col0_array_row0_col1_bottom_layer_W', 'row0_col0_array_row0_col1_bottom_via_W', 'row0_col0_array_row0_col1_bottom_met_W', 'row0_col0_array_row0_col1_top_met_W', 'row0_col0_array_row0_col2_bottom_layer_W', 'row0_col0_array_row0_col2_bottom_via_W', 'row0_col0_array_row0_col2_bottom_met_W', 'row0_col0_array_row0_col2_top_met_W', 'row0_col0_array_row0_col3_bottom_layer_W', 'row0_col0_array_row0_col3_bottom_via_W', 'row0_col0_array_row0_col3_bottom_met_W', 'row0_col0_array_row0_col3_top_met_W', 'row0_col1_array_row0_col0_bottom_layer_W', 'row0_col1_array_row0_col0_bottom_via_W', 'row0_col1_array_row0_col0_bottom_met_W', 'row0_col1_array_row0_col0_top_met_W', 'row0_col1_array_row0_col1_bottom_layer_W', 'row0_col1_array_row0_col1_bottom_via_W', 'row0_col1_array_row0_col1_bottom_met_W', 'row0_col1_array_row0_col1_top_met_W', 'row0_col1_array_row0_col2_bottom_layer_W', 'row0_col1_array_row0_col2_bottom_via_W', 'row0_col1_array_row0_col2_bottom_met_W', 'row0_col1_array_row0_col2_top_met_W', 'row0_col1_array_row0_col3_bottom_layer_W', 'row0_col1_array_row0_col3_bottom_via_W', 'row0_col1_array_row0_col3_bottom_met_W', 'row0_col1_array_row0_col3_top_met_W', 'row0_col0_array_row1_col0_bottom_layer_W', 'row0_col0_array_row1_col0_bottom_via_W', 'row0_col0_array_row1_col0_bottom_met_W', 'row0_col0_array_row1_col0_top_met_W', 'row0_col0_array_row1_col1_bottom_layer_W', 'row0_col0_array_row1_col1_bottom_via_W', 'row0_col0_array_row1_col1_bottom_met_W', 'row0_col0_array_row1_col1_top_met_W', 'row0_col0_array_row1_col2_bottom_layer_W', 'row0_col0_array_row1_col2_bottom_via_W', 'row0_col0_array_row1_col2_bottom_met_W', 'row0_col0_array_row1_col2_top_met_W', 'row0_col0_array_row1_col3_bottom_layer_W', 'row0_col0_array_row1_col3_bottom_via_W', 'row0_col0_array_row1_col3_bottom_met_W', 'row0_col0_array_row1_col3_top_met_W', 'row0_col1_array_row1_col0_bottom_layer_W', 'row0_col1_array_row1_col0_bottom_via_W', 'row0_col1_array_row1_col0_bottom_met_W', 'row0_col1_array_row1_col0_top_met_W', 'row0_col1_array_row1_col1_bottom_layer_W', 'row0_col1_array_row1_col1_bottom_via_W', 'row0_col1_array_row1_col1_bottom_met_W', 'row0_col1_array_row1_col1_top_met_W', 'row0_col1_array_row1_col2_bottom_layer_W', 'row0_col1_array_row1_col2_bottom_via_W', 'row0_col1_array_row1_col2_bottom_met_W', 'row0_col1_array_row1_col2_top_met_W', 'row0_col1_array_row1_col3_bottom_layer_W', 'row0_col1_array_row1_col3_bottom_via_W', 'row0_col1_array_row1_col3_bottom_met_W', 'row0_col1_array_row1_col3_top_met_W', 'row0_col0_bottom_met_W', 'row0_col0_top_met_W', 'row0_col1_bottom_met_W', 'row0_col1_top_met_W', 'row0_col0_array_row2_col0_bottom_layer_W', 'row0_col0_array_row2_col0_bottom_via_W', 'row0_col0_array_row2_col0_bottom_met_W', 'row0_col0_array_row2_col0_top_met_W', 'row0_col0_array_row2_col1_bottom_layer_W', 'row0_col0_array_row2_col1_bottom_via_W', 'row0_col0_array_row2_col1_bottom_met_W', 'row0_col0_array_row2_col1_top_met_W', 'row0_col0_array_row2_col2_bottom_layer_W', 'row0_col0_array_row2_col2_bottom_via_W', 'row0_col0_array_row2_col2_bottom_met_W', 'row0_col0_array_row2_col2_top_met_W', 'row0_col0_array_row2_col3_bottom_layer_W', 'row0_col0_array_row2_col3_bottom_via_W', 'row0_col0_array_row2_col3_bottom_met_W', 'row0_col0_array_row2_col3_top_met_W', 'row0_col1_array_row2_col0_bottom_layer_W', 'row0_col1_array_row2_col0_bottom_via_W', 'row0_col1_array_row2_col0_bottom_met_W', 'row0_col1_array_row2_col0_top_met_W', 'row0_col1_array_row2_col1_bottom_layer_W', 'row0_col1_array_row2_col1_bottom_via_W', 'row0_col1_array_row2_col1_bottom_met_W', 'row0_col1_array_row2_col1_top_met_W', 'row0_col1_array_row2_col2_bottom_layer_W', 'row0_col1_array_row2_col2_bottom_via_W', 'row0_col1_array_row2_col2_bottom_met_W', 'row0_col1_array_row2_col2_top_met_W', 'row0_col1_ ...

# %%
# stdp_comp.show()
display_component(stdp_comp, scale = 1,path=".")

# %%
# =========================================================================
# 4. ADD AVDD & AVSS POWER RAILS AND CONNECT SUPPLY NODES
# =========================================================================

# https://gemini.google.com/app/131a537106def8cd
# Calculate full horizontal span of the cell to draw supply rails
bbox = evaluate_bbox(stdp_comp)
top_y = stdp_comp.ymax + 3.0
bottom_y = stdp_comp.ymin - 3.0

# Draw horizontal metal2 power rails
avdd_rail = stdp_comp << gf.components.rectangle(
    size=(bbox[0]+4, 1.0), 
    layer=pdk.get_layer("metal2")
)
avdd_rail.move((-2, top_y))

avss_rail = stdp_comp << gf.components.rectangle(
    size=(bbox[0]+4, 1.0), 
    layer=pdk.get_layer("metal2")
)
avss_rail.move((-2, bottom_y))

#adding a VIA M2M3 to the avdd avss pin, moving to the center of the rail
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
via_avdd = stdp_comp << viam2m3
via_avdd.move((bbox[0]/2, top_y + 0.5))
via_avss = stdp_comp << viam2m3
via_avss.move((bbox[0]/2, bottom_y + 0.5))

# Add global ports for the supply rails
stdp_comp.add_port("avdd", center=(bbox[0]/2, top_y + 0.5), width=1.0, orientation=180, layer=pdk.get_layer("metal3"), port_type="electrical")
stdp_comp.add_port("avss", center=(bbox[0]/2, bottom_y + 0.5), width=1.0, orientation=180, layer=pdk.get_layer("metal3"), port_type="electrical")
# add label to those global ports 
stdp_comp.add_label(text="avdd", position=(bbox[0]/2, top_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1.5)
stdp_comp.add_label(text="avss", position=(bbox[0]/2, bottom_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1.5)
# Out:
# Label(text='avss', origin=(37.49, 0.7999999999999998), layer=(42, 10))

# %%
# =========================================================================
# 5. ADD MET2 PHYSICAL PINS AND LABELS FOR LVS
# =========================================================================

# Map port names to their source port objects
pins_to_create = {
    # "avdd": xm1_ref.ports["multiplier_0_source_W"],
    # "avss": xm3_ref.ports["multiplier_0_source_W"],
    "nvpost": xm2_ref.ports["multiplier_0_gate_E"],
    "nvpre": xm8_ref.ports["multiplier_0_gate_E"],
    "vpost": xm12_ref.ports["multiplier_0_gate_E"],
    "vpre": xm3_ref.ports["multiplier_0_gate_E"],
    "vb_idep": xm16_ref.ports["multiplier_0_gate_E"],
    "vb_itd": chain_refs[0].ports["multiplier_0_gate_W"],
    "vb_itp": xm17_ref.ports["multiplier_0_gate_E"],
    "vb_pot": xmcm_1_ref.ports["multiplier_0_gate_E"],
    "vw": cw_ref.ports["row0_col0_top_met_E"],
    "Iout": xm5_ref.ports["multiplier_0_drain_W"]
}

for pin_name, port in pins_to_create.items():
    # Extract center position, size, and orientation from port object
    center = port.center
    width = port.width
    height = port.width  # Standard square pin area around the port center

    # 1. Add pin rectangle shape on met2_pin
    # stdp_comp.add_polygon(
    #     [
    #         (center[0] - width / 2, center[1] - height / 2),
    #         (center[0] + width / 2, center[1] - height / 2),
    #         (center[0] + width / 2, center[1] + height / 2),
    #         (center[0] - width / 2, center[1] + height / 2),
    #     ],
    #     layer=pdk.get_layer("metal3") ,
    # )
    
    #adding a via to each pin port to have them into metal 3
    viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
    via_port = stdp_comp << viam2m3
    via_port.move(center)

    stdp_comp.add_port(pin_name, center=center, width=1.0, orientation=180, layer=pdk.get_layer("metal3"),  port_type="electrical") 

    # 2. Add text label on met2_pin layer for net identity
    stdp_comp.add_label(
        text=pin_name, position=center, layer=pdk.get_glayer("met3_label"), magnification=1.2
    )

# %%
via_avdd.pprint_ports()
# Out:
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name           ┃ width ┃ center         ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ bottom_layer_W │ 0.5   │ [37.24, 43.4]  │ 180.0       │ [36, 0] │ electrical │
# │ bottom_layer_N │ 0.5   │ [37.49, 43.65] │ 90.0        │ [36, 0] │ electrical │
# │ bottom_layer_E │ 0.5   │ [37.74, 43.4]  │ 0.0         │ [36, 0] │ electrical │
# │ bottom_layer_S │ 0.5   │ [37.49, 43.15] │ 270.0       │ [36, 0] │ electrical │
# │ bottom_via_W   │ 0.26  │ [37.36, 43.4]  │ 180.0       │ [38, 0] │ electrical │
# │ bottom_via_N   │ 0.26  │ [37.49, 43.53] │ 90.0        │ [38, 0] │ electrical │
# │ bottom_via_E   │ 0.26  │ [37.62, 43.4]  │ 0.0         │ [38, 0] │ electrical │
# │ bottom_via_S   │ 0.26  │ [37.49, 43.27] │ 270.0       │ [38, 0] │ electrical │
# │ bottom_met_W   │ 0.5   │ [37.24, 43.4]  │ 180.0       │ [36, 0] │ electrical │
# │ bottom_met_N   │ 0.5   │ [37.49, 43.65] │ 90.0        │ [36, 0] │ electrical │
# │ bottom_met_E   │ 0.5   │ [37.74, 43.4]  │ 0.0         │ [36, 0] │ electrical │
# │ bottom_met_S   │ 0.5   │ [37.49, 43.15] │ 270.0       │ [36, 0] │ electrical │
# │ top_met_W      │ 0.5   │ [37.24, 43.4]  │ 180.0       │ [42, 0] │ electrical │
# │ top_met_N      │ 0.5   │ [37.49, 43.65] │ 90.0        │ [42, 0] │ electrical │
# │ top_met_E      │ 0.5   │ [37.74, 43.4]  │ 0.0         │ [42, 0] │ electrical │
# │ top_met_S      │ 0.5   │ [37.49, 43.15] │ 270.0       │ [42, 0] │ electrical │
# └────────────────┴───────┴────────────────┴─────────────┴─────────┴────────────┘

# %%
# =========================================================================
# 3. ROUTING & NET CONNECTIONS
# =========================================================================
# https://gemini.google.com/app/131a537106def8cd
# Gemini commited plenty of error in LVS. We have to modify each connection
# Connect PMOS bulks to avdd rail
stdp_comp << L_route(pdk, xm5_ref.ports["tie_W_top_met_N"], via_avdd.ports["bottom_met_W"])
stdp_comp << L_route(pdk, xm1_ref.ports["tie_W_top_met_N"], via_avdd.ports["bottom_met_W"])
stdp_comp << straight_route(pdk,  xm1_ref.ports["tie_E_top_met_E"], xm2_ref.ports["tie_W_top_met_W"])
stdp_comp << straight_route(pdk, xm7_ref.ports["tie_E_top_met_E"], xm8_ref.ports["tie_W_top_met_W"])
stdp_comp << L_route(pdk, xm8_ref.ports["tie_E_top_met_N"], via_avdd.ports["bottom_met_W"])
stdp_comp << L_route(pdk, xm17_ref.ports["tie_W_top_met_N"], via_avdd.ports["bottom_met_W"])
stdp_comp << L_route(pdk, xm16_ref.ports["tie_W_top_met_N"], via_avdd.ports["bottom_met_W"])
# Connect NMOS BULKS TO AVSS
stdp_comp << L_route(pdk, chain_refs[1].ports["tie_W_top_met_S"], via_avss.ports["bottom_met_W"] )
stdp_comp << L_route(pdk, chain_refs[2].ports["tie_W_top_met_S"], via_avss.ports["bottom_met_W"])
stdp_comp << L_route(pdk, chain_refs[3].ports["tie_W_top_met_S"], via_avss.ports["bottom_met_W"])
stdp_comp << L_route(pdk, chain_refs[4].ports["tie_W_top_met_S"], via_avss.ports["bottom_met_W"])
stdp_comp << straight_route(pdk, xm3_ref.ports["tie_W_top_met_S"], chain_refs[1].ports["tie_W_top_met_N"]) # Tie all the transistor's bulk of the middle row together,
stdp_comp << straight_route(pdk, xm3_ref.ports["tie_S_top_met_E"], chain_refs[0].ports["tie_S_top_met_W"]) #  then sending one connection to vdd
# Out:
# ComponentReference (parent Component "straight_route_ed82dd1f", ports ['route_W', 'route_N', 'route_E', 'route_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
display_component(stdp_comp, scale = 2,path=".")

# %%
# Connect MIM Capacitor Ground plates to avss
stdp_comp << straight_route(pdk, cw_ref.ports["row0_col0_top_met_S"], stdp_comp.ports["avss"])
stdp_comp << straight_route(pdk, cdep_ref.ports["row0_col0_bottom_met_E"], cw_ref.ports["row2_col0_bottom_met_S"])

#connect MIM Capacitor Cpot plate to avdd
stdp_comp << straight_route(pdk, cpot_ref.ports["row1_col0_array_row0_col3_top_met_N"], stdp_comp.ports["avdd"])

# Connecting the corresponding PMOS sources to avdd
stdp_comp << L_route(pdk,  xm1_ref.ports["multiplier_0_source_E"], xm1_ref.ports["tie_E_top_met_N"])  # SOURCE XM1
stdp_comp << L_route(pdk,  xm16_ref.ports["multiplier_0_source_E"], xm16_ref.ports["tie_E_top_met_N"])   # SOURCE XM16
stdp_comp << L_route(pdk,  xm17_ref.ports["multiplier_0_source_E"], xm17_ref.ports["tie_E_top_met_N"]) # SOURCE XM17
stdp_comp << L_route(pdk,  xm7_ref.ports["multiplier_0_source_E"], xm7_ref.ports["tie_E_top_met_N"]) # SOURCE XM7
stdp_comp << L_route(pdk,  xm5_ref.ports["multiplier_0_source_E"], xm5_ref.ports["tie_E_top_met_N"]) # SOURCE XM7

# Connecting the corresponding NMOS SOURCES TO AVSS
stdp_comp << L_route(pdk,  xm9_ref.ports["multiplier_0_source_E"], xm9_ref.ports["tie_E_top_met_N"]) #xm9
stdp_comp << L_route(pdk,  chain_refs[4].ports["multiplier_0_source_E"], chain_refs[4].ports["tie_E_top_met_N"]) #chain[4]
stdp_comp << L_route(pdk,  xm4_ref.ports["multiplier_0_source_E"], xm4_ref.ports["tie_E_top_met_N"]) #xm4
stdp_comp << L_route(pdk,  xmcm_1_ref.ports["multiplier_0_source_E"], xmcm_1_ref.ports["tie_E_top_met_N"]) #xmcm1
# Out:
# ComponentReference (parent Component "L_route_4e64478a", ports ['bottom_layer_W', 'bottom_via_W', 'bottom_met_W', 'top_met_W', 'bottom_layer_N', 'bottom_via_N', 'bottom_met_N', 'top_met_N', 'bottom_layer_E', 'bottom_via_E', 'bottom_met_E', 'top_met_E', 'bottom_layer_S', 'bottom_via_S', 'bottom_met_S', 'top_met_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
# stdp_comp.show()
display_component(stdp_comp, scale = 1,path=".")

# %%
# --- B. INTERNAL NET ROUTING ---
# net1: XM1 Drain -> XM2 Source
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
xm1_xm2_via = stdp_comp << viam2m3
xm1_xm2_via.move(xm1_ref.ports["multiplier_0_drain_E"].center).movex(2).movey(-5)
stdp_comp << c_route(pdk, xm1_ref.ports["multiplier_0_drain_W"], xm1_xm2_via.ports["bottom_met_W"], extension=1.5)
stdp_comp << L_route(pdk, xm1_xm2_via.ports["top_met_N"],xm2_ref.ports["multiplier_0_source_W"])


# net2: XM3 Source -> XM4 Drain
xm3_xm4_via = stdp_comp << viam2m3
xm3_xm4_via.move(xm3_ref.ports["multiplier_0_source_E"].center).movex(2)
stdp_comp << straight_route(pdk, xm3_ref.ports["multiplier_0_source_E"], xm3_xm4_via.ports["bottom_met_W"])
stdp_comp << L_route(pdk, xm3_xm4_via.ports["top_met_N"], xm4_ref.ports["multiplier_0_drain_W"])


# net3: XM7 Drain -> XMCM_1 Drain
xm7_xmcm_via = stdp_comp << viam2m3
xm7_xmcm_via.move(xm7_ref.ports["multiplier_0_drain_E"].center).movex(8).movey(-5)
stdp_comp << c_route(pdk, xm7_xmcm_via.ports["bottom_met_W"], xm7_ref.ports["multiplier_0_drain_W"], extension=2)
stdp_comp << L_route(pdk, xm7_xmcm_via.ports["top_met_S"], xmcm_1_ref.ports["multiplier_0_drain_W"])

# net4: XM7 Gate -> XM8 Drain
xm7g_xm8d_via = stdp_comp << viam2m3
xm7g_xm8d_via.move(xm7_ref.ports["multiplier_0_gate_E"].center).movex(2.8)
stdp_comp << straight_route(pdk,  xm7_ref.ports["multiplier_0_gate_E"], xm7g_xm8d_via.ports["bottom_met_W"])
stdp_comp << L_route(pdk,  xm7g_xm8d_via.ports["top_met_N"], xm8_ref.ports["multiplier_0_drain_E"])

# net5: XM9 Diode connection (Drain to Gate) and connecting to XM12 Drain & XM16 Drain
xm16_xm9_via = stdp_comp << viam2m3
xm16_xm9_via.move(xm16_ref.ports["multiplier_0_drain_W"].center).movex(-2).movey(-12)
stdp_comp << L_route(pdk, xm16_ref.ports["multiplier_0_drain_W"], xm16_xm9_via.ports["top_met_N"])
stdp_comp << c_route(pdk, xm9_ref.ports["multiplier_0_drain_W"], xm16_xm9_via.ports["bottom_met_W"])
stdp_comp << c_route(pdk, xm9_ref.ports["multiplier_0_gate_W"], xm16_xm9_via.ports["bottom_met_W"], extension=2)
stdp_comp << c_route(pdk, xm12_ref.ports["multiplier_0_drain_W"], xm16_xm9_via.ports["bottom_met_W"])

# vpot: XM1 Gate -> XM8 Source -> XM17 Drain -> Cpot Top Plate
vpot_via = stdp_comp << viam2m3
vpot_via.move(cpot_ref.ports["row1_col0_array_row0_col0_bottom_met_N"].center).movey(8)
stdp_comp << c_route(pdk, xm1_ref.ports["multiplier_0_gate_W"], vpot_via.ports["bottom_met_W"])
vpot_via_2 = stdp_comp << viam2m3
vpot_via_2.move(xm8_ref.ports["multiplier_0_source_E"].center).movex(1)
stdp_comp << straight_route(pdk, xm8_ref.ports["multiplier_0_source_W"], vpot_via_2.ports["bottom_met_W"])
stdp_comp << L_route(pdk, vpot_via_2.ports["top_met_N"], vpot_via.ports["bottom_met_W"])  
stdp_comp << straight_route(pdk, vpot_via.ports["bottom_met_S"], cpot_ref.ports["row1_col0_bottom_met_N"])
stdp_comp << c_route(pdk, xm17_ref.ports["multiplier_0_drain_W"], vpot_via.ports["bottom_met_W"])

# vdep: XM4 Gate -> XM12 Source -> Cdep Top Plate -> XMCM_5 Drain
vdep_via = stdp_comp << viam2m3
vdep_via.move(chain_refs[0].ports["multiplier_0_drain_N"].center).movey(1.8)
stdp_comp << c_route(pdk, xm4_ref.ports["multiplier_0_gate_W"], vdep_via.ports["bottom_met_W"])
stdp_comp << c_route(pdk, xm12_ref.ports["multiplier_0_source_W"], vdep_via.ports["bottom_met_W"], extension=1.8)
stdp_comp << c_route(pdk, chain_refs[0].ports["multiplier_0_drain_W"], vdep_via.ports["bottom_met_W"], extension=1.5)
stdp_comp << L_route(pdk, vdep_via.ports["bottom_met_E"], cdep_ref.ports["row0_col0_top_met_S"])

# vw (Weight node): XM2 Drain -> XM3 Drain -> Cw Top Plate
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
cw_via = stdp_comp << viam2m3
cw_via.move(xm2_ref.ports["multiplier_0_drain_W"].center).movex(-2).movey(14)
stdp_comp << L_route(pdk, xm2_ref.ports["drain_W"], cw_via.ports["top_met_S"])
stdp_comp << c_route(pdk, cw_via.ports["bottom_met_W"], xm3_ref.ports["multiplier_0_drain_W"], extension=3)
stdp_comp << L_route(pdk, cw_via.ports["bottom_met_E"], cw_ref.ports["row4_col0_top_met_N"])
stdp_comp << c_route(pdk, cw_via.ports["bottom_met_W"], xm5_ref.ports["gate_W"], extension=1.8)

# --- C. LONG-CHANNEL BIAS CHAIN SERIES CONNECTIONS (XMCM_5 to XMCM_9) ---
# net6: XMCM_5 Source -> XMCM_6 Drain
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
drain_1_via = stdp_comp << viam2m3
drain_1_via.move(chain_refs[1].ports["multiplier_0_drain_N"].center).movey(1.8)
stdp_comp << c_route(pdk, chain_refs[0].ports["multiplier_0_source_E"], drain_1_via.ports["bottom_met_E"])
stdp_comp << straight_route(pdk, drain_1_via.ports["top_met_S"], chain_refs[1].ports["multiplier_0_drain_N"])

# net7: XMCM_6 Source -> XMCM_7 Drain
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
c1_c2_via = stdp_comp << viam2m3
c1_c2_via.move(chain_refs[1].ports["multiplier_0_source_E"]).movex(2)
stdp_comp << straight_route(pdk, chain_refs[1].ports["multiplier_0_source_E"], c1_c2_via.ports["bottom_met_W"])
stdp_comp << L_route(pdk, c1_c2_via.ports["top_met_N"], chain_refs[2].ports["multiplier_0_drain_W"])

# # net8: XMCM_7 Source -> XMCM_9 Drain
c2_c3_via = stdp_comp << viam2m3
c2_c3_via.move(chain_refs[2].ports["multiplier_0_source_E"]).movex(2)
stdp_comp << straight_route(pdk, chain_refs[2].ports["multiplier_0_source_E"], c2_c3_via.ports["bottom_met_W"])
stdp_comp << L_route(pdk, c2_c3_via.ports["top_met_N"], chain_refs[3].ports["multiplier_0_drain_W"])

# # net9: XMCM_9 Source -> XMCM_8 Drain
c3_c4_via = stdp_comp << viam2m3
c3_c4_via.move(chain_refs[3].ports["multiplier_0_source_E"]).movex(2)
stdp_comp << straight_route(pdk, chain_refs[3].ports["multiplier_0_source_E"], c3_c4_via.ports["bottom_met_W"])
stdp_comp << L_route(pdk, c3_c4_via.ports["top_met_N"], chain_refs[4].ports["multiplier_0_drain_W"])

# Connect all Gates of XMCM_5..9 bias chain to vb_itd line
stdp_comp << straight_route(pdk, chain_refs[1].ports["multiplier_0_gate_E"], chain_refs[4].ports["multiplier_0_gate_W"])
# Out:
# ComponentReference (parent Component "straight_route_591f4a27", ports ['route_W', 'route_N', 'route_E', 'route_S'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
# stdp_comp.show()
display_component(stdp_comp, scale = 1,path=".")

# %%
stdp_comp.pprint_ports()
# Out:
# ┏━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name    ┃ width ┃ center          ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ avdd    │ 1.0   │ [37.49, 43.4]   │ 180         │ [42, 0] │ electrical │
# │ avss    │ 1.0   │ [37.49, 0.8]    │ 180         │ [42, 0] │ electrical │
# │ nvpost  │ 1.0   │ [8.35, 24.31]   │ 180         │ [42, 0] │ electrical │
# │ nvpre   │ 1.0   │ [19.93, 24.31]  │ 180         │ [42, 0] │ electrical │
# │ vpost   │ 1.0   │ [19.93, 12.255] │ 180         │ [42, 0] │ electrical │
# │ vpre    │ 1.0   │ [2.56, 12.255]  │ 180         │ [42, 0] │ electrical │
# │ vb_idep │ 1.0   │ [37.65, 19.46]  │ 180         │ [42, 0] │ electrical │
# │ vb_itd  │ 1.0   │ [33.05, 12.255] │ 180         │ [42, 0] │ electrical │
# │ vb_itp  │ 1.0   │ [29.69, 24.31]  │ 180         │ [42, 0] │ electrical │
# │ vb_pot  │ 1.0   │ [27.89, 12.2]   │ 180         │ [42, 0] │ electrical │
# │ vw      │ 1.0   │ [66.58, 6.8]    │ 180         │ [42, 0] │ electrical │
# │ Iout    │ 1.0   │ [1.4, 34.1]     │ 180         │ [42, 0] │ electrical │
# └─────────┴───────┴─────────────────┴─────────────┴─────────┴────────────┘

# %%
stdp_comp.show()
display_component(stdp_comp, scale = 1,path=".")
# Out:
# 2026-08-21 21:34:01.932 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?

# %%
# -------------------------------------------------------------------
# Adding tap ring. Discarded
# -------------------------------------------------------------------
# shift_amount = -prec_center(stdp_comp.flatten())[0];
# shift_vertical = -prec_center(stdp_comp.flatten())[1];
# tap_ring = tapring(pdk, enclosed_rectangle=evaluate_bbox(stdp_comp.flatten(), padding=pdk.get_grule("nwell")['min_separation']+1));
# tring_ref = stdp_comp << tap_ring;
# tring_ref.movex(destination=shift_amount).movey(destination=shift_vertical);
# component = component_snap_to_grid(rename_ports_by_orientation(stdp_comp))
# display_component(stdp_comp, scale = 1,path=".")
# stdp_comp.show()

# %%
evaluate_bbox(stdp_comp)
# Out:
# (79.08, 43.6)

# %%
stdp_est_area = evaluate_bbox(stdp_comp)[0] * evaluate_bbox(stdp_comp)[1]
stdp_est_area
# Out:
# 3447.888

# %%
# netlist = Netlist(circuit_name="stdp", nodes=['avss', 'avdd', 'nvpost', 'nvpre', 'vpost', 'vpre', 'vb_idep', 'vb_itd', 'vb_itp', 'vb_pot', 'vw', 'iout'])

# # M1 - M4: Main Cascode Output Stage
# netlist.connect_netlist(xm1.info['netlist'], [('D', 'n1'),   ('G', 'vpot'),   ('S', 'avdd'), ('B', 'avdd')])
# netlist.connect_netlist(xm2.info['netlist'], [('D', 'vw'),   ('G', 'nvpost'), ('S', 'n1'),   ('B', 'avdd')])
# netlist.connect_netlist(xm3.info['netlist'], [('D', 'vw'),   ('G', 'vpre'),   ('S', 'n2'),   ('B', 'avss')])
# netlist.connect_netlist(xm4.info['netlist'], [('D', 'n2'),   ('G', 'vdep'),   ('S', 'avss'), ('B', 'avss')])

# # M5: Output/Load Branch
# netlist.connect_netlist(xm5.info['netlist'], [('D', 'iout'), ('G', 'vw'),     ('S', 'avdd'), ('B', 'avdd')])

# # M7 - M9: Auxiliary Control Branches
# netlist.connect_netlist(xm7.info['netlist'], [('D', 'n4'),   ('G', 'n3'),     ('S', 'avdd'), ('B', 'avdd')])
# netlist.connect_netlist(xm8.info['netlist'], [('D', 'n3'),   ('G', 'nvpre'),  ('S', 'vpot'), ('B', 'avdd')])
# netlist.connect_netlist(xm9.info['netlist'], [('D', 'n5'),   ('G', 'n5'),     ('S', 'avss'), ('B', 'avss')])

# # M12, M16, M17: Bias & Feedback Control
# netlist.connect_netlist(xm12.info['netlist'], [('D', 'n5'),   ('G', 'vpost'),  ('S', 'vdep'), ('B', 'avss')])
# netlist.connect_netlist(xm16.info['netlist'], [('D', 'n5'),   ('G', 'vb_idep'), ('S', 'avdd'), ('B', 'avdd')])
# netlist.connect_netlist(xm17.info['netlist'], [('D', 'vpot'), ('G', 'vb_itp'),  ('S', 'avdd'), ('B', 'avdd')])

# # MCM_1: Current Mirror / Bias Branch
# netlist.connect_netlist(xmcm_1.info['netlist'], [('D', 'n4'),   ('G', 'vb_pot'), ('S', 'avss'), ('B', 'avss')])

# # MCM_5 - MCM_9: Stacked Current Mirror Network (vb_itd)
# netlist.connect_netlist(xmcm_chain[0].info['netlist'], [('D', 'vdep'), ('G', 'vb_itd'), ('S', 'n6'),   ('B', 'avss')])
# netlist.connect_netlist(xmcm_chain[1].info['netlist'], [('D', 'n6'),   ('G', 'vb_itd'), ('S', 'n7'),   ('B', 'avss')])
# netlist.connect_netlist(xmcm_chain[2].info['netlist'], [('D', 'n7'),   ('G', 'vb_itd'), ('S', 'n8'),   ('B', 'avss')])
# netlist.connect_netlist(xmcm_chain[3].info['netlist'], [('D', 'n8'),   ('G', 'vb_itd'), ('S', 'n9'),   ('B', 'avss')])
# netlist.connect_netlist(xmcm_chain[4].info['netlist'], [('D', 'n9'),   ('G', 'vb_itd'), ('S', 'avss'), ('B', 'avss')])

# #connecting capacitors
# netlist.connect_netlist(cpot.info["netlist"], [("V1","avdd"),("V2", "vpot")])
# netlist.connect_netlist(cdep.info["netlist"], [("V1","vdep"),("V2", "avss")])
# netlist.connect_netlist(cw.info["netlist"], [("V1","vw"),("V2", "avss")])


# stdp_comp.info["netlist"] = netlist

# %%
stdp_comp.name="stdp"
drc_result = gf180.drc_magic(stdp_comp, stdp_comp.name)
# Out:
# 2026-08-21 21:34:02.523 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpb7yffzuq/stdp.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmpb7yffzuq/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "stdp".
# Reading "c_route_3115e93c".
# Reading "c_route_2a2c3905".
# Reading "via_stack_22f48a44$10".
# Reading "L_route_e52df609".
# Reading "via_stack_22f48a44$8".
# Reading "via_stack_22f48a44$25".
# Reading "L_route_5f70f4fd".
# Reading "c_route_48defd91".
# Reading "xm5".
# Reading "compass_e1e0dc30".
# Reading "straight_route_2ec1e763".
# Reading "xm12".
# Reading "via_stack_22f48a44$22".
# Reading "rectangle_e1e0dc30$1".
# Reading "c_route_1c96c6a1".
# Reading "straight_route_e23f0c1c".
# Reading "L_route_511eaaf1".
# Reading "straight_route_1be9fc01".
# Reading "via_stack_22f48a44$14".
# Reading "via_stack_22f48a44$6".
# Reading "xmcm_chain_3".
# Reading "xm9".
# Reading "xmcm_1".
# Reading "straight_route_d3e30dac".
# Reading "straight_route_ed82dd1f".
# Reading "xm16".
# Reading "rectangle_e1e0dc30".
# Reading "via_stack_22f48a44$11".
# Reading "straight_route_7367aac9".
# Reading "L_route_ff71bb75".
# Reading "c_route_a185e435".
# Reading "straight_route_591f4a27".
# Reading "L_route_365f61f9".
# Reading "xm4".
# Reading "L_route_9657134e".
# Reading "straight_route_f3c2e732".
# Reading "c_route_12c3dfa3".
# Reading "L_route_70197ec4".
# Reading "L_route_a1f8726c".
# Reading "L_route_4e64478a".
# Reading "L_route_08f1951a".
# Reading "straight_route_631d6b20".
# Reading "xm3".
# Reading "c_route_29f44436".
# Reading "L_route_6f836912".
# Reading "straight_route_fa26b353".
# Reading "c_route_22d100d9".
# Reading "L_route_9ae06287".
# Reading "via_stack_22f48a44$5".
# Reading "cpot".
# Reading "xmcm_chain_0".
# Reading "L_route_57e2bf48".
# Reading "xm8".
# Reading "L_route_dfaf8135".
# Reading "xm17".
# Reading "via_stack_22f48a44$12".
# Reading "L_route_0d16257b".
# Reading "straight_route_6a4dcd4f".
# Reading "straight_route_87af12d4".
# Reading "xm7".
# Reading "straight_route_f2061b8b".
# Reading "L_route_a798498f".
# Reading "cdep".
# Reading "straight_route_0dfaefd2".
# Reading "c_route_7721f53f".
# Reading "c_route_f47fc27f".
# Reading "L_route_42664837".
# Reading "compass_e1e0dc30$1".
# Reading "L_route_8bbfbe64".
# Reading "L_route_bf7286ae".
# Reading "c_route_72df0b41".
# Reading "straight_route_51acfb17".
# Reading "via_stack_22f48a44$3".
# Reading "c_route_ea2b3656".
# Reading "via_stack_22f48a44$9".
# Reading "L_route_27d1e538".
# Reading "L_route_3f686335".
# Reading "xmcm_chain_4".
# Reading "xm2".
# Reading "straight_route_30e81840".
# Reading "L_route_008dc9ca".
# Reading "via_stack_22f48a44$4".
# Reading "xmcm_chain_1".
# Reading "xm1".
# Reading "L_route_2a635f8c".
# Reading "L_route_5bcfbb30".
# Reading "via_stack_22f48a44$13".
# Reading "L_route_5a7504b1".
# Reading "L_route_5f53519c".
# Reading "via_stack_22f48a44$7".
# Reading "L_route_7b3c1014".
# Reading "L_route_b05c3b53".
# Reading "via_stack_22f48a44$26".
# Reading "xmcm_chain_2".
# Reading "L_route_1ac69898".
# Reading "c_route_9a27df84".
# Reading "L_route_22874ebc".
# Reading "cw".
# [INFO]: Loading stdp
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmpb7yffzuq/stdp.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
#At first, we need to properly set PDKPATH and PDK_ROOT 

print("Making sure your environment varriables are still correctly set")
print(" I am using PDK in: ",os.environ['PDK_ROOT'],"\n PDK name: ",os.environ['PDK'],"\n The PDK files are at: ",os.environ['PDKPATH'])
# Out:
# Making sure your environment varriables are still correctly set
#  I am using PDK in:  /foss/pdks
#  PDK name:  gf180mcuD
#  The PDK files are at:  /foss/pdks/gf180mcuD

# %%
import os
from pathlib import Path
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name=stdp_comp.name
path_to_dir = "/foss/designs/libs/snn_analog/stdp/"

pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"

stdp_comp.write_gds(str(gds_path))
    
magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
exit
"""

with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# 2026-08-21 21:34:03.010 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/stdp/stdp.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "stdp".
# Reading "c_route_3115e93c".
# Reading "c_route_2a2c3905".
# Reading "via_stack_22f48a44$10".
# Reading "L_route_e52df609".
# Reading "via_stack_22f48a44$8".
# Reading "via_stack_22f48a44$25".
# Reading "L_route_5f70f4fd".
# Reading "c_route_48defd91".
# Reading "xm5".
# Reading "compass_e1e0dc30".
# Reading "straight_route_2ec1e763".
# Reading "xm12".
# Reading "via_stack_22f48a44$22".
# Reading "rectangle_e1e0dc30$1".
# Reading "c_route_1c96c6a1".
# Reading "straight_route_e23f0c1c".
# Reading "L_route_511eaaf1".
# Reading "straight_route_1be9fc01".
# Reading "via_stack_22f48a44$14".
# Reading "via_stack_22f48a44$6".
# Reading "xmcm_chain_3".
# Reading "xm9".
# Reading "xmcm_1".
# Reading "straight_route_d3e30dac".
# Reading "straight_route_ed82dd1f".
# Reading "xm16".
# Reading "rectangle_e1e0dc30".
# Reading "via_stack_22f48a44$11".
# Reading "straight_route_7367aac9".
# Reading "L_route_ff71bb75".
# Reading "c_route_a185e435".
# Reading "straight_route_591f4a27".
# Reading "L_route_365f61f9".
# Reading "xm4".
# Reading "L_route_9657134e".
# Reading "straight_route_f3c2e732".
# Reading "c_route_12c3dfa3".
# Reading "L_route_70197ec4".
# Reading "L_route_a1f8726c".
# Reading "L_route_4e64478a".
# Reading "L_route_08f1951a".
# Reading "straight_route_631d6b20".
# Reading "xm3".
# Reading "c_route_29f44436".
# Reading "L_route_6f836912".
# Reading "straight_route_fa26b353".
# Reading "c_route_22d100d9".
# Reading "L_route_9ae06287".
# Reading "via_stack_22f48a44$5".
# Reading "cpot".
# Reading "xmcm_chain_0".
# Reading "L_route_57e2bf48".
# Reading "xm8".
# Reading "L_route_dfaf8135".
# Reading "xm17".
# Reading "via_stack_22f48a44$12".
# Reading "L_route_0d16257b".
# Reading "straight_route_6a4dcd4f".
# Reading "straight_route_87af12d4".
# Reading "xm7".
# Reading "straight_route_f2061b8b".
# Reading "L_route_a798498f".
# Reading "cdep".
# Reading "straight_route_0dfaefd2".
# Reading "c_route_7721f53f".
# Reading "c_route_f47fc27f".
# Reading "L_route_42664837".
# Reading "compass_e1e0dc30$1".
# Reading "L_route_8bbfbe64".
# Reading "L_route_bf7286ae".
# Reading "c_route_72df0b41".
# Reading "straight_route_51acfb17".
# Reading "via_stack_22f48a44$3".
# Reading "c_route_ea2b3656".
# Reading "via_stack_22f48a44$9".
# Reading "L_route_27d1e538".
# Reading "L_route_3f686335".
# Reading "xmcm_chain_4".
# Reading "xm2".
# Reading "straight_route_30e81840".
# Reading "L_route_008dc9ca".
# Reading "via_stack_22f48a44$4".
# Reading "xmcm_chain_1".
# Reading "xm1".
# Reading "L_route_2a635f8c".
# Reading "L_route_5bcfbb30".
# Reading "via_stack_22f48a44$13".
# Reading "L_route_5a7504b1".
# Reading "L_route_5f53519c".
# Reading "via_stack_22f48a44$7".
# Reading "L_route_7b3c1014".
# Reading "L_route_b05c3b53".
# Reading "via_stack_22f48a44$26".
# Reading "xmcm_chain_2".
# Reading "L_route_1ac69898".
# Reading "c_route_9a27df84".
# Reading "L_route_22874ebc".
# Reading "cw".
# Extracting via_stack_22f48a44$25 into via_stack_22f48a44$25.ext:
# Extracting xm4 into xm4.ext:
# Extracting straight_route_631d6b20 into straight_route_631d6b20.ext:
# Extracting xm3 into xm3.ext:
# Extracting straight_route_30e81840 into straight_route_30e81840.ext:
# Extracting xm12 into xm12.ext:
# Extracting xm9 into xm9.ext:
# Extracting L_route_365f61f9 into L_route_365f61f9.ext:
# Extracting straight_route_6a4dcd4f into straight_route_6a4dcd4f.ext:
# Extracting via_stack_22f48a44$26 into via_stack_22f48a44$26.ext:
# Extracting xmcm_chain_1 into xmcm_chain_1.ext:
# Extracting xmcm_chain_2 into xmcm_chain_2.ext:
# Extracting via_stack_22f48a44$3 into via_stack_22f48a44$3.ext:
# Extracting L_route_42664837 into L_route_42664837.ext:
# Extracting L_route_0d16257b into L_route_0d16257b.ext:
# Extracting xmcm_chain_0 into xmcm_chain_0.ext:
# Extracting straight_route_d3e30dac into straight_route_d3e30dac.ext:
# Extracting xmcm_1 into xmcm_1.ext:
# Extracting xmcm_chain_3 into xmcm_chain_3.ext:
# Extracting c_route_9a27df84 into c_route_9a27df84.ext:
# Extracting L_route_5a7504b1 into L_route_5a7504b1.ext:
# Extracting straight_route_591f4a27 into straight_route_591f4a27.ext:
# Extracting straight_route_ed82dd1f into straight_route_ed82dd1f.ext:
# Extracting L_route_5f70f4fd into L_route_5f70f4fd.ext:
# Extracting via_stack_22f48a44$14 into via_stack_22f48a44$14.ext:
# Extracting straight_route_f3c2e732 into straight_route_f3c2e732.ext:
# Extracting L_route_dfaf8135 into L_route_dfaf8135.ext:
# Extracting L_route_2a635f8c into L_route_2a635f8c.ext:
# Extracting L_route_5bcfbb30 into L_route_5bcfbb30.ext:
# Extracting via_stack_22f48a44$7 into via_stack_22f48a44$7.ext:
# Extracting via_stack_22f48a44$6 into via_stack_22f48a44$6.ext:
# Extracting via_stack_22f48a44$11 into via_stack_22f48a44$11.ext:
# Extracting c_route_a185e435 into c_route_a185e435.ext:
# Extracting L_route_4e64478a into L_route_4e64478a.ext:
# Extracting c_route_29f44436 into c_route_29f44436.ext:
# Extracting via_stack_22f48a44$9 into via_stack_22f48a44$9.ext:
# Extracting c_route_48defd91 into c_route_48defd91.ext:
# Extracting c_route_22d100d9 into c_route_22d100d9.ext:
# Extracting c_route_f47fc27f into c_route_f47fc27f.ext:
# Extracting via_stack_22f48a44$8 into via_stack_22f48a44$8.ext:
# Extracting L_route_bf7286ae into L_route_bf7286ae.ext:
# Extracting c_route_7721f53f into c_route_7721f53f.ext:
# Extracting c_route_12c3dfa3 into c_route_12c3dfa3.ext:
# Extracting c_route_3115e93c into c_route_3115e93c.ext:
# Extracting xm16 into xm16.ext:
# Extracting L_route_6f836912 into L_route_6f836912.ext:
# Extracting L_route_e52df609 into L_route_e52df609.ext:
# Extracting straight_route_1be9fc01 into straight_route_1be9fc01.ext:
# Extracting L_route_a1f8726c into L_route_a1f8726c.ext:
# Extracting L_route_9ae06287 into L_route_9ae06287.ext:
# Extracting cpot into cpot.ext:
# Extracting cdep into cdep.ext:
# Extracting xmcm_chain_4 into xmcm_chain_4.ext:
# Extracting via_stack_22f48a44$12 into via_stack_22f48a44$12.ext:
# Extracting straight_route_0dfaefd2 into straight_route_0dfaefd2.ext:
# Extracting straight_route_51acfb17 into straight_route_51acfb17.ext:
# Extracting L_route_b05c3b53 into L_route_b05c3b53.ext:
# Extracting compass_e1e0dc30$1 into compass_e1e0dc30$1.ext:
# Extracting rectangle_e1e0dc30$1 into rectangle_e1e0dc30$1.ext:
# Extracting L_route_ff71bb75 into L_route_ff71bb75.ext:
# Extracting straight_route_f2061b8b into straight_route_f2061b8b.ext:
# Extracting c_route_ea2b3656 into c_route_ea2b3656.ext:
# Extracting xm2 into xm2.ext:
# Extracting xm1 into xm1.ext:
# Extracting L_route_1ac69898 into L_route_1ac69898.ext:
# Extracting straight_route_2ec1e763 into straight_route_2ec1e763.ext:
# Extracting straight_route_fa26b353 into straight_route_fa26b353.ext:
# Extracting xm8 into xm8.ext:
# Extracting xm7 into xm7.ext:
# Extracting L_route_8bbfbe64 into L_route_8bbfbe64.ext:
# Extracting via_stack_22f48a44$4 into via_stack_22f48a44$4.ext:
# Extracting L_route_5f53519c into L_route_5f53519c.ext:
# Extracting xm5 into xm5.ext:
# Extracting via_stack_22f48a44$13 into via_stack_22f48a44$13.ext:
# Extracting L_route_27d1e538 into L_route_27d1e538.ext:
# Extracting via_stack_22f48a44$22 into via_stack_22f48a44$22.ext:
# Extracting L_route_008dc9ca into L_route_008dc9ca.ext:
# Extracting c_route_72df0b41 into c_route_72df0b41.ext:
# Extracting xm17 into xm17.ext:
# Extracting via_stack_22f48a44$5 into via_stack_22f48a44$5.ext:
# Extracting L_route_08f1951a into L_route_08f1951a.ext:
# Extracting straight_route_e23f0c1c into straight_route_e23f0c1c.ext:
# Extracting via_stack_22f48a44$10 into via_stack_22f48a44$10.ext:
# Extracting L_route_a798498f into L_route_a798498f.ext:
# Extracting L_route_57e2bf48 into L_route_57e2bf48.ext:
# Extracting L_route_511eaaf1 into L_route_511eaaf1.ext:
# Extracting L_route_9657134e into L_route_9657134e.ext:
# Extracting L_route_3f686335 into L_route_3f686335.ext:
# Extracting L_route_7b3c1014 into L_route_7b3c1014.ext:
# Extracting L_route_22874ebc into L_route_22874ebc.ext:
# Extracting straight_route_87af12d4 into straight_route_87af12d4.ext:
# Extracting straight_route_7367aac9 into straight_route_7367aac9.ext:
# Extracting L_route_70197ec4 into L_route_70197ec4.ext:
# Extracting compass_e1e0dc30 into compass_e1e0dc30.ext:
# Extracting rectangle_e1e0dc30 into rectangle_e1e0dc30.ext:
# Extracting c_route_1c96c6a1 into c_route_1c96c6a1.ext:
# Extracting c_route_2a2c3905 into c_route_2a2c3905.ext:
# Extracting cw into cw.ext:
# Extracting stdp into stdp.ext:
# exttosim finished.
# Adding  avdd; Tnew = 0.01ns, Told = 0.00ns
# Adding  avss; Tnew = 5.68ns, Told = 0.00ns
# Adding  nvpost; Tnew = 0.00ns, Told = 0.00ns
# Adding  nvpre; Tnew = 0.00ns, Told = 0.00ns
# Adding  vpost; Tnew = 0.00ns, Told = 0.00ns
# Adding  vpre; Tnew = 0.00ns, Told = 0.00ns
# Adding  vb_idep; Tnew = 0.00ns, Told = 0.00ns
# Adding  vb_itd; Tnew = 0.00ns, Told = 0.00ns
# Adding  vb_itp; Tnew = 0.00ns, Told = 0.00ns
# Adding  vb_pot; Tnew = 0.00ns, Told = 0.00ns
# Adding  vw; Tnew = 0.00ns, Told = 0.00ns
# Adding  Iout; Tnew = 0.00ns, Told = 0.00ns
# Total Nets: 78
# Nets extracted: 12 (0.153846)
# Nets output: 12 (0.153846)
# exttospice finished.

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: L_route_70197ec4.ext
# Deleted: L_route_a798498f.ext
# Deleted: L_route_e52df609.ext
# Deleted: L_route_22874ebc.ext
# Deleted: compass_e1e0dc30.ext
# Deleted: c_route_ea2b3656.ext
# Deleted: straight_route_1be9fc01.ext
# Deleted: via_stack_22f48a44$3.ext
# Deleted: L_route_008dc9ca.ext
# Deleted: straight_route_631d6b20.ext
# Deleted: L_route_7b3c1014.ext
# Deleted: L_route_bf7286ae.ext
# Deleted: c_route_29f44436.ext
# Deleted: compass_e1e0dc30$1.ext
# Deleted: L_route_5f53519c.ext
# Deleted: via_stack_22f48a44$6.ext
# Deleted: via_stack_22f48a44$7.ext
# Deleted: L_route_ff71bb75.ext
# Deleted: L_route_57e2bf48.ext
# Deleted: straight_route_0dfaefd2.ext
# Deleted: L_route_511eaaf1.ext
# Deleted: L_route_08f1951a.ext
# Deleted: via_stack_22f48a44$5.ext
# Deleted: straight_route_fa26b353.ext
# Deleted: via_stack_22f48a44$4.ext
# Deleted: via_stack_22f48a44$13.ext
# Deleted: stdp.ext
# Deleted: L_route_b05c3b53.ext
# Deleted: via_stack_22f48a44$12.ext
# Deleted: L_route_27d1e538.ext
# Deleted: xm12.ext
# Deleted: via_stack_22f48a44$10.ext
# Deleted: xm8.ext
# Deleted: L_route_8bbfbe64.ext
# Deleted: straight_route_e23f0c1c.ext
# Deleted: xm9.ext
# Deleted: cpot.ext
# Deleted: L_route_dfaf8135.ext
# Deleted: via_stack_22f48a44$11.ext
# Deleted: straight_route_f3c2e732.ext
# Deleted: xm17.ext
# Deleted: L_route_42664837.ext
# Deleted: via_stack_22f48a44$14.ext
# Deleted: xm16.ext
# Deleted: c_route_7721f53f.ext
# Deleted: c_route_72df0b41.ext
# Deleted: c_route_a185e435.ext
# Deleted: L_route_6f836912.ext
# Deleted: L_route_9657134e.ext
# Deleted: straight_route_f2061b8b.ext
# Deleted: L_route_2a635f8c.ext
# Deleted: via_stack_22f48a44$26.ext
# Deleted: c_route_12c3dfa3.ext
# Deleted: xm2.ext
# Deleted: xm3.ext
# Deleted: cdep.ext
# Deleted: via_stack_22f48a44$25.ext
# Deleted: straight_route_87af12d4.ext
# Deleted: L_route_365f61f9.ext
# Deleted: xm1.ext
# Deleted: L_route_0d16257b.ext
# Deleted: L_route_5f70f4fd.ext
# Deleted: c_route_f47fc27f.ext
# Deleted: xm4.ext
# Deleted: c_route_2a2c3905.ext
# Deleted: rectangle_e1e0dc30$1.ext
# Deleted: xm5.ext
# Deleted: straight_route_7367aac9.ext
# Deleted: L_route_5bcfbb30.ext
# Deleted: stdp.res.ext
# Deleted: straight_route_591f4a27.ext
# Deleted: L_route_9ae06287.ext
# Deleted: xm7.ext
# Deleted: straight_route_2ec1e763.ext
# Deleted: straight_route_6a4dcd4f.ext
# Deleted: via_stack_22f48a44$22.ext
# Deleted: xmcm_chain_3.ext
# Deleted: cw.ext
# Deleted: via_stack_22f48a44$9.ext
# Deleted: c_route_9a27df84.ext
# Deleted: c_route_1c96c6a1.ext
# Deleted: straight_route_51acfb17.ext
# Deleted: via_stack_22f48a44$8.ext
# Deleted: xmcm_chain_2.ext
# Deleted: L_route_3f686335.ext
# Deleted: c_route_48defd91.ext
# Deleted: c_route_22d100d9.ext
# Deleted: c_route_3115e93c.ext
# Deleted: xmcm_chain_0.ext
# Deleted: xmcm_chain_1.ext
# Deleted: xmcm_1.ext
# Deleted: rectangle_e1e0dc30.ext
# Deleted: xmcm_chain_4.ext
# Deleted: L_route_5a7504b1.ext
# Deleted: L_route_1ac69898.ext
# Deleted: straight_route_d3e30dac.ext
# Deleted: L_route_a1f8726c.ext
# Deleted: straight_route_ed82dd1f.ext
# Deleted: L_route_4e64478a.ext
# Deleted: straight_route_30e81840.ext
# Error deleting stdp.res.ext: [Errno 2] No such file or directory: 'stdp.res.ext'
# Deleted: stdp.nodes
# Deleted: stdp.sim

# %%
import os
from pathlib import Path

gf180.lvs_netgen(
    layout=stdp_comp,
    design_name = stdp_comp.name,
    pdk_root = Path(os.environ['PDKPATH']),
    lvs_setup_tcl_file = Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    lvs_schematic_ref_file = Path(str(path_to_dir + "stdp.spice")),
    netlist = Path(str(path_to_dir + "stdp_sch.spice")),
    output_file_path =  Path(str(path_to_dir))
)
# Out:
# 2026-08-21 21:34:03.918 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpkxmk3gmg/stdp.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:17:18 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "stdp".
# Reading "c_route_3115e93c".
# Reading "c_route_2a2c3905".
# Reading "via_stack_22f48a44$10".
# Reading "L_route_e52df609".
# Reading "via_stack_22f48a44$8".
# Reading "via_stack_22f48a44$25".
# Reading "L_route_5f70f4fd".
# Reading "c_route_48defd91".
# Reading "xm5".
# Reading "compass_e1e0dc30".
# Reading "straight_route_2ec1e763".
# Reading "xm12".
# Reading "via_stack_22f48a44$22".
# Reading "rectangle_e1e0dc30$1".
# Reading "c_route_1c96c6a1".
# Reading "straight_route_e23f0c1c".
# Reading "L_route_511eaaf1".
# Reading "straight_route_1be9fc01".
# Reading "via_stack_22f48a44$14".
# Reading "via_stack_22f48a44$6".
# Reading "xmcm_chain_3".
# Reading "xm9".
# Reading "xmcm_1".
# Reading "straight_route_d3e30dac".
# Reading "straight_route_ed82dd1f".
# Reading "xm16".
# Reading "rectangle_e1e0dc30".
# Reading "via_stack_22f48a44$11".
# Reading "straight_route_7367aac9".
# Reading "L_route_ff71bb75".
# Reading "c_route_a185e435".
# Reading "straight_route_591f4a27".
# Reading "L_route_365f61f9".
# Reading "xm4".
# Reading "L_route_9657134e".
# Reading "straight_route_f3c2e732".
# Reading "c_route_12c3dfa3".
# Reading "L_route_70197ec4".
# Reading "L_route_a1f8726c".
# Reading "L_route_4e64478a".
# Reading "L_route_08f1951a".
# Reading "straight_route_631d6b20".
# Reading "xm3".
# Reading "c_route_29f44436".
# Reading "L_route_6f836912".
# Reading "straight_route_fa26b353".
# Reading "c_route_22d100d9".
# Reading "L_route_9ae06287".
# Reading "via_stack_22f48a44$5".
# Reading "cpot".
# Reading "xmcm_chain_0".
# Reading "L_route_57e2bf48".
# Reading "xm8".
# Reading "L_route_dfaf8135".
# Reading "xm17".
# Reading "via_stack_22f48a44$12".
# Reading "L_route_0d16257b".
# Reading "straight_route_6a4dcd4f".
# Reading "straight_route_87af12d4".
# Reading "xm7".
# Reading "straight_route_f2061b8b".
# Reading "L_route_a798498f".
# Reading "cdep".
# Reading "straight_route_0dfaefd2".
# Reading "c_route_7721f53f".
# Reading "c_route_f47fc27f".
# Reading "L_route_42664837".
# Reading "compass_e1e0dc30$1".
# Reading "L_route_8bbfbe64".
# Reading "L_route_bf7286ae".
# Reading "c_route_72df0b41".
# Reading "straight_route_51acfb17".
# Reading "via_stack_22f48a44$3".
# Reading "c_route_ea2b3656".
# Reading "via_stack_22f48a44$9".
# Reading "L_route_27d1e538".
# Reading "L_route_3f686335".
# Reading "xmcm_chain_4".
# Reading "xm2".
# Reading "straight_route_30e81840".
# Reading "L_route_008dc9ca".
# Reading "via_stack_22f48a44$4".
# Reading "xmcm_chain_1".
# Reading "xm1".
# Reading "L_route_2a635f8c".
# Reading "L_route_5bcfbb30".
# Reading "via_stack_22f48a44$13".
# Reading "L_route_5a7504b1".
# Reading "L_route_5f53519c".
# Reading "via_stack_22f48a44$7".
# Reading "L_route_7b3c1014".
# Reading "L_route_b05c3b53".
# Reading "via_stack_22f48a44$26".
# Reading "xmcm_chain_2".
# Reading "L_route_1ac69898".
# Reading "c_route_9a27df84".
# Reading "L_route_22874ebc".
# Reading "cw".
# Extracting via_stack_22f48a44$25 into via_stack_22f48a44$25.ext:
# Extracting xm4 into xm4.ext:
# Extracting straight_route_631d6b20 into straight_route_631d6b20.ext:
# Extracting xm3 into xm3.ext:
# Extracting straight_route_30e81840 into straight_route_30e81840.ext:
# Extracting xm12 into xm12.ext:
# Extracting xm9 into xm9.ext:
# Extracting L_route_365f61f9 into L_route_365f61f9.ext:
# Extracting straight_route_6a4dcd4f into straight_route_6a4dcd4f.ext:
# Extracting via_stack_22f48a44$26 into via_stack_22f48a44$26.ext:
# Extracting xmcm_chain_1 into xmcm_chain_1.ext:
# Extracting xmcm_chain_2 into xmcm_chain_2.ext:
# Extracting via_stack_22f48a44$3 into via_stack_22f48a44$3.ext:
# Extracting L_route_42664837 into L_route_42664837.ext:
# Extracting L_route_0d16257b into L_route_0d16257b.ext:
# Extracting xmcm_chain_0 into xmcm_chain_0.ext:
# Extracting straight_route_d3e30dac into straight_route_d3e30dac.ext:
# Extracting xmcm_1 into xmcm_1.ext:
# Extracting xmcm_chain_3 into xmcm_chain_3.ext:
# Extracting c_route_9a27df84 into c_route_9a27df84.ext:
# Extracting L_route_5a7504b1 into L_route_5a7504b1.ext:
# Extracting straight_route_591f4a27 into straight_route_591f4a27.ext:
# Extracting straight_route_ed82dd1f into straight_route_ed82dd1f.ext:
# Extracting L_route_5f70f4fd into L_route_5f70f4fd.ext:
# Extracting via_stack_22f48a44$14 into via_stack_22f48a44$14.ext:
# Extracting straight_route_f3c2e732 into straight_route_f3c2e732.ext:
# Extracting L_route_dfaf8135 into L_route_dfaf8135.ext:
# Extracting L_route_2a635f8c into L_route_2a635f8c.ext:
# Extracting L_route_5bcfbb30 into L_route_5bcfbb30.ext:
# Extracting via_stack_22f48a44$7 into via_stack_22f48a44$7.ext:
# Extracting via_stack_22f48a44$6 into via_stack_22f48a44$6.ext:
# Extracting via_stack_22f48a44$11 into via_stack_22f48a44$11.ext:
# Extracting c_route_a185e435 into c_route_a185e435.ext:
# Extracting L_route_4e64478a into L_route_4e64478a.ext:
# Extracting c_route_29f44436 into c_route_29f44436.ext:
# Extracting via_stack_22f48a44$9 into via_stack_22f48a44$9.ext:
# Extracting c_route_48defd91 into c_route_48defd91.ext:
# Extracting c_route_22d100d9 into c_route_22d100d9.ext:
# Extracting c_route_f47fc27f into c_route_f47fc27f.ext:
# Extracting via_stack_22f48a44$8 into via_stack_22f48a44$8.ext:
# Extracting L_route_bf7286ae into L_route_bf7286ae.ext:
# Extracting c_route_7721f53f into c_route_7721f53f.ext:
# Extracting c_route_12c3dfa3 into c_route_12c3dfa3.ext:
# Extracting c_route_3115e93c into c_route_3115e93c.ext:
# Extracting xm16 into xm16.ext:
# Extracting L_route_6f836912 into L_route_6f836912.ext:
# Extracting L_route_e52df609 into L_route_e52df609.ext:
# Extracting straight_route_1be9fc01 into straight_route_1be9fc01.ext:
# Extracting L_route_a1f8726c into L_route_a1f8726c.ext:
# Extracting L_route_9ae06287 into L_route_9ae06287.ext:
# Extracting cpot into cpot.ext:
# Extracting cdep into cdep.ext:
# Extracting xmcm_chain_4 into xmcm_chain_4.ext:
# Extracting via_stack_22f48a44$12 into via_stack_22f48a44$12.ext:
# Extracting straight_route_0dfaefd2 into straight_route_0dfaefd2.ext:
# Extracting straight_route_51acfb17 into straight_route_51acfb17.ext:
# Extracting L_route_b05c3b53 into L_route_b05c3b53.ext:
# Extracting compass_e1e0dc30$1 into compass_e1e0dc30$1.ext:
# Extracting rectangle_e1e0dc30$1 into rectangle_e1e0dc30$1.ext:
# Extracting L_route_ff71bb75 into L_route_ff71bb75.ext:
# Extracting straight_route_f2061b8b into straight_route_f2061b8b.ext:
# Extracting c_route_ea2b3656 into c_route_ea2b3656.ext:
# Extracting xm2 into xm2.ext:
# Extracting xm1 into xm1.ext:
# Extracting L_route_1ac69898 into L_route_1ac69898.ext:
# Extracting straight_route_2ec1e763 into straight_route_2ec1e763.ext:
# Extracting straight_route_fa26b353 into straight_route_fa26b353.ext:
# Extracting xm8 into xm8.ext:
# Extracting xm7 into xm7.ext:
# Extracting L_route_8bbfbe64 into L_route_8bbfbe64.ext:
# Extracting via_stack_22f48a44$4 into via_stack_22f48a44$4.ext:
# Extracting L_route_5f53519c into L_route_5f53519c.ext:
# Extracting xm5 into xm5.ext:
# Extracting via_stack_22f48a44$13 into via_stack_22f48a44$13.ext:
# Extracting L_route_27d1e538 into L_route_27d1e538.ext:
# Extracting via_stack_22f48a44$22 into via_stack_22f48a44$22.ext:
# Extracting L_route_008dc9ca into L_route_008dc9ca.ext:
# Extracting c_route_72df0b41 into c_route_72df0b41.ext:
# Extracting xm17 into xm17.ext:
# Extracting via_stack_22f48a44$5 into via_stack_22f48a44$5.ext:
# Extracting L_route_08f1951a into L_route_08f1951a.ext:
# Extracting straight_route_e23f0c1c into straight_route_e23f0c1c.ext:
# Extracting via_stack_22f48a44$10 into via_stack_22f48a44$10.ext:
# Extracting L_route_a798498f into L_route_a798498f.ext:
# Extracting L_route_57e2bf48 into L_route_57e2bf48.ext:
# Extracting L_route_511eaaf1 into L_route_511eaaf1.ext:
# Extracting L_route_9657134e into L_route_9657134e.ext:
# Extracting L_route_3f686335 into L_route_3f686335.ext:
# Extracting L_route_7b3c1014 into L_route_7b3c1014.ext:
# Extracting L_route_22874ebc into L_route_22874ebc.ext:
# Extracting straight_route_87af12d4 into straight_route_87af12d4.ext:
# Extracting straight_route_7367aac9 into straight_route_7367aac9.ext:
# Extracting L_route_70197ec4 into L_route_70197ec4.ext:
# Extracting compass_e1e0dc30 into compass_e1e0dc30.ext:
# Extracting rectangle_e1e0dc30 into rectangle_e1e0dc30.ext:
# Extracting c_route_1c96c6a1 into c_route_1c96c6a1.ext:
# Extracting c_route_2a2c3905 into c_route_2a2c3905.ext:
# Extracting cw into cw.ext:
# Extracting stdp into stdp.ext:
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmpkxmk3gmg/stdp_lvsmag.spice stdp" "/tmp/tmpkxmk3gmg/stdp.spice stdp" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpkxmk3gmg/stdp_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:08:04 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice for /tmp/tmpkxmk3gmg/stdp_lvsmag.spice stdp
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpkxmk3gmg/stdp.spice for /tmp/tmpkxmk3gmg/stdp.spice stdp
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Duplicate cell stdp in file
# Renaming original cell to stdp[[0]]
# Call to undefined subcircuit unitcap
# Creating placeholder cell definition.
# Call to undefined subcircuit cap_mim_2f0fF
# Creating placeholder cell definition.
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# No property par1 found for device cap_mim_2f0fF
# Comparison output logged to file /tmp/tmpkxmk3gmg/stdp_lvs.rpt
# Logging to file "/tmp/tmpkxmk3gmg/stdp_lvs.rpt" enabled
# Circuit pfet_03v3 contains no devices.
# Circuit nfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'xm5'
# Circuit xm5 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm5'
# Circuit xm5 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm5 xm5
#
# Flattening instances of xm5 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm5 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm3'
# Circuit xm3 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm3'
# Circuit xm3 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm3 xm3
#
# Flattening instances of xm3 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm3 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm1'
# Circuit xm1 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm1'
# Circuit xm1 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm1 xm1
#
# Flattening instances of xm1 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm1 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xmcm_chain_4'
# Circuit xmcm_chain_4 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xmcm_chain_4'
# Circuit xmcm_chain_4 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xmcm_chain_4 xmcm_chain_4
#
# Flattening instances of xmcm_chain_4 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xmcm_chain_4 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm8'
# Circuit xm8 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm8'
# Circuit xm8 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm8 xm8
#
# Flattening instances of xm8 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm8 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xmcm_chain_2'
# Circuit xmcm_chain_2 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xmcm_chain_2'
# Circuit xmcm_chain_2 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xmcm_chain_2 xmcm_chain_2
#
# Flattening instances of xmcm_chain_2 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xmcm_chain_2 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm16'
# Circuit xm16 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm16'
# Circuit xm16 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm16 xm16
#
# Flattening instances of xm16 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm16 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xmcm_chain_0'
# Circuit xmcm_chain_0 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xmcm_chain_0'
# Circuit xmcm_chain_0 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xmcm_chain_0 xmcm_chain_0
#
# Flattening instances of xmcm_chain_0 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xmcm_chain_0 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm4'
# Circuit xm4 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm4'
# Circuit xm4 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm4 xm4
#
# Flattening instances of xm4 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm4 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm12'
# Circuit xm12 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm12'
# Circuit xm12 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm12 xm12
#
# Flattening instances of xm12 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm12 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm2'
# Circuit xm2 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm2'
# Circuit xm2 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm2 xm2
#
# Flattening instances of xm2 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm2 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xmcm_1'
# Circuit xmcm_1 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xmcm_1'
# Circuit xmcm_1 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xmcm_1 xmcm_1
#
# Flattening instances of xmcm_1 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xmcm_1 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm9'
# Circuit xm9 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm9'
# Circuit xm9 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm9 xm9
#
# Flattening instances of xm9 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm9 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xmcm_chain_3'
# Circuit xmcm_chain_3 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xmcm_chain_3'
# Circuit xmcm_chain_3 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xmcm_chain_3 xmcm_chain_3
#
# Flattening instances of xmcm_chain_3 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xmcm_chain_3 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm17'
# Circuit xm17 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm17'
# Circuit xm17 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm17 xm17
#
# Flattening instances of xm17 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm17 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xm7'
# Circuit xm7 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm7'
# Circuit xm7 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm7 xm7
#
# Flattening instances of xm7 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xm7 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'xmcm_chain_1'
# Circuit xmcm_chain_1 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xmcm_chain_1'
# Circuit xmcm_chain_1 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xmcm_chain_1 xmcm_chain_1
#
# Flattening instances of xmcm_chain_1 in file /tmp/tmpkxmk3gmg/stdp_lvsmag.spice
# Flattening instances of xmcm_chain_1 in file /tmp/tmpkxmk3gmg/stdp.spice
#
# Contents of circuit 1:  Circuit: 'stdp'
# Circuit stdp contains 17 device instances.
#   Class: nfet_03v3             instances:  10
#   Class: pfet_03v3             instances:   7
# Circuit contains 22 nets.
# Contents of circuit 2:  Circuit: 'stdp'
# Circuit stdp contains 31 device instances.
#   Class: cap_mim_2f0fF         instances:  14
#   Class: nfet_03v3             instances:  10
#   Class: pfet_03v3             instances:   7
# Circuit contains 23 nets.
#
# Circuit was modified by parallel/series device merging.
# New circuit summary:
#
# Contents of circuit 1:  Circuit: 'stdp'
# Circuit stdp contains 17 device instances.
#   Class: nfet_03v3             instances:  10
#   Class: pfet_03v3             instances:   7
# Circuit contains 22 nets.
# Contents of circuit 2:  Circuit: 'stdp'
# Circuit stdp contains 20 device instances.
#   Class: cap_mim_2f0fF         instances:   3
#   Class: nfet_03v3             instances:  10
#   Class: pfet_03v3             instances:   7
# Circuit contains 23 nets.
#
# Circuit 1 contains 17 devices, Circuit 2 contains 20 devices. *** MISMATCH ***
# Circuit 1 contains 22 nets,    Circuit 2 contains 23 nets. *** MISMATCH ***
#
#
# Final result:
# Top level cell failed pin matching.
#
# Logging to file "/tmp/tmpkxmk3gmg/stdp_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Subcircuit summary:
# Circuit 1: xm5                             |Circuit 2: xm5
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm5                             |Circuit 2: xm5
#
# ---------------------------------------------------------------------------------------
# Net: a_1500_n131#                          |Net: a_1500_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n1620_n131#                         |Net: a_n1620_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n1500_n339#                         |Net: a_n1500_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/top = 2
#                                            |  c/bottom = 2
#                                            |
# Net: w_n1886_n560#                         |Net: w_n1886_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm5                             |Circuit 2: xm5
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm5 xm5
#
# Subcircuit summary:
# Circuit 1: xm3                             |Circuit 2: xm3
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm3                             |Circuit 2: xm3
#
# ---------------------------------------------------------------------------------------
# Net: a_63_n131#                            |Net: a_63_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n63_n339#                           |Net: a_n63_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 2
#                                            |  c/bottom = 1
#                                            |
# Net: a_n183_n131#                          |Net: a_n183_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n393_n504#                          |Net: a_n393_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm3                             |Circuit 2: xm3
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm3 xm3
#
# Subcircuit summary:
# Circuit 1: xm1                             |Circuit 2: xm1
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm1                             |Circuit 2: xm1
#
# ---------------------------------------------------------------------------------------
# Net: a_63_n131#                            |Net: a_63_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n183_n131#                          |Net: a_n183_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n63_n339#                           |Net: a_n63_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n449_n560#                          |Net: w_n449_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm1                             |Circuit 2: xm1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm1 xm1
#
# Subcircuit summary:
# Circuit 1: xmcm_chain_4                    |Circuit 2: xmcm_chain_4
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xmcm_chain_4                    |Circuit 2: xmcm_chain_4
#
# ---------------------------------------------------------------------------------------
# Net: a_1000_n131#                          |Net: a_1000_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# ...
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm7 xm7
#
# Subcircuit summary:
# Circuit 1: xmcm_chain_1                    |Circuit 2: xmcm_chain_1
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xmcm_chain_1                    |Circuit 2: xmcm_chain_1
#
# ---------------------------------------------------------------------------------------
# Net: a_1000_n131#                          |Net: a_1000_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n1000_n339#                         |Net: a_n1000_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 2
#                                            |  c/bottom = 1
#                                            |
# Net: a_n1120_n131#                         |Net: a_n1120_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n1330_n504#                         |Net: a_n1330_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xmcm_chain_1                    |Circuit 2: xmcm_chain_1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xmcm_chain_1 xmcm_chain_1
# Flattening unmatched subcell unitcap in circuit stdp (1)(14 instances)
#
# Class stdp (1):  Merged 11 parallel devices.
# Subcircuit summary:
# Circuit 1: stdp                            |Circuit 2: stdp
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (7)                              |pfet_03v3 (7)
# nfet_03v3 (10)                             |nfet_03v3 (10)
# (no matching element)                      |cap_mim_2f0fF (14->3)
# Number of devices: 17 **Mismatch**         |Number of devices: 20 **Mismatch**
# Number of nets: 22 **Mismatch**            |Number of nets: 23 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: stdp                            |Circuit 2: stdp
#
# ---------------------------------------------------------------------------------------
# Net: vw                                    |Net: vw
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#   nfet_03v3/(1|3) = 3                      |  nfet_03v3/(1|3) = 1
#   nfet_03v3/2 = 1                          |  cap_mim_2f0fF/1 = 1
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |
# Net: avdd                                  |Net: avdd
#   pfet_03v3/(1|3) = 5                      |  pfet_03v3/(1|3) = 5
#   pfet_03v3/4 = 7                          |  pfet_03v3/4 = 7
#                                            |  cap_mim_2f0fF/1 = 1
#                                            |
# Net: Iout                                  |Net: vdep
#   pfet_03v3/(1|3) = 3                      |  nfet_03v3/2 = 1
#   pfet_03v3/2 = 1                          |  nfet_03v3/(1|3) = 2
#                                            |  cap_mim_2f0fF/1 = 1
#                                            |
# Net: xmcm_chain_4_0/a_n1000_n339#          |Net: vpot
#   nfet_03v3/2 = 4                          |  pfet_03v3/2 = 1
#                                            |  pfet_03v3/(1|3) = 2
#                                            |  cap_mim_2f0fF/2 = 1
#                                            |
# Net: avss                                  |Net: avss
#   nfet_03v3/4 = 10                         |  nfet_03v3/4 = 10
#   nfet_03v3/(1|3) = 4                      |  nfet_03v3/(1|3) = 4
#                                            |  cap_mim_2f0fF/2 = 2
#                                            |
# (no matching net)                          |Net: vb_itd
#                                            |  nfet_03v3/2 = 5
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# Net: xmcm_chain_4_0/a_1000_n131#           |Net: n9
#   nfet_03v3/(1|3) = 2                      |  nfet_03v3/(1|3) = 2
#                                            |
# Net: xmcm_chain_1_0/a_1000_n131#           |Net: n6
#   nfet_03v3/(1|3) = 2                      |  nfet_03v3/(1|3) = 2
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# Net: vb_itd                                |Net: iout
#   nfet_03v3/2 = 1                          |  pfet_03v3/(1|3) = 1
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: stdp                            |Circuit 2: stdp
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: unitcap:1[0]/cap_mim_2f0fF:Cdep
#                                            |  1 = 4
#                                            |  2 = 16
#                                            |
# (no matching instance)                     |Instance: unitcap:2[0]/cap_mim_2f0fF:Cdep
#                                            |  1 = 4
#                                            |  2 = 16
#                                            |
# (no matching instance)                     |Instance: unitcap:3[0]/cap_mim_2f0fF:Cdep
#                                            |  1 = 13
#                                            |  2 = 4
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# Instance: xmcm_chain_4_0/nfet_03v3:0       |Instance: nfet_03v3:CM_9
#   (1,3) = (14,2)                           |  (1,3) = (16,2)
#   2 = 4                                    |  2 = 5
#   4 = 14                                   |  4 = 16
#                                            |
# Instance: xmcm_chain_0_0/nfet_03v3:0       |Instance: nfet_03v3:CM_5
#   (1,3) = (6,2)                            |  (1,3) = (4,2)
#   2 = 1                                    |  2 = 5
#   4 = 14                                   |  4 = 16
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# Instance: xm5_0/pfet_03v3:0                |Instance: pfet_03v3:5
#   (1,3) = (12,4)                           |  (1,3) = (13,1)
#   2 = 6                                    |  2 = 4
#   4 = 12                                   |  4 = 13
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#
# Subcircuit pins:
# Circuit 1: stdp                            |Circuit 2: stdp
# -------------------------------------------|-------------------------------------------
# vw                                         |(no pin, node is vpot)
# avdd                                       |vw **Mismatch**
# Iout                                       |(no pin, node is vdep)
# avss                                       |avss
# vb_itd                                     |iout **Mismatch**
# vpre                                       |vpre
# vb_pot                                     |vb_pot
# nvpost                                     |nvpost
# nvpre                                      |nvpre
# vpost                                      |vpost
# vb_itp                                     |vb_itp
# vb_idep                                    |vb_idep
# (no pin, node is avss)                     |avdd
# (no pin, node is avss)                     |vb_itd
# ---------------------------------------------------------------------------------------
# Cell pin lists for stdp and stdp altered to match.
# Device classes stdp and stdp are equivalent.
#
# Final result: Top level cell failed pin matching.
# {'magic_subproc_code': 0,
#  'netgen_subproc_code': 0,
#  'result_str': 'LVS run succeeded\nErrors found in LVS report: /tmp/tmpkxmk3gmg/stdp_lvs.rpt'}

# %%
from pathlib import Path
import os
import subprocess

pdk_name = os.environ.get("PDK", "gf180mcuD")
pdk_root = Path(os.environ.get("PDK_ROOT", ""))
pdk_path_env = Path(os.environ.get("PDKPATH", ""))

# Resolve the correct magicrc path even if PDKPATH is stale or duplicated.
candidate_pdkpaths = [
    pdk_path_env,
    pdk_root / pdk_name,
    pdk_root,
]
magicrc_file = None
for candidate in candidate_pdkpaths:
    if not str(candidate):
        continue
    rc = candidate / "libs.tech" / "magic" / f"{pdk_name}.magicrc"
    if rc.exists():
        magicrc_file = rc
        break

if magicrc_file is None:
    raise FileNotFoundError(
        "No se encontro el magicrc. Revisar PDK_ROOT/PDK/PDKPATH. "
        f"Busque en: {[str(c) for c in candidate_pdkpaths if str(c)]}"
    )

# --- Cambio clave: usar path_to_dir en vez de Path.cwd()/"exports" --
output_dir = Path(path_to_dir)
output_dir.mkdir(parents=True, exist_ok=True)

design_name = stdp_comp.name
gds_path = output_dir / f"{design_name}.gds"
lef_path = output_dir / f"{design_name}.lef"

stdp_comp.write_gds(str(gds_path))

magic_script = f"""
drc off
gds flatglob *\\$\\$*
gds read {gds_path}
load {design_name}
lef write {lef_path}
quit -noprompt
"""

result = subprocess.run(
    ["magic", "-rcfile", str(magicrc_file), "-noconsole", "-dnull"],
    input=magic_script,
    text=True,
    capture_output=True,
    check=True,
)

print(f"CWD kernel: {Path.cwd()}")
print(f"LEF generado: {lef_path}")
print(f"LEF existe: {lef_path.exists()}")
if lef_path.exists():
    print("\nCabecera LEF:")
    with open(lef_path, "r", encoding="utf-8", errors="ignore") as f:
        for _ in range(15):
            line = f.readline()
            if not line:
                break
            print(line.rstrip())
else:
    print("\n--- STDOUT COMPLETO DE MAGIC (para depurar) ---")
    print(result.stdout)
    print("\n--- STDERR COMPLETO DE MAGIC ---")
    print(result.stderr)
# Out:
# 2026-08-21 21:34:04.789 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/stdp/stdp.gds'
# CWD kernel: /foss/designs
# LEF generado: /foss/designs/libs/snn_analog/stdp/stdp.lef
# LEF existe: True
#
# Cabecera LEF:
# VERSION 5.7 ;
#   NOWIREEXTENSIONATPIN ON ;
#   DIVIDERCHAR "/" ;
#   BUSBITCHARS "[]" ;
# MACRO stdp
#   CLASS BLOCK ;
#   FOREIGN stdp ;
#   ORIGIN 2.100 -0.300 ;
#   SIZE 79.080 BY 43.600 ;
#   PIN avdd
#     ANTENNADIFFAREA 70.643997 ;
#     PORT
#       LAYER Nwell ;
#         RECT 0.000 29.855 18.860 35.455 ;
#         RECT 0.000 22.955 4.490 28.555 ;
