# %%
import os
import subprocess
from pathlib import Path
import tempfile

try:
    _printenv = subprocess.run(
        ['bash', '-c', 'source ~/.bashrc 2>/dev/null && printenv'],
        text=True, capture_output=True, timeout=10,
    ).stdout
    for _line in _printenv.splitlines():
        if '=' in _line:
            _k, _v = _line.split('=', 1)
            os.environ.setdefault(_k, _v)
except Exception:
    pass
if 'PDK_ROOT' in os.environ and 'PDK' in os.environ:
    os.environ.setdefault('PDKPATH', os.path.join(os.environ['PDK_ROOT'], os.environ['PDK']))

import gdstk
import svgutils.transform as sg
import IPython.display
from IPython.display import clear_output
import ipywidgets as widgets

# Redirect all outputs here
hide = widgets.Output()

def display_gds(gds_file,path,scale = 3):
  
  # Generate an SVG image
  top_level_cell = gdstk.read_gds(gds_file).top_level()[0]
  top_level_cell.write_svg(os.path.join(path,'out.svg'))
    
  # Scale the image for displaying
  fig = sg.fromfile(os.path.join(path,'out.svg'))
  fig.set_size((str(float(fig.width) * scale), str(float(fig.height) * scale)))
  fig.save(os.path.join(path,'out.svg'))

  # Display the image
  IPython.display.display(IPython.display.SVG(os.path.join(path,'out.svg')))
  os.remove(os.path.join(path,'out.gds'))

def display_component(component,path,scale = 3):
  # Save to a GDS file
  with hide:
    component.write_gds(os.path.join(path,'out.gds'))
  display_gds(os.path.join(path,'out.gds'),path,scale)

import gdsfactory as gf
from gdsfactory import Component
from gdsfactory.components import text_freetype, rectangle
from glayout import MappedPDK, gf180
from glayout import nmos, pmos
from glayout import via_stack
from glayout import rename_ports_by_orientation
from glayout import tapring
from glayout.primitives.mimcap import mimcap_array
from glayout.routing.straight_route import straight_route
from glayout.routing.c_route import c_route
from glayout.routing.L_route import L_route
from glayout.util.comp_utils import evaluate_bbox, prec_center, prec_ref_center, align_comp_to_port
from glayout.util.port_utils import add_ports_perimeter,print_ports
from glayout.util.snap_to_grid import component_snap_to_grid
from glayout.spice.netlist import Netlist

# Base parameters for PMOS and NMOS
encoder_config = {
    "pdk": gf180,
    "layout_rules": {
        "spacing": gf180.util_max_metal_seperation()+1.5,
        "routing_metal": "met2",
        "dummy_devices": False,
        "tie_layers": ("met2", "met1"),
        "sd_rmult": 1,
    },
}

nmos_kwargs = {
    "with_tie": True,
    "with_dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "with_dummy": (False, False),
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False,
    "with_substrate_tap": False
}

pmos_kwargs = {
    "with_tie": True,
    "dnwell": False,
    "sd_route_topmet": "met2",
    "gate_route_topmet": "met2",
    "sd_route_left": True,
    "rmult": None,
    "gate_rmult": 1,
    "with_dummy": (False, False),
    "interfinger_rmult": 1,
    "substrate_tap_layers": ("met2","met1"),
    "dummy_routes": False,
    "with_substrate_tap": False
}

pdk = gf180
encoder_comp = Component(name="encoder")
encoder_comp.name = "encoder"
rules = encoder_config["layout_rules"]
spacing = rules["spacing"]
tie_layers = rules["tie_layers"]
sd_rmult = rules["sd_rmult"]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# ----------------------------------------------------------------------
# 1. Component Instantiation
# ----------------------------------------------------------------------

# --- Differential Pair (M1, M2): Long channel L=10u, W=0.28u ---
xm1 = nmos(pdk, width=0.5, length=10.0, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
xm2 = nmos(pdk, width=0.5, length=10.0, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult,**nmos_kwargs)

# --- Active Diode Loads (M3, M4): W=2u, L=0.28u ---
xm3 = pmos(pdk, width=2.0, length=0.28, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
xm4 = pmos(pdk, width=2.0, length=0.28, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)

# --- Output PMOS Current Mirrors (M5, M6, M7, M8): W=0.93u, L=1.86u ---
xm5 = pmos(pdk, width=0.93, length=1.86, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
xm8 = pmos(pdk, width=0.93, length=1.86, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
xm6 = pmos(pdk, width=0.93, length=1.86, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
xm7 = pmos(pdk, width=0.93, length=1.86, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)

# --- Tail Current Source & Bias Network (M9, M10, M11): W=0.28u, L=0.28u ---
xm9  = nmos(pdk, width=0.5, length=0.28, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
xm10 = nmos(pdk, width=0.5, length=0.28, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **nmos_kwargs)
xm11 = pmos(pdk, width=0.5, length=0.28, fingers=1, tie_layers=tie_layers, sd_rmult=sd_rmult, **pmos_kwargs)
# Out:
# 2026-09-05 00:34:28.697 | INFO     | gdsfactory.pdk:activate:337 - 'gf180' PDK is now active

# %%
# ----------------------------------------------------------------------
# 2. Structural Placement & Floorplanning
# -----------------------------------------------------------------------

# Set instance names
xm1.name  = "xm1"
xm2.name  = "xm2"
xm3.name  = "xm3"
xm4.name  = "xm4"
xm5.name  = "xm5"
xm6.name  = "xm6"
xm7.name  = "xm7"
xm8.name  = "xm8"
xm9.name  = "xm9"
xm10.name = "xm10"
xm11.name = "xm11"

# Create references for all devices in the top component
xm1_ref  = encoder_comp << xm1
xm2_ref  = encoder_comp << xm2
xm3_ref  = encoder_comp << xm3
xm4_ref  = encoder_comp << xm4
xm5_ref  = encoder_comp << xm5
xm6_ref  = encoder_comp << xm6
xm7_ref  = encoder_comp << xm7
xm8_ref  = encoder_comp << xm8
xm9_ref  = encoder_comp << xm9
xm10_ref = encoder_comp << xm10
xm11_ref = encoder_comp << xm11

#dynamic bbox
xm10_xy = evaluate_bbox(xm10)
xm9_xy  = evaluate_bbox(xm9)

xm1_xy  = evaluate_bbox(xm1)
xm2_xy  = evaluate_bbox(xm2)

xm8_xy  = evaluate_bbox(xm8)
xm5_xy  = evaluate_bbox(xm5)
xm3_xy  = evaluate_bbox(xm3)
xm11_xy = evaluate_bbox(xm11)
xm4_xy  = evaluate_bbox(xm4)
xm7_xy  = evaluate_bbox(xm7)
xm6_xy  = evaluate_bbox(xm6)


# Calculate Row Y-Coordinates dynamically to prevent Y-axis overlap
bottom_row_y = xm10_xy[1] / 2
middle_row_y = bottom_row_y + (xm10_xy[1] / 2) + spacing + (xm1_xy[1] / 2)
top_row_y    = middle_row_y + (xm1_xy[1] / 2) + spacing + (xm3_xy[1] / 2)


# # --- BOTTOM ROW: Bias & Tail NMOS Array (xm9, xm10) ---
# xm9_ref.move((0 + xm9_xy[0] / 2, bottom_row_y + xm9_xy[1] / 2))
# xm10_ref.move((xm9_ref.xmax + xm10_xy[0] / 2 + spacing, bottom_row_y + xm10_xy[1] / 2))

# # --- MIDDLE ROW: Differential Input NMOS Pair (xm1, xm2) ---
xm1_ref.move((0 + xm1_xy[0] / 2, middle_row_y + xm1_xy[1] / 2))
xm9_ref.move((xm1_ref.xmax + xm9_xy[0] / 2 + spacing, middle_row_y + xm9_xy[1] / 2))
xm10_ref.move((xm9_ref.xmax + xm10_xy[0] / 2 + spacing, middle_row_y + xm10_xy[1] / 2))
xm2_ref.move((xm10_ref.xmax + xm2_xy[0] / 2 + spacing, middle_row_y + xm2_xy[1] / 2))

# --- SINGLE ROW: NMOS Array (xm1, xm9, xm10, xm2) ---
# xm1_ref.move((0 + xm1_xy[0] / 2, bottom_row_y + xm1_xy[1] / 2))
# xm9_ref.move((xm1_ref.xmax + xm9_xy[0] / 2 + spacing, bottom_row_y + xm9_xy[1] / 2))
# xm10_ref.move((xm9_ref.xmax + xm10_xy[0] / 2 + spacing, bottom_row_y + xm10_xy[1] / 2))
# xm2_ref.move((xm10_ref.xmax + xm2_xy[0] / 2 + spacing, bottom_row_y + xm2_xy[1] / 2))

# --- TOP ROW: PMOS Array (Alineación por la base) ---
xm3_ref.move((0 + xm3_xy[0] / 2, top_row_y + xm3_xy[1] / 2))
xm5_ref.move((xm3_ref.xmax + xm5_xy[0] / 2 + spacing, top_row_y + xm5_xy[1] / 2))
xm8_ref.move((xm5_ref.xmax + xm8_xy[0] / 2 + spacing, top_row_y + xm8_xy[1] / 2))
xm11_ref.move((xm8_ref.xmax + xm11_xy[0] / 2 + spacing, top_row_y + xm11_xy[1] / 2))
xm6_ref.move((xm11_ref.xmax + xm6_xy[0] / 2 + spacing, top_row_y + xm6_xy[1] / 2))
xm7_ref.move((xm6_ref.xmax + xm7_xy[0] / 2 + spacing, top_row_y + xm7_xy[1] / 2))
xm4_ref.move((xm7_ref.xmax + xm4_xy[0] / 2 + spacing, top_row_y + xm4_xy[1] / 2))
# Out:
# ComponentReference (parent Component "xm4", ports ['multiplier_0_gate_W', 'gate_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row0_col0_bottom_via_W', 'multiplier_0_leftsd_array_row0_col0_bottom_met_W', 'multiplier_0_leftsd_array_row0_col0_top_met_W', 'multiplier_0_row0_col0_gate_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_W', 'multiplier_0_row0_col0_rightsd_top_met_W', 'multiplier_0_leftsd_array_row1_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row1_col0_bottom_via_W', 'multiplier_0_leftsd_array_row1_col0_bottom_met_W', 'multiplier_0_leftsd_array_row1_col0_top_met_W', 'multiplier_0_leftsd_top_met_W', 'multiplier_0_plusdoped_W', 'multiplier_0_diff_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_W', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_W', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_W', 'multiplier_0_leftsd_array_row2_col0_bottom_via_W', 'multiplier_0_leftsd_array_row2_col0_bottom_met_W', 'multiplier_0_leftsd_array_row2_col0_top_met_W', 'multiplier_0_source_W', 'source_W', 'multiplier_0_drain_W', 'drain_W', 'multiplier_0_leftsd_array_row0_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row0_col0_bottom_via_N', 'multiplier_0_leftsd_array_row0_col0_bottom_met_N', 'multiplier_0_leftsd_array_row0_col0_top_met_N', 'multiplier_0_leftsd_array_row1_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row1_col0_bottom_via_N', 'multiplier_0_leftsd_array_row1_col0_bottom_met_N', 'multiplier_0_leftsd_array_row1_col0_top_met_N', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_N', 'multiplier_0_leftsd_array_row2_col0_bottom_via_N', 'multiplier_0_leftsd_array_row2_col0_bottom_met_N', 'multiplier_0_leftsd_array_row2_col0_top_met_N', 'multiplier_0_leftsd_top_met_N', 'multiplier_0_row0_col0_gate_N', 'multiplier_0_plusdoped_N', 'multiplier_0_diff_N', 'multiplier_0_drain_N', 'multiplier_0_source_N', 'multiplier_0_gate_N', 'source_N', 'drain_N', 'gate_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row0_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row1_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_N', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_N', 'multiplier_0_row0_col0_rightsd_top_met_N', 'multiplier_0_drain_E', 'drain_E', 'multiplier_0_source_E', 'source_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_layer_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_via_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_bottom_met_E', 'multiplier_0_row0_col0_rightsd_array_row2_col0_top_met_E', 'multiplier_0_leftsd_array_row2_col0_bottom_layer_E', 'multiplier_0_leftsd_array_row2_col0_bottom_via_E', 'multiplier_0_leftsd_array_row2_col0_bottom_met_E', 'multiplier_0_leftsd_array_row2_col0_top_met_E', 'multiplier_0_row0_col0_gate_E', 'multiplier_0_row0_col0_rightsd_array_row1_col0_bottom_layer_E', 'multiplier_0_row0_col0_rightsd_array_row ...

# %%
# =========================================================================
# 3. ADD Vdd & VSS POWER RAILS, CONNECT SUPPLY NODES AND ADD PORTS
# =========================================================================
psize=(2,2)
# Calculate full horizontal span of the cell to draw supply rails
bbox = evaluate_bbox(encoder_comp)
top_y = encoder_comp.ymax + 3.0
bottom_y = encoder_comp.ymin - 3.0

#via m2m3
viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
#via m2m5
viam2m5 = via_stack(pdk, "met2", "met5", centered=True)
#via m2m4
viam2m4 = via_stack(pdk, "met2", "met3", centered=True)
#create via in every port

#via en iex1
iex1_via = encoder_comp << viam2m4
iex1_via.move(xm8_ref.ports["multiplier_0_drain_S"].center).movex(0.25).movey(0.25)

#via en iex2
iex2_via = encoder_comp << viam2m4
iex2_via.move(xm5_ref.ports["multiplier_0_drain_S"].center).movex(0.25).movey(0.25)

#via en iex3
iex3_via = encoder_comp << viam2m4
iex3_via.move(xm7_ref.ports["multiplier_0_drain_S"].center).movex(0.25).movey(0.25)

#via en iex4
iex4_via = encoder_comp << viam2m4
iex4_via.move(xm6_ref.ports["multiplier_0_drain_S"].center).movex(0.25).movey(0.25)

#via en vin
vin_via = encoder_comp << viam2m4
vin_via.move(xm1_ref.ports["multiplier_0_gate_W"].center).movex(0.25)

#via en vin_neg
vin_neg_via = encoder_comp << viam2m4
vin_neg_via.move(xm2_ref.ports["multiplier_0_gate_W"].center).movex(0.25)


# Draw horizontal metal2 power rails
Vdd_rail = encoder_comp << gf.components.rectangle(size=(bbox[0]+4, 1.0),layer=pdk.get_layer("metal5"))
Vdd_rail.move((-2, top_y))

Vss_rail = encoder_comp << gf.components.rectangle(size=(bbox[0]+4, 1.0), layer=pdk.get_layer("metal5"))
Vss_rail.move((-2, bottom_y))

#via en vdd
vdd_via = encoder_comp << viam2m5
vdd_via.move((encoder_comp.xmax/2, top_y+0.5))

#via en vss
vss_via = encoder_comp << viam2m5
vss_via.move((bbox[0]/2, bottom_y + 0.5))

#############################################################################
####################  ANILLO DE PDN  #########################################

# --------  Adding inner ring AVDD --------  
## METAL5 TOP avdd
# bbox_vdd = evaluate_bbox(Vdd_rail)

# avdd_M5_top_inner = encoder_comp << gf.components.rectangle(
#     size=(bbox_vdd[0]+10, 6.13), 
#     layer=pdk.get_layer("metal5")
# )
# avdd_M5_top_inner.move((-7, top_y + bbox_vdd[1] + 2))

# avdd_M5_top_inner_label = encoder_comp << gf.components.rectangle(
#     size=(bbox_vdd[0]+10, 6.13), 
#     layer=pdk.get_layer("metal5_label")
# )
# avdd_M5_top_inner_label.move((-7, top_y + bbox_vdd[1] + 2))

# ## METAL5 BOTTOM avdd
# bbox_vss = evaluate_bbox(Vss_rail)

# avdd_M5_bot_inner = encoder_comp<< gf.components.rectangle(
#     size=(bbox_vdd[0]+10, 6.13), 
#     layer=pdk.get_layer("metal5")
# )
# bbox_vssbot = evaluate_bbox(avdd_M5_bot_inner)
# avdd_M5_bot_inner.move((-7, bottom_y - bbox_vssbot[1] - 2))

# avdd_M5_bot_inner_label = encoder_comp << gf.components.rectangle(
#     size=(bbox_vdd[0]+10, 6.13), 
#     layer=pdk.get_layer("metal5_label")
# )
# avdd_M5_bot_inner_label.move((-7, bottom_y - bbox_vssbot[1] - 2))

# #metal4 left avdd
# avdd_M4_left = encoder_comp << gf.components.rectangle(
#     size=(5, evaluate_bbox(encoder_comp)[1]), 
#     layer=pdk.get_layer("metal4")
# )
# avdd_M4_left.move((avdd_M5_bot_inner.xmin, avdd_M5_bot_inner.ymin))

# avdd_M4_left_label = encoder_comp << gf.components.rectangle(
#     size=(5, evaluate_bbox(encoder_comp)[1]), 
#     layer=pdk.get_layer("metal4_label")
# )
# avdd_M4_left_label.move((avdd_M5_bot_inner.xmin, avdd_M5_bot_inner.ymin))

# #metal4 right avdd
# avdd_M4_right = encoder_comp << gf.components.rectangle(
#     size=(5, evaluate_bbox(encoder_comp)[1]), 
#     layer=pdk.get_layer("metal4")
# )
# avdd_M4_right.move((avdd_M5_bot_inner.xmax - evaluate_bbox(avdd_M4_left)[0], avdd_M5_bot_inner.ymin))

# avdd_M4_right_label = encoder_comp << gf.components.rectangle(
#     size=(5, evaluate_bbox(encoder_comp)[1]), 
#     layer=pdk.get_layer("metal4_label")
# )
# avdd_M4_right_label.move((avdd_M5_bot_inner.xmax - evaluate_bbox(avdd_M4_left)[0], avdd_M5_bot_inner.ymin))

# # --------  Adding outer ring AVSS --------  

# avss_M5_top_outer = encoder_comp << gf.components.rectangle(
#     size=(evaluate_bbox(encoder_comp)[0]+14, 6.13), 
#     layer=pdk.get_layer("metal5")
# )
# avss_M5_top_outer.move((-7 + avdd_M5_top_inner.xmin, avdd_M5_top_inner.ymax + 2))

# avss_M5_top_outer_label = encoder_comp << gf.components.rectangle(
#     size=evaluate_bbox(avss_M5_top_outer), 
#     layer=pdk.get_layer("metal5_label")
# )
# avss_M5_top_outer_label.move((-7 + avdd_M5_top_inner.xmin, avdd_M5_top_inner.ymax + 2))


# avss_M5_bot_outer = encoder_comp << gf.components.rectangle(
#     size=(evaluate_bbox(avss_M5_top_outer)[0], 6.13), 
#     layer=pdk.get_layer("metal5")
# )
# avss_M5_bot_outer.move((-7 + avdd_M5_top_inner.xmin, avdd_M5_bot_inner.ymin - evaluate_bbox(avss_M5_bot_outer)[1] - 2))

# avss_M5_bot_outer_label = encoder_comp << gf.components.rectangle(
#     size=(evaluate_bbox(avss_M5_top_outer)[0], 6.13), 
#     layer=pdk.get_layer("metal5_label")
# )
# avss_M5_bot_outer_label.move((-7 + avdd_M5_top_inner.xmin, avdd_M5_bot_inner.ymin - evaluate_bbox(avss_M5_bot_outer)[1] - 2))

# #metal4 left avdd
# avss_M4_left_outer = encoder_comp << gf.components.rectangle(
#     size=(5, evaluate_bbox(encoder_comp)[1]), 
#     layer=pdk.get_layer("metal4")
# )
# avss_M4_left_outer.move((avss_M5_bot_outer.xmin, avss_M5_bot_outer.ymin))

# avss_M4_left_outer_label = encoder_comp << gf.components.rectangle(
#     size=evaluate_bbox(avss_M4_left_outer), 
#     layer=pdk.get_layer("metal4_label")
# )
# avss_M4_left_outer_label.move((avss_M5_bot_outer.xmin, avss_M5_bot_outer.ymin))

# #metal4 right avdd
# avss_M4_right_outer = encoder_comp << gf.components.rectangle(
#     size=(5, evaluate_bbox(avss_M4_left_outer)[1]), 
#     layer=pdk.get_layer("metal4")
# )
# avss_M4_right_outer.move((avss_M5_bot_outer.xmax - evaluate_bbox(avss_M4_right_outer)[0], avss_M5_bot_outer.ymin))

# avss_M4_right_outer_label = encoder_comp << gf.components.rectangle(
#     size=evaluate_bbox(avss_M4_right_outer), 
#     layer=pdk.get_layer("metal4_label")
# )
# avss_M4_right_outer_label.move((avss_M5_bot_outer.xmax - evaluate_bbox(avss_M4_right_outer)[0], avss_M5_bot_outer.ymin))

# # ----- Adding vias m4m5 in each corner of the inner ring
# viam4m5 = via_stack(pdk, "met2", "met5", centered=True, fullbottom=True, fulltop=True)
# via_nw_inner = encoder_comp << viam4m5
# via_ne_inner = encoder_comp << viam4m5
# via_sw_inner = encoder_comp << viam4m5
# via_se_inner = encoder_comp << viam4m5
# via_nw_inner.move((avdd_M5_top_inner.xmin + 2.5, avdd_M5_top_inner.ymax - 2.5))
# via_ne_inner.move((avdd_M5_top_inner.xmax - 2.5, avdd_M5_top_inner.ymax - 2.5))
# via_sw_inner.move((avdd_M5_bot_inner.xmin + 2.5, avdd_M5_bot_inner.ymin + 2.5))
# via_se_inner.move((avdd_M5_bot_inner.xmax - 2.5, avdd_M5_bot_inner.ymin + 2.5))

# Crear la vía individual
# viam4m5 = via_stack(pdk, "met2", "met5", centered=True, fullbottom=True, fulltop=True)

# def place_via_array(parent_comp, via_comp, base_x, base_y, rows=5, cols=5, pitch=1):
#     """
#     Instancia una matriz de vías a partir de una coordenada de origen (base_x, base_y).
#     """
#     for r in range(rows):
#         for c in range(cols):
#             inst = parent_comp << via_comp
#             # Centra o distribuye el arreglo alrededor del punto base
#             x_offset = (c - (cols - 1) / 2) * pitch
#             y_offset = (r - (rows - 1) / 2) * pitch
#             inst.move((base_x + x_offset, base_y + y_offset))

# # Define el espaciamiento entre centros de vías según las reglas DRC de tu PDK
# VIA_PITCH = 1  # Ajustar según min_spacing + via_width

# # ----- Agregar arreglos de vías en las esquinas del anillo INTERNO (3x3 = 9 vías)
# inner_corners = [
#     (avdd_M5_top_inner.xmin + 2.5, avdd_M5_top_inner.ymax - 2.5),  # NW
#     (avdd_M5_top_inner.xmax - 2.5, avdd_M5_top_inner.ymax - 2.5),  # NE
#     (avdd_M5_bot_inner.xmin + 2.5, avdd_M5_bot_inner.ymin + 2.5),  # SW
#     (avdd_M5_bot_inner.xmax - 2.5, avdd_M5_bot_inner.ymin + 2.5)   # SE
# ]

# for x, y in inner_corners:
#     place_via_array(encoder_comp, viam4m5, x, y, rows=3, cols=3, pitch=VIA_PITCH)


# # ----- Agregar arreglos de vías en las esquinas del anillo EXTERNO (3x3 = 9 vías)
# outer_corners = [
#     (avss_M5_top_outer.xmin + 2.5, avss_M5_top_outer.ymax - 2.5),  # NW
#     (avss_M5_top_outer.xmax - 2.5, avss_M5_top_outer.ymax - 2.5),  # NE
#     (avss_M5_bot_outer.xmin + 2.5, avss_M5_bot_outer.ymin + 2.5),  # SW
#     (avss_M5_bot_outer.xmax - 2.5, avss_M5_bot_outer.ymin + 2.5)   # SE
# ]

# for x, y in outer_corners:
#     place_via_array(encoder_comp, viam4m5, x, y, rows=3, cols=3, pitch=VIA_PITCH)

# #adding a VIA M2M3 to the avdd avss pin, moving to the center of the rail
# viam2m3 = via_stack(pdk, "met2", "met3", centered=True) #met2 is the bottom layer. met3 is the top layer.
# via_avdd = encoder_comp << viam2m3
# via_avdd.move((bbox[0]/2, top_y + 0.5))
# via_avss = encoder_comp << viam2m3
# via_avss.move((bbox[0]/2, bottom_y + 0.5))


# # ---------connecting inner ring to avdd---------
# encoder_comp << L_route(pdk, via_nw_inner.ports["top_met_S"], via_avdd.ports["bottom_met_W"])
# encoder_comp << L_route(pdk, via_ne_inner.ports["top_met_S"], via_avdd.ports["bottom_met_E"])

# # ---------connecting outer ring to avss---------
# encoder_comp << L_route(pdk, via_sw_outer.ports["top_met_N"], via_avss.ports["bottom_met_W"])
# encoder_comp << L_route(pdk, via_se_outer.ports["top_met_N"], via_avss.ports["bottom_met_E"])

# ####################################### VIAS ##################################


# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avdd_M5 = encoder_comp << viam2m5
# via_avdd_M5.move((-3.5, top_y + bbox_vss_M5[1] - 0.5))
# via_avdd_M5B = encoder_comp << viam2m5
# via_avdd_M5B.move((-3.5, bottom_y - bbox_vss_M5[1] + 0.5))

# encoder_comp  << straight_route(pdk, via_avdd_M5.ports["bottom_met_S"], via_avdd_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")
# #encoder_comp  << straight_route(pdk, via_avdd_M5.ports["bottom_met_S"], via_avdd_M5B.ports["bottom_met_N"],glayer1="met4_label",glayer2="met4_label",width="5")


# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avss_M5 = encoder_comp << viam2m5
# via_avss_M5.move((-10.5, top_y + 2* bbox_vss_M5[1] + 2.5))
# via_avss_M5B = encoder_comp << viam2m5
# via_avss_M5B.move((-10.5, bottom_y - 2*bbox_vss_M5[1] - 2.5))

# encoder_comp  << straight_route(pdk, via_avss_M5.ports["bottom_met_S"], via_avss_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avddL_M5 = encoder_comp << viam2m5
# via_avddL_M5.move((51, top_y + bbox_vss_M5[1] - 0.5))
# via_avddL_M5B = encoder_comp << viam2m5
# via_avddL_M5B.move((51, bottom_y - bbox_vss_M5[1] + 0.5))

# encoder_comp  << straight_route(pdk, via_avddL_M5.ports["bottom_met_S"], via_avddL_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

# #adding a VIA M2M5 to the avdd avss pin, moving to the center of the rail
# viam2m5 = via_stack(pdk, "met2", "met5", centered=True) #met2 is the bottom layer. met5 is the top layer.
# via_avssL_M5 = encoder_comp << viam2m5
# via_avssL_M5.move((58, top_y + 2* bbox_vss_M5[1] + 2.5))
# via_avssL_M5B = encoder_comp << viam2m5
# via_avssL_M5B.move((58, bottom_y - 2*bbox_vss_M5[1] - 2.5))

# encoder_comp  << straight_route(pdk, via_avssL_M5.ports["bottom_met_S"], via_avssL_M5B.ports["bottom_met_N"],glayer1="met4",glayer2="met4",width="5")

# #################################################################################

# #connecting ports to ring
# encoder_comp  << L_route(pdk, vdd_via.ports["bottom_met_N"], via_avddL_M5.ports["bottom_met_W"])
# encoder_comp  << L_route(pdk, vss_via.ports["bottom_met_S"], via_avssL_M5B.ports["bottom_met_W"])

# ##################################################################################


#----------- Adding snippet code to move all the placed components to the proper position, 
#----------- in order to set origin into 0,0
# Place this snippet after all your material polygones are placed, and before your ports are placed
bbox_all = encoder_comp.bbox[0]
for ref in encoder_comp.references:
    ref.movex(-1*bbox_all[0]).movey(-1*bbox_all[1])

# %%
encoder_comp.show()
display_component(encoder_comp, scale=1, path=".")
# Out:
# 2026-09-05 00:34:37.386 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?

# %%
# # Helper to place a metal-to-metal via stack on a port
# def place_via_on_port(comp, port_name, via_type="via1"):
#     v = comp << via_stack(pdk, via_type)
#     v.move(comp.ports[port_name].center)
#     return v

# %%
# ----------------------------------------------------------------------
# 4. Interconnect Routing
# ----------------------------------------------------------------------

# Connect PMOS sources to avdd rail
encoder_comp << L_route(pdk, xm8_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm5_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm3_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm4_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm7_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm6_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm11_ref.ports["tie_N_top_met_N"], vdd_via.ports["bottom_met_W"])


# Connect NMOS BULKS TO AVSS
encoder_comp << L_route(pdk, xm9_ref.ports["tie_S_top_met_S"], vss_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm10_ref.ports["tie_S_top_met_S"], vss_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm1_ref.ports["tie_S_top_met_S"], vss_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm2_ref.ports["tie_S_top_met_S"], vss_via.ports["bottom_met_W"])

# Connecting the corresponding PMOS sources to avdd
encoder_comp << L_route(pdk,  xm8_ref.ports["multiplier_0_source_E"], xm8_ref.ports["tie_E_top_met_N"])  # SOURCE XM8
encoder_comp << L_route(pdk,  xm5_ref.ports["multiplier_0_source_E"], xm5_ref.ports["tie_E_top_met_N"])   # SOURCE XM5
encoder_comp << L_route(pdk,  xm3_ref.ports["multiplier_0_source_E"], xm3_ref.ports["tie_E_top_met_N"]) # SOURCE XM3
encoder_comp << L_route(pdk,  xm4_ref.ports["multiplier_0_source_E"], xm4_ref.ports["tie_E_top_met_N"]) # SOURCE XM4
encoder_comp << L_route(pdk,  xm7_ref.ports["multiplier_0_source_E"], xm7_ref.ports["tie_E_top_met_N"])   # SOURCE XM7
encoder_comp << L_route(pdk,  xm6_ref.ports["multiplier_0_source_E"], xm6_ref.ports["tie_E_top_met_N"]) # SOURCE XM6
encoder_comp << L_route(pdk,  xm11_ref.ports["multiplier_0_source_E"], xm11_ref.ports["tie_E_top_met_N"]) # SOURCE XM11

# Connecting the corresponding NMOS SOURCES TO AVSS
encoder_comp << L_route(pdk,  xm9_ref.ports["multiplier_0_source_E"], xm9_ref.ports["tie_E_top_met_N"]) #xm9
encoder_comp << L_route(pdk,  xm10_ref.ports["multiplier_0_source_E"], xm10_ref.ports["tie_E_top_met_N"]) #xm10

# --- B. Node 'x' Connections (M1 Drain, M3 Gate/Drain, M5 Gate, M8 Gate) ---
# Route M1 Drain to M3 Drain
encoder_comp << c_route(pdk, xm1_ref.ports["multiplier_0_drain_W"], xm3_ref.ports["multiplier_0_drain_W"],extension = 2)
encoder_comp << c_route(pdk, xm3_ref.ports["multiplier_0_gate_E"], xm3_ref.ports["multiplier_0_drain_E"])
encoder_comp << straight_route(pdk, xm5_ref.ports["multiplier_0_gate_E"], xm8_ref.ports["multiplier_0_gate_W"])
encoder_comp << straight_route(pdk, xm3_ref.ports["multiplier_0_gate_E"], xm5_ref.ports["multiplier_0_gate_W"])


# # --- C. Node 'y' Connections (M2 Drain, M4 Gate/Drain, M6 Gate, M7 Gate) ---
encoder_comp << c_route(pdk, xm2_ref.ports["multiplier_0_drain_E"], xm4_ref.ports["multiplier_0_drain_E"])
encoder_comp << straight_route(pdk, xm6_ref.ports["multiplier_0_gate_W"], xm7_ref.ports["multiplier_0_gate_E"])
encoder_comp << c_route(pdk, xm4_ref.ports["multiplier_0_gate_W"], xm4_ref.ports["multiplier_0_drain_W"],extension=1.5)
encoder_comp << straight_route(pdk, xm7_ref.ports["multiplier_0_gate_E"], xm4_ref.ports["multiplier_0_gate_W"])

# # --- D. Bias Network (net1) Routing ---
encoder_comp << c_route(pdk, xm10_ref.ports["multiplier_0_gate_W"], xm10_ref.ports["multiplier_0_drain_W"], extension=1.5)
encoder_comp << c_route(pdk, xm11_ref.ports["multiplier_0_gate_W"], xm11_ref.ports["multiplier_0_drain_W"], extension=1.5)
encoder_comp << c_route(pdk, xm11_ref.ports["multiplier_0_drain_E"], xm10_ref.ports["multiplier_0_drain_E"], extension=1.5)
encoder_comp << straight_route(pdk, xm9_ref.ports["multiplier_0_gate_E"], xm10_ref.ports["multiplier_0_gate_W"])

#create via xm1xm9
xm1_xm9_via = encoder_comp << viam2m3
#via XM1 und XM9
xm1_xm9_via.move(xm1_ref.ports["multiplier_0_source_E"].center).movex(2)
encoder_comp << straight_route(pdk, xm1_ref.ports["multiplier_0_source_E"], xm1_xm9_via.ports["bottom_met_W"])
encoder_comp << L_route(pdk, xm1_xm9_via.ports["top_met_N"], xm9_ref.ports["multiplier_0_drain_W"])

#create via xm2xm9 
xm2_xm9_via = encoder_comp << viam2m3
#via XM2 und XM9
xm2_xm9_via.move(xm2_ref.ports["multiplier_0_source_E"].center).movex(2)
encoder_comp << straight_route(pdk, xm2_ref.ports["multiplier_0_source_E"], xm2_xm9_via.ports["bottom_met_W"])
encoder_comp << c_route(pdk, xm1_xm9_via.ports["top_met_N"], xm2_xm9_via.ports["top_met_N"], extension=2.5, cglayer="met2")
# Out:
# ComponentReference (parent Component "c_route_420c9b31", ports ['con_E', 'con_W'], origin (0.0, 0.0), rotation 0.0, x_reflection False)

# %%
encoder_comp.show()
display_component(encoder_comp, scale=1, path=".")
# Out:
# 2026-09-05 00:34:40.280 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?

# %%
################# ADD PORTS ##################################
# Add global ports for the supply rails
encoder_comp.add_port("vdd", 
                    center=vdd_via.center,
                    width=1.0, orientation=180, 
                    layer=pdk.get_layer("metal5"), port_type="electrical")

encoder_comp.add_port("vss",center = vss_via.center,width=1.0, orientation=180, layer=pdk.get_layer("metal5"), port_type="electrical")
# # add label to those global ports 
# # encoder_comp.add_label(text="Vdd", position=(bbox[0]/2, top_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1)
# # encoder_comp.add_label(text="Vss", position=(bbox[0]/2, bottom_y + 0.5), layer=pdk.get_glayer("met3_label") , magnification=1)

encoder_comp.add_label(
    text="vss",                         # Etiqueta para el rail inferior
    position=vss_via.center,
    layer=pdk.get_glayer("met5_label"),

    magnification=1.5
)

# add label to those global ports 
encoder_comp.add_label(
    text="vdd",                         # Etiqueta para el rail superior
    position=vdd_via.center,
    layer=pdk.get_glayer("met5_label"), # Capa de etiquetas para metal2
    magnification=1.5
)

# Vin
vin_port = encoder_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal3"))
vin_port.move(xm1_ref.ports["multiplier_0_gate_W"].center).movex(-evaluate_bbox(vin_port)[0]/2).movey(-evaluate_bbox(vin_port)[1]/2)

encoder_comp.add_port(
    "Vin", 
    center=xm1_ref.ports["multiplier_0_gate_W"].center, 
    width=1.0, 
    orientation=180, 
    layer=pdk.get_layer("metal3"), 
    port_type="electrical"
)

encoder_comp.add_label(
    text="Vin", 
    position=xm1_ref.ports["multiplier_0_gate_W"].center, 
    layer=pdk.get_glayer("met3_label"), 
    magnification=1
)

# Vin_neg
vinneg_ref = encoder_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal3"))
vinneg_ref.move(xm2_ref.ports["multiplier_0_gate_W"].center).movex(-evaluate_bbox(vinneg_ref)[0]/2).movey(-evaluate_bbox(vinneg_ref)[1]/2)

encoder_comp.add_port(
    "Vin_neg", 
    center=xm2_ref.ports["multiplier_0_gate_W"].center, 
    width=1.0, 
    orientation=180,
    layer=pdk.get_layer("metal3"), 
    port_type="electrical"
)

encoder_comp.add_label(
    text="Vin_neg", 
    position=xm2_ref.ports["multiplier_0_gate_W"].center, 
    layer=pdk.get_glayer("met3_label"), 
    magnification=1
)

# Iex_1_i
iex1_ref = encoder_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal3"))
iex1_ref.move(xm8_ref.ports["multiplier_0_drain_S"].center).movex(-evaluate_bbox(iex1_ref)[0]/2).movey(-evaluate_bbox(iex1_ref)[1]/2)

encoder_comp.add_port(
    "Iex_1_i", 
    center=xm8_ref.ports["multiplier_0_drain_S"].center, 
    width=1.0, 
    orientation=270, 
    layer=pdk.get_layer("metal3"), 
    port_type="electrical"
)

encoder_comp.add_label(
    text="Iex_1_i", 
    position=xm8_ref.ports["multiplier_0_drain_S"].center, 
    layer=pdk.get_glayer("met3_label"), 
    magnification=1
)

# Iex_2_i
iex2_ref = encoder_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal3"))
iex2_ref.move(xm5_ref.ports["multiplier_0_drain_S"].center).movex(-evaluate_bbox(iex2_ref)[0]/2).movey(-evaluate_bbox(iex2_ref)[1]/2)

encoder_comp.add_port(
    "Iex_2_i", 
    center=xm5_ref.ports["multiplier_0_drain_S"].center, 
    width=1.0, 
    orientation=270, 
    layer=pdk.get_layer("metal3"), 
    port_type="electrical"
)

encoder_comp.add_label(
    text="Iex_2_i", 
    position=xm5_ref.ports["multiplier_0_drain_S"].center, 
    layer=pdk.get_glayer("met3_label"), 
    magnification=1
)

# Iex_3_i
iex3_ref = encoder_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal3"))
iex3_ref.move(xm7_ref.ports["multiplier_0_drain_S"].center).movex(-evaluate_bbox(iex3_ref)[0]/2).movey(-evaluate_bbox(iex3_ref)[1]/2)

encoder_comp.add_port(
    "Iex_3_i", 
    center=xm7_ref.ports["multiplier_0_drain_S"].center, 
    width=1.0, 
    orientation=270, 
    layer=pdk.get_layer("metal3"), 
    port_type="electrical"
)

encoder_comp.add_label(
    text="Iex_3_i", 
    position=xm7_ref.ports["multiplier_0_drain_S"].center, 
    layer=pdk.get_glayer("met3_label"), 
    magnification=1
)

# Iex_4_i
iex4_ref = encoder_comp << gf.components.rectangle(size=psize, layer=pdk.get_layer("metal3"))
iex4_ref.move(xm6_ref.ports["multiplier_0_drain_S"].center).movex(-evaluate_bbox(iex4_ref)[0]/2).movey(-evaluate_bbox(iex4_ref)[1]/2)

encoder_comp.add_port(
    "Iex_4_i", 
    center=xm6_ref.ports["multiplier_0_drain_S"].center, 
    width=1.0, 
    orientation=270, 
    layer=pdk.get_layer("metal3"), 
    port_type="electrical"
)

encoder_comp.add_label(
    text="Iex_4_i", 
    position=xm6_ref.ports["multiplier_0_drain_S"].center, 
    layer=pdk.get_glayer("met3_label"), 
    magnification=1
)
# Out:
# Label(text='Iex_4_i', origin=(32.379999999999995, 15.575), layer=(42, 10))

# %%
# bbox1 = evaluate_bbox(encoder_comp
#                      )
# boundary = encoder_comp << gf.components.rectangle(
#     size=(bbox1[0], bbox1[1]), 
#     layer=(0,0)
# )
# boundary.move((encoder_comp.xmin, encoder_comp.ymin))

# %%
encoder_comp.show()
display_component(encoder_comp, scale=1, path=".")
# Out:
# 2026-09-05 00:34:40.618 | WARNING  | gdsfactory.klive:show:48 - Could not connect to klive server. Is klayout open and klive plugin installed?

# %%
encoder_comp.pprint_ports()
# Out:
# ┏━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ name    ┃ width ┃ center          ┃ orientation ┃ layer   ┃ port_type  ┃
# ┡━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━┩
# │ vdd     │ 1.0   │ [26.5, 21.735]  │ 180         │ [81, 0] │ electrical │
# │ vss     │ 1.0   │ [25.5, 0.5]     │ 180         │ [81, 0] │ electrical │
# │ Vin     │ 1.0   │ [3.93, 4.355]   │ 180         │ [42, 0] │ electrical │
# │ Vin_neg │ 1.0   │ [32.07, 4.355]  │ 180         │ [42, 0] │ electrical │
# │ Iex_1_i │ 1.0   │ [18.62, 15.575] │ 270         │ [42, 0] │ electrical │
# │ Iex_2_i │ 1.0   │ [11.1, 15.575]  │ 270         │ [42, 0] │ electrical │
# │ Iex_3_i │ 1.0   │ [39.9, 15.575]  │ 270         │ [42, 0] │ electrical │
# │ Iex_4_i │ 1.0   │ [32.38, 15.575] │ 270         │ [42, 0] │ electrical │
# └─────────┴───────┴─────────────────┴─────────────┴─────────┴────────────┘

# %%
evaluate_bbox(encoder_comp)
# Out:
# (51.0, 22.235)

# %%
evaluate_bbox(encoder_comp)[0] * evaluate_bbox(encoder_comp)[1]
# Out:
# 1133.985

# %%
drc_result = gf180.drc_magic(encoder_comp, encoder_comp.name)
# Out:
# 2026-09-05 00:34:41.069 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmparv_vg0j/encoder.gds'
# using default pdk_root
# Defaulting to stale magic_commands.tcl
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Loading "/tmp/tmparv_vg0j/magic_commands.tcl" from command line.
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "encoder".
# Reading "xm11".
# Reading "straight_route_ff57ad5f".
# Reading "compass_50f39e54".
# Reading "c_route_b2553670".
# Reading "compass_layer42__0_size2__2$2".
# Reading "c_route_04ee7531".
# Reading "xm5".
# Reading "L_route_b9b0439d".
# Reading "L_route_1f185563".
# Reading "compass_layer42__0_size2__2".
# Reading "L_route_a891df28".
# Reading "rectangle_50f39e54".
# Reading "compass_layer42__0_size2__2$5".
# Reading "L_route_1a450bf3".
# Reading "straight_route_d8785de4".
# Reading "L_route_aac58595".
# Reading "via_stack_7490b2b5".
# Reading "L_route_0982d815".
# Reading "xm9".
# Reading "L_route_0b27eaa6".
# Reading "straight_route_9d656d86".
# Reading "compass_layer42__0_size2__2$3".
# Reading "xm4".
# Reading "L_route_aef27d6b".
# Reading "via_stack_b843013f".
# Reading "straight_route_3751675e".
# Reading "c_route_679dd2e5".
# Reading "L_route_1f6eb2fc".
# Reading "rectangle_layer42__0_size2__2$3".
# Reading "xm3".
# Reading "L_route_52557085".
# Reading "L_route_c52907dc".
# Reading "c_route_481192b6".
# Reading "L_route_171a04ac".
# Reading "c_route_86cd68ff".
# Reading "rectangle_50f39e54$1".
# Reading "c_route_f370e2cd".
# Reading "xm8".
# Reading "straight_route_3d652be3".
# Reading "rectangle_layer42__0_size2__2$5".
# Reading "xm7".
# Reading "c_route_c935389e".
# Reading "L_route_744f09a4".
# Reading "xm10".
# Reading "L_route_ec792bf5".
# Reading "rectangle_layer42__0_size2__2$2".
# Reading "L_route_31e7c68d".
# Reading "xm2".
# Reading "c_route_420c9b31".
# Reading "L_route_da279ef4".
# Reading "L_route_0a7485ec".
# Reading "L_route_a6bb1778".
# Reading "L_route_4362e3b7".
# Reading "L_route_049704b8".
# Reading "rectangle_layer42__0_size2__2$1".
# Reading "compass_layer42__0_size2__2$4".
# Reading "xm1".
# Reading "rectangle_layer42__0_size2__2".
# Reading "L_route_11addbd7".
# Reading "straight_route_88abcf1b".
# Reading "via_stack_7490b2b5$1".
# Reading "compass_50f39e54$1".
# Reading "rectangle_layer42__0_size2__2$4".
# Reading "compass_layer42__0_size2__2$1".
# Reading "xm6".
# Reading "straight_route_5cfec76b".
# [INFO]: Loading encoder
#
# Loading DRC CIF style.
# No errors found.
# [INFO]: DONE with /tmp/tmparv_vg0j/encoder.rpt
#
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722

# %%
#At first, we need to properly set PDKPATH and PDK_ROOT 

print("Making sure your environment varriables are still correctly set")
print(" I am using PDK in: ",os.environ['PDK_ROOT'],"\n PDK name: ",os.environ['PDK'],"\n The PDK files are at: ",os.environ['PDKPATH'])
# Out:
# Making sure your environment varriables are still correctly set
#  I am using PDK in:  /foss/pdks
#  PDK name:  gf180mcuD
#  The PDK files are at:  /foss/pdks/gf180mcuD

# %%
import os
from pathlib import Path
import tempfile
magicrc_file = Path(os.environ['PDKPATH']) / "libs.tech" / "magic" / f"{os.environ['PDK']}.magicrc"
design_name=encoder_comp.name
path_to_dir = "/foss/designs/libs/snn_analog/encoder/"

pex_path = path_to_dir + f"{design_name}.spice"
gds_path = path_to_dir + f"{design_name}.gds"
lef_path = path_to_dir + f"{design_name}.lef"

encoder_comp.write_gds(str(gds_path))

magic_script_content = f"""
drc off            
gds flatglob *\\$\\$*
gds read {gds_path}

flatten {design_name}
load {design_name}
select top cell
extract do local
extract all
ext2sim labels on
ext2sim
extresist tolerance 10
extresist
ext2spice lvs
ext2spice cthresh 0
ext2spice extresist on
ext2spice -o {str(pex_path)}
port avdd use power
port avss use ground
lef write {lef_path}
exit
"""


with tempfile.NamedTemporaryFile(mode='w', delete=False) as magic_script_file:
    magic_script_file.write(magic_script_content)
    magic_script_path = magic_script_file.name
    
magic_cmd = f"bash -c 'magic -rcfile {magicrc_file} -noconsole -dnull < {magic_script_path}'",
magic_subproc = subprocess.run(
    magic_cmd, 
    shell=True,
    check=True,
    capture_output=True
)

magic_subproc_code = magic_subproc.returncode
magic_subproc_out = magic_subproc.stdout.decode('utf-8')
print(magic_subproc_out)
# Out:
# 2026-09-05 00:34:41.708 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/foss/designs/libs/snn_analog/encoder/encoder.gds'
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "encoder".
# Reading "xm11".
# Reading "straight_route_ff57ad5f".
# Reading "compass_50f39e54".
# Reading "c_route_b2553670".
# Reading "compass_layer42__0_size2__2$2".
# Reading "c_route_04ee7531".
# Reading "xm5".
# Reading "L_route_b9b0439d".
# Reading "L_route_1f185563".
# Reading "compass_layer42__0_size2__2".
# Reading "L_route_a891df28".
# Reading "rectangle_50f39e54".
# Reading "compass_layer42__0_size2__2$5".
# Reading "L_route_1a450bf3".
# Reading "straight_route_d8785de4".
# Reading "L_route_aac58595".
# Reading "via_stack_7490b2b5".
# Reading "L_route_0982d815".
# Reading "xm9".
# Reading "L_route_0b27eaa6".
# Reading "straight_route_9d656d86".
# Reading "compass_layer42__0_size2__2$3".
# Reading "xm4".
# Reading "L_route_aef27d6b".
# Reading "via_stack_b843013f".
# Reading "straight_route_3751675e".
# Reading "c_route_679dd2e5".
# Reading "L_route_1f6eb2fc".
# Reading "rectangle_layer42__0_size2__2$3".
# Reading "xm3".
# Reading "L_route_52557085".
# Reading "L_route_c52907dc".
# Reading "c_route_481192b6".
# Reading "L_route_171a04ac".
# Reading "c_route_86cd68ff".
# Reading "rectangle_50f39e54$1".
# Reading "c_route_f370e2cd".
# Reading "xm8".
# Reading "straight_route_3d652be3".
# Reading "rectangle_layer42__0_size2__2$5".
# Reading "xm7".
# Reading "c_route_c935389e".
# Reading "L_route_744f09a4".
# Reading "xm10".
# Reading "L_route_ec792bf5".
# Reading "rectangle_layer42__0_size2__2$2".
# Reading "L_route_31e7c68d".
# Reading "xm2".
# Reading "c_route_420c9b31".
# Reading "L_route_da279ef4".
# Reading "L_route_0a7485ec".
# Reading "L_route_a6bb1778".
# Reading "L_route_4362e3b7".
# Reading "L_route_049704b8".
# Reading "rectangle_layer42__0_size2__2$1".
# Reading "compass_layer42__0_size2__2$4".
# Reading "xm1".
# Reading "rectangle_layer42__0_size2__2".
# Reading "L_route_11addbd7".
# Reading "straight_route_88abcf1b".
# Reading "via_stack_7490b2b5$1".
# Reading "compass_50f39e54$1".
# Reading "rectangle_layer42__0_size2__2$4".
# Reading "compass_layer42__0_size2__2$1".
# Reading "xm6".
# Reading "straight_route_5cfec76b".
# Extracting c_route_b2553670 into c_route_b2553670.ext:
# Extracting compass_layer42__0_size2__2 into compass_layer42__0_size2__2.ext:
# Extracting rectangle_layer42__0_size2__2 into rectangle_layer42__0_size2__2.ext:
# Extracting via_stack_7490b2b5$1 into via_stack_7490b2b5$1.ext:
# Extracting straight_route_88abcf1b into straight_route_88abcf1b.ext:
# Extracting xm9 into xm9.ext:
# Extracting via_stack_7490b2b5 into via_stack_7490b2b5.ext:
# Extracting L_route_b9b0439d into L_route_b9b0439d.ext:
# Extracting L_route_049704b8 into L_route_049704b8.ext:
# Extracting xm10 into xm10.ext:
# Extracting c_route_481192b6 into c_route_481192b6.ext:
# Extracting via_stack_b843013f into via_stack_b843013f.ext:
# Extracting L_route_a891df28 into L_route_a891df28.ext:
# Extracting straight_route_ff57ad5f into straight_route_ff57ad5f.ext:
# Extracting L_route_1f6eb2fc into L_route_1f6eb2fc.ext:
# Extracting L_route_0982d815 into L_route_0982d815.ext:
# Extracting L_route_4362e3b7 into L_route_4362e3b7.ext:
# Extracting xm1 into xm1.ext:
# Extracting compass_layer42__0_size2__2$1 into compass_layer42__0_size2__2$1.ext:
# Extracting rectangle_layer42__0_size2__2$1 into rectangle_layer42__0_size2__2$1.ext:
# Extracting xm2 into xm2.ext:
# Extracting c_route_f370e2cd into c_route_f370e2cd.ext:
# Extracting L_route_171a04ac into L_route_171a04ac.ext:
# Extracting straight_route_9d656d86 into straight_route_9d656d86.ext:
# Extracting c_route_04ee7531 into c_route_04ee7531.ext:
# Extracting compass_50f39e54$1 into compass_50f39e54$1.ext:
# Extracting rectangle_50f39e54$1 into rectangle_50f39e54$1.ext:
# Extracting c_route_420c9b31 into c_route_420c9b31.ext:
# Extracting xm5 into xm5.ext:
# Extracting L_route_0b27eaa6 into L_route_0b27eaa6.ext:
# Extracting compass_layer42__0_size2__2$3 into compass_layer42__0_size2__2$3.ext:
# Extracting rectangle_layer42__0_size2__2$3 into rectangle_layer42__0_size2__2$3.ext:
# Extracting xm3 into xm3.ext:
# Extracting c_route_86cd68ff into c_route_86cd68ff.ext:
# Extracting straight_route_3d652be3 into straight_route_3d652be3.ext:
# Extracting xm11 into xm11.ext:
# Extracting straight_route_d8785de4 into straight_route_d8785de4.ext:
# Extracting c_route_679dd2e5 into c_route_679dd2e5.ext:
# Extracting L_route_c52907dc into L_route_c52907dc.ext:
# Extracting xm8 into xm8.ext:
# Extracting compass_layer42__0_size2__2$2 into compass_layer42__0_size2__2$2.ext:
# Extracting rectangle_layer42__0_size2__2$2 into rectangle_layer42__0_size2__2$2.ext:
# Extracting L_route_a6bb1778 into L_route_a6bb1778.ext:
# Extracting L_route_11addbd7 into L_route_11addbd7.ext:
# Extracting L_route_aac58595 into L_route_aac58595.ext:
# Extracting L_route_52557085 into L_route_52557085.ext:
# Extracting L_route_1a450bf3 into L_route_1a450bf3.ext:
# Extracting L_route_aef27d6b into L_route_aef27d6b.ext:
# Extracting compass_layer42__0_size2__2$5 into compass_layer42__0_size2__2$5.ext:
# Extracting rectangle_layer42__0_size2__2$5 into rectangle_layer42__0_size2__2$5.ext:
# Extracting L_route_744f09a4 into L_route_744f09a4.ext:
# Extracting L_route_ec792bf5 into L_route_ec792bf5.ext:
# Extracting xm6 into xm6.ext:
# Extracting straight_route_5cfec76b into straight_route_5cfec76b.ext:
# Extracting xm4 into xm4.ext:
# Extracting straight_route_3751675e into straight_route_3751675e.ext:
# Extracting xm7 into xm7.ext:
# Extracting c_route_c935389e into c_route_c935389e.ext:
# Extracting L_route_da279ef4 into L_route_da279ef4.ext:
# Extracting compass_layer42__0_size2__2$4 into compass_layer42__0_size2__2$4.ext:
# Extracting rectangle_layer42__0_size2__2$4 into rectangle_layer42__0_size2__2$4.ext:
# Extracting L_route_1f185563 into L_route_1f185563.ext:
# Extracting L_route_0a7485ec into L_route_0a7485ec.ext:
# Extracting L_route_31e7c68d into L_route_31e7c68d.ext:
# Extracting compass_50f39e54 into compass_50f39e54.ext:
# Extracting rectangle_50f39e54 into rectangle_50f39e54.ext:
# Extracting encoder into encoder.ext:
# exttosim finished.
# Adding  vss; Tnew = 1.77ns, Told = 0.00ns
# Adding  vdd; Tnew = 0.04ns, Told = 0.00ns
# Adding  Vin; Tnew = 0.00ns, Told = 0.00ns
# Adding  Vin_neg; Tnew = 0.00ns, Told = 0.00ns
# Adding  Iex_1_i
# Adding  Iex_2_i
# Adding  Iex_3_i
# Adding  Iex_4_i
# Total Nets: 52
# Nets extracted: 8 (0.153846)
# Nets output: 8 (0.153846)
# exttospice finished.
# Generating LEF output /foss/designs/libs/snn_analog/encoder/encoder.lef for cell encoder:
# Diagnostic:  Write LEF header for cell encoder
# Diagnostic:  Writing LEF output for cell encoder
# Diagnostic:  Scale value is 0.005000

# %%
import glob
extensions = [
            "els"
            "*.gds",
            "*.ext",
            "*.res.ext",
            "*.lvs.rpt",
            "*_lvs.rpt",
            "*.nodes",
            "*.sim",
            "*.pex.spice",
            "*_pex.spice"
            ]
files_to_delete = []
for ext in extensions:
    files_to_delete.extend(glob.glob(ext))
    
# Delete the files
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    except OSError as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted: compass_50f39e54$1.ext
# Deleted: compass_50f39e54.ext
# Deleted: compass_layer42__0_size2__2$1.ext
# Deleted: compass_layer42__0_size2__2$2.ext
# Deleted: compass_layer42__0_size2__2$3.ext
# Deleted: compass_layer42__0_size2__2$4.ext
# Deleted: compass_layer42__0_size2__2$5.ext
# Deleted: compass_layer42__0_size2__2.ext
# Deleted: c_route_04ee7531.ext
# Deleted: c_route_420c9b31.ext
# Deleted: c_route_481192b6.ext
# Deleted: c_route_679dd2e5.ext
# Deleted: c_route_86cd68ff.ext
# Deleted: c_route_b2553670.ext
# Deleted: c_route_c935389e.ext
# Deleted: c_route_f370e2cd.ext
# Deleted: encoder.ext
# Deleted: encoder.res.ext
# Deleted: L_route_049704b8.ext
# Deleted: L_route_0982d815.ext
# Deleted: L_route_0a7485ec.ext
# Deleted: L_route_0b27eaa6.ext
# Deleted: L_route_11addbd7.ext
# Deleted: L_route_171a04ac.ext
# Deleted: L_route_1a450bf3.ext
# Deleted: L_route_1f185563.ext
# Deleted: L_route_1f6eb2fc.ext
# Deleted: L_route_31e7c68d.ext
# Deleted: L_route_4362e3b7.ext
# Deleted: L_route_52557085.ext
# Deleted: L_route_744f09a4.ext
# Deleted: L_route_a6bb1778.ext
# Deleted: L_route_a891df28.ext
# Deleted: L_route_aac58595.ext
# Deleted: L_route_aef27d6b.ext
# Deleted: L_route_b9b0439d.ext
# Deleted: L_route_c52907dc.ext
# Deleted: L_route_da279ef4.ext
# Deleted: L_route_ec792bf5.ext
# Deleted: rectangle_50f39e54$1.ext
# Deleted: rectangle_50f39e54.ext
# Deleted: rectangle_layer42__0_size2__2$1.ext
# Deleted: rectangle_layer42__0_size2__2$2.ext
# Deleted: rectangle_layer42__0_size2__2$3.ext
# Deleted: rectangle_layer42__0_size2__2$4.ext
# Deleted: rectangle_layer42__0_size2__2$5.ext
# Deleted: rectangle_layer42__0_size2__2.ext
# Deleted: straight_route_3751675e.ext
# Deleted: straight_route_3d652be3.ext
# Deleted: straight_route_5cfec76b.ext
# Deleted: straight_route_88abcf1b.ext
# Deleted: straight_route_9d656d86.ext
# Deleted: straight_route_d8785de4.ext
# Deleted: straight_route_ff57ad5f.ext
# Deleted: via_stack_7490b2b5$1.ext
# Deleted: via_stack_7490b2b5.ext
# Deleted: via_stack_b843013f.ext
# Deleted: xm1.ext
# Deleted: xm10.ext
# Deleted: xm11.ext
# Deleted: xm2.ext
# Deleted: xm3.ext
# Deleted: xm4.ext
# Deleted: xm5.ext
# Deleted: xm6.ext
# Deleted: xm7.ext
# Deleted: xm8.ext
# Deleted: xm9.ext
# Error deleting encoder.res.ext: [Errno 2] No such file or directory: 'encoder.res.ext'
# Deleted: encoder.nodes
# Deleted: encoder.sim

# %%
import os
from pathlib import Path

# Ruta donde guardas tus archivos de la neurona
path_to_dir = "/foss/designs/libs/snn_analog/encoder/"

# Ejecutar LVS con Netgen usando el PDK gf180
gf180.lvs_netgen(
    layout=encoder_comp,   # tu layout exportado
    design_name=encoder_comp.name,   # nombre del diseño
    pdk_root=Path(os.environ['PDKPATH']),   # raíz del PDK
    lvs_setup_tcl_file=Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
    
    # Netlist de referencia (esquemático ideal)
    lvs_schematic_ref_file=Path(path_to_dir + "encoder.spice"),
    
    # Netlist extraído del layout (PEX/LVS)
    netlist=Path(path_to_dir + "encoder_lvs.spice"),
    
    # Carpeta donde se guarda el reporte .lvs.rpt
    output_file_path=Path(path_to_dir)
)


# gf180.lvs_netgen(
#     layout=encoder_comp,
#     design_name = encoder_comp.name,
#     pdk_root = Path(os.environ['PDKPATH']),
#     lvs_setup_tcl_file = Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
#     netlist = Path(str(path_to_dir + "encoder_lvs.spice")),
#     output_file_path =  Path(str(path_to_dir))
# )
# Out:
# 2026-09-05 00:34:42.970 | INFO     | gdsfactory.component:_write_library:1851 - Wrote to '/tmp/tmpa2ky9m38/encoder.gds'
# using user specified pdk_root, will search for required files in the specified directory
# Warning: Design name not found in the netlist file
#
# Magic 8.3 revision 636 - Compiled on Thu Apr 16 09:13:57 PM CEST 2026.
# Starting magic under Tcl interpreter
# Using the terminal as the console.
# WARNING: RLIMIT_NOFILE is above 1024 and Tcl_Version<9 this may cause runtime issues [rlim_cur=1048576]
# Using NULL graphics device.
# Processing system .magicrc file
# Switching to WIRING tool.
# Switching to NETLIST tool.
# Switching to PICK tool.
# Switching to BOX tool.
# Sourcing design .magicrc for technology gf180mcuD ...
# 10 Magic internal units = 1 Lambda
# Input style import: scaleFactor=10, multiplier=2
# The following types are not handled by extraction and will be treated as non-electrical types:
#     obsactive mvobsactive filldiff fillpoly m1hole obsm1 fillm1 obsv1 m2hole obsm2 fillm2 obsv2 m3hole obsm3 fillm3 m4hole obsm4 fillm4 m5hole obsm5 fillm5 glass fillblock lvstext obscomment
# Scaled tech values by 10 / 1 to match internal grid scaling
# Loading gf180mcuD Device Generator Menu ...
# Using technology "gf180mcuD", version 1.0.575-2-g7b70722
# Warning: Calma reading is not undoable!  I hope that's OK.
# Library written using GDS-II Release 6.0
# Library name: library
# Reading "encoder".
# Reading "xm11".
# Reading "straight_route_ff57ad5f".
# Reading "compass_50f39e54".
# Reading "c_route_b2553670".
# Reading "compass_layer42__0_size2__2$2".
# Reading "c_route_04ee7531".
# Reading "xm5".
# Reading "L_route_b9b0439d".
# Reading "L_route_1f185563".
# Reading "compass_layer42__0_size2__2".
# Reading "L_route_a891df28".
# Reading "rectangle_50f39e54".
# Reading "compass_layer42__0_size2__2$5".
# Reading "L_route_1a450bf3".
# Reading "straight_route_d8785de4".
# Reading "L_route_aac58595".
# Reading "via_stack_7490b2b5".
# Reading "L_route_0982d815".
# Reading "xm9".
# Reading "L_route_0b27eaa6".
# Reading "straight_route_9d656d86".
# Reading "compass_layer42__0_size2__2$3".
# Reading "xm4".
# Reading "L_route_aef27d6b".
# Reading "via_stack_b843013f".
# Reading "straight_route_3751675e".
# Reading "c_route_679dd2e5".
# Reading "L_route_1f6eb2fc".
# Reading "rectangle_layer42__0_size2__2$3".
# Reading "xm3".
# Reading "L_route_52557085".
# Reading "L_route_c52907dc".
# Reading "c_route_481192b6".
# Reading "L_route_171a04ac".
# Reading "c_route_86cd68ff".
# Reading "rectangle_50f39e54$1".
# Reading "c_route_f370e2cd".
# Reading "xm8".
# Reading "straight_route_3d652be3".
# Reading "rectangle_layer42__0_size2__2$5".
# Reading "xm7".
# Reading "c_route_c935389e".
# Reading "L_route_744f09a4".
# Reading "xm10".
# Reading "L_route_ec792bf5".
# Reading "rectangle_layer42__0_size2__2$2".
# Reading "L_route_31e7c68d".
# Reading "xm2".
# Reading "c_route_420c9b31".
# Reading "L_route_da279ef4".
# Reading "L_route_0a7485ec".
# Reading "L_route_a6bb1778".
# Reading "L_route_4362e3b7".
# Reading "L_route_049704b8".
# Reading "rectangle_layer42__0_size2__2$1".
# Reading "compass_layer42__0_size2__2$4".
# Reading "xm1".
# Reading "rectangle_layer42__0_size2__2".
# Reading "L_route_11addbd7".
# Reading "straight_route_88abcf1b".
# Reading "via_stack_7490b2b5$1".
# Reading "compass_50f39e54$1".
# Reading "rectangle_layer42__0_size2__2$4".
# Reading "compass_layer42__0_size2__2$1".
# Reading "xm6".
# Reading "straight_route_5cfec76b".
# Extracting c_route_b2553670 into c_route_b2553670.ext:
# Extracting compass_layer42__0_size2__2 into compass_layer42__0_size2__2.ext:
# Extracting rectangle_layer42__0_size2__2 into rectangle_layer42__0_size2__2.ext:
# Extracting via_stack_7490b2b5$1 into via_stack_7490b2b5$1.ext:
# Extracting straight_route_88abcf1b into straight_route_88abcf1b.ext:
# Extracting xm9 into xm9.ext:
# Extracting via_stack_7490b2b5 into via_stack_7490b2b5.ext:
# Extracting L_route_b9b0439d into L_route_b9b0439d.ext:
# Extracting L_route_049704b8 into L_route_049704b8.ext:
# Extracting xm10 into xm10.ext:
# Extracting c_route_481192b6 into c_route_481192b6.ext:
# Extracting via_stack_b843013f into via_stack_b843013f.ext:
# Extracting L_route_a891df28 into L_route_a891df28.ext:
# Extracting straight_route_ff57ad5f into straight_route_ff57ad5f.ext:
# Extracting L_route_1f6eb2fc into L_route_1f6eb2fc.ext:
# Extracting L_route_0982d815 into L_route_0982d815.ext:
# Extracting L_route_4362e3b7 into L_route_4362e3b7.ext:
# Extracting xm1 into xm1.ext:
# Extracting compass_layer42__0_size2__2$1 into compass_layer42__0_size2__2$1.ext:
# Extracting rectangle_layer42__0_size2__2$1 into rectangle_layer42__0_size2__2$1.ext:
# Extracting xm2 into xm2.ext:
# Extracting c_route_f370e2cd into c_route_f370e2cd.ext:
# Extracting L_route_171a04ac into L_route_171a04ac.ext:
# Extracting straight_route_9d656d86 into straight_route_9d656d86.ext:
# Extracting c_route_04ee7531 into c_route_04ee7531.ext:
# Extracting compass_50f39e54$1 into compass_50f39e54$1.ext:
# Extracting rectangle_50f39e54$1 into rectangle_50f39e54$1.ext:
# Extracting c_route_420c9b31 into c_route_420c9b31.ext:
# Extracting xm5 into xm5.ext:
# Extracting L_route_0b27eaa6 into L_route_0b27eaa6.ext:
# Extracting compass_layer42__0_size2__2$3 into compass_layer42__0_size2__2$3.ext:
# Extracting rectangle_layer42__0_size2__2$3 into rectangle_layer42__0_size2__2$3.ext:
# Extracting xm3 into xm3.ext:
# Extracting c_route_86cd68ff into c_route_86cd68ff.ext:
# Extracting straight_route_3d652be3 into straight_route_3d652be3.ext:
# Extracting xm11 into xm11.ext:
# Extracting straight_route_d8785de4 into straight_route_d8785de4.ext:
# Extracting c_route_679dd2e5 into c_route_679dd2e5.ext:
# Extracting L_route_c52907dc into L_route_c52907dc.ext:
# Extracting xm8 into xm8.ext:
# Extracting compass_layer42__0_size2__2$2 into compass_layer42__0_size2__2$2.ext:
# Extracting rectangle_layer42__0_size2__2$2 into rectangle_layer42__0_size2__2$2.ext:
# Extracting L_route_a6bb1778 into L_route_a6bb1778.ext:
# Extracting L_route_11addbd7 into L_route_11addbd7.ext:
# Extracting L_route_aac58595 into L_route_aac58595.ext:
# Extracting L_route_52557085 into L_route_52557085.ext:
# Extracting L_route_1a450bf3 into L_route_1a450bf3.ext:
# Extracting L_route_aef27d6b into L_route_aef27d6b.ext:
# Extracting compass_layer42__0_size2__2$5 into compass_layer42__0_size2__2$5.ext:
# Extracting rectangle_layer42__0_size2__2$5 into rectangle_layer42__0_size2__2$5.ext:
# Extracting L_route_744f09a4 into L_route_744f09a4.ext:
# Extracting L_route_ec792bf5 into L_route_ec792bf5.ext:
# Extracting xm6 into xm6.ext:
# Extracting straight_route_5cfec76b into straight_route_5cfec76b.ext:
# Extracting xm4 into xm4.ext:
# Extracting straight_route_3751675e into straight_route_3751675e.ext:
# Extracting xm7 into xm7.ext:
# Extracting c_route_c935389e into c_route_c935389e.ext:
# Extracting L_route_da279ef4 into L_route_da279ef4.ext:
# Extracting compass_layer42__0_size2__2$4 into compass_layer42__0_size2__2$4.ext:
# Extracting rectangle_layer42__0_size2__2$4 into rectangle_layer42__0_size2__2$4.ext:
# Extracting L_route_1f185563 into L_route_1f185563.ext:
# Extracting L_route_0a7485ec into L_route_0a7485ec.ext:
# Extracting L_route_31e7c68d into L_route_31e7c68d.ext:
# Extracting compass_50f39e54 into compass_50f39e54.ext:
# Extracting rectangle_50f39e54 into rectangle_50f39e54.ext:
# Extracting encoder into encoder.ext:
# exttospice finished.
#
# Running netgen command: bash /foss/tools/bin/netgen -batch lvs "/tmp/tmpa2ky9m38/encoder_lvsmag.spice encoder" "/tmp/tmpa2ky9m38/encoder.spice encoder" /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl /tmp/tmpa2ky9m38/encoder_lvs.rpt
# Netgen 1.5.318 compiled on Thu Apr 16 09:02:45 PM CEST 2026
# Warning: netgen command 'format' use fully-qualified name '::netgen::format'
# Warning: netgen command 'global' use fully-qualified name '::netgen::global'
# Reading netlist file /tmp/tmpa2ky9m38/encoder_lvsmag.spice for /tmp/tmpa2ky9m38/encoder_lvsmag.spice encoder
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Reading netlist file /tmp/tmpa2ky9m38/encoder.spice for /tmp/tmpa2ky9m38/encoder.spice encoder
# Call to undefined subcircuit pfet_03v3
# Creating placeholder cell definition.
# Call to undefined subcircuit nfet_03v3
# Creating placeholder cell definition.
# Duplicate cell encoder in file
# Renaming original cell to encoder[[0]]
#
# Reading setup file /foss/pdks/gf180mcuD/libs.tech/netgen/gf180mcuD_setup.tcl
#
# No property w found for device r
# No property l found for device r
# No property area found for device c
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property nf found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model nfet_03v3 pin 1 == 3
# No property par1 found for device nfet_03v3
# No property NRD found for device nfet_03v3
# No property NRS found for device nfet_03v3
# No property par found for device nfet_03v3
# No property sa found for device nfet_03v3
# No property sb found for device nfet_03v3
# No property sd found for device nfet_03v3
# No property par found for device nfet_03v3
# No property dtemp found for device nfet_03v3
# No property $D found for device nfet_03v3
# No property $X found for device nfet_03v3
# No property $Y found for device nfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property nf found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Model pfet_03v3 pin 1 == 3
# No property par1 found for device pfet_03v3
# No property NRD found for device pfet_03v3
# No property NRS found for device pfet_03v3
# No property par found for device pfet_03v3
# No property sa found for device pfet_03v3
# No property sb found for device pfet_03v3
# No property sd found for device pfet_03v3
# No property par found for device pfet_03v3
# No property dtemp found for device pfet_03v3
# No property $D found for device pfet_03v3
# No property $X found for device pfet_03v3
# No property $Y found for device pfet_03v3
# Comparison output logged to file /tmp/tmpa2ky9m38/encoder_lvs.rpt
# Logging to file "/tmp/tmpa2ky9m38/encoder_lvs.rpt" enabled
# Circuit pfet_03v3 contains no devices.
# Circuit nfet_03v3 contains no devices.
#
# Contents of circuit 1:  Circuit: 'xm5'
# Circuit xm5 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm5'
# Circuit xm5 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm5 xm5
#
# Flattening instances of xm5 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm5 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm3'
# Circuit xm3 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm3'
# Circuit xm3 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm3 xm3
#
# Flattening instances of xm3 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm3 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm11'
# Circuit xm11 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm11'
# Circuit xm11 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm11 xm11
#
# Flattening instances of xm11 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm11 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm1'
# Circuit xm1 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm1'
# Circuit xm1 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm1 xm1
#
# Flattening instances of xm1 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm1 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm8'
# Circuit xm8 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm8'
# Circuit xm8 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm8 xm8
#
# Flattening instances of xm8 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm8 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm6'
# Circuit xm6 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm6'
# Circuit xm6 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm6 xm6
#
# Flattening instances of xm6 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm6 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm4'
# Circuit xm4 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm4'
# Circuit xm4 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm4 xm4
#
# Flattening instances of xm4 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm4 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm2'
# Circuit xm2 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm2'
# Circuit xm2 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm2 xm2
#
# Flattening instances of xm2 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm2 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm10'
# Circuit xm10 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm10'
# Circuit xm10 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm10 xm10
#
# Flattening instances of xm10 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm10 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm9'
# Circuit xm9 contains 1 device instances.
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm9'
# Circuit xm9 contains 7 device instances.
#   Class: c                     instances:   6
#   Class: nfet_03v3             instances:   1
# Circuit contains 4 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 7 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 4 nets.
#
#   Flattening non-matched subcircuits xm9 xm9
#
# Flattening instances of xm9 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm9 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'xm7'
# Circuit xm7 contains 1 device instances.
#   Class: pfet_03v3             instances:   1
# Circuit contains 4 nets.
# Contents of circuit 2:  Circuit: 'xm7'
# Circuit xm7 contains 11 device instances.
#   Class: c                     instances:  10
#   Class: pfet_03v3             instances:   1
# Circuit contains 5 nets.
#
# Circuit 1 contains 1 devices, Circuit 2 contains 11 devices. *** MISMATCH ***
# Circuit 1 contains 4 nets,    Circuit 2 contains 5 nets. *** MISMATCH ***
#
#   Flattening non-matched subcircuits xm7 xm7
#
# Flattening instances of xm7 in file /tmp/tmpa2ky9m38/encoder_lvsmag.spice
# Flattening instances of xm7 in file /tmp/tmpa2ky9m38/encoder.spice
#
# Contents of circuit 1:  Circuit: 'encoder'
# Circuit encoder contains 11 device instances.
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   7
# Circuit contains 12 nets.
# Contents of circuit 2:  Circuit: 'encoder'
# Circuit encoder contains 11 device instances.
#   Class: nfet_03v3             instances:   4
#   Class: pfet_03v3             instances:   7
# Circuit contains 12 nets.
#
# Circuit 1 contains 11 devices, Circuit 2 contains 11 devices.
# Circuit 1 contains 12 nets,    Circuit 2 contains 12 nets.
#
#
# Final result:
# Circuits match uniquely.
# .
# Logging to file "/tmp/tmpa2ky9m38/encoder_lvs.rpt" disabled
# LVS Done.
#
#
# Circuit 1 cell pfet_03v3 and Circuit 2 cell pfet_03v3 are black boxes.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell pfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: pfet_03v3                       |Circuit 2: pfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes pfet_03v3 and pfet_03v3 are equivalent.
#
# Circuit 1 cell nfet_03v3 and Circuit 2 cell nfet_03v3 are black boxes.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
# Warning: Equate pins:  cell nfet_03v3 is a placeholder, treated as a black box.
#
# Subcircuit pins:
# Circuit 1: nfet_03v3                       |Circuit 2: nfet_03v3
# -------------------------------------------|-------------------------------------------
# 1                                          |1
# 2                                          |2
# 3                                          |3
# 4                                          |4
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes nfet_03v3 and nfet_03v3 are equivalent.
#
# Subcircuit summary:
# Circuit 1: xm5                             |Circuit 2: xm5
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm5                             |Circuit 2: xm5
#
# ---------------------------------------------------------------------------------------
# Net: a_186_n173#                           |Net: a_186_n173#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n306_n173#                          |Net: a_n306_n173#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n186_n382#                          |Net: a_n186_n382#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n572_n603#                          |Net: w_n572_n603#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm5                             |Circuit 2: xm5
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm5 xm5
#
# Subcircuit summary:
# Circuit 1: xm3                             |Circuit 2: xm3
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm3                             |Circuit 2: xm3
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n281#                            |Net: a_28_n281#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n178_n281#                          |Net: a_n178_n281#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n50_n489#                           |Net: a_n50_n489#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n444_n709#                          |Net: w_n444_n709#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm3                             |Circuit 2: xm3
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm3 xm3
#
# Subcircuit summary:
# Circuit 1: xm11                            |Circuit 2: xm11
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm11                            |Circuit 2: xm11
#
# ---------------------------------------------------------------------------------------
# Net: a_28_n131#                            |Net: a_28_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n444_n560#                          |Net: w_n444_n560#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm11                            |Circuit 2: xm11
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm11 xm11
#
# Subcircuit summary:
# Circuit 1: xm1                             |Circuit 2: xm1
# -------------------------------------------|-------------------------------------------
# nfet_03v3 (1)                              |nfet_03v3 (1)
# (no matching element)                      |c (6)
# Number of devices: 1 **Mismatch**          |Number of devices: 7 **Mismatch**
# Number of nets: 4                          |Number of nets: 4
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm1                             |Circuit 2: xm1
#
# ---------------------------------------------------------------------------------------
# Net: a_1000_n131#                          |Net: a_1000_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/top = 3
#                                            |
# Net: a_n1000_n339#                         |Net: a_n1000_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 2
#                                            |  c/bottom = 1
#                                            |
# Net: a_n1120_n131#                         |Net: a_n1120_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n1330_n504#                         |Net: a_n1330_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm1                             |Circuit 2: xm1
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm1 xm1
#
# Subcircuit summary:
# Circuit 1: xm8                             |Circuit 2: xm8
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm8                             |Circuit 2: xm8
#
# ---------------------------------------------------------------------------------------
# Net: a_186_n173#                           |Net: a_186_n173#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n306_n173#                          |Net: a_n306_n173#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n186_n382#                          |Net: a_n186_n382#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
# ...
#                                            |
# Net: a_n50_n339#                           |Net: a_n50_n339#
#   nfet_03v3/2 = 1                          |  nfet_03v3/2 = 1
#                                            |  c/top = 2
#                                            |  c/bottom = 1
#                                            |
# Net: a_n178_n131#                          |Net: a_n178_n131#
#   nfet_03v3/(1|3) = 1                      |  nfet_03v3/(1|3) = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 1
#                                            |
# Net: a_n388_n504#                          |Net: a_n388_n504#
#   nfet_03v3/4 = 1                          |  nfet_03v3/4 = 1
#                                            |  c/bottom = 3
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm9                             |Circuit 2: xm9
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 4
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 4
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm9 xm9
#
# Subcircuit summary:
# Circuit 1: xm7                             |Circuit 2: xm7
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (1)                              |pfet_03v3 (1)
# (no matching element)                      |c (10)
# Number of devices: 1 **Mismatch**          |Number of devices: 11 **Mismatch**
# Number of nets: 4 **Mismatch**             |Number of nets: 5 **Mismatch**
# ---------------------------------------------------------------------------------------
# NET mismatches: Class fragments follow (with fanout counts):
# Circuit 1: xm7                             |Circuit 2: xm7
#
# ---------------------------------------------------------------------------------------
# Net: a_186_n173#                           |Net: a_186_n173#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/bottom = 3
#                                            |  c/top = 1
#                                            |
# Net: a_n306_n173#                          |Net: a_n306_n173#
#   pfet_03v3/(1|3) = 1                      |  pfet_03v3/(1|3) = 1
#                                            |  c/top = 4
#                                            |
# Net: a_n186_n382#                          |Net: a_n186_n382#
#   pfet_03v3/2 = 1                          |  pfet_03v3/2 = 1
#                                            |  c/bottom = 2
#                                            |  c/top = 2
#                                            |
# Net: w_n572_n603#                          |Net: w_n572_n603#
#   pfet_03v3/4 = 1                          |  pfet_03v3/4 = 1
#                                            |  c/top = 3
#                                            |  c/bottom = 1
#                                            |
# (no matching net)                          |Net: VSUBS
#                                            |  c/bottom = 4
# ---------------------------------------------------------------------------------------
# DEVICE mismatches: Class fragments follow (with node fanout counts):
# Circuit 1: xm7                             |Circuit 2: xm7
#
# ---------------------------------------------------------------------------------------
# (no matching instance)                     |Instance: c:0
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:1
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:2
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:3
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:4
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:5
#                                            |  top = 5
#                                            |  bottom = 5
#                                            |
# (no matching instance)                     |Instance: c:6
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:7
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:8
#                                            |  top = 5
#                                            |  bottom = 4
#                                            |
# (no matching instance)                     |Instance: c:9
#                                            |  top = 5
#                                            |  bottom = 4
# ---------------------------------------------------------------------------------------
# Netlists do not match.
# Port matching may fail to disambiguate symmetries.
#   Flattening non-matched subcircuits xm7 xm7
#
# Subcircuit summary:
# Circuit 1: encoder                         |Circuit 2: encoder
# -------------------------------------------|-------------------------------------------
# pfet_03v3 (7)                              |pfet_03v3 (7)
# nfet_03v3 (4)                              |nfet_03v3 (4)
# Number of devices: 11                      |Number of devices: 11
# Number of nets: 12                         |Number of nets: 12
# ---------------------------------------------------------------------------------------
# Resolving symmetries by property value.
# Resolving symmetries by pin name.
# Netlists match uniquely.
#
# Subcircuit pins:
# Circuit 1: encoder                         |Circuit 2: encoder
# -------------------------------------------|-------------------------------------------
# vss                                        |Vss
# Vin                                        |Vin
# Vin_neg                                    |Vin_neg
# Iex_2_i                                    |Iex_2_i
# Iex_3_i                                    |Iex_3_i
# Iex_4_i                                    |Iex_4_i
# Iex_1_i                                    |Iex_1_i
# vdd                                        |Vdd
# ---------------------------------------------------------------------------------------
# Cell pin lists are equivalent.
# Device classes encoder and encoder are equivalent.
#
# Final result: Circuits match uniquely.
# .
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 8
#       5 path_to_dir = "/foss/designs/libs/snn_analog/encoder/"
#       7 # Ejecutar LVS con Netgen usando el PDK gf180
# ----> 8 gf180.lvs_netgen(
#       9     layout=encoder_comp,   # tu layout exportado
#      10     design_name=encoder_comp.name,   # nombre del diseño
#      11     pdk_root=Path(os.environ['PDKPATH']),   # raíz del PDK
#      12     lvs_setup_tcl_file=Path(os.environ['PDKPATH']) / "libs.tech" / "netgen" / f"{os.environ['PDK']}_setup.tcl",
#      13
#      14     # Netlist de referencia (esquemático ideal)
#      15     lvs_schematic_ref_file=Path(path_to_dir + "encoder.spice"),
#      16
#      17     # Netlist extraído del layout (PEX/LVS)
#      18     netlist=Path(path_to_dir + "encoder_lvs.spice"),
#      19
#      20     # Carpeta donde se guarda el reporte .lvs.rpt
#      21     output_file_path=Path(path_to_dir)
#      22 )
#      25 # gf180.lvs_netgen(
#      26 #     layout=encoder_comp,
#      27 #     design_name = encoder_comp.name,
#    (...)
#      31 #     output_file_path =  Path(str(path_to_dir))
#      32 # )
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:56, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      54 @wraps(_func)
#      55 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 56     return vd.call(*args, **kwargs)
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:151, in ValidatedFunction.call(self, *args, **kwargs)
#     149 def call(self, *args: Any, **kwargs: Any) -> Any:
#     150     m = self.init_model_instance(*args, **kwargs)
# --> 151     return self.execute(m)
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/site-packages/pydantic/deprecated/decorator.py:227, in ValidatedFunction.execute(self, m)
#     225     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     226 else:
# --> 227     return self.raw_function(**d, **var_kwargs)
#
# File /foss/designs/libs/gLayout/src/glayout/pdk/mappedpdk.py:938, in MappedPDK.lvs_netgen(self, layout, design_name, pdk_root, lvs_setup_tcl_file, lvs_schematic_ref_file, magic_drc_file, netlist, output_file_path, copy_intermediate_files, show_scripts)
#     933 # Overwrite the report file if it exists. When the run
#     934 # failed before the report was written, leave the
#     935 # original exception (raised in the try block) intact
#     936 # rather than masking it with a FileNotFoundError here.
#     937 if Path(report_path).is_file():
# --> 938     shutil.copy(report_path, new_output_file_path)
#     939 # if not new_output_file_path.exists():
#     940 #     shutil.copy(report_path, path_to_dir / output_file_path)
#     941 # else:
#     942 #     raise ValueError("Output file already exists!")
#     944 if copy_intermediate_files:
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/shutil.py:418, in copy(src, dst, follow_symlinks)
#     416     dst = os.path.join(dst, os.path.basename(src))
#     417 copyfile(src, dst, follow_symlinks=follow_symlinks)
# --> 418 copymode(src, dst, follow_symlinks=follow_symlinks)
#     419 return dst
#
# File ~/conda-env/miniconda3/envs/GLdev/lib/python3.10/shutil.py:307, in copymode(src, dst, follow_symlinks)
#     304     stat_func, chmod_func = _stat, os.chmod
#     306 st = stat_func(src)
# --> 307 chmod_func(dst, stat.S_IMODE(st.st_mode))
#
# PermissionError: [Errno 1] Operation not permitted: '/foss/designs/libs/snn_analog/encoder/lvs/encoder/encoder_lvs.rpt'
